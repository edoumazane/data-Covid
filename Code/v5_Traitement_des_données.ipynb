# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 21/06/2021. Retrieve data from how many days? 0
# Ok, will retrieve data from 21/06/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-06-21-19h09.csv
# ./Temp/v5/sp-pos-quot-dep-2021-06-21-19h09-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour   P    T  cl_age90       pop
# 369359  83 2020-12-11  23  423        19  115973.0
# 127178  2A 2021-03-14   0   17        79   17664.0
# 172606  39 2020-05-26   0   21        59   36427.0
# (459888, 6)
#        entity three_class       jour   P     T       pop
# 15993      10       30-59 2021-05-28  11   557  114529.0
# 140747     87       whole 2020-12-11  59  1136  370774.0
# 145392     90        0-29 2020-10-28  31   205   48923.0
# (186528, 6)
#        entity three_class       jour   P     T        pop  P hebdo  T hebdo  \
# 152694     94         60+ 2021-06-02  17  1260   288118.0    134.0   7594.0
# 125487     78       whole 2020-05-28  18   774  1448625.0    136.0   5391.0
# 128838     80         60+ 2020-07-01   0   191   151853.0      3.0    975.0
#
#         incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 152694        46.508722                1.764551          2635.725640
# 125487         9.388213                2.522723           372.146001
# 128838         1.975595                0.307692           642.068316
# (186528, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-06-21-19h05.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-06-21-19h05-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (91278, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 14634 2020-05-30     9    0       NaN       NaN     NaN  384   1
# 54176 2020-12-16     0    0       NaN       NaN     NaN   39   0
# 8878  2020-05-01     5    3       NaN       NaN     NaN   35   0
#
#                            entity three_class
# 14634  Provence-Alpes-Côte d'Azur       30-59
# 54176            Pays de la Loire        0-29
# 8878         Auvergne-Rhône-Alpes        0-29
# 'd_hosp_2: '
# (27660, 6)
#                    entity three_class       jour  hosp  rea   dc
# 16409  Nouvelle-Aquitaine       30-59 2021-05-06   211   70  118
# 27616              France        0-29 2021-06-11   271   38   92
# 8654                Corse         60+ 2021-01-31    53    7  117
# 'd_hosp_3: '
# (27660, 10)
#                        entity three_class       jour  hosp  rea  dc  dc hebdo  \
# 3464  Bourgogne-Franche-Comté        0-29 2021-04-27    18    5   4       1.0
# 2316  Bourgogne-Franche-Comté        0-29 2020-07-14     1    0   0       0.0
# 628      Auvergne-Rhône-Alpes        0-29 2020-08-22     6    1   1       0.0
#
#       taux hosp  taux rea  taux décès
# 3464   1.993318  0.553699     0.11074
# 2316   0.110740  0.000000     0.00000
# 628    0.211627  0.035271     0.00000

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1, True)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute-DROM.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-06-21-19h05.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-06-21-19h05-3C-compute-DROM.csv

# %%
dout.entity.unique()
# Out:
# array(['Auvergne-Rhône-Alpes', 'Bourgogne-Franche-Comté', 'Bretagne',
#        'Centre-Val de Loire', 'Corse', 'Grand Est', 'Guadeloupe',
#        'Guyane', 'Hauts-de-France', 'La Réunion', 'Martinique', 'Mayotte',
#        'Normandie', 'Nouvelle-Aquitaine', 'Occitanie', 'Pays de la Loire',
#        "Provence-Alpes-Côte d'Azur", 'Île-de-France', 'France'],
#       dtype=object)

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-06-21-19h05.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-06-21-19h05-compute.csv

# %%
dout.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad   dc  \
# 26089     56 2020-12-16   160   12       NaN       NaN     NaN  877  192
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 26089       7.0  21.176178  1.588213    0.926458

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 139678  974     1 2021-06-21    78   22      40.0      16.0     0.0  1001  131
# 139679  974     2 2021-06-21    68   12      39.0      17.0     0.0   935  102
# 139680  976     0 2021-06-21     4    1       3.0       0.0     0.0  1271  131
# 139681  976     1 2021-06-21     1    1       0.0       0.0     0.0   577   77
# 139682  976     2 2021-06-21     3    0       3.0       0.0     0.0   673   53
#
# [139683 rows x 10 columns]
# (139683, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 46556    976 2021-06-17     5    2       3.0       0.0     0.0  1271  130
# 46557    976 2021-06-18     4    1       3.0       0.0     0.0  1271  131
# 46558    976 2021-06-19     4    1       3.0       0.0     0.0  1271  131
# 46559    976 2021-06-20     4    1       3.0       0.0     0.0  1271  131
# 46560    976 2021-06-21     4    1       3.0       0.0     0.0  1271  131
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 46556       0.0   1.789094  0.715638    0.000000
# 46557       1.0   1.431276  0.357819    0.357819
# 46558       1.0   1.431276  0.357819    0.357819
# 46559       1.0   1.431276  0.357819    0.357819
# 46560       1.0   1.431276  0.357819    0.357819
#
# [46561 rows x 13 columns]
# (46561, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[(d_vac_1.dep != '20') & (d_vac_1.dep != '98')]
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-06-21-19h05.csv
# ./Temp/v5/vacsi-a-dep-2021-06-21-19h05-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (203280, 9)
#       dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 19935  11           49 2021-02-12       32         34          915
# 27592  15           69 2021-05-12       97        123         7217
# 90858  50           69 2021-02-07        0          0          637
#
#        n_cum_complet  couv_dose1  couv_complet
# 19935            400         2.0           0.9
# 27592           2304        63.1          20.1
# 90858            139         1.9           0.4

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (81664, 9)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 42237     59       30-59 2021-06-20     1647       6903       580924
# 82        01         60+ 2021-01-16      143          0         1211
# 62562     88         60+ 2021-05-28      327       1196        92269
#
#        n_cum_complet  couv_dose1  couv_complet
# 42237         256849       178.0          78.9
# 82                 1         3.9           0.0
# 62562          56490       399.9         252.7

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (81664, 11)
#                    entity three_class       jour  n_dose1  n_complet  \
# 68607                 972       whole 2021-03-16      305         55
# 15029                  23       30-59 2021-02-26       89         26
# 78058  Nouvelle-Aquitaine         60+ 2021-05-30      347       1300
#
#        n_cum_dose1  n_cum_complet  couv_dose1  couv_complet  taux dose 1  \
# 68607         8106           3691         2.3           1.0     2.259518
# 15029         1768           1171        12.0           7.9     4.300343
# 78058      1504638         915898      4837.9        3011.7    80.454998
#
#        taux complet
# 68607      1.028853
# 15029      2.848248
# 78058     48.974286

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 9.737970113754272  s
