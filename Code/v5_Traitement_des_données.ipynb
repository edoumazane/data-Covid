# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 25/06/2021. Retrieve data from how many days? 0
# Ok, will retrieve data from 25/06/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-06-25-19h10.csv
# ./Temp/v5/sp-pos-quot-dep-2021-06-25-19h10-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#       dep       jour   P    T  cl_age90      pop
# 19082  05 2020-08-31   1   35        89   8430.0
# 87844  21 2021-02-08  12  122        90   8177.0
# 91334  22 2020-11-12  30  387        19  71112.0
# (464464, 6)
#           entity three_class       jour  P    T       pop
# 5744          04        0-29 2020-12-17  7  210   47550.0
# 23218         15         60+ 2020-09-10  7   89   52889.0
# 167294  Bretagne         60+ 2020-05-18  2  482  985248.0
# (188384, 6)
#       entity three_class       jour   P    T       pop  P hebdo  T hebdo  \
# 26748     17        0-29 2020-11-20  14  519  183823.0     81.0   2523.0
# 66905     41       30-59 2020-08-01   0   34  120994.0     12.0    662.0
# 76471     47       whole 2020-06-17   0   99  330336.0      2.0    912.0
#
#        incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 26748        44.064127                3.210464          1372.515953
# 66905         9.917847                1.812689           547.134569
# 76471         0.605444                0.219298           276.082534
# (188384, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-06-25-19h10.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-06-25-19h10-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (92070, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 62977 2021-01-30     0    0       NaN       NaN     NaN     3    0
# 5723  2020-04-15    40    6       NaN       NaN     NaN   164    1
# 66217 2021-02-15   412   70       NaN       NaN     NaN  2951  735
#
#                            entity three_class
# 62977            Outre-mer (DROM)        0-29
# 5723   Provence-Alpes-Côte d'Azur        0-29
# 66217     Bourgogne-Franche-Comté         60+
# 'd_hosp_2: '
# (27900, 6)
#                         entity three_class       jour  hosp  rea    dc
# 2219   Bourgogne-Franche-Comté       whole 2020-06-15   223   19  1032
# 24473            Île-de-France       30-59 2020-05-30  1162  196   679
# 9460                 Grand Est        0-29 2020-04-27    71   13     2
# 'd_hosp_3: '
# (27900, 10)
#                    entity three_class       jour  hosp  rea  dc  dc hebdo  \
# 14248           Normandie        0-29 2021-01-19    14    2   0       0.0
# 15640  Nouvelle-Aquitaine        0-29 2020-09-24    13    3   2       0.0
# 10232           Grand Est        0-29 2020-11-06    22    0   3       0.0
#
#        taux hosp  taux rea  taux décès
# 14248   1.246366  0.178052         0.0
# 15640   0.688208  0.158817         0.0
# 10232   1.173602  0.000000         0.0

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1, True)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute-DROM.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-06-25-19h10.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-06-25-19h10-3C-compute-DROM.csv

# %%
dout.entity.unique()
# Out:
# array(['Auvergne-Rhône-Alpes', 'Bourgogne-Franche-Comté', 'Bretagne',
#        'Centre-Val de Loire', 'Corse', 'Grand Est', 'Guadeloupe',
#        'Guyane', 'Hauts-de-France', 'La Réunion', 'Martinique', 'Mayotte',
#        'Normandie', 'Nouvelle-Aquitaine', 'Occitanie', 'Pays de la Loire',
#        "Provence-Alpes-Côte d'Azur", 'Île-de-France', 'France'],
#       dtype=object)

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-06-25-19h10.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-06-25-19h10-compute.csv

# %%
dout.sample()
# Out:
#      entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad    dc  \
# 2672     06 2021-02-28   708  120       NaN       NaN     NaN  4218  1057
#
#       dc hebdo  taux hosp   taux rea  taux décès
# 2672      63.0  65.592239  11.117329    5.836598

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 140890  974     1 2021-06-25    73   18      38.0      17.0     0.0  1020  134
# 140891  974     2 2021-06-25    70   16      37.0      17.0     0.0   952  104
# 140892  976     0 2021-06-25     2    0       2.0       0.0     0.0  1272  131
# 140893  976     1 2021-06-25     1    0       1.0       0.0     0.0   578   77
# 140894  976     2 2021-06-25     1    0       1.0       0.0     0.0   673   53
#
# [140895 rows x 10 columns]
# (140895, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 46960    976 2021-06-21     4    1       3.0       0.0     0.0  1271  131
# 46961    976 2021-06-22     3    1       2.0       0.0     0.0  1272  131
# 46962    976 2021-06-23     3    1       2.0       0.0     0.0  1272  131
# 46963    976 2021-06-24     1    0       1.0       0.0     0.0  1274  131
# 46964    976 2021-06-25     2    0       2.0       0.0     0.0  1272  131
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 46960       1.0   1.431276  0.357819    0.357819
# 46961       1.0   1.073457  0.357819    0.357819
# 46962       1.0   1.073457  0.357819    0.357819
# 46963       1.0   0.357819  0.000000    0.357819
# 46964       0.0   0.715638  0.000000    0.000000
#
# [46965 rows x 13 columns]
# (46965, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[(d_vac_1.dep != '20') & (d_vac_1.dep != '98')]
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-06-25-19h05.csv
# ./Temp/v5/vacsi-a-dep-2021-06-25-19h05-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (207900, 9)
#        dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 42483   24           69 2020-12-30        1          0            1
# 128552  70           59 2021-01-28       30          2          896
# 56529   30           59 2021-01-05        0          0            0
#
#         n_cum_complet  couv_dose1  couv_complet
# 42483               0         0.0           0.0
# 128552             11         2.7           0.0
# 56529               0         0.0           0.0

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (83520, 9)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 33444     46        0-29 2021-03-18        2          0          247
# 48069     66       30-59 2021-05-13     1514        293        44234
# 53687     74       whole 2021-04-07     3145       1186       106147
#
#        n_cum_complet  couv_dose1  couv_complet
# 33444             75         3.3           1.0
# 48069          13673        73.7          22.9
# 53687          32279        12.8           3.9

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (83520, 11)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 1511      03       whole 2021-01-13      669          1         2055
# 50367     69       whole 2021-06-16     9913      12229       854089
# 18137     27       30-59 2021-01-30       16         17         2748
#
#        n_cum_complet  couv_dose1  couv_complet  taux dose 1  taux complet
# 1511               3         0.6           0.0     0.620256      0.000905
# 50367         446897        45.5          23.8    45.525895     23.821154
# 18137            258         3.5           0.4     1.173948      0.110218

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 10.013222455978394  s
