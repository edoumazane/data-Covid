# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 11/05/2021. Retrieve data from how many days? 0
# Ok, will retrieve data from 11/05/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-05-11-19h09.csv
# ./Temp/v5/sp-pos-quot-dep-2021-05-11-19h09-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour  P    T  cl_age90       pop
# 302500  76 2020-07-16  0  155         9  145855.0
# 294080  74 2020-06-02  0   33        69   85386.0
# 317579  79 2021-04-29  2   57        90    6753.0
# (412984, 6)
#        entity three_class       jour  P    T        pop
# 119971     83       whole 2020-06-11  1  531  1073836.0
# 116934     80         60+ 2021-05-01  6  173   151853.0
# 42872      2B        0-29 2021-01-17  0   43    56033.0
# (167504, 6)
#         entity three_class       jour     P       T         pop  P hebdo  \
# 154496  France        0-29 2021-05-06  8163  218134  23555651.0  51910.0
# 121137      83       30-59 2021-03-30   388    4478    397118.0   2295.0
# 30388       23        0-29 2020-05-29     0      48     29443.0      2.0
#
#          T hebdo  incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 154496  980249.0       220.371749                5.295593          4161.417572
# 121137   24354.0       577.913869                9.423503          6132.686003
# 30388      213.0         6.792786                0.938967           723.431716
# (167504, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-05-11-19h05.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-05-11-19h05-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (83160, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres   rad    dc  \
# 53305 2020-12-12     0    0       NaN       NaN     NaN     7     0
# 16973 2020-06-11   176   18       NaN       NaN     NaN  2075   407
# 82928 2021-05-10   174    2      91.0      81.0     0.0  1992  1151
#
#                    entity three_class
# 53305    Outre-mer (DROM)         60+
# 16973  Nouvelle-Aquitaine       whole
# 82928           Occitanie         60+
# 'd_hosp_2: '
# (25200, 6)
#                        entity three_class       jour  hosp  rea    dc
# 2199  Bourgogne-Franche-Comté       whole 2020-07-25    34    6  1061
# 9530                Grand Est         60+ 2020-12-25  2597  212  5474
# 9262                Grand Est         60+ 2020-10-19   357   56  3596
# 'd_hosp_3: '
# (25200, 10)
#                         entity three_class       jour  hosp  rea   dc  \
# 12610                Normandie         60+ 2020-10-16   385   47  486
# 3109   Bourgogne-Franche-Comté       30-59 2021-03-10   120   28  123
# 19969         Pays de la Loire       30-59 2021-03-25   117   31   65
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 12610      22.0  40.434551  4.936166    2.310546
# 3109        2.0  11.638339  2.715612    0.193972
# 19969       4.0   8.201335  2.173003    0.280388

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-05-11-19h05.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-05-11-19h05-compute.csv

# %%
dout.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 21408     50 2021-04-30   148   26      69.0      53.0     0.0  1304  334
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 21408       7.0    30.1629  5.298888    1.426624

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 127255  974     1 2021-05-11    98   27      53.0      18.0     0.0   795  105
# 127256  974     2 2021-05-11    75   13      50.0      12.0     0.0   753   74
# 127257  976     0 2021-05-11    11    6       5.0       0.0     0.0  1255  127
# 127258  976     1 2021-05-11     3    2       1.0       0.0     0.0   571   74
# 127259  976     2 2021-05-11     7    4       3.0       0.0     0.0   664   52
#
# [127260 rows x 10 columns]
# (127260, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 42415    976 2021-05-07    10    4       6.0       0.0     0.0  1252  127
# 42416    976 2021-05-08    14    7       7.0       0.0     0.0  1252  127
# 42417    976 2021-05-09    14    7       7.0       0.0     0.0  1252  127
# 42418    976 2021-05-10    14    7       7.0       0.0     0.0  1252  127
# 42419    976 2021-05-11    11    6       5.0       0.0     0.0  1255  127
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 42415       1.0   3.578189  1.431276    0.357819
# 42416       1.0   5.009464  2.504732    0.357819
# 42417       1.0   5.009464  2.504732    0.357819
# 42418       1.0   5.009464  2.504732    0.357819
# 42419       1.0   3.936008  2.146913    0.357819
#
# [42420 rows x 13 columns]
# (42420, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[d_vac_1.dep != '20']
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-05-11-19h06.csv
# ./Temp/v5/vacsi-a-dep-2021-05-11-19h06-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (157410, 9)
#         dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 6287     04           69 2021-03-14       52          0         1286
# 2714     02           24 2021-01-10        0          0            2
# 141003  977           59 2021-02-28        0          0           35
#
#         n_cum_complet  couv_dose1  couv_complet
# 6287              407        10.7           3.4
# 2714                0         0.0           0.0
# 141003              4         2.3           0.3

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (62640, 9)
#                            entity three_class       jour  n_dose1  n_complet  \
# 61865  Provence-Alpes-Côte d'Azur       30-59 2021-03-13     3760        101
# 22066                          40         60+ 2021-04-22     1507       1516
# 11289                          22       30-59 2021-04-28      774        719
#
#        n_cum_dose1  n_cum_complet  couv_dose1  couv_complet
# 61865        93567          41391        82.2          36.3
# 22066        82192          31958       310.6         126.5
# 11289        36075          13684        48.4          18.3

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (62640, 11)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 41557     76       30-59 2021-05-05     1980       1519        87437
# 49698     92         60+ 2020-12-31        0          0           66
# 17020     31        0-29 2021-03-07       41          1         2739
#
#        n_cum_complet  couv_dose1  couv_complet  taux dose 1  taux complet
# 41557          33092        56.1          21.2    18.884188      7.147038
# 49698              0         0.1           0.0     0.019795      0.000000
# 17020            920         2.4           0.9     0.507769      0.170554

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 7.057848930358887  s
