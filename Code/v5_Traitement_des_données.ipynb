# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 06/05/2021. Retrieve data from how many days? 0
# Ok, will retrieve data from 06/05/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-05-06-19h05.csv
# ./Temp/v5/sp-pos-quot-dep-2021-05-06-19h05-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour    P     T  cl_age90       pop
# 361967  92 2020-10-14  140  1318        19  192311.0
# 54333   14 2021-03-20   26   376        49   84964.0
# 53939   14 2021-02-12    8   336        69   91001.0
# (407264, 6)
#                     entity three_class       jour   P    T        pop
# 156834  Nouvelle-Aquitaine         60+ 2020-06-30   2  945  1870161.0
# 20646                   15         60+ 2020-11-06  13  180    52889.0
# 12606                   09         60+ 2021-03-12   6  202    52468.0
# (165184, 6)
#       entity three_class       jour    P     T       pop  P hebdo  T hebdo  \
# 60965     42       30-59 2021-02-26  104  1845  278180.0    613.0   9521.0
# 6907      05       whole 2021-03-11   59   860  141756.0    389.0   4624.0
# 94430     66         60+ 2020-09-01    9   491  161364.0     15.0   1672.0
#
#        incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 60965       220.360917                6.438399          3422.604069
# 6907        274.415192                8.412630          3261.943057
# 94430         9.295754                0.897129          1036.166679
# (165184, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-05-06-19h05.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-05-06-19h05-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (82170, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 20839 2020-07-01     0    0       NaN       NaN     NaN   51   4
# 65209 2021-02-10     1    0       NaN       NaN     NaN   51   0
# 49790 2020-11-24     9    0       NaN       NaN     NaN  204   3
#
#                     entity three_class
# 20839     Outre-mer (DROM)       30-59
# 65209  Centre-Val de Loire        0-29
# 49790            Normandie       30-59
# 'd_hosp_2: '
# (24900, 6)
#                         entity three_class       jour  hosp  rea    dc
# 2283   Bourgogne-Franche-Comté       whole 2020-08-20    23    4  1064
# 13335       Nouvelle-Aquitaine       whole 2020-03-31   672  202    78
# 1480      Auvergne-Rhône-Alpes        0-29 2021-03-23    42    3     9
# 'd_hosp_3: '
# (24900, 10)
#                         entity three_class       jour  hosp  rea  dc  \
# 19885         Pays de la Loire       30-59 2021-04-28   168   52  80
# 2485   Bourgogne-Franche-Comté       30-59 2020-10-10    20    3  39
# 16784         Outre-mer (DROM)        0-29 2020-05-03     7    0   0
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 19885       1.0  11.776276  3.645038    0.070097
# 2485        1.0   1.939723  0.290958    0.096986
# 16784       0.0   0.731550  0.000000    0.000000

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-05-06-19h05.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-05-06-19h05-compute.csv

# %%
dout.sample()
# Out:
#      entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 8486     22 2020-09-20     9    0       NaN       NaN     NaN  244  41
#
#       dc hebdo  taux hosp  taux rea  taux décès
# 8486       1.0   1.509596       0.0    0.167733

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 125740  974     1 2021-05-06    93   22      54.0      17.0     0.0   769   99
# 125741  974     2 2021-05-06    72   13      48.0      11.0     0.0   728   70
# 125742  976     0 2021-05-06    11    4       7.0       0.0     0.0  1251  126
# 125743  976     1 2021-05-06     7    2       5.0       0.0     0.0   567   74
# 125744  976     2 2021-05-06     4    2       2.0       0.0     0.0   664   51
#
# [125745 rows x 10 columns]
# (125745, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 41910    976 2021-05-02    12    4       8.0       0.0     0.0  1241  126
# 41911    976 2021-05-03    13    4       9.0       0.0     0.0  1243  126
# 41912    976 2021-05-04    11    4       7.0       0.0     0.0  1246  126
# 41913    976 2021-05-05    11    4       7.0       0.0     0.0  1248  126
# 41914    976 2021-05-06    11    4       7.0       0.0     0.0  1251  126
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 41910       2.0   4.293827  1.431276    0.715638
# 41911       1.0   4.651645  1.431276    0.357819
# 41912       1.0   3.936008  1.431276    0.357819
# 41913       1.0   3.936008  1.431276    0.357819
# 41914       1.0   3.936008  1.431276    0.357819
#
# [41915 rows x 13 columns]
# (41915, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[d_vac_1.dep != '20']
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-05-06-19h05.csv
# ./Temp/v5/vacsi-a-dep-2021-05-06-19h05-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (151580, 9)
#         dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 132831  973           29 2021-04-07       15         10          330
# 108109   80           29 2021-03-16        6          0          829
# 134493  974           59 2021-03-10       78         79         3422
#
#         n_cum_complet  couv_dose1  couv_complet
# 132831            144         1.7           0.7
# 108109            196         2.7           0.6
# 134493           1742         2.7           1.4

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (60320, 9)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 48957     94       30-59 2021-01-15      619          2         4843
# 21289     40       30-59 2021-04-28      596        289        22990
# 17336     33        0-29 2021-02-09       18         43          734
#
#        n_cum_complet  couv_dose1  couv_complet
# 48957              5         2.7           0.0
# 21289           7409        41.6          13.7
# 17336            159         0.7           0.1

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (60320, 11)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 45690     87         60+ 2021-04-18       87        135        61339
# 45448     87        0-29 2021-02-17       28          4          260
# 27404     52        0-29 2021-03-28        0          0          251
#
#        n_cum_complet  couv_dose1  couv_complet  taux dose 1  taux complet
# 45690          24526       263.2         107.2    51.267928     20.499147
# 45448             62         1.4           0.4     0.221637      0.052852
# 27404            100         2.7           1.1     0.492640      0.196271

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 8.726871728897095  s
