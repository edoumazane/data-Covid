# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 20/05/2021. Retrieve data from how many days?
# Ok, will retrieve data from 19/05/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-05-19-19h09.csv
# ./Temp/v5/sp-pos-quot-dep-2021-05-19-19h09-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour  P    T  cl_age90       pop
# 266390  65 2020-12-31  5  172        39   22948.0
# 41310   11 2020-07-17  0   48        59   51248.0
# 142718  35 2020-07-11  3   62        49  143253.0
# (422136, 6)
#       entity three_class       jour   P    T       pop
# 28215     21       whole 2020-06-24   3  393  532886.0
# 83862     56         60+ 2021-03-10  29  724  245813.0
# 54498     36         60+ 2021-04-18   1   30   79390.0
# (171216, 6)
#        entity three_class       jour   P    T       pop  P hebdo  T hebdo  \
# 22383      16       whole 2020-07-12   0    8  348180.0      1.0    449.0
# 37872      27        0-29 2021-01-11  41  626  207302.0    207.0   3324.0
# 137209     92       30-59 2021-05-02  72  946  670166.0   2296.0  26562.0
#
#         incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 22383          0.287208                0.222717           128.956287
# 37872         99.854319                6.227437          1603.457757
# 137209       342.601684                8.643927          3963.495612
# (171216, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-05-19-19h09.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-05-19-19h09-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (84744, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres   rad  dc  \
# 47381 2020-11-12   176   30       NaN       NaN     NaN  2970  63
# 30244 2020-08-17     4    1       NaN       NaN     NaN   177   3
# 6289  2020-04-18   178   59       NaN       NaN     NaN   169  53
#
#                    entity three_class
# 47381       Île-de-France       30-59
# 30244  Nouvelle-Aquitaine       30-59
# 6289   Nouvelle-Aquitaine         60+
# 'd_hosp_2: '
# (25680, 6)
#                         entity three_class       jour  hosp  rea    dc
# 3307   Bourgogne-Franche-Comté       whole 2021-04-20  1391  209  4415
# 18778         Outre-mer (DROM)         60+ 2021-05-06   328   57   590
# 18296         Outre-mer (DROM)        0-29 2021-01-06    18    2     5
# 'd_hosp_3: '
# (25680, 10)
#                         entity three_class       jour  hosp  rea    dc  \
# 2916   Bourgogne-Franche-Comté        0-29 2021-01-13    32    6     2
# 8304                     Corse        0-29 2021-03-17     0    0     0
# 16658                Occitanie         60+ 2021-01-24  1430  174  2391
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 2916        0.0   3.543676  0.664439    0.000000
# 8304        0.0   0.000000  0.000000    0.000000
# 16658     104.0  81.828097  9.956705    5.951134

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-05-19-19h09.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-05-19-19h09-compute.csv

# %%
dout.sample()
# Out:
#      entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 9109     23 2020-07-17     2    2       NaN       NaN     NaN   78  14
#
#       dc hebdo  taux hosp  taux rea  taux décès
# 9109       1.0   1.720134  1.720134    0.860067

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 129679  974     1 2021-05-19    92   20      52.0      20.0     0.0   837  109
# 129680  974     2 2021-05-19    73   14      44.0      15.0     0.0   801   78
# 129681  976     0 2021-05-19    11    6       5.0       0.0     0.0  1258  128
# 129682  976     1 2021-05-19     3    2       1.0       0.0     0.0   572   75
# 129683  976     2 2021-05-19     8    4       4.0       0.0     0.0   665   52
#
# [129684 rows x 10 columns]
# (129684, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 43223    976 2021-05-15    10    6       4.0       0.0     0.0  1256  128
# 43224    976 2021-05-16    10    6       4.0       0.0     0.0  1256  128
# 43225    976 2021-05-17    11    6       5.0       0.0     0.0  1256  128
# 43226    976 2021-05-18    11    6       5.0       0.0     0.0  1256  128
# 43227    976 2021-05-19    11    6       5.0       0.0     0.0  1258  128
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 43223       1.0   3.578189  2.146913    0.357819
# 43224       1.0   3.578189  2.146913    0.357819
# 43225       1.0   3.936008  2.146913    0.357819
# 43226       1.0   3.936008  2.146913    0.357819
# 43227       0.0   3.936008  2.146913    0.000000
#
# [43228 rows x 13 columns]
# (43228, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[d_vac_1.dep != '20']
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-05-19-19h05.csv
# ./Temp/v5/vacsi-a-dep-2021-05-19-19h05-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (168311, 9)
#       dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 87990  60           64 2021-02-10       16         79          873
# 81106  55           74 2021-01-21       23          0          221
# 4280   02           80 2021-05-09       72         16        21819
#
#        n_cum_complet  couv_dose1  couv_complet
# 87990            345         1.8           0.7
# 81106              0         2.0           0.0
# 4280           17045        67.0          52.4

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (66352, 9)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 45675     79       whole 2021-04-27     1868       2328        92438
# 42492     74        0-29 2021-02-06        1          0          158
# 3661      07       30-59 2021-02-22       97         40         3454
#
#        n_cum_complet  couv_dose1  couv_complet
# 45675          34486        24.8           9.3
# 42492              3         0.3           0.0
# 3661            1650         8.0           3.8

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (66352, 11)
#           entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 32255         56       whole 2021-02-20      365        262        36236
# 63643  Occitanie       whole 2021-02-02    10006       3993       176021
# 42354         74         60+ 2021-01-02        0          0            0
#
#        n_cum_complet  couv_dose1  couv_complet  taux dose 1  taux complet
# 32255          10145         4.8           1.3     4.795875      1.342702
# 63643          12376        44.9           3.0     2.970890      0.208883
# 42354              0         0.0           0.0     0.000000      0.000000

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 7.345553398132324  s
