# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 09/05/2021. Retrieve data from how many days? 0
# Ok, will retrieve data from 09/05/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-05-09-19h08.csv
# ./Temp/v5/sp-pos-quot-dep-2021-05-09-19h08-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour   P    T  cl_age90       pop
# 204025  51 2021-01-06  20  190        89   26142.0
# 81820   22 2021-01-26   7  244        29   47869.0
# 364750  92 2020-09-21  86  938        19  192311.0
# (410696, 6)
#                entity three_class       jour    P      T         pop
# 131522             91         60+ 2020-12-10   27   1068    270795.0
# 165447  Île-de-France       whole 2020-07-28  503  24642  12278210.0
# 30300              23        0-29 2020-06-18    0     21     29443.0
# (166576, 6)
#                   entity three_class       jour    P     T        pop  \
# 163646  Pays de la Loire         60+ 2021-04-22  280  4091  1044051.0
# 49645                 34       30-59 2020-12-04   45  1920   435285.0
# 105600                73        0-29 2020-11-22    7    48   142034.0
#
#         P hebdo  T hebdo  incidence hebdo  taux de positifs hebdo  \
# 163646   1839.0  28129.0       176.140821                6.537737
# 49645     292.0   9759.0        67.082486                2.992110
# 105600    412.0   3143.0       290.071391               13.108495
#
#         taux de tests hebdo
# 163646          2694.217045
# 49645           2241.979393
# 105600          2212.850444
# (166576, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-05-09-19h08.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-05-09-19h08-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (82764, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres    rad    dc  \
# 71644 2021-03-14     1    0       1.0       0.0     0.0    235     0
# 63833 2021-02-03  1765  159       NaN       NaN     NaN  12409  3407
# 35731 2020-09-14     1    1       NaN       NaN     NaN     56     0
#
#                         entity three_class
# 71644     Auvergne-Rhône-Alpes        0-29
# 63833  Bourgogne-Franche-Comté       whole
# 35731                Normandie        0-29
# 'd_hosp_2: '
# (25080, 6)
#                     entity three_class       jour   hosp   rea     dc
# 24799               France       whole 2021-02-28  25280  3492  61572
# 6551   Centre-Val de Loire       whole 2021-04-05   1098   180   2269
# 10268      Hauts-de-France        0-29 2020-05-16     13     2      1
# 'd_hosp_3: '
# (25080, 10)
#                      entity three_class       jour  hosp  rea   dc  dc hebdo  \
# 16664             Occitanie        0-29 2021-04-26    20    2    3       0.0
# 1221   Auvergne-Rhône-Alpes       30-59 2021-01-17   425   70  205       8.0
# 11637       Hauts-de-France       30-59 2021-04-23   683  208  319      10.0
#
#        taux hosp  taux rea  taux décès
# 16664   1.022372  0.102237    0.000000
# 1221   13.773672  2.268605    0.259269
# 11637  30.020038  9.142266    0.439532

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-05-09-19h08.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-05-09-19h08-compute.csv

# %%
dout.sample()
# Out:
#      entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 6315     16 2020-05-02     5    2       NaN       NaN     NaN   41  11
#
#       dc hebdo  taux hosp  taux rea  taux décès
# 6315       1.0   1.436039  0.574416    0.287208

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 126649  974     1 2021-05-09    83   22      44.0      17.0     0.0   786  103
# 126650  974     2 2021-05-09    71   14      46.0      11.0     0.0   740   72
# 126651  976     0 2021-05-09    14    7       7.0       0.0     0.0  1252  127
# 126652  976     1 2021-05-09     7    3       4.0       0.0     0.0   568   74
# 126653  976     2 2021-05-09     6    4       2.0       0.0     0.0   664   52
#
# [126654 rows x 10 columns]
# (126654, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 42213    976 2021-05-05    11    4       7.0       0.0     0.0  1248  126
# 42214    976 2021-05-06    11    4       7.0       0.0     0.0  1251  126
# 42215    976 2021-05-07    10    4       6.0       0.0     0.0  1252  127
# 42216    976 2021-05-08    14    7       7.0       0.0     0.0  1252  127
# 42217    976 2021-05-09    14    7       7.0       0.0     0.0  1252  127
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 42213       1.0   3.936008  1.431276    0.357819
# 42214       1.0   3.936008  1.431276    0.357819
# 42215       1.0   3.578189  1.431276    0.357819
# 42216       1.0   5.009464  2.504732    0.357819
# 42217       1.0   5.009464  2.504732    0.357819
#
# [42218 rows x 13 columns]
# (42218, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[d_vac_1.dep != '20']
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-05-09-19h09.csv
# ./Temp/v5/vacsi-a-dep-2021-05-09-19h09-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (155078, 9)
#        dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 119530  87           79 2021-04-02      241        113         9326
# 121482  89           49 2021-02-18       26         23          793
# 91186   67           64 2021-03-18      125         21         9447
#
#         n_cum_complet  couv_dose1  couv_complet
# 119530           4135        63.1          28.0
# 121482            363         1.9           0.9
# 91186            2521        13.2           3.5

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (61712, 9)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 909       02       30-59 2021-03-31      271         76        13650
# 25922     48         60+ 2021-04-02      379        111        10045
# 48795     91       whole 2021-04-01     3718       1600       138292
#
#        n_cum_complet  couv_dose1  couv_complet
# 909             4550        20.2           6.8
# 25922           4555       203.9          93.4
# 48795          43262        10.5           3.3

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (61712, 11)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 43418     81         60+ 2021-03-18      794        463        26992
# 31702     59         60+ 2021-03-15     4144       1081       151021
# 50163     94       whole 2021-02-03      755        387        31484
#
#        n_cum_complet  couv_dose1  couv_complet  taux dose 1  taux complet
# 43418          13322       109.7          54.5    21.394206     10.559188
# 31702          46188       139.3          44.3    25.100137      7.676582
# 50163           1156         2.2           0.1     2.239195      0.082217

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 6.9662024974823  s
