# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 29/04/2021. Retrieve data from how many days? 0
# Ok, will retrieve data from 29/04/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-04-29-19h05.csv
# ./Temp/v5/sp-pos-quot-dep-2021-04-29-19h05-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour   P    T  cl_age90      pop
# 344196  89 2020-12-28  16  229        69  47469.0
# 222460  57 2021-04-08  23  524        79  85112.0
# 64037   17 2021-01-05  15  433        69  99076.0
# (399256, 6)
#       entity three_class       jour   P    T       pop
# 58151     41       whole 2020-12-27   2   84  327835.0
# 82426     59         60+ 2020-05-28   9  644  601674.0
# 40314     2A         60+ 2021-03-15  16  544   50569.0
# (161936, 6)
#                   entity three_class       jour    P     T       pop  P hebdo  \
# 84733                 60       30-59 2021-01-11  160  1994  327864.0    696.0
# 156750  Outre-mer (DROM)         60+ 2020-08-20   19   868  417424.0    115.0
# 19964                 15        0-29 2020-08-26    1    83   37394.0      6.0
#
#         T hebdo  incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 84733    9736.0       212.283142                7.148726          2969.523949
# 156750   4976.0        27.549925                2.311093          1192.073288
# 19964     407.0        16.045355                1.474201          1088.409905
# (161936, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-04-29-19h09.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-04-29-19h09-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (80784, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 52603 2020-12-08     0    0       NaN       NaN     NaN    34    0
# 49474 2020-11-22   877  230       NaN       NaN     NaN  3317  349
# 58169 2021-01-05     1    0       NaN       NaN     NaN    94    0
#
#                      entity three_class
# 52603              Bretagne        0-29
# 49474  Auvergne-Rhône-Alpes         60+
# 58169             Occitanie        0-29
# 'd_hosp_2: '
# (24480, 6)
#                         entity three_class       jour  hosp  rea    dc
# 1808   Bourgogne-Franche-Comté        0-29 2020-05-01    11    3     0
# 18387         Pays de la Loire       whole 2020-07-04   137    3   469
# 8426                 Grand Est         60+ 2020-05-23  2158  154  3199
# 'd_hosp_3: '
# (24480, 10)
#                         entity three_class       jour  hosp  rea    dc  \
# 2255   Bourgogne-Franche-Comté       whole 2020-08-20    23    4  1064
# 10244          Hauts-de-France        0-29 2020-07-09     7    0     1
# 6528                     Corse        0-29 2020-03-18     0    0     0
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 2255        2.0   0.826435  0.143728    0.071864
# 10244       0.0   0.315823  0.000000    0.000000
# 6528        NaN   0.000000  0.000000         NaN

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-04-29-19h09.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-04-29-19h09-compute.csv

# %%
dout.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 30562     74 2021-03-23   244   36     131.0      60.0    17.0  4046  880
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 30562      31.0  29.454192    4.3457    3.742131

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 123619  974     1 2021-04-29    87   21      49.0      17.0     0.0   736   91
# 123620  974     2 2021-04-29    64   16      37.0      11.0     0.0   700   67
# 123621  976     0 2021-04-29    22    6      16.0       0.0     0.0  1230  125
# 123622  976     1 2021-04-29     8    2       6.0       0.0     0.0   561   74
# 123623  976     2 2021-04-29    13    4       9.0       0.0     0.0   650   50
#
# [123624 rows x 10 columns]
# (123624, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 41203    976 2021-04-25    18    5      13.0       0.0     0.0  1228  124
# 41204    976 2021-04-26    20    6      14.0       0.0     0.0  1228  125
# 41205    976 2021-04-27    21    6      15.0       0.0     0.0  1228  125
# 41206    976 2021-04-28    22    6      16.0       0.0     0.0  1230  125
# 41207    976 2021-04-29    22    6      16.0       0.0     0.0  1230  125
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 41203       0.0   6.440740  1.789094    0.000000
# 41204       1.0   7.156378  2.146913    0.357819
# 41205       1.0   7.514196  2.146913    0.357819
# 41206       1.0   7.872015  2.146913    0.357819
# 41207       1.0   7.872015  2.146913    0.357819
#
# [41208 rows x 13 columns]
# (41208, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[d_vac_1.dep != '20']
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-04-29-19h09.csv
# ./Temp/v5/vacsi-a-dep-2021-04-29-19h09-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (143418, 9)
#        dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 104246  81           74 2021-03-02       26         36         1299
# 62804   49           24 2021-03-11       55         26         1084
# 92362   73           24 2021-04-18        0          0          596
#
#         n_cum_complet  couv_dose1  couv_complet
# 104246            690         5.4           2.9
# 62804             138         1.5           0.2
# 92362              95         1.9           0.3

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (57072, 9)
#               entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 56719  Île-de-France       whole 2021-01-30     4431        159       239885
# 36129             73       30-59 2021-02-18      106         94         4103
# 14781             30       30-59 2021-01-01        0          0            0
#
#        n_cum_complet  couv_dose1  couv_complet
# 56719           5593        15.2           0.3
# 36129           2224         7.1           3.8
# 14781              0         0.0           0.0

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (57072, 11)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 28401     57       30-59 2021-03-26     1133        557        39125
# 25368     51        0-29 2021-03-06        5          0         1437
# 15978     32         60+ 2021-02-23      384        461         9727
#
#        n_cum_complet  couv_dose1  couv_complet  taux dose 1  taux complet
# 28401          13663        27.8           9.8     9.511504      3.321551
# 25368            190         3.6           0.5     0.701352      0.092733
# 15978           3649        72.7          26.1    14.197098      5.325919

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 8.396910190582275  s

# %% [markdown]
# # Données hospitalières (3) Estimation par classe d'âge et par département

# %% [markdown]
# ## dfs pops et pops_prop

# %% [markdown]
# ### df dpops

# %%
fname = dp.retrieve_temp('sp-pos-quot-dep', 'tot-3C-compute')
dtes = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v5/sp-pos-quot-dep-2021-04-29-19h05-tot-3C-compute.csv

# %%
columns = pd.Index(dtes.three_class.unique(), name = 'clage')
index = pd.Index(dtes.entity.unique(), name = 'entity')
dpops = pd.DataFrame(index = index, columns = columns)
dpops.sample()
# Out:
# clage         0-29 30-59  60+ whole
# entity
# Île-de-France  NaN   NaN  NaN   NaN

# %%
for entity in dtes.entity.unique():
    for clage in dtes.three_class.unique():
        dpops.loc[entity, clage] = dtes[(dtes.entity == entity) & (dtes.three_class == clage) & (dtes.jour == '2021-01-01')]["pop"].values[0]

# %%
dpops.sample()
# Out:
# clage       0-29     30-59      60+     whole
# entity
# 53      103116.0  112210.0  90039.0  305365.0

# %%
dpops.shape
dpops.loc['France', :]
dpops.loc['France','60+']
# Out:
# (116, 4)
# clage
# 0-29     23555651.0
# 30-59    25657812.0
# 60+      17850240.0
# whole    67063703.0
# Name: France, dtype: object
# 17850240.0

# %%
dout = dpops
fname = path_temp + '-pops.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ./Temp/v5/vacsi-a-dep-2021-04-29-19h09-pops.csv

# %% [markdown]
# ### df dpops_prop

# %%
dpops_prop = dpops.divide(dpops.whole, axis = 'index')
dpops_prop
# Out:
# clage                           0-29     30-59       60+ whole
# entity
# 01                          0.354913  0.403463  0.241624   1.0
# 02                          0.344635   0.37594  0.279426   1.0
# 03                          0.286133  0.358127   0.35574   1.0
# 04                          0.287838  0.369062  0.343099   1.0
# 05                          0.296248   0.37973  0.324022   1.0
# ...                              ...       ...       ...   ...
# Occitanie                   0.330174  0.374871  0.294955   1.0
# Outre-mer (DROM)            0.432203  0.375058  0.192739   1.0
# Pays de la Loire            0.350137  0.375243   0.27462   1.0
# Provence-Alpes-Côte d'Azur  0.324136  0.377594   0.29827   1.0
# Île-de-France               0.390357  0.404643     0.205   1.0
#
# [116 rows x 4 columns]

# %% [markdown]
# ## taux hosp

# %% [markdown]
# ### empty df dhosps

# %%
fname = dp.retrieve_temp('donnees-hospitalieres-classe-age-covid19', '3C-compute')
dhos = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
fname = dp.retrieve_temp('donnees-hospitalieres-covid19', 'compute')
dhosdep = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-04-29-19h09-3C-compute.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-04-29-19h09-compute.csv

# %%
columns = pd.MultiIndex.from_tuples([(i, j) for i in dpops.index.unique() for j in dtes.three_class.unique()],
                       name = ['entity', 'clage'])
index = pd.Index(dhos.jour.unique(), name = "jour")
dhosps = pd.DataFrame(index = index, columns = columns)
dhosps.shape
dhosps.sample()
# Out:
# (408, 464)
# entity       01                    02                    03        ...  \
# clage      0-29 30-59  60+ whole 0-29 30-59  60+ whole 0-29 30-59  ...
# jour                                                               ...
# 2021-01-09  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire       Provence-Alpes-Côte d'Azur                   \
# clage                   60+ whole                       0-29 30-59  60+ whole
# jour
# 2021-01-09              NaN   NaN                        NaN   NaN  NaN   NaN
#
# entity     Île-de-France
# clage               0-29 30-59  60+ whole
# jour
# 2021-01-09           NaN   NaN  NaN   NaN
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (1) fill it with data for each (entity = dc.regs, clage)

# %%
dhos.sample()
# Out:
#                    entity three_class       jour  hosp  rea  dc  dc hebdo  \
# 805  Auvergne-Rhône-Alpes       30-59 2020-10-05   143   21  64       2.0
#
#      taux hosp  taux rea  taux décès
# 805   4.634435  0.680581    0.064817

# %%
dhos = dhos.set_index(dhos.jour)
dhos.sample()
# Out:
#               entity three_class       jour  hosp  rea   dc  dc hebdo  \
# jour
# 2020-09-05  Bretagne       whole 2020-09-05    63    6  269       0.0
#
#             taux hosp  taux rea  taux décès
# jour
# 2020-09-05   1.886014   0.17962         0.0

# %%
for entity, clage in dhosps.columns:
    dhosps.loc[:,(entity,clage)] = dhos[(dhos.entity == entity) & (dhos.three_class == clage)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                   02                   03        ...  \
# clage      0-29 30-59 60+ whole 0-29 30-59 60+ whole 0-29 30-59  ...
# jour                                                             ...
# 2020-05-19  NaN   NaN NaN   NaN  NaN   NaN NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire            Provence-Alpes-Côte d'Azur            \
# clage                   60+      whole                       0-29     30-59
# jour
# 2020-05-19        42.143535  12.573002                   0.671255  5.605085
#
# entity                           Île-de-France                         \
# clage             60+      whole          0-29      30-59         60+
# jour
# 2020-05-19  63.927891  21.441353      3.087912  29.647998  238.654003
#
# entity
# clage           whole
# jour
# 2020-05-19  62.647568
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (2) fill it with data for each (entity = dc.deps, clage = ['whole'])

# %%
dhosdep.sample()
dhosdep = dhosdep.set_index(dhosdep.jour)
dhosdep.sample()
# Out:
#      entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 6000     15 2020-12-31    62    5       NaN       NaN     NaN  295  59
#
#       dc hebdo  taux hosp  taux rea  taux décès
# 6000       4.0  43.414023  3.501131    2.800905
#            entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad  \
# jour
# 2021-04-09     90 2021-04-09    91   20      58.0      13.0     0.0  1774
#
#              dc  dc hebdo  taux hosp   taux rea  taux décès
# jour
# 2021-04-09  529       7.0  64.932748  14.270934    4.994827

# %%
for entity in dhosdep.entity.unique():
    for clage in ['whole']:
        dhosps.loc[:,(entity, clage)] = dhosdep[(dhosdep.entity == entity)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                       02                       03        ...  \
# clage      0-29 30-59 60+     whole 0-29 30-59 60+     whole 0-29 30-59  ...
# jour                                                                     ...
# 2020-08-24  NaN   NaN NaN  3.805436  NaN   NaN NaN  8.364224  NaN   NaN  ...
#
# entity     Pays de la Loire           Provence-Alpes-Côte d'Azur           \
# clage                   60+     whole                       0-29    30-59
# jour
# 2020-08-24         8.045584  2.814459                   0.427162  3.03827
#
# entity                          Île-de-France
# clage             60+     whole          0-29     30-59       60+     whole
# jour
# 2020-08-24  18.700898  7.002066      1.314449  9.480113  73.81707  19.68528
#
# [1 rows x 464 columns]

# %%
dhosps['01', 'whole']
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-25    28.312441
# 2021-04-26    30.595703
# 2021-04-27    31.204573
# 2021-04-28    29.225746
# 2021-04-29    28.921311
# Name: (01, whole), Length: 408, dtype: float64

# %%
dhosps.loc[:,('01', 'whole')]
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-25    28.312441
# 2021-04-26    30.595703
# 2021-04-27    31.204573
# 2021-04-28    29.225746
# 2021-04-29    28.921311
# Name: (01, whole), Length: 408, dtype: float64

# %% [markdown]
# ### (3) estimate data for missing (entity = dc.deps, clage = ['0-29', '30-59', '60+'])

# %% [markdown]
# La proportion observée au niveau régional pour la classe d'âge considérée par rapport à l'ensemble de la population est appliquée au taux départemental :
# Taux (département, classe d'âge) = taux (département) * taux (région, classe d'âge) / taux (région)

# %%
for entity in dc.deps:
    for clage in ['0-29', '30-59', '60+']:
        dhosps.loc[:,(entity, clage)] = (
            dhosps.loc[:,(entity, 'whole')]
            * dhosps.loc[:,(dc.dep2reg[entity], clage)]
            / dhosps.loc[:,(dc.dep2reg[entity], 'whole')]
#             * dpops_prop.loc[entity, clage]
#             / dpops_prop.loc[dc.dep2reg[entity], clage]
        )

# %%
dhosps.loc[:,('Auvergne-Rhône-Alpes', '0-29')]
# Out:
# jour
# 2020-03-18    0.141085
# 2020-03-19    0.176356
# 2020-03-20    0.141085
# 2020-03-21    0.246899
# 2020-03-22    0.387984
#                 ...
# 2021-04-25    1.798833
# 2021-04-26    1.693020
# 2021-04-27    1.728291
# 2021-04-28    1.657748
# 2021-04-29    2.010461
# Name: (Auvergne-Rhône-Alpes, 0-29), Length: 408, dtype: float64

# %% [markdown]
# ## Fonction

# %%
# def estimate_deps(din, dindep, column):
#     columns = pd.MultiIndex.from_tuples([(i, j) for i in dtes.entity.unique() for j in dtes.three_class.unique()],
#                        name = ['entity', 'clage'])
#     index = pd.Index(din.jour.unique(), name = "jour")
#     dout = pd.DataFrame(index = index, columns = columns)

#     din = din.copy().set_index(din.jour)
#     for entity, clage in dout.columns:
#         dout.loc[:,(entity,clage)] = din[(din.entity == entity) & (din.three_class == clage)][column]

#     dindep = dindep.copy().set_index(dindep.jour)
#     for entity in dindep.entity.unique():
#         for clage in ['whole']:
#             dout.loc[:,(entity, clage)] = dindep[(dindep.entity == entity)][column]

#     for entity in dc.deps:
#         for clage in ['0-29', '30-59', '60+']:
#             dout.loc[:,(entity, clage)] = (
#                 dout.loc[:,(entity, 'whole')]
#                 * dout.loc[:,(dc.dep2reg[entity], clage)]
#                 / dout.loc[:,(dc.dep2reg[entity], 'whole')]
#             )
#     dout = pd.melt(dout.T.reset_index(), id_vars = ['entity', 'clage'], value_name = column)
#     return dout

# %%
# d1 = estimate_deps(dhos, dhosdep, "taux hosp")

# d2 = estimate_deps(dhos, dhosdep, "taux rea")

# d3 = estimate_deps(dhos, dhosdep, "taux décès")

# dout = pd.merge(pd.merge(d1,d2), d3)
# fname = path_temp + '-estimates-hosp.csv'
# dout.to_csv(fname, sep = ';', index = False)
# print(fname)

# %%
# dout
