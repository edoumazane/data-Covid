# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 28/05/2021. Retrieve data from how many days?
# Ok, will retrieve data from 27/05/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-05-27-19h09.csv
# ./Temp/v5/sp-pos-quot-dep-2021-05-27-19h09-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour  P   T  cl_age90      pop
# 283303  68 2020-09-08  1  46        90   8647.0
# 275550  66 2020-10-28  1  55         9  48883.0
# 166523  40 2020-07-10  0  72        59  58062.0
# (431288, 6)
#                  entity three_class       jour     P      T         pop
# 159916           France        0-29 2020-05-30   129   4992  23555651.0
# 163367  Hauts-de-France       whole 2020-09-15  1617  29567   5962662.0
# 105831               70       whole 2020-07-19     0     37    233194.0
# (174928, 6)
#        entity three_class       jour    P    T       pop  P hebdo  T hebdo  \
# 24207      17       whole 2020-06-01    0   26  647080.0      3.0    852.0
# 27945      19       30-59 2020-11-29    1   14   86672.0     68.0   1580.0
# 107760     71        0-29 2020-11-02  208  988  163376.0    957.0   5114.0
#
#         incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 24207          0.463621                0.352113           131.668418
# 27945         78.456710                4.303797          1822.964741
# 107760       585.765351               18.713336          3130.202723
# (174928, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-05-27-19h05.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-05-27-19h05-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (86328, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres   rad  dc  \
# 83425 2021-05-13     1    0       1.0       0.0     0.0    78   0
# 51690 2020-12-04     0    0       NaN       NaN     NaN     1   0
# 61561 2021-01-22    79   22       NaN       NaN     NaN  1563  22
#
#                            entity three_class
# 83425         Centre-Val de Loire        0-29
# 51690            Outre-mer (DROM)        0-29
# 61561  Provence-Alpes-Côte d'Azur       30-59
# 'd_hosp_2: '
# (26160, 6)
#                        entity three_class       jour  hosp  rea   dc
# 2090  Bourgogne-Franche-Comté         60+ 2020-06-12   204   17  993
# 9560                Grand Est        0-29 2020-10-14     4    0    3
# 4089                 Bretagne       30-59 2020-08-15    15    3   11
# 'd_hosp_3: '
# (26160, 10)
#                  entity three_class       jour  hosp  rea   dc  dc hebdo  \
# 13581         Normandie       30-59 2021-02-24   128   28   91       3.0
# 23181     Île-de-France       30-59 2020-07-23   544   71  735       4.0
# 17876  Outre-mer (DROM)        0-29 2020-07-05    25    2    1       0.0
#
#        taux hosp  taux rea  taux décès
# 13581  10.422791  2.279985    0.244284
# 23181  10.949430  1.429062    0.080511
# 17876   2.612680  0.209014    0.000000

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1, True)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute-DROM.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-05-27-19h05.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-05-27-19h05-3C-compute-DROM.csv

# %%
dout.entity.unique()
# Out:
# array(['Auvergne-Rhône-Alpes', 'Bourgogne-Franche-Comté', 'Bretagne',
#        'Centre-Val de Loire', 'Corse', 'Grand Est', 'Guadeloupe',
#        'Guyane', 'Hauts-de-France', 'La Réunion', 'Martinique', 'Mayotte',
#        'Normandie', 'Nouvelle-Aquitaine', 'Occitanie', 'Pays de la Loire',
#        "Provence-Alpes-Côte d'Azur", 'Île-de-France', 'France'],
#       dtype=object)

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-05-27-19h05.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-05-27-19h05-compute.csv

# %%
dout.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad   dc  \
# 25566     58 2020-12-21    84    3       NaN       NaN     NaN  338  103
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 25566      12.0  42.085012  1.503036    6.012145

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 132103  974     1 2021-05-27    81   20      41.0      20.0     0.0   885  116
# 132104  974     2 2021-05-27    75   16      41.0      18.0     0.0   827   85
# 132105  976     0 2021-05-27     7    3       4.0       0.0     0.0  1261  130
# 132106  976     1 2021-05-27     2    1       1.0       0.0     0.0   572   76
# 132107  976     2 2021-05-27     5    2       3.0       0.0     0.0   668   53
#
# [132108 rows x 10 columns]
# (132108, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 44031    976 2021-05-23    10    5       5.0       0.0     0.0  1260  128
# 44032    976 2021-05-24    10    5       5.0       0.0     0.0  1260  128
# 44033    976 2021-05-25     9    5       4.0       0.0     0.0  1261  128
# 44034    976 2021-05-26     9    4       5.0       0.0     0.0  1261  128
# 44035    976 2021-05-27     7    3       4.0       0.0     0.0  1261  130
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 44031       0.0   3.578189  1.789094    0.000000
# 44032       0.0   3.578189  1.789094    0.000000
# 44033       0.0   3.220370  1.789094    0.000000
# 44034       0.0   3.220370  1.431276    0.000000
# 44035       2.0   2.504732  1.073457    0.715638
#
# [44036 rows x 13 columns]
# (44036, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[(d_vac_1.dep != '20') & (d_vac_1.dep != '98')]
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-05-27-19h05.csv
# ./Temp/v5/vacsi-a-dep-2021-05-27-19h05-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (177727, 9)
#        dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 110211  71           80 2021-05-08       15         37        34961
# 140010  90           74 2021-01-29       34          9          362
# 124696  80           64 2021-04-27      428        125        15271
#
#         n_cum_complet  couv_dose1  couv_complet
# 110211          27871        75.4          60.1
# 140010             11         4.9           0.1
# 124696           2635        42.6           7.4

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (70064, 9)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 49824     82        0-29 2021-03-11       18          2          314
# 21913     36       30-59 2021-02-07        0          0         1867
# 3776      07        0-29 2021-02-03        8          1          121
#
#        n_cum_complet  couv_dose1  couv_complet
# 49824             96         2.4           0.7
# 21913            578         6.6           2.0
# 3776               3         0.8           0.0

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (70064, 11)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 21680     35        0-29 2021-05-11      287        275        11746
# 39925     66       30-59 2021-01-11      174          1          637
# 30617     50       30-59 2021-04-10      639        109        20779
#
#        n_cum_complet  couv_dose1  couv_complet  taux dose 1  taux complet
# 21680           4598        15.0           6.0     2.875771      1.125727
# 39925              1         1.0           0.0     0.369079      0.000579
# 30617           6869        33.2          11.0    11.578754      3.827637

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 9.359915494918823  s
