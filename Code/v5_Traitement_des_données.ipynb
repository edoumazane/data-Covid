# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 05/05/2021. Retrieve data from how many days? 0
# Ok, will retrieve data from 05/05/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-05-05-19h08.csv
# ./Temp/v5/sp-pos-quot-dep-2021-05-05-19h08-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour  P    T  cl_age90       pop
# 367403  94 2020-06-12  2  154        39  201248.0
# 285974  73 2020-08-03  1   38        79   38517.0
# 211415  54 2020-07-01  1  273        69   87766.0
# (406120, 6)
#        entity three_class       jour   P     T       pop
# 18664      14        0-29 2020-07-03   0   277  237080.0
# 133852     94        0-29 2020-08-14  83  1110  548476.0
# 54073      38       30-59 2020-06-10   1   166  488885.0
# (164720, 6)
#        entity three_class       jour   P    T       pop  P hebdo  T hebdo  \
# 122657     86       30-59 2020-09-24  14  336  157001.0     91.0   2315.0
# 76088      53        0-29 2020-12-06   1   27  103116.0     67.0   1045.0
# 4042       03         60+ 2021-03-09  24  449  117862.0    106.0   2423.0
#
#         incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 122657        57.961414                3.930886          1474.512901
# 76088         64.975368                6.411483          1013.421777
# 4042          89.935687                4.374742          2055.794064
# (164720, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-05-05-19h09.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-05-05-19h09-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (81972, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres    rad    dc  \
# 45589 2020-11-03     3    0       NaN       NaN     NaN     62     6
# 7965  2020-04-27     0    0       NaN       NaN     NaN      2     0
# 79262 2021-04-22  1584  591     739.0     235.0    19.0  15168  2502
#
#                  entity three_class
# 45589  Outre-mer (DROM)       30-59
# 7965   Outre-mer (DROM)        0-29
# 79262     Île-de-France         60+
# 'd_hosp_2: '
# (24840, 6)
#                            entity three_class       jour  hosp  rea    dc
# 200          Auvergne-Rhône-Alpes        0-29 2020-05-07    28    6     0
# 20167  Provence-Alpes-Côte d'Azur       whole 2020-05-30   880   77   898
# 8851                    Grand Est       whole 2020-08-07   543   17  3627
# 'd_hosp_3: '
# (24840, 10)
#                            entity three_class       jour  hosp  rea    dc  \
# 21425  Provence-Alpes-Côte d'Azur       30-59 2021-04-10   565  155   222
# 21665               Île-de-France       30-59 2020-04-21  2810  891   474
# 22243               Île-de-France       whole 2020-09-12  2381  212  7790
#
#        dc hebdo  taux hosp   taux rea  taux décès
# 21425      11.0  29.596942   8.119515    0.576224
# 21665      95.0  56.558638  17.933718    1.912125
# 22243      37.0  19.392078   1.726636    0.301347

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-05-05-19h09.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-05-05-19h09-compute.csv

# %%
dout.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 37065     89 2020-10-23    47    8       NaN       NaN     NaN  482  96
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 37065       1.0  14.152534  2.408942    0.301118

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 125437  974     1 2021-05-05    90   22      51.0      17.0     0.0   765   98
# 125438  974     2 2021-05-05    71   17      43.0      11.0     0.0   724   70
# 125439  976     0 2021-05-05    11    4       7.0       0.0     0.0  1248  126
# 125440  976     1 2021-05-05     7    2       5.0       0.0     0.0   567   74
# 125441  976     2 2021-05-05     4    2       2.0       0.0     0.0   661   51
#
# [125442 rows x 10 columns]
# (125442, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 41809    976 2021-05-01    12    4       8.0       0.0     0.0  1241  126
# 41810    976 2021-05-02    12    4       8.0       0.0     0.0  1241  126
# 41811    976 2021-05-03    13    4       9.0       0.0     0.0  1243  126
# 41812    976 2021-05-04    11    4       7.0       0.0     0.0  1246  126
# 41813    976 2021-05-05    11    4       7.0       0.0     0.0  1248  126
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 41809       2.0   4.293827  1.431276    0.715638
# 41810       2.0   4.293827  1.431276    0.715638
# 41811       1.0   4.651645  1.431276    0.357819
# 41812       1.0   3.936008  1.431276    0.357819
# 41813       1.0   3.936008  1.431276    0.357819
#
# [41814 rows x 13 columns]
# (41814, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[d_vac_1.dep != '20']
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-05-05-19h08.csv
# ./Temp/v5/vacsi-a-dep-2021-05-05-19h08-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (150414, 9)
#       dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 95481  72           24 2021-01-17        0          0            8
# 49513  36           49 2021-04-12       30         19         1856
# 1802   01           49 2021-05-01      141         86         7387
#
#        n_cum_complet  couv_dose1  couv_complet
# 95481              0         0.0           0.0
# 49513            640         7.2           2.5
# 1802            2475         8.2           2.8

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (59856, 9)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 48728     94        0-29 2021-02-21        1          0         1625
# 13651     28       whole 2021-02-23      202        341        18083
# 38995     75       whole 2021-03-10     7096       1754       177799
#
#        n_cum_complet  couv_dose1  couv_complet
# 48728            722         1.5           0.7
# 13651           9511         4.2           2.2
# 38995          80207         8.3           3.7

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (59856, 11)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 38454     74         60+ 2021-03-04     1021        823        22654
# 26908     52        0-29 2021-01-15       11          0           51
# 12721     26       30-59 2021-03-21        7          0        10483
#
#        n_cum_complet  couv_dose1  couv_complet  taux dose 1  taux complet
# 38454          13320        66.8          39.8    12.066945      7.095070
# 26908              0         0.6           0.0     0.100098      0.000000
# 12721           3539        15.5           5.2     5.326728      1.798272

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 8.830605268478394  s

# %% [markdown]
# # Données hospitalières (3) Estimation par classe d'âge et par département

# %% [markdown]
# ## dfs pops et pops_prop

# %% [markdown]
# ### df dpops

# %%
fname = dp.retrieve_temp('sp-pos-quot-dep', 'tot-3C-compute')
dtes = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v5/sp-pos-quot-dep-2021-05-05-19h08-tot-3C-compute.csv

# %%
columns = pd.Index(dtes.three_class.unique(), name = 'clage')
index = pd.Index(dtes.entity.unique(), name = 'entity')
dpops = pd.DataFrame(index = index, columns = columns)
dpops.sample()
# Out:
# clage  0-29 30-59  60+ whole
# entity
# 54      NaN   NaN  NaN   NaN

# %%
for entity in dtes.entity.unique():
    for clage in dtes.three_class.unique():
        dpops.loc[entity, clage] = dtes[(dtes.entity == entity) & (dtes.three_class == clage) & (dtes.jour == '2021-01-01')]["pop"].values[0]

# %%
dpops.sample()
# Out:
# clage       0-29     30-59       60+     whole
# entity
# 66      145044.0  172592.0  161364.0  479000.0

# %%
dpops.shape
dpops.loc['France', :]
dpops.loc['France','60+']
# Out:
# (116, 4)
# clage
# 0-29     23555651.0
# 30-59    25657812.0
# 60+      17850240.0
# whole    67063703.0
# Name: France, dtype: object
# 17850240.0

# %%
dout = dpops
fname = path_temp + '-pops.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ./Temp/v5/vacsi-a-dep-2021-05-05-19h08-pops.csv

# %% [markdown]
# ### df dpops_prop

# %%
dpops_prop = dpops.divide(dpops.whole, axis = 'index')
dpops_prop
# Out:
# clage                           0-29     30-59       60+ whole
# entity
# 01                          0.354913  0.403463  0.241624   1.0
# 02                          0.344635   0.37594  0.279426   1.0
# 03                          0.286133  0.358127   0.35574   1.0
# 04                          0.287838  0.369062  0.343099   1.0
# 05                          0.296248   0.37973  0.324022   1.0
# ...                              ...       ...       ...   ...
# Occitanie                   0.330174  0.374871  0.294955   1.0
# Outre-mer (DROM)            0.432203  0.375058  0.192739   1.0
# Pays de la Loire            0.350137  0.375243   0.27462   1.0
# Provence-Alpes-Côte d'Azur  0.324136  0.377594   0.29827   1.0
# Île-de-France               0.390357  0.404643     0.205   1.0
#
# [116 rows x 4 columns]

# %% [markdown]
# ## taux hosp

# %% [markdown]
# ### empty df dhosps

# %%
fname = dp.retrieve_temp('donnees-hospitalieres-classe-age-covid19', '3C-compute')
dhos = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
fname = dp.retrieve_temp('donnees-hospitalieres-covid19', 'compute')
dhosdep = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-05-05-19h09-3C-compute.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-05-05-19h09-compute.csv

# %%
columns = pd.MultiIndex.from_tuples([(i, j) for i in dpops.index.unique() for j in dtes.three_class.unique()],
                       name = ['entity', 'clage'])
index = pd.Index(dhos.jour.unique(), name = "jour")
dhosps = pd.DataFrame(index = index, columns = columns)
dhosps.shape
dhosps.sample()
# Out:
# (414, 464)
# entity       01                    02                    03        ...  \
# clage      0-29 30-59  60+ whole 0-29 30-59  60+ whole 0-29 30-59  ...
# jour                                                               ...
# 2021-02-17  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire       Provence-Alpes-Côte d'Azur                   \
# clage                   60+ whole                       0-29 30-59  60+ whole
# jour
# 2021-02-17              NaN   NaN                        NaN   NaN  NaN   NaN
#
# entity     Île-de-France
# clage               0-29 30-59  60+ whole
# jour
# 2021-02-17           NaN   NaN  NaN   NaN
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (1) fill it with data for each (entity = dc.regs, clage)

# %%
dhos.sample()
# Out:
#           entity three_class       jour  hosp  rea  dc  dc hebdo  taux hosp  \
# 11613  Normandie       30-59 2020-03-23    28    5   0       NaN   2.279985
#
#        taux rea  taux décès
# 11613   0.40714         NaN

# %%
dhos = dhos.set_index(dhos.jour)
dhos.sample()
# Out:
#                              entity three_class       jour  hosp  rea  dc  \
# jour
# 2021-03-27  Bourgogne-Franche-Comté        0-29 2021-03-27    19    2   3
#
#             dc hebdo  taux hosp  taux rea  taux décès
# jour
# 2021-03-27       0.0   2.104058   0.22148         0.0

# %%
for entity, clage in dhosps.columns:
    dhosps.loc[:,(entity,clage)] = dhos[(dhos.entity == entity) & (dhos.three_class == clage)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                   02                   03        ...  \
# clage      0-29 30-59 60+ whole 0-29 30-59 60+ whole 0-29 30-59  ...
# jour                                                             ...
# 2020-12-10  NaN   NaN NaN   NaN  NaN   NaN NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire            Provence-Alpes-Côte d'Azur             \
# clage                   60+      whole                       0-29      30-59
# jour
# 2020-12-10        81.126305  24.146476                   2.013766  10.529178
#
# entity                            Île-de-France                         \
# clage              60+      whole          0-29      30-59         60+
# jour
# 2020-12-10  137.736754  45.948583      1.898649  13.948447  163.645054
#
# entity
# clage           whole
# jour
# 2020-12-10  40.347901
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (2) fill it with data for each (entity = dc.deps, clage = ['whole'])

# %%
dhosdep.sample()
dhosdep = dhosdep.set_index(dhosdep.jour)
dhosdep.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 20062     48 2020-09-24     4    0       NaN       NaN     NaN   31   1
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 20062       0.0   5.243426       0.0         0.0
#            entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# jour
# 2020-07-04     27 2020-07-04    34    0       NaN       NaN     NaN  239  84
#
#             dc hebdo  taux hosp  taux rea  taux décès
# jour
# 2020-07-04       2.0   5.660186       0.0    0.332952

# %%
for entity in dhosdep.entity.unique():
    for clage in ['whole']:
        dhosps.loc[:,(entity, clage)] = dhosdep[(dhosdep.entity == entity)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                       02                        03        ...  \
# clage      0-29 30-59 60+     whole 0-29 30-59 60+      whole 0-29 30-59  ...
# jour                                                                      ...
# 2020-12-20  NaN   NaN NaN  46.73075  NaN   NaN NaN  55.317936  NaN   NaN  ...
#
# entity     Pays de la Loire          Provence-Alpes-Côte d'Azur             \
# clage                   60+    whole                       0-29      30-59
# jour
# 2020-12-20        84.574413  25.1197                   0.793302  10.319642
#
# entity                           Île-de-France                         \
# clage              60+     whole          0-29      30-59         60+
# jour
# 2020-12-20  136.476764  45.09805       1.71087  13.948447  158.758348
#
# entity
# clage           whole
# jour
# 2020-12-20  39.272826
#
# [1 rows x 464 columns]

# %%
dhosps['01', 'whole']
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-05-01    28.008007
# 2021-05-02    27.551354
# 2021-05-03    28.769094
# 2021-05-04    25.572528
# 2021-05-05    27.399137
# Name: (01, whole), Length: 414, dtype: float64

# %%
dhosps.loc[:,('01', 'whole')]
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-05-01    28.008007
# 2021-05-02    27.551354
# 2021-05-03    28.769094
# 2021-05-04    25.572528
# 2021-05-05    27.399137
# Name: (01, whole), Length: 414, dtype: float64

# %% [markdown]
# ### (3) estimate data for missing (entity = dc.deps, clage = ['0-29', '30-59', '60+'])

# %% [markdown]
# La proportion observée au niveau régional pour la classe d'âge considérée par rapport à l'ensemble de la population est appliquée au taux départemental :
# Taux (département, classe d'âge) = taux (département) * taux (région, classe d'âge) / taux (région)

# %%
for entity in dc.deps:
    for clage in ['0-29', '30-59', '60+']:
        dhosps.loc[:,(entity, clage)] = (
            dhosps.loc[:,(entity, 'whole')]
            * dhosps.loc[:,(dc.dep2reg[entity], clage)]
            / dhosps.loc[:,(dc.dep2reg[entity], 'whole')]
#             * dpops_prop.loc[entity, clage]
#             / dpops_prop.loc[dc.dep2reg[entity], clage]
        )

# %%
dhosps.loc[:,('Auvergne-Rhône-Alpes', '0-29')]
# Out:
# jour
# 2020-03-18    0.141085
# 2020-03-19    0.176356
# 2020-03-20    0.141085
# 2020-03-21    0.246899
# 2020-03-22    0.387984
#                 ...
# 2021-05-01    1.728291
# 2021-05-02    1.728291
# 2021-05-03    1.763562
# 2021-05-04    1.693020
# 2021-05-05    1.834105
# Name: (Auvergne-Rhône-Alpes, 0-29), Length: 414, dtype: float64

# %% [markdown]
# ## Fonction

# %%
# def estimate_deps(din, dindep, column):
#     columns = pd.MultiIndex.from_tuples([(i, j) for i in dtes.entity.unique() for j in dtes.three_class.unique()],
#                        name = ['entity', 'clage'])
#     index = pd.Index(din.jour.unique(), name = "jour")
#     dout = pd.DataFrame(index = index, columns = columns)

#     din = din.copy().set_index(din.jour)
#     for entity, clage in dout.columns:
#         dout.loc[:,(entity,clage)] = din[(din.entity == entity) & (din.three_class == clage)][column]

#     dindep = dindep.copy().set_index(dindep.jour)
#     for entity in dindep.entity.unique():
#         for clage in ['whole']:
#             dout.loc[:,(entity, clage)] = dindep[(dindep.entity == entity)][column]

#     for entity in dc.deps:
#         for clage in ['0-29', '30-59', '60+']:
#             dout.loc[:,(entity, clage)] = (
#                 dout.loc[:,(entity, 'whole')]
#                 * dout.loc[:,(dc.dep2reg[entity], clage)]
#                 / dout.loc[:,(dc.dep2reg[entity], 'whole')]
#             )
#     dout = pd.melt(dout.T.reset_index(), id_vars = ['entity', 'clage'], value_name = column)
#     return dout

# %%
# d1 = estimate_deps(dhos, dhosdep, "taux hosp")

# d2 = estimate_deps(dhos, dhosdep, "taux rea")

# d3 = estimate_deps(dhos, dhosdep, "taux décès")

# dout = pd.merge(pd.merge(d1,d2), d3)
# fname = path_temp + '-estimates-hosp.csv'
# dout.to_csv(fname, sep = ';', index = False)
# print(fname)

# %%
# dout
