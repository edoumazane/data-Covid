# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 04/05/2021. Retrieve data from how many days? 0
# Ok, will retrieve data from 04/05/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-05-04-19h08.csv
# ./Temp/v5/sp-pos-quot-dep-2021-05-04-19h08-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour  P   T  cl_age90       pop
# 150486  38 2020-12-27  5  80        69  141349.0
# 352686  90 2020-12-01  3  62        49   17954.0
# 167064  42 2021-03-28  3  79        79   72406.0
# (404976, 6)
#        entity three_class       jour   P    T       pop
# 115544     81        0-29 2020-12-11  17  286  117950.0
# 41283      2B       whole 2020-07-06   0  115  182258.0
# 82102      57         60+ 2021-04-25   6  501  283694.0
# (164256, 6)
#       entity three_class       jour    P     T       pop  P hebdo  T hebdo  \
# 54190     38         60+ 2020-08-16    1    51  313894.0     21.0   1900.0
# 1171      01       whole 2021-03-01  263  3733  656955.0   1288.0  17258.0
# 41951     2B       whole 2020-12-20    4   223  182258.0     65.0   6828.0
#
#        incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 54190         6.690157                1.105263           605.299878
# 1171        196.056046                7.463205          2626.968362
# 41951        35.663729                0.951963          3746.337609
# (164256, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-05-04-19h05.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-05-04-19h05-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (81774, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres   rad  dc  \
# 73292 2021-03-23     0    0       0.0       0.0     0.0    10   2
# 72821 2021-03-20     2    0       1.0       1.0     0.0   136   0
# 75355 2021-04-02   120   35      75.0       8.0     2.0  2058  72
#
#                  entity three_class
# 73292  Outre-mer (DROM)         60+
# 72821         Occitanie        0-29
# 75355         Grand Est       30-59
# 'd_hosp_2: '
# (24780, 6)
#                    entity three_class       jour  hosp  rea    dc
# 12449           Normandie       30-59 2020-10-25    76   15    37
# 16087           Occitanie       whole 2021-01-16  1382  187  2344
# 13518  Nouvelle-Aquitaine         60+ 2020-06-01   262   27   376
# 'd_hosp_3: '
# (24780, 10)
#                  entity three_class       jour  hosp  rea   dc  dc hebdo  \
# 16920  Outre-mer (DROM)        0-29 2020-06-26    23    1    0       0.0
# 4697           Bretagne       30-59 2021-03-01    93   18   31       2.0
# 21809     Île-de-France       30-59 2020-06-09  1023  149  701      17.0
#
#        taux hosp  taux rea  taux décès
# 16920   2.403665  0.104507    0.000000
# 4697    7.468752  1.445565    0.160618
# 21809  20.590565  2.999017    0.342170

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-05-04-19h05.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-05-04-19h05-compute.csv

# %%
dout.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 10670     27 2021-02-26   122   11       NaN       NaN     NaN  1161  321
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 10670      12.0  20.310078  1.831237    1.997713

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 125134  974     1 2021-05-04    88   23      49.0      16.0     0.0   761   94
# 125135  974     2 2021-05-04    71   18      42.0      11.0     0.0   720   69
# 125136  976     0 2021-05-04    11    4       7.0       0.0     0.0  1246  126
# 125137  976     1 2021-05-04     7    2       5.0       0.0     0.0   565   74
# 125138  976     2 2021-05-04     4    2       2.0       0.0     0.0   661   51
#
# [125139 rows x 10 columns]
# (125139, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 41708    976 2021-04-30    12    3       9.0       0.0     0.0  1241  126
# 41709    976 2021-05-01    12    4       8.0       0.0     0.0  1241  126
# 41710    976 2021-05-02    12    4       8.0       0.0     0.0  1241  126
# 41711    976 2021-05-03    13    4       9.0       0.0     0.0  1243  126
# 41712    976 2021-05-04    11    4       7.0       0.0     0.0  1246  126
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 41708       2.0   4.293827  1.073457    0.715638
# 41709       2.0   4.293827  1.431276    0.715638
# 41710       2.0   4.293827  1.431276    0.715638
# 41711       1.0   4.651645  1.431276    0.357819
# 41712       1.0   3.936008  1.431276    0.357819
#
# [41713 rows x 13 columns]
# (41713, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[d_vac_1.dep != '20']
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-05-04-19h09.csv
# ./Temp/v5/vacsi-a-dep-2021-05-04-19h09-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (149248, 9)
#        dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 19544   15           39 2021-03-25       17          1          615
# 146118  69            0 2021-03-07      632          5        94680
# 109410  82           59 2021-04-04       33          1         4208
#
#         n_cum_complet  couv_dose1  couv_complet
# 19544             185         4.4           1.3
# 146118          49316         5.0           2.6
# 109410           1556        11.9           4.4

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (59392, 9)
#           entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 47455         92       whole 2021-03-24     6289        487       141109
# 30793         60       30-59 2021-01-14      324          0         1362
# 55977  Normandie       30-59 2021-02-07      191        495        29532
#
#        n_cum_complet  couv_dose1  couv_complet
# 47455          45258         8.7           2.8
# 30793              0         1.2           0.0
# 55977          11298        35.5          12.5

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (59392, 11)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 20570     40         60+ 2021-01-18      308          0         1865
# 43201     84       30-59 2021-02-13        4         57         4112
# 16670     32         60+ 2021-03-08      173        261        12706
#
#        n_cum_complet  couv_dose1  couv_complet  taux dose 1  taux complet
# 20570              3         6.6           0.0     1.369823      0.002203
# 43201           1856         5.6           2.5     1.947256      0.878917
# 16670           6706        94.7          49.6    18.545115      9.787781

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 8.61005687713623  s

# %% [markdown]
# # Données hospitalières (3) Estimation par classe d'âge et par département

# %% [markdown]
# ## dfs pops et pops_prop

# %% [markdown]
# ### df dpops

# %%
fname = dp.retrieve_temp('sp-pos-quot-dep', 'tot-3C-compute')
dtes = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v5/sp-pos-quot-dep-2021-05-04-19h08-tot-3C-compute.csv

# %%
columns = pd.Index(dtes.three_class.unique(), name = 'clage')
index = pd.Index(dtes.entity.unique(), name = 'entity')
dpops = pd.DataFrame(index = index, columns = columns)
dpops.sample()
# Out:
# clage                      0-29 30-59  60+ whole
# entity
# Provence-Alpes-Côte d'Azur  NaN   NaN  NaN   NaN

# %%
for entity in dtes.entity.unique():
    for clage in dtes.three_class.unique():
        dpops.loc[entity, clage] = dtes[(dtes.entity == entity) & (dtes.three_class == clage) & (dtes.jour == '2021-01-01')]["pop"].values[0]

# %%
dpops.sample()
# Out:
# clage       0-29     30-59       60+      whole
# entity
# 78      543417.0  578277.0  326931.0  1448625.0

# %%
dpops.shape
dpops.loc['France', :]
dpops.loc['France','60+']
# Out:
# (116, 4)
# clage
# 0-29     23555651.0
# 30-59    25657812.0
# 60+      17850240.0
# whole    67063703.0
# Name: France, dtype: object
# 17850240.0

# %%
dout = dpops
fname = path_temp + '-pops.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ./Temp/v5/vacsi-a-dep-2021-05-04-19h09-pops.csv

# %% [markdown]
# ### df dpops_prop

# %%
dpops_prop = dpops.divide(dpops.whole, axis = 'index')
dpops_prop
# Out:
# clage                           0-29     30-59       60+ whole
# entity
# 01                          0.354913  0.403463  0.241624   1.0
# 02                          0.344635   0.37594  0.279426   1.0
# 03                          0.286133  0.358127   0.35574   1.0
# 04                          0.287838  0.369062  0.343099   1.0
# 05                          0.296248   0.37973  0.324022   1.0
# ...                              ...       ...       ...   ...
# Occitanie                   0.330174  0.374871  0.294955   1.0
# Outre-mer (DROM)            0.432203  0.375058  0.192739   1.0
# Pays de la Loire            0.350137  0.375243   0.27462   1.0
# Provence-Alpes-Côte d'Azur  0.324136  0.377594   0.29827   1.0
# Île-de-France               0.390357  0.404643     0.205   1.0
#
# [116 rows x 4 columns]

# %% [markdown]
# ## taux hosp

# %% [markdown]
# ### empty df dhosps

# %%
fname = dp.retrieve_temp('donnees-hospitalieres-classe-age-covid19', '3C-compute')
dhos = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
fname = dp.retrieve_temp('donnees-hospitalieres-covid19', 'compute')
dhosdep = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-05-04-19h05-3C-compute.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-05-04-19h05-compute.csv

# %%
columns = pd.MultiIndex.from_tuples([(i, j) for i in dpops.index.unique() for j in dtes.three_class.unique()],
                       name = ['entity', 'clage'])
index = pd.Index(dhos.jour.unique(), name = "jour")
dhosps = pd.DataFrame(index = index, columns = columns)
dhosps.shape
dhosps.sample()
# Out:
# (413, 464)
# entity       01                    02                    03        ...  \
# clage      0-29 30-59  60+ whole 0-29 30-59  60+ whole 0-29 30-59  ...
# jour                                                               ...
# 2020-05-22  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire       Provence-Alpes-Côte d'Azur                   \
# clage                   60+ whole                       0-29 30-59  60+ whole
# jour
# 2020-05-22              NaN   NaN                        NaN   NaN  NaN   NaN
#
# entity     Île-de-France
# clage               0-29 30-59  60+ whole
# jour
# 2020-05-22           NaN   NaN  NaN   NaN
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (1) fill it with data for each (entity = dc.regs, clage)

# %%
dhos.sample()
# Out:
#          entity three_class       jour  hosp  rea   dc  dc hebdo  taux hosp  \
# 9705  Grand Est       30-59 2021-03-14   298   85  338      14.0  14.027873
#
#       taux rea  taux décès
# 9705  4.001239    0.659028

# %%
dhos = dhos.set_index(dhos.jour)
dhos.sample()
# Out:
#                           entity three_class       jour  hosp  rea  dc  \
# jour
# 2020-09-10  Auvergne-Rhône-Alpes       30-59 2020-09-10    83   14  62
#
#             dc hebdo  taux hosp  taux rea  taux décès
# jour
# 2020-09-10       0.0   2.689917  0.453721         0.0

# %%
for entity, clage in dhosps.columns:
    dhosps.loc[:,(entity,clage)] = dhos[(dhos.entity == entity) & (dhos.three_class == clage)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                   02                   03        ...  \
# clage      0-29 30-59 60+ whole 0-29 30-59 60+ whole 0-29 30-59  ...
# jour                                                             ...
# 2021-03-23  NaN   NaN NaN   NaN  NaN   NaN NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire            Provence-Alpes-Côte d'Azur             \
# clage                   60+      whole                       0-29      30-59
# jour
# 2021-03-23        68.483245  21.910691                   2.440928  26.820592
#
# entity                           Île-de-France                         \
# clage             60+      whole          0-29      30-59         60+
# jour
# 2021-03-23  168.44071  61.574662       3.02532  29.587615  195.905258
#
# entity
# clage           whole
# jour
# 2021-03-23  53.965521
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (2) fill it with data for each (entity = dc.deps, clage = ['whole'])

# %%
dhosdep.sample()
dhosdep = dhosdep.set_index(dhosdep.jour)
dhosdep.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 18916     45 2021-02-12   319   51       NaN       NaN     NaN  1831  372
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 18916      33.0  46.713233   7.46826    4.832403
#            entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad  \
# jour
# 2021-01-28     95 2021-01-28   474   39       NaN       NaN     NaN  5426
#
#               dc  dc hebdo  taux hosp  taux rea  taux décès
# jour
# 2021-01-28  1300      24.0  37.969999  3.124114    1.922532

# %%
for entity in dhosdep.entity.unique():
    for clage in ['whole']:
        dhosps.loc[:,(entity, clage)] = dhosdep[(dhosdep.entity == entity)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                       02                       03        ...  \
# clage      0-29 30-59 60+     whole 0-29 30-59 60+     whole 0-29 30-59  ...
# jour                                                                     ...
# 2020-10-14  NaN   NaN NaN  6.697567  NaN   NaN NaN  11.40576  NaN   NaN  ...
#
# entity     Pays de la Loire           Provence-Alpes-Côte d'Azur            \
# clage                   60+     whole                       0-29     30-59
# jour
# 2020-10-14        18.773029  6.049771                   0.671255  7.438523
#
# entity                           Île-de-France                        \
# clage             60+      whole          0-29      30-59        60+
# jour
# 2020-10-14  52.985877  18.909533      1.230992  12.257726  81.047805
#
# entity
# clage           whole
# jour
# 2020-10-14  22.226367
#
# [1 rows x 464 columns]

# %%
dhosps['01', 'whole']
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-30    29.530181
# 2021-05-01    28.008007
# 2021-05-02    27.551354
# 2021-05-03    28.769094
# 2021-05-04    25.572528
# Name: (01, whole), Length: 413, dtype: float64

# %%
dhosps.loc[:,('01', 'whole')]
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-30    29.530181
# 2021-05-01    28.008007
# 2021-05-02    27.551354
# 2021-05-03    28.769094
# 2021-05-04    25.572528
# Name: (01, whole), Length: 413, dtype: float64

# %% [markdown]
# ### (3) estimate data for missing (entity = dc.deps, clage = ['0-29', '30-59', '60+'])

# %% [markdown]
# La proportion observée au niveau régional pour la classe d'âge considérée par rapport à l'ensemble de la population est appliquée au taux départemental :
# Taux (département, classe d'âge) = taux (département) * taux (région, classe d'âge) / taux (région)

# %%
for entity in dc.deps:
    for clage in ['0-29', '30-59', '60+']:
        dhosps.loc[:,(entity, clage)] = (
            dhosps.loc[:,(entity, 'whole')]
            * dhosps.loc[:,(dc.dep2reg[entity], clage)]
            / dhosps.loc[:,(dc.dep2reg[entity], 'whole')]
#             * dpops_prop.loc[entity, clage]
#             / dpops_prop.loc[dc.dep2reg[entity], clage]
        )

# %%
dhosps.loc[:,('Auvergne-Rhône-Alpes', '0-29')]
# Out:
# jour
# 2020-03-18    0.141085
# 2020-03-19    0.176356
# 2020-03-20    0.141085
# 2020-03-21    0.246899
# 2020-03-22    0.387984
#                 ...
# 2021-04-30    2.045732
# 2021-05-01    1.728291
# 2021-05-02    1.728291
# 2021-05-03    1.763562
# 2021-05-04    1.693020
# Name: (Auvergne-Rhône-Alpes, 0-29), Length: 413, dtype: float64

# %% [markdown]
# ## Fonction

# %%
# def estimate_deps(din, dindep, column):
#     columns = pd.MultiIndex.from_tuples([(i, j) for i in dtes.entity.unique() for j in dtes.three_class.unique()],
#                        name = ['entity', 'clage'])
#     index = pd.Index(din.jour.unique(), name = "jour")
#     dout = pd.DataFrame(index = index, columns = columns)

#     din = din.copy().set_index(din.jour)
#     for entity, clage in dout.columns:
#         dout.loc[:,(entity,clage)] = din[(din.entity == entity) & (din.three_class == clage)][column]

#     dindep = dindep.copy().set_index(dindep.jour)
#     for entity in dindep.entity.unique():
#         for clage in ['whole']:
#             dout.loc[:,(entity, clage)] = dindep[(dindep.entity == entity)][column]

#     for entity in dc.deps:
#         for clage in ['0-29', '30-59', '60+']:
#             dout.loc[:,(entity, clage)] = (
#                 dout.loc[:,(entity, 'whole')]
#                 * dout.loc[:,(dc.dep2reg[entity], clage)]
#                 / dout.loc[:,(dc.dep2reg[entity], 'whole')]
#             )
#     dout = pd.melt(dout.T.reset_index(), id_vars = ['entity', 'clage'], value_name = column)
#     return dout

# %%
# d1 = estimate_deps(dhos, dhosdep, "taux hosp")

# d2 = estimate_deps(dhos, dhosdep, "taux rea")

# d3 = estimate_deps(dhos, dhosdep, "taux décès")

# dout = pd.merge(pd.merge(d1,d2), d3)
# fname = path_temp + '-estimates-hosp.csv'
# dout.to_csv(fname, sep = ';', index = False)
# print(fname)

# %%
# dout
