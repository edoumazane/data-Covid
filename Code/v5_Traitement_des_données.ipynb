# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 02/05/2021. Retrieve data from how many days? 0
# Ok, will retrieve data from 02/05/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-05-02-19h09.csv
# ./Temp/v5/sp-pos-quot-dep-2021-05-02-19h09-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour   P    T  cl_age90       pop
# 276608  71 2020-10-14  37  308        29   45987.0
# 323613  83 2020-12-02  25  443        49  131324.0
# 345312  89 2020-07-16   1   25         9   35145.0
# (402688, 6)
#        entity three_class       jour  P    T       pop
# 65250      46         60+ 2020-09-10  2  109   67407.0
# 136722    972         60+ 2020-06-18  1   53  110330.0
# 59412      42        0-29 2020-07-21  1  279  266546.0
# (163328, 6)
#        entity three_class       jour    P      T        pop  P hebdo  T hebdo  \
# 20720      15        0-29 2021-01-20   15    209    37394.0     59.0   1195.0
# 103968     73        0-29 2021-03-05   69    831   142034.0    245.0   4078.0
# 83615      59       whole 2020-09-25  887  11958  2588988.0   5393.0  69340.0
#
#         incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 20720        157.779323                4.937238          3195.699845
# 103968       172.493910                6.007847          2871.143529
# 83615        208.305330                7.777618          2678.266566
# (163328, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-05-02-19h09.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-05-02-19h09-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (81378, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 57764 2021-01-03    10    1       NaN       NaN     NaN   229    2
# 41379 2020-10-12    12    3       NaN       NaN     NaN    71   16
# 17886 2020-06-16   502   30       NaN       NaN     NaN  1861  528
#
#                     entity three_class
# 57764   Nouvelle-Aquitaine        0-29
# 41379                Corse         60+
# 17886  Centre-Val de Loire       whole
# 'd_hosp_2: '
# (24660, 6)
#                      entity three_class       jour  hosp   rea   dc
# 23197                France       30-59 2020-05-02  3942  1095  957
# 1104   Auvergne-Rhône-Alpes        0-29 2020-12-19    35     2    4
# 14416    Nouvelle-Aquitaine        0-29 2021-01-28    22     3    2
# 'd_hosp_3: '
# (24660, 10)
#                     entity three_class       jour  hosp  rea  dc  dc hebdo  \
# 5145   Centre-Val de Loire       30-59 2020-05-10    67   17  16       0.0
# 18685     Pays de la Loire       30-59 2020-08-15    17    5  17       0.0
# 4297              Bretagne       30-59 2020-11-25    54   11  17       1.0
#
#        taux hosp  taux rea  taux décès
# 5145    7.026611  1.782871    0.000000
# 18685   1.191647  0.350484    0.000000
# 4297    4.336695  0.883401    0.080309

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-05-02-19h09.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-05-02-19h09-compute.csv

# %%
dout.sample()
# Out:
#     entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 983     03 2020-08-26     5    0       NaN       NaN     NaN  206  41
#
#      dc hebdo  taux hosp  taux rea  taux décès
# 983       0.0   1.509138       0.0         0.0

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 124528  974     1 2021-05-02    87   23      49.0      15.0     0.0   752   93
# 124529  974     2 2021-05-02    71   15      45.0      11.0     0.0   709   68
# 124530  976     0 2021-05-02    12    4       8.0       0.0     0.0  1241  126
# 124531  976     1 2021-05-02     8    2       6.0       0.0     0.0   563   74
# 124532  976     2 2021-05-02     4    2       2.0       0.0     0.0   658   51
#
# [124533 rows x 10 columns]
# (124533, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 41506    976 2021-04-28    22    6      16.0       0.0     0.0  1230  125
# 41507    976 2021-04-29    22    6      16.0       0.0     0.0  1230  125
# 41508    976 2021-04-30    12    3       9.0       0.0     0.0  1241  126
# 41509    976 2021-05-01    12    4       8.0       0.0     0.0  1241  126
# 41510    976 2021-05-02    12    4       8.0       0.0     0.0  1241  126
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 41506       1.0   7.872015  2.146913    0.357819
# 41507       1.0   7.872015  2.146913    0.357819
# 41508       2.0   4.293827  1.073457    0.715638
# 41509       2.0   4.293827  1.431276    0.715638
# 41510       2.0   4.293827  1.431276    0.715638
#
# [41511 rows x 13 columns]
# (41511, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[d_vac_1.dep != '20']
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-05-02-19h10.csv
# ./Temp/v5/vacsi-a-dep-2021-05-02-19h10-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (146916, 9)
#        dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 138339  27            0 2021-04-23     2427       1092       109673
# 74944   57           59 2021-04-06      356        203        28095
# 137817  23            0 2021-04-05        0          0        21243
#
#         n_cum_complet  couv_dose1  couv_complet
# 138339          47430        18.3           7.9
# 74944            8890        19.1           6.0
# 137817           9552        18.3           8.2

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (58464, 9)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 14149     2A       30-59 2021-01-05        0          0            0
# 9123      19       whole 2021-01-08      247          0          589
# 1577      04       30-59 2021-01-12      119          0          211
#
#        n_cum_complet  couv_dose1  couv_complet
# 14149              0         0.0           0.0
# 9123               0         0.2           0.0
# 1577               0         0.9           0.0

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (58464, 11)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 11818     25         60+ 2021-02-21        0        134        21441
# 28986     57         60+ 2021-03-01     1518       1135        45610
# 14010     29         60+ 2021-04-06     2532       1080       106318
#
#        n_cum_complet  couv_dose1  couv_complet  taux dose 1  taux complet
# 11818           9808        83.5          37.6    15.180221      6.944061
# 28986          16797        89.0          32.2    16.077182      5.920816
# 14010          39008       202.2          75.3    38.236045     14.028778

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 8.634024143218994  s

# %% [markdown]
# # Données hospitalières (3) Estimation par classe d'âge et par département

# %% [markdown]
# ## dfs pops et pops_prop

# %% [markdown]
# ### df dpops

# %%
fname = dp.retrieve_temp('sp-pos-quot-dep', 'tot-3C-compute')
dtes = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v5/sp-pos-quot-dep-2021-05-02-19h09-tot-3C-compute.csv

# %%
columns = pd.Index(dtes.three_class.unique(), name = 'clage')
index = pd.Index(dtes.entity.unique(), name = 'entity')
dpops = pd.DataFrame(index = index, columns = columns)
dpops.sample()
# Out:
# clage  0-29 30-59  60+ whole
# entity
# 88      NaN   NaN  NaN   NaN

# %%
for entity in dtes.entity.unique():
    for clage in dtes.three_class.unique():
        dpops.loc[entity, clage] = dtes[(dtes.entity == entity) & (dtes.three_class == clage) & (dtes.jour == '2021-01-01')]["pop"].values[0]

# %%
dpops.sample()
# Out:
# clage       0-29     30-59       60+      whole
# entity
# 31      539419.0  553435.0  308081.0  1400935.0

# %%
dpops.shape
dpops.loc['France', :]
dpops.loc['France','60+']
# Out:
# (116, 4)
# clage
# 0-29     23555651.0
# 30-59    25657812.0
# 60+      17850240.0
# whole    67063703.0
# Name: France, dtype: object
# 17850240.0

# %%
dout = dpops
fname = path_temp + '-pops.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ./Temp/v5/vacsi-a-dep-2021-05-02-19h10-pops.csv

# %% [markdown]
# ### df dpops_prop

# %%
dpops_prop = dpops.divide(dpops.whole, axis = 'index')
dpops_prop
# Out:
# clage                           0-29     30-59       60+ whole
# entity
# 01                          0.354913  0.403463  0.241624   1.0
# 02                          0.344635   0.37594  0.279426   1.0
# 03                          0.286133  0.358127   0.35574   1.0
# 04                          0.287838  0.369062  0.343099   1.0
# 05                          0.296248   0.37973  0.324022   1.0
# ...                              ...       ...       ...   ...
# Occitanie                   0.330174  0.374871  0.294955   1.0
# Outre-mer (DROM)            0.432203  0.375058  0.192739   1.0
# Pays de la Loire            0.350137  0.375243   0.27462   1.0
# Provence-Alpes-Côte d'Azur  0.324136  0.377594   0.29827   1.0
# Île-de-France               0.390357  0.404643     0.205   1.0
#
# [116 rows x 4 columns]

# %% [markdown]
# ## taux hosp

# %% [markdown]
# ### empty df dhosps

# %%
fname = dp.retrieve_temp('donnees-hospitalieres-classe-age-covid19', '3C-compute')
dhos = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
fname = dp.retrieve_temp('donnees-hospitalieres-covid19', 'compute')
dhosdep = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-05-02-19h09-3C-compute.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-05-02-19h09-compute.csv

# %%
columns = pd.MultiIndex.from_tuples([(i, j) for i in dpops.index.unique() for j in dtes.three_class.unique()],
                       name = ['entity', 'clage'])
index = pd.Index(dhos.jour.unique(), name = "jour")
dhosps = pd.DataFrame(index = index, columns = columns)
dhosps.shape
dhosps.sample()
# Out:
# (411, 464)
# entity       01                    02                    03        ...  \
# clage      0-29 30-59  60+ whole 0-29 30-59  60+ whole 0-29 30-59  ...
# jour                                                               ...
# 2021-01-05  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire       Provence-Alpes-Côte d'Azur                   \
# clage                   60+ whole                       0-29 30-59  60+ whole
# jour
# 2021-01-05              NaN   NaN                        NaN   NaN  NaN   NaN
#
# entity     Île-de-France
# clage               0-29 30-59  60+ whole
# jour
# 2021-01-05           NaN   NaN  NaN   NaN
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (1) fill it with data for each (entity = dc.regs, clage)

# %%
dhos.sample()
# Out:
#                  entity three_class       jour  hosp  rea  dc  dc hebdo  \
# 16898  Outre-mer (DROM)         60+ 2020-07-10   109   26  69       7.0
#
#        taux hosp  taux rea  taux décès
# 16898  25.661127  6.121003    1.647962

# %%
dhos = dhos.set_index(dhos.jour)
dhos.sample()
# Out:
#                entity three_class       jour  hosp  rea   dc  dc hebdo  \
# jour
# 2020-03-22  Grand Est         60+ 2020-03-22  1354  280  254       NaN
#
#             taux hosp  taux rea  taux décès
# jour
# 2020-03-22  89.500897  18.50831         NaN

# %%
for entity, clage in dhosps.columns:
    dhosps.loc[:,(entity,clage)] = dhos[(dhos.entity == entity) & (dhos.three_class == clage)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                   02                   03        ...  \
# clage      0-29 30-59 60+ whole 0-29 30-59 60+ whole 0-29 30-59  ...
# jour                                                             ...
# 2021-02-18  NaN   NaN NaN   NaN  NaN   NaN NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire            Provence-Alpes-Côte d'Azur             \
# clage                   60+      whole                       0-29      30-59
# jour
# 2021-02-18        71.165106  21.621354                    1.70865  20.848819
#
# entity                            Île-de-France                         \
# clage              60+      whole          0-29      30-59         60+
# jour
# 2021-02-18  196.889948  67.548175      2.044699  16.061848  157.725385
#
# entity
# clage          whole
# jour
# 2021-02-18  40.03841
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (2) fill it with data for each (entity = dc.deps, clage = ['whole'])

# %%
dhosdep.sample()
dhosdep = dhosdep.set_index(dhosdep.jour)
dhosdep.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad    dc  \
# 34499     83 2021-04-08   572   71     308.0     174.0    19.0  4959  1231
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 34499      57.0  53.266979   6.61181    5.308073
#            entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad  \
# jour
# 2021-01-18     84 2021-01-18   291   13       NaN       NaN     NaN  1957
#
#              dc  dc hebdo  taux hosp  taux rea  taux décès
# jour
# 2021-01-18  505      29.0  51.871935  2.317303    5.169368

# %%
for entity in dhosdep.entity.unique():
    for clage in ['whole']:
        dhosps.loc[:,(entity, clage)] = dhosdep[(dhosdep.entity == entity)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                      02                        03        ...  \
# clage      0-29 30-59 60+    whole 0-29 30-59 60+      whole 0-29 30-59  ...
# jour                                                                     ...
# 2020-03-21  NaN   NaN NaN  0.60887  NaN   NaN NaN  11.595856  NaN   NaN  ...
#
# entity     Pays de la Loire           Provence-Alpes-Côte d'Azur            \
# clage                   60+     whole                       0-29     30-59
# jour
# 2020-03-21         6.608873  2.314695                   0.793302  7.228988
#
# entity                          Île-de-France
# clage             60+     whole          0-29      30-59        60+      whole
# jour
# 2020-03-21  12.069374  6.606469      0.980621  13.908192  55.462125  17.738742
#
# [1 rows x 464 columns]

# %%
dhosps['01', 'whole']
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-28    29.225746
# 2021-04-29    28.921311
# 2021-04-30    29.530181
# 2021-05-01    28.008007
# 2021-05-02    27.551354
# Name: (01, whole), Length: 411, dtype: float64

# %%
dhosps.loc[:,('01', 'whole')]
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-28    29.225746
# 2021-04-29    28.921311
# 2021-04-30    29.530181
# 2021-05-01    28.008007
# 2021-05-02    27.551354
# Name: (01, whole), Length: 411, dtype: float64

# %% [markdown]
# ### (3) estimate data for missing (entity = dc.deps, clage = ['0-29', '30-59', '60+'])

# %% [markdown]
# La proportion observée au niveau régional pour la classe d'âge considérée par rapport à l'ensemble de la population est appliquée au taux départemental :
# Taux (département, classe d'âge) = taux (département) * taux (région, classe d'âge) / taux (région)

# %%
for entity in dc.deps:
    for clage in ['0-29', '30-59', '60+']:
        dhosps.loc[:,(entity, clage)] = (
            dhosps.loc[:,(entity, 'whole')]
            * dhosps.loc[:,(dc.dep2reg[entity], clage)]
            / dhosps.loc[:,(dc.dep2reg[entity], 'whole')]
#             * dpops_prop.loc[entity, clage]
#             / dpops_prop.loc[dc.dep2reg[entity], clage]
        )

# %%
dhosps.loc[:,('Auvergne-Rhône-Alpes', '0-29')]
# Out:
# jour
# 2020-03-18    0.141085
# 2020-03-19    0.176356
# 2020-03-20    0.141085
# 2020-03-21    0.246899
# 2020-03-22    0.387984
#                 ...
# 2021-04-28    1.657748
# 2021-04-29    2.010461
# 2021-04-30    2.045732
# 2021-05-01    1.728291
# 2021-05-02    1.728291
# Name: (Auvergne-Rhône-Alpes, 0-29), Length: 411, dtype: float64

# %% [markdown]
# ## Fonction

# %%
# def estimate_deps(din, dindep, column):
#     columns = pd.MultiIndex.from_tuples([(i, j) for i in dtes.entity.unique() for j in dtes.three_class.unique()],
#                        name = ['entity', 'clage'])
#     index = pd.Index(din.jour.unique(), name = "jour")
#     dout = pd.DataFrame(index = index, columns = columns)

#     din = din.copy().set_index(din.jour)
#     for entity, clage in dout.columns:
#         dout.loc[:,(entity,clage)] = din[(din.entity == entity) & (din.three_class == clage)][column]

#     dindep = dindep.copy().set_index(dindep.jour)
#     for entity in dindep.entity.unique():
#         for clage in ['whole']:
#             dout.loc[:,(entity, clage)] = dindep[(dindep.entity == entity)][column]

#     for entity in dc.deps:
#         for clage in ['0-29', '30-59', '60+']:
#             dout.loc[:,(entity, clage)] = (
#                 dout.loc[:,(entity, 'whole')]
#                 * dout.loc[:,(dc.dep2reg[entity], clage)]
#                 / dout.loc[:,(dc.dep2reg[entity], 'whole')]
#             )
#     dout = pd.melt(dout.T.reset_index(), id_vars = ['entity', 'clage'], value_name = column)
#     return dout

# %%
# d1 = estimate_deps(dhos, dhosdep, "taux hosp")

# d2 = estimate_deps(dhos, dhosdep, "taux rea")

# d3 = estimate_deps(dhos, dhosdep, "taux décès")

# dout = pd.merge(pd.merge(d1,d2), d3)
# fname = path_temp + '-estimates-hosp.csv'
# dout.to_csv(fname, sep = ';', index = False)
# print(fname)

# %%
# dout
