# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 09/05/2021. Retrieve data from how many days?
# Ok, will retrieve data from 08/05/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-05-08-19h08.csv
# ./Temp/v5/sp-pos-quot-dep-2021-05-08-19h08-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour   P    T  cl_age90      pop
# 54071   14 2021-01-29  18  376        69  91001.0
# 95940   26 2020-09-19   0    2        90   7457.0
# 185707  47 2020-07-08   0    9        59  45512.0
# (409552, 6)
#        entity three_class       jour  P    T       pop
# 7273       06       30-59 2020-06-10  3  265  409246.0
# 96038      67         60+ 2020-06-05  0  454  288451.0
# 128899     90       whole 2020-05-17  0   28  140145.0
# (166112, 6)
#                entity three_class       jour    P     T        pop  P hebdo  \
# 165012  Île-de-France        0-29 2020-08-04  310  8380  4792882.0   1459.0
# 61160              42        0-29 2021-01-22  105  1373   266546.0    666.0
# 44634              31         60+ 2020-07-12    1    32   308081.0      4.0
#
#         T hebdo  incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 165012  48203.0        30.440975                3.026783          1005.720566
# 61160    7213.0       249.863063                9.233329          2706.099510
# 44634    1212.0         1.298360                0.330033           393.403034
# (166112, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-05-08-19h09.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-05-08-19h09-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (82566, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 60765 2021-01-18     2    0       NaN       NaN     NaN  177   0
# 64357 2021-02-06     7    2       NaN       NaN     NaN  188  44
# 56625 2020-12-28     3    1       NaN       NaN     NaN  108  28
#
#                            entity three_class
# 60765  Provence-Alpes-Côte d'Azur        0-29
# 64357            Outre-mer (DROM)         60+
# 56625                       Corse         60+
# 'd_hosp_2: '
# (25020, 6)
#                         entity three_class       jour  hosp  rea    dc
# 17160         Outre-mer (DROM)        0-29 2020-07-16    31    1     1
# 9260                 Grand Est        0-29 2020-11-03    19    1     3
# 2759   Bourgogne-Franche-Comté       whole 2020-12-15  1807  186  2267
# 'd_hosp_3: '
# (25020, 10)
#                  entity three_class       jour  hosp  rea    dc  dc hebdo  \
# 18944  Pays de la Loire        0-29 2020-08-14     1    0     0       0.0
# 19767  Pays de la Loire       whole 2021-03-07   777   76  2071      59.0
# 13132         Normandie        0-29 2021-03-17    16    5     0       0.0
#
#        taux hosp  taux rea  taux décès
# 18944   0.075123  0.000000    0.000000
# 19767  20.437704  1.999055    1.551898
# 13132   1.424418  0.445131    0.000000

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-05-08-19h09.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-05-08-19h09-compute.csv

# %%
dout.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad   dc  \
# 17606     42 2020-06-18   106    7       NaN       NaN     NaN  934  245
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 17606       1.0  13.860974  0.915347    0.130764

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 126346  974     1 2021-05-08    80   22      41.0      17.0     0.0   784  102
# 126347  974     2 2021-05-08    69   14      44.0      11.0     0.0   737   71
# 126348  976     0 2021-05-08    14    7       7.0       0.0     0.0  1252  127
# 126349  976     1 2021-05-08     7    3       4.0       0.0     0.0   568   74
# 126350  976     2 2021-05-08     6    4       2.0       0.0     0.0   664   52
#
# [126351 rows x 10 columns]
# (126351, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 42112    976 2021-05-04    11    4       7.0       0.0     0.0  1246  126
# 42113    976 2021-05-05    11    4       7.0       0.0     0.0  1248  126
# 42114    976 2021-05-06    11    4       7.0       0.0     0.0  1251  126
# 42115    976 2021-05-07    10    4       6.0       0.0     0.0  1252  127
# 42116    976 2021-05-08    14    7       7.0       0.0     0.0  1252  127
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 42112       1.0   3.936008  1.431276    0.357819
# 42113       1.0   3.936008  1.431276    0.357819
# 42114       1.0   3.936008  1.431276    0.357819
# 42115       1.0   3.578189  1.431276    0.357819
# 42116       1.0   5.009464  2.504732    0.357819
#
# [42117 rows x 13 columns]
# (42117, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[d_vac_1.dep != '20']
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-05-08-19h05.csv
# ./Temp/v5/vacsi-a-dep-2021-05-08-19h05-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (153912, 9)
#       dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 66205  49           29 2021-03-10       43         11         1033
# 45103  33           29 2021-03-28       33          0         3298
# 53167  39           39 2021-04-09       40         12         1196
#
#        n_cum_complet  couv_dose1  couv_complet
# 66205            150         2.6           0.4
# 45103            696         3.4           0.7
# 53167            664         4.2           2.3

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (61248, 9)
#                            entity three_class       jour  n_dose1  n_complet  \
# 8875                           17       whole 2021-04-12     2870       1593
# 6019                           12       whole 2021-02-17      357       1425
# 60546  Provence-Alpes-Côte d'Azur         60+ 2021-03-25    23011       5627
#
#        n_cum_dose1  n_cum_complet  couv_dose1  couv_complet
# 8875        136793          50714        21.1           7.8
# 6019         17535           5827         6.3           2.1
# 60546       499537         178058      1009.9         381.8

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (61248, 11)
#        entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 56406  France         60+ 2021-04-15   223936     130919      8959189
# 17312      32        0-29 2021-04-10        1          0          620
# 6779       13       whole 2021-04-16     9861       5450       397165
#
#        n_cum_complet  couv_dose1  couv_complet  taux dose 1  taux complet
# 56406        3553573     25839.9       10759.4    50.170222     19.899518
# 17312            244         7.5           3.0     1.204304      0.473952
# 6779          155966        19.5           7.7    19.521802      7.666177

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 6.9410552978515625  s
