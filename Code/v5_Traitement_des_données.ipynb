# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 27/04/2021. Retrieve data from how many days? 0
# Ok, will retrieve data from 27/04/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-04-27-19h10.csv
# ./Temp/v5/sp-pos-quot-dep-2021-04-27-19h10-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour   P    T  cl_age90       pop
# 188910  49 2020-10-30  45  329        79   67943.0
# 363105  95 2020-06-26   2  130        69  121128.0
# 217479  56 2021-04-16   7  122        90   12010.0
# (396968, 6)
#            entity three_class       jour    P     T        pop
# 148698  Grand Est         60+ 2020-06-27    7  1620  1512834.0
# 116014         83         60+ 2020-12-01   58  1374   357417.0
# 63671          45       whole 2021-03-11  209  2678   682890.0
# (161008, 6)
#                entity three_class       jour     P      T        pop  P hebdo  \
# 160938  Île-de-France         60+ 2021-04-07  1668  16615  2517033.0   8921.0
# 116272             83        0-29 2021-02-04   147   2363   319301.0    912.0
# 48590              35         60+ 2020-05-15     5    161   258341.0      0.0
#
#         T hebdo  incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 160938  90604.0        354.42523                9.846144          3599.634967
# 116272  13397.0        285.62391                6.807494          4195.727542
# 48590       0.0          0.00000                     NaN             0.000000
# (161008, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-04-27-19h05.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-04-27-19h05-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (80388, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres   rad    dc  \
# 40550 2020-10-08     8    1       NaN       NaN     NaN   226     2
# 80110 2021-04-26   661  169     371.0     114.0     7.0  7127  2220
# 15792 2020-06-05    38   11       NaN       NaN     NaN   377    39
#
#                    entity three_class
# 40550           Occitanie       30-59
# 80110           Grand Est         60+
# 15792  Nouvelle-Aquitaine         60+
# 'd_hosp_2: '
# (24360, 6)
#                         entity three_class       jour  hosp  rea   dc
# 2557   Bourgogne-Franche-Comté       30-59 2020-11-06   164   23   43
# 4106                  Bretagne         60+ 2020-10-18   167   24  294
# 14836                Occitanie        0-29 2020-05-12     3    0    1
# 'd_hosp_3: '
# (24360, 10)
#                    entity three_class       jour  hosp  rea    dc  dc hebdo  \
# 6103  Centre-Val de Loire       whole 2021-01-19   989  113  1513      84.0
# 8027                Corse       whole 2021-04-04    92   16   171       6.0
# 8736            Grand Est        0-29 2020-08-19     9    0     3       0.0
#
#       taux hosp  taux rea  taux décès
# 6103  38.646807  4.415661    3.282439
# 8027  26.691501  4.642000    1.740750
# 8736   0.480110  0.000000    0.000000

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-04-27-19h05.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-04-27-19h05-compute.csv

# %%
dout.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 36906     90 2021-03-19    67   12      40.0      15.0     0.0  1651  515
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 36906       8.0  47.807628   8.56256    5.708373

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 123013  974     1 2021-04-27    96   28      53.0      15.0     0.0   719   90
# 123014  974     2 2021-04-27    59   14      35.0      10.0     0.0   693   66
# 123015  976     0 2021-04-27    21    6      15.0       0.0     0.0  1228  125
# 123016  976     1 2021-04-27     6    2       4.0       0.0     0.0   560   74
# 123017  976     2 2021-04-27    14    4      10.0       0.0     0.0   649   50
#
# [123018 rows x 10 columns]
# (123018, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 41001    976 2021-04-23    18    5      13.0       0.0     0.0  1228  124
# 41002    976 2021-04-24    18    5      13.0       0.0     0.0  1228  124
# 41003    976 2021-04-25    18    5      13.0       0.0     0.0  1228  124
# 41004    976 2021-04-26    20    6      14.0       0.0     0.0  1228  125
# 41005    976 2021-04-27    21    6      15.0       0.0     0.0  1228  125
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 41001       0.0   6.440740  1.789094    0.000000
# 41002       0.0   6.440740  1.789094    0.000000
# 41003       0.0   6.440740  1.789094    0.000000
# 41004       1.0   7.156378  2.146913    0.357819
# 41005       1.0   7.514196  2.146913    0.357819
#
# [41006 rows x 13 columns]
# (41006, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[d_vac_1.dep != '20']
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-04-27-19h05.csv
# ./Temp/v5/vacsi-a-dep-2021-04-27-19h05-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (141086, 9)
#         dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 4552     03           74 2021-03-12      256         99         3194
# 111985   89           64 2021-02-25       62         21          823
# 128264  978           24 2020-12-31        0          0            0
#
#         n_cum_complet  couv_dose1  couv_complet
# 4552             1300        13.8           5.6
# 111985            551         3.5           2.3
# 128264              0         0.0           0.0

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (56144, 9)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 45294     93         60+ 2021-03-07     3221         10        45905
# 6145      13       30-59 2021-03-21      108          9        42523
# 44654     92         60+ 2021-01-27     1878         65        15789
#
#        n_cum_complet  couv_dose1  couv_complet
# 45294          21250        98.6          46.5
# 6145           18704        16.2           7.2
# 44654            186        24.3           0.2

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (56144, 11)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 37440     77        0-29 2021-02-08        7         46          503
# 7120      15        0-29 2021-03-23       13          1          267
# 40534     83         60+ 2021-03-27     3421        322       108457
#
#        n_cum_complet  couv_dose1  couv_complet  taux dose 1  taux complet
# 37440            164         0.5           0.1     0.090248      0.029425
# 7120              66         4.3           1.1     0.714018      0.176499
# 40534          37403       154.5          53.5    30.344667     10.464807

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 29.451637983322144  s

# %% [markdown]
# # Données hospitalières (3) Estimation par classe d'âge et par département

# %% [markdown]
# ## dfs pops et pops_prop

# %% [markdown]
# ### df dpops

# %%
fname = dp.retrieve_temp('sp-pos-quot-dep', 'tot-3C-compute')
dtes = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v5/sp-pos-quot-dep-2021-04-27-19h10-tot-3C-compute.csv

# %%
columns = pd.Index(dtes.three_class.unique(), name = 'clage')
index = pd.Index(dtes.entity.unique(), name = 'entity')
dpops = pd.DataFrame(index = index, columns = columns)
dpops.sample()
# Out:
# clage  0-29 30-59  60+ whole
# entity
# 85      NaN   NaN  NaN   NaN

# %%
for entity in dtes.entity.unique():
    for clage in dtes.three_class.unique():
        dpops.loc[entity, clage] = dtes[(dtes.entity == entity) & (dtes.three_class == clage) & (dtes.jour == '2021-01-01')]["pop"].values[0]

# %%
dpops.sample()
# Out:
# clage      0-29    30-59      60+     whole
# entity
# 05      41995.0  53829.0  45932.0  141756.0

# %%
dpops.shape
dpops.loc['France', :]
dpops.loc['France','60+']
# Out:
# (116, 4)
# clage
# 0-29     23555651.0
# 30-59    25657812.0
# 60+      17850240.0
# whole    67063703.0
# Name: France, dtype: object
# 17850240.0

# %%
dout = dpops
fname = path_temp + '-pops.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ./Temp/v5/vacsi-a-dep-2021-04-27-19h05-pops.csv

# %% [markdown]
# ### df dpops_prop

# %%
dpops_prop = dpops.divide(dpops.whole, axis = 'index')
dpops_prop
# Out:
# clage                           0-29     30-59       60+ whole
# entity
# 01                          0.354913  0.403463  0.241624   1.0
# 02                          0.344635   0.37594  0.279426   1.0
# 03                          0.286133  0.358127   0.35574   1.0
# 04                          0.287838  0.369062  0.343099   1.0
# 05                          0.296248   0.37973  0.324022   1.0
# ...                              ...       ...       ...   ...
# Occitanie                   0.330174  0.374871  0.294955   1.0
# Outre-mer (DROM)            0.432203  0.375058  0.192739   1.0
# Pays de la Loire            0.350137  0.375243   0.27462   1.0
# Provence-Alpes-Côte d'Azur  0.324136  0.377594   0.29827   1.0
# Île-de-France               0.390357  0.404643     0.205   1.0
#
# [116 rows x 4 columns]

# %% [markdown]
# ## taux hosp

# %% [markdown]
# ### empty df dhosps

# %%
fname = dp.retrieve_temp('donnees-hospitalieres-classe-age-covid19', '3C-compute')
dhos = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
fname = dp.retrieve_temp('donnees-hospitalieres-covid19', 'compute')
dhosdep = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-04-27-19h05-3C-compute.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-04-27-19h05-compute.csv

# %%
columns = pd.MultiIndex.from_tuples([(i, j) for i in dpops.index.unique() for j in dtes.three_class.unique()],
                       name = ['entity', 'clage'])
index = pd.Index(dhos.jour.unique(), name = "jour")
dhosps = pd.DataFrame(index = index, columns = columns)
dhosps.shape
dhosps.sample()
# Out:
# (406, 464)
# entity       01                    02                    03        ...  \
# clage      0-29 30-59  60+ whole 0-29 30-59  60+ whole 0-29 30-59  ...
# jour                                                               ...
# 2020-06-12  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire       Provence-Alpes-Côte d'Azur                   \
# clage                   60+ whole                       0-29 30-59  60+ whole
# jour
# 2020-06-12              NaN   NaN                        NaN   NaN  NaN   NaN
#
# entity     Île-de-France
# clage               0-29 30-59  60+ whole
# jour
# 2020-06-12           NaN   NaN  NaN   NaN
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (1) fill it with data for each (entity = dc.regs, clage)

# %%
dhos.sample()
# Out:
#                    entity three_class       jour  hosp  rea    dc  dc hebdo  \
# 14474  Nouvelle-Aquitaine         60+ 2021-03-23  1009  166  2972      77.0
#
#        taux hosp  taux rea  taux décès
# 14474  53.952574  8.876241    4.117293

# %%
dhos = dhos.set_index(dhos.jour)
dhos.sample()
# Out:
#                                 entity three_class       jour  hosp  rea   dc  \
# jour
# 2021-04-22  Provence-Alpes-Côte d'Azur       30-59 2021-04-22   579  156  238
#
#             dc hebdo  taux hosp  taux rea  taux décès
# jour
# 2021-04-22      12.0  30.330318  8.171899    0.628608

# %%
for entity, clage in dhosps.columns:
    dhosps.loc[:,(entity,clage)] = dhos[(dhos.entity == entity) & (dhos.three_class == clage)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                   02                   03        ...  \
# clage      0-29 30-59 60+ whole 0-29 30-59 60+ whole 0-29 30-59  ...
# jour                                                             ...
# 2021-04-18  NaN   NaN NaN   NaN  NaN   NaN NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire            Provence-Alpes-Côte d'Azur            \
# clage                   60+      whole                       0-29     30-59
# jour
# 2021-04-18        68.483245  23.331072                   2.318882  32.21614
#
# entity                           Île-de-France                         \
# clage              60+     whole          0-29      30-59         60+
# jour
# 2021-04-18  170.496482  64.30428      4.193719  40.355897  232.217853
#
# entity
# clage          whole
# jour
# 2021-04-18  66.35332
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (2) fill it with data for each (entity = dc.deps, clage = ['whole'])

# %%
dhosdep.sample()
dhosdep = dhosdep.set_index(dhosdep.jour)
dhosdep.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 36462     89 2021-02-09   180   15       NaN       NaN     NaN  1385  353
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 36462      15.0  54.201195  4.516766    4.516766
#            entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad   dc  \
# jour
# 2020-12-08     39 2020-12-08   183    8       NaN       NaN     NaN  754  172
#
#             dc hebdo  taux hosp  taux rea  taux décès
# jour
# 2020-12-08      16.0   70.97177  3.102591    6.205182

# %%
for entity in dhosdep.entity.unique():
    for clage in ['whole']:
        dhosps.loc[:,(entity, clage)] = dhosdep[(dhosdep.entity == entity)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                        02                       03        ...  \
# clage      0-29 30-59 60+      whole 0-29 30-59 60+     whole 0-29 30-59  ...
# jour                                                                      ...
# 2020-12-13  NaN   NaN NaN  50.079534  NaN   NaN NaN  43.72208  NaN   NaN  ...
#
# entity     Pays de la Loire           Provence-Alpes-Côte d'Azur             \
# clage                   60+     whole                       0-29      30-59
# jour
# 2020-12-13        82.084113  24.40951                   2.196835  10.529178
#
# entity                            Île-de-France                         \
# clage              60+      whole          0-29      30-59         60+
# jour
# 2020-12-13  138.399906  46.205721      1.877785  14.290617  163.883429
#
# entity
# clage           whole
# jour
# 2020-12-13  40.502647
#
# [1 rows x 464 columns]

# %%
dhosps['01', 'whole']
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-23    28.008007
# 2021-04-24    28.312441
# 2021-04-25    28.312441
# 2021-04-26    30.595703
# 2021-04-27    31.204573
# Name: (01, whole), Length: 406, dtype: float64

# %%
dhosps.loc[:,('01', 'whole')]
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-23    28.008007
# 2021-04-24    28.312441
# 2021-04-25    28.312441
# 2021-04-26    30.595703
# 2021-04-27    31.204573
# Name: (01, whole), Length: 406, dtype: float64

# %% [markdown]
# ### (3) estimate data for missing (entity = dc.deps, clage = ['0-29', '30-59', '60+'])

# %% [markdown]
# La proportion observée au niveau régional pour la classe d'âge considérée par rapport à l'ensemble de la population est appliquée au taux départemental :
# Taux (département, classe d'âge) = taux (département) * taux (région, classe d'âge) / taux (région)

# %%
for entity in dc.deps:
    for clage in ['0-29', '30-59', '60+']:
        dhosps.loc[:,(entity, clage)] = (
            dhosps.loc[:,(entity, 'whole')]
            * dhosps.loc[:,(dc.dep2reg[entity], clage)]
            / dhosps.loc[:,(dc.dep2reg[entity], 'whole')]
#             * dpops_prop.loc[entity, clage]
#             / dpops_prop.loc[dc.dep2reg[entity], clage]
        )

# %%
dhosps.loc[:,('Auvergne-Rhône-Alpes', '0-29')]
# Out:
# jour
# 2020-03-18    0.141085
# 2020-03-19    0.176356
# 2020-03-20    0.141085
# 2020-03-21    0.246899
# 2020-03-22    0.387984
#                 ...
# 2021-04-23    2.186817
# 2021-04-24    2.010461
# 2021-04-25    1.798833
# 2021-04-26    1.693020
# 2021-04-27    1.728291
# Name: (Auvergne-Rhône-Alpes, 0-29), Length: 406, dtype: float64

# %% [markdown]
# ## Fonction

# %%
# def estimate_deps(din, dindep, column):
#     columns = pd.MultiIndex.from_tuples([(i, j) for i in dtes.entity.unique() for j in dtes.three_class.unique()],
#                        name = ['entity', 'clage'])
#     index = pd.Index(din.jour.unique(), name = "jour")
#     dout = pd.DataFrame(index = index, columns = columns)

#     din = din.copy().set_index(din.jour)
#     for entity, clage in dout.columns:
#         dout.loc[:,(entity,clage)] = din[(din.entity == entity) & (din.three_class == clage)][column]

#     dindep = dindep.copy().set_index(dindep.jour)
#     for entity in dindep.entity.unique():
#         for clage in ['whole']:
#             dout.loc[:,(entity, clage)] = dindep[(dindep.entity == entity)][column]

#     for entity in dc.deps:
#         for clage in ['0-29', '30-59', '60+']:
#             dout.loc[:,(entity, clage)] = (
#                 dout.loc[:,(entity, 'whole')]
#                 * dout.loc[:,(dc.dep2reg[entity], clage)]
#                 / dout.loc[:,(dc.dep2reg[entity], 'whole')]
#             )
#     dout = pd.melt(dout.T.reset_index(), id_vars = ['entity', 'clage'], value_name = column)
#     return dout

# %%
# d1 = estimate_deps(dhos, dhosdep, "taux hosp")

# d2 = estimate_deps(dhos, dhosdep, "taux rea")

# d3 = estimate_deps(dhos, dhosdep, "taux décès")

# dout = pd.merge(pd.merge(d1,d2), d3)
# fname = path_temp + '-estimates-hosp.csv'
# dout.to_csv(fname, sep = ';', index = False)
# print(fname)

# %%
# dout
