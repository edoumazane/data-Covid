# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 30/04/2021. Retrieve data from how many days? 0
# Ok, will retrieve data from 30/04/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-04-30-19h05.csv
# ./Temp/v5/sp-pos-quot-dep-2021-04-30-19h05-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour    P     T  cl_age90       pop
# 22630   06 2021-03-16  119  1443        39  126997.0
# 34678   10 2020-05-15    1    21        69   38744.0
# 133104  34 2020-11-29    1    61        49  145553.0
# (400400, 6)
#        entity three_class       jour     P      T        pop
# 77011      55       whole 2020-05-15    21    312   181641.0
# 100894     72         60+ 2020-06-05     0    144   164613.0
# 18099      13       whole 2021-04-02  2192  27442  2034469.0
# (162400, 6)
#        entity three_class       jour    P     T        pop  P hebdo  T hebdo  \
# 130791     93       whole 2020-10-07  864  5765  1670149.0   4344.0  29741.0
# 51948      37        0-29 2020-06-19    0    67   207312.0      4.0    396.0
# 56447      40       whole 2020-09-01   22  1057   411979.0    113.0   5141.0
#
#         incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 130791       260.096554               14.606099          1780.739323
# 51948          1.929459                1.010101           191.016439
# 56447         27.428583                2.198016          1247.879139
# (162400, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-04-30-19h05.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-04-30-19h05-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (80982, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres   rad  dc  \
# 23197 2020-07-13    12    2       NaN       NaN     NaN    19   7
# 31215 2020-08-22    22    1       NaN       NaN     NaN   437  88
# 70999 2021-03-11    80   18       NaN       NaN     NaN  1884  68
#
#                  entity three_class
# 23197  Outre-mer (DROM)         60+
# 31215  Pays de la Loire         60+
# 70999         Grand Est       30-59
# 'd_hosp_2: '
# (24540, 6)
#                         entity three_class       jour  hosp   rea     dc
# 2325   Bourgogne-Franche-Comté       30-59 2020-09-06     6     2     37
# 22834            Île-de-France         60+ 2021-04-13  5809  1091  16228
# 18563         Pays de la Loire       whole 2020-08-06   101    12    478
# 'd_hosp_3: '
# (24540, 10)
#                            entity three_class       jour  hosp  rea    dc  \
# 10702             Hauts-de-France         60+ 2020-10-25  1472  209  2158
# 20553  Provence-Alpes-Côte d'Azur       30-59 2020-11-03   313   67    69
# 11677                   Normandie       30-59 2020-05-13    47    9    28
#
#        dc hebdo   taux hosp   taux rea  taux décès
# 10702     123.0  100.062131  14.207191    8.361170
# 20553       6.0   16.396182   3.509726    0.314304
# 11677       3.0    3.827118   0.732852    0.244284

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-04-30-19h05.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-04-30-19h05-compute.csv

# %%
dout.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 19399     47 2020-09-10    14    4       NaN       NaN     NaN   93  13
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 19399       0.0   4.238109  1.210888         0.0

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 123922  974     1 2021-04-30    82   22      45.0      15.0     0.0   744   92
# 123923  974     2 2021-04-30    66   15      40.0      11.0     0.0   703   67
# 123924  976     0 2021-04-30    12    3       9.0       0.0     0.0  1241  126
# 123925  976     1 2021-04-30     8    2       6.0       0.0     0.0   563   74
# 123926  976     2 2021-04-30     4    1       3.0       0.0     0.0   658   51
#
# [123927 rows x 10 columns]
# (123927, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 41304    976 2021-04-26    20    6      14.0       0.0     0.0  1228  125
# 41305    976 2021-04-27    21    6      15.0       0.0     0.0  1228  125
# 41306    976 2021-04-28    22    6      16.0       0.0     0.0  1230  125
# 41307    976 2021-04-29    22    6      16.0       0.0     0.0  1230  125
# 41308    976 2021-04-30    12    3       9.0       0.0     0.0  1241  126
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 41304       1.0   7.156378  2.146913    0.357819
# 41305       1.0   7.514196  2.146913    0.357819
# 41306       1.0   7.872015  2.146913    0.357819
# 41307       1.0   7.872015  2.146913    0.357819
# 41308       2.0   4.293827  1.073457    0.715638
#
# [41309 rows x 13 columns]
# (41309, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[d_vac_1.dep != '20']
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-04-30-19h09.csv
# ./Temp/v5/vacsi-a-dep-2021-04-30-19h09-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (144584, 9)
#        dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 57007   43           80 2021-03-28       18          2        10838
# 118605  92           69 2021-02-26       58         44         2277
# 86196   67           64 2021-01-12       76          0          273
#
#         n_cum_complet  couv_dose1  couv_complet
# 57007            6160        61.8          35.1
# 118605           1603         3.3           2.3
# 86196               0         0.4           0.0

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (57536, 9)
#                     entity three_class       jour  n_dose1  n_complet  \
# 51627  Centre-Val de Loire       whole 2021-01-06      328          0
# 24354                   49         60+ 2021-01-08      167          0
# 54105            Normandie       30-59 2021-01-06      815          1
#
#        n_cum_dose1  n_cum_complet  couv_dose1  couv_complet
# 51627          542              0         0.0           0.0
# 24354          570              0         1.1           0.0
# 54105          929              1         0.9           0.0

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (57536, 11)
#      entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 7364     15        0-29 2021-04-11        0          0          555
# 9328     19        0-29 2021-04-06       20          4          796
# 833      02       30-59 2021-03-21      286         15        10684
#
#       n_cum_complet  couv_dose1  couv_complet  taux dose 1  taux complet
# 7364            100         8.8           1.6     1.484195      0.267423
# 9328            223         6.6           1.9     1.158391      0.324524
# 833            4153        15.8           6.1     5.402426      2.099988

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 8.486951351165771  s

# %% [markdown]
# # Données hospitalières (3) Estimation par classe d'âge et par département

# %% [markdown]
# ## dfs pops et pops_prop

# %% [markdown]
# ### df dpops

# %%
fname = dp.retrieve_temp('sp-pos-quot-dep', 'tot-3C-compute')
dtes = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v5/sp-pos-quot-dep-2021-04-30-19h05-tot-3C-compute.csv

# %%
columns = pd.Index(dtes.three_class.unique(), name = 'clage')
index = pd.Index(dtes.entity.unique(), name = 'entity')
dpops = pd.DataFrame(index = index, columns = columns)
dpops.sample()
# Out:
# clage  0-29 30-59  60+ whole
# entity
# 13      NaN   NaN  NaN   NaN

# %%
for entity in dtes.entity.unique():
    for clage in dtes.three_class.unique():
        dpops.loc[entity, clage] = dtes[(dtes.entity == entity) & (dtes.three_class == clage) & (dtes.jour == '2021-01-01')]["pop"].values[0]

# %%
dpops.sample()
# Out:
# clage       0-29     30-59       60+      whole
# entity
# 83      319301.0  397118.0  357417.0  1073836.0

# %%
dpops.shape
dpops.loc['France', :]
dpops.loc['France','60+']
# Out:
# (116, 4)
# clage
# 0-29     23555651.0
# 30-59    25657812.0
# 60+      17850240.0
# whole    67063703.0
# Name: France, dtype: object
# 17850240.0

# %%
dout = dpops
fname = path_temp + '-pops.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ./Temp/v5/vacsi-a-dep-2021-04-30-19h09-pops.csv

# %% [markdown]
# ### df dpops_prop

# %%
dpops_prop = dpops.divide(dpops.whole, axis = 'index')
dpops_prop
# Out:
# clage                           0-29     30-59       60+ whole
# entity
# 01                          0.354913  0.403463  0.241624   1.0
# 02                          0.344635   0.37594  0.279426   1.0
# 03                          0.286133  0.358127   0.35574   1.0
# 04                          0.287838  0.369062  0.343099   1.0
# 05                          0.296248   0.37973  0.324022   1.0
# ...                              ...       ...       ...   ...
# Occitanie                   0.330174  0.374871  0.294955   1.0
# Outre-mer (DROM)            0.432203  0.375058  0.192739   1.0
# Pays de la Loire            0.350137  0.375243   0.27462   1.0
# Provence-Alpes-Côte d'Azur  0.324136  0.377594   0.29827   1.0
# Île-de-France               0.390357  0.404643     0.205   1.0
#
# [116 rows x 4 columns]

# %% [markdown]
# ## taux hosp

# %% [markdown]
# ### empty df dhosps

# %%
fname = dp.retrieve_temp('donnees-hospitalieres-classe-age-covid19', '3C-compute')
dhos = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
fname = dp.retrieve_temp('donnees-hospitalieres-covid19', 'compute')
dhosdep = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-04-30-19h05-3C-compute.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-04-30-19h05-compute.csv

# %%
columns = pd.MultiIndex.from_tuples([(i, j) for i in dpops.index.unique() for j in dtes.three_class.unique()],
                       name = ['entity', 'clage'])
index = pd.Index(dhos.jour.unique(), name = "jour")
dhosps = pd.DataFrame(index = index, columns = columns)
dhosps.shape
dhosps.sample()
# Out:
# (409, 464)
# entity       01                    02                    03        ...  \
# clage      0-29 30-59  60+ whole 0-29 30-59  60+ whole 0-29 30-59  ...
# jour                                                               ...
# 2020-10-15  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire       Provence-Alpes-Côte d'Azur                   \
# clage                   60+ whole                       0-29 30-59  60+ whole
# jour
# 2020-10-15              NaN   NaN                        NaN   NaN  NaN   NaN
#
# entity     Île-de-France
# clage               0-29 30-59  60+ whole
# jour
# 2020-10-15           NaN   NaN  NaN   NaN
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (1) fill it with data for each (entity = dc.regs, clage)

# %%
dhos.sample()
# Out:
#                            entity three_class       jour  hosp  rea  dc  \
# 20008  Provence-Alpes-Côte d'Azur        0-29 2020-06-20     2    1   1
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 20008       0.0   0.122046  0.061023         0.0

# %%
dhos = dhos.set_index(dhos.jour)
dhos.sample()
# Out:
#               entity three_class       jour  hosp  rea   dc  dc hebdo  \
# jour
# 2020-09-09  Bretagne       whole 2020-09-09    69    8  269       0.0
#
#             taux hosp  taux rea  taux décès
# jour
# 2020-09-09   2.065634  0.239494         0.0

# %%
for entity, clage in dhosps.columns:
    dhosps.loc[:,(entity,clage)] = dhos[(dhos.entity == entity) & (dhos.three_class == clage)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                   02                   03        ...  \
# clage      0-29 30-59 60+ whole 0-29 30-59 60+ whole 0-29 30-59  ...
# jour                                                             ...
# 2020-09-19  NaN   NaN NaN   NaN  NaN   NaN NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire           Provence-Alpes-Côte d'Azur            \
# clage                   60+     whole                       0-29     30-59
# jour
# 2020-09-19         7.758242  2.709245                   1.281487  6.443228
#
# entity                          Île-de-France
# clage             60+     whole          0-29     30-59        60+     whole
# jour
# 2020-09-19  37.667056  14.18215      1.439635  8.614625  55.501855  15.53158
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (2) fill it with data for each (entity = dc.deps, clage = ['whole'])

# %%
dhosdep.sample()
dhosdep = dhosdep.set_index(dhosdep.jour)
dhosdep.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 19648     48 2020-04-03     9    1       NaN       NaN     NaN    8   0
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 19648       0.0  11.797709  1.310857         0.0
#            entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# jour
# 2020-03-19     59 2020-03-19   138   35       NaN       NaN     NaN   36   5
#
#             dc hebdo  taux hosp  taux rea  taux décès
# jour
# 2020-03-19       NaN   5.330268   1.35188         NaN

# %%
for entity in dhosdep.entity.unique():
    for clage in ['whole']:
        dhosps.loc[:,(entity, clage)] = dhosdep[(dhosdep.entity == entity)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                        02                        03        \
# clage      0-29 30-59 60+      whole 0-29 30-59 60+      whole 0-29 30-59
# jour
# 2020-12-26  NaN   NaN NaN  38.967661  NaN   NaN NaN  56.268416  NaN   NaN
#
# entity      ... Pays de la Loire            Provence-Alpes-Côte d'Azur  \
# clage       ...              60+      whole                       0-29
# jour        ...
# 2020-12-26  ...        80.360059  23.778229                   1.220464
#
# entity                                     Île-de-France             \
# clage          30-59        60+      whole          0-29      30-59
# jour
# 2020-12-26  9.533882  143.50618  46.996915      1.940377  13.264108
#
# entity
# clage              60+      whole
# jour
# 2020-12-26  159.989956  39.321693
#
# [1 rows x 464 columns]

# %%
dhosps['01', 'whole']
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-26    30.595703
# 2021-04-27    31.204573
# 2021-04-28    29.225746
# 2021-04-29    28.921311
# 2021-04-30    29.530181
# Name: (01, whole), Length: 409, dtype: float64

# %%
dhosps.loc[:,('01', 'whole')]
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-26    30.595703
# 2021-04-27    31.204573
# 2021-04-28    29.225746
# 2021-04-29    28.921311
# 2021-04-30    29.530181
# Name: (01, whole), Length: 409, dtype: float64

# %% [markdown]
# ### (3) estimate data for missing (entity = dc.deps, clage = ['0-29', '30-59', '60+'])

# %% [markdown]
# La proportion observée au niveau régional pour la classe d'âge considérée par rapport à l'ensemble de la population est appliquée au taux départemental :
# Taux (département, classe d'âge) = taux (département) * taux (région, classe d'âge) / taux (région)

# %%
for entity in dc.deps:
    for clage in ['0-29', '30-59', '60+']:
        dhosps.loc[:,(entity, clage)] = (
            dhosps.loc[:,(entity, 'whole')]
            * dhosps.loc[:,(dc.dep2reg[entity], clage)]
            / dhosps.loc[:,(dc.dep2reg[entity], 'whole')]
#             * dpops_prop.loc[entity, clage]
#             / dpops_prop.loc[dc.dep2reg[entity], clage]
        )

# %%
dhosps.loc[:,('Auvergne-Rhône-Alpes', '0-29')]
# Out:
# jour
# 2020-03-18    0.141085
# 2020-03-19    0.176356
# 2020-03-20    0.141085
# 2020-03-21    0.246899
# 2020-03-22    0.387984
#                 ...
# 2021-04-26    1.693020
# 2021-04-27    1.728291
# 2021-04-28    1.657748
# 2021-04-29    2.010461
# 2021-04-30    2.045732
# Name: (Auvergne-Rhône-Alpes, 0-29), Length: 409, dtype: float64

# %% [markdown]
# ## Fonction

# %%
# def estimate_deps(din, dindep, column):
#     columns = pd.MultiIndex.from_tuples([(i, j) for i in dtes.entity.unique() for j in dtes.three_class.unique()],
#                        name = ['entity', 'clage'])
#     index = pd.Index(din.jour.unique(), name = "jour")
#     dout = pd.DataFrame(index = index, columns = columns)

#     din = din.copy().set_index(din.jour)
#     for entity, clage in dout.columns:
#         dout.loc[:,(entity,clage)] = din[(din.entity == entity) & (din.three_class == clage)][column]

#     dindep = dindep.copy().set_index(dindep.jour)
#     for entity in dindep.entity.unique():
#         for clage in ['whole']:
#             dout.loc[:,(entity, clage)] = dindep[(dindep.entity == entity)][column]

#     for entity in dc.deps:
#         for clage in ['0-29', '30-59', '60+']:
#             dout.loc[:,(entity, clage)] = (
#                 dout.loc[:,(entity, 'whole')]
#                 * dout.loc[:,(dc.dep2reg[entity], clage)]
#                 / dout.loc[:,(dc.dep2reg[entity], 'whole')]
#             )
#     dout = pd.melt(dout.T.reset_index(), id_vars = ['entity', 'clage'], value_name = column)
#     return dout

# %%
# d1 = estimate_deps(dhos, dhosdep, "taux hosp")

# d2 = estimate_deps(dhos, dhosdep, "taux rea")

# d3 = estimate_deps(dhos, dhosdep, "taux décès")

# dout = pd.merge(pd.merge(d1,d2), d3)
# fname = path_temp + '-estimates-hosp.csv'
# dout.to_csv(fname, sep = ';', index = False)
# print(fname)

# %%
# dout
