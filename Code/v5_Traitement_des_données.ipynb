# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 10/05/2021. Retrieve data from how many days? 0
# Ok, will retrieve data from 10/05/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-05-10-19h06.csv
# ./Temp/v5/sp-pos-quot-dep-2021-05-10-19h06-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#       dep       jour   P    T  cl_age90       pop
# 27924  08 2020-05-31   0    1        69   36558.0
# 15720  04 2021-04-27  10   72        19   18061.0
# 37377  10 2020-10-17  68  522         0  309907.0
# (411840, 6)
#                  entity three_class       jour    P     T        pop
# 45763                31       whole 2021-02-17  452  8657  1400935.0
# 70568                49        0-29 2020-05-15    2   120   293749.0
# 155793  Hauts-de-France       30-59 2020-07-20   35  3025  2275147.0
# (167040, 6)
#                          entity three_class       jour     P      T  \
# 103432                       71        0-29 2021-03-07     5     41
# 53404                        37        0-29 2020-06-13     1     36
# 147535  Bourgogne-Franche-Comté       whole 2020-10-23  2355  15191
#
#               pop  P hebdo  T hebdo  incidence hebdo  taux de positifs hebdo  \
# 103432   163376.0    164.0   3525.0       100.381941                4.652482
# 53404    207312.0      3.0    357.0         1.447094                0.840336
# 147535  2783039.0  10597.0  77049.0       380.770805               13.753585
#
#         taux de tests hebdo
# 103432          2157.599647
# 53404            172.204214
# 147535          2768.520312
# (167040, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-05-10-19h05.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-05-10-19h05-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (82962, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres   rad    dc  \
# 61806 2021-01-24     9    3       NaN       NaN     NaN   128    18
# 7884  2020-04-26   180   66       NaN       NaN     NaN   390    68
# 17721 2020-06-15  1171   88       NaN       NaN     NaN  6072  1797
#
#                  entity three_class
# 61806  Outre-mer (DROM)         60+
# 7884          Occitanie         60+
# 17721   Hauts-de-France       whole
# 'd_hosp_2: '
# (25140, 6)
#                  entity three_class       jour  hosp  rea    dc
# 12021         Normandie       30-59 2020-05-29    36    5    28
# 16542         Occitanie         60+ 2021-03-17  1139  207  3333
# 18675  Pays de la Loire       whole 2020-05-16   497   39   407
# 'd_hosp_3: '
# (25140, 10)
#                     entity three_class       jour  hosp  rea  dc  dc hebdo  \
# 10297      Hauts-de-France       30-59 2020-05-17   234   46  80       8.0
# 18089     Outre-mer (DROM)       30-59 2021-02-13   101   29  68       1.0
# 5061   Centre-Val de Loire       30-59 2020-03-26    46   20   1       1.0
#
#        taux hosp  taux rea  taux décès
# 10297  10.285050  2.021847    0.351626
# 18089  12.090002  3.471387    0.119703
# 5061    4.824240  2.097496    0.104875

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-05-10-19h05.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-05-10-19h05-compute.csv

# %%
dout.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 28709     68 2020-10-21    48   10       NaN       NaN     NaN  3280  845
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 28709       1.0   6.289275  1.310266    0.131027

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 126952  974     1 2021-05-10    89   24      48.0      17.0     0.0   788  105
# 126953  974     2 2021-05-10    77   15      51.0      11.0     0.0   742   72
# 126954  976     0 2021-05-10    14    7       7.0       0.0     0.0  1252  127
# 126955  976     1 2021-05-10     7    3       4.0       0.0     0.0   568   74
# 126956  976     2 2021-05-10     6    4       2.0       0.0     0.0   664   52
#
# [126957 rows x 10 columns]
# (126957, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 42314    976 2021-05-06    11    4       7.0       0.0     0.0  1251  126
# 42315    976 2021-05-07    10    4       6.0       0.0     0.0  1252  127
# 42316    976 2021-05-08    14    7       7.0       0.0     0.0  1252  127
# 42317    976 2021-05-09    14    7       7.0       0.0     0.0  1252  127
# 42318    976 2021-05-10    14    7       7.0       0.0     0.0  1252  127
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 42314       1.0   3.936008  1.431276    0.357819
# 42315       1.0   3.578189  1.431276    0.357819
# 42316       1.0   5.009464  2.504732    0.357819
# 42317       1.0   5.009464  2.504732    0.357819
# 42318       1.0   5.009464  2.504732    0.357819
#
# [42319 rows x 13 columns]
# (42319, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[d_vac_1.dep != '20']
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-05-10-19h05.csv
# ./Temp/v5/vacsi-a-dep-2021-05-10-19h05-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (156244, 9)
#        dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 143360  09            0 2021-04-20      764        523        39068
# 98690   72           69 2021-03-03       46         12          937
# 24401   18           39 2021-01-09        6          0            6
#
#         n_cum_complet  couv_dose1  couv_complet
# 143360          14255        25.6           9.4
# 98690             485         2.6           1.4
# 24401               0         0.0           0.0

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (62176, 9)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 38825     72       30-59 2021-02-23      169         62         5292
# 44044     82        0-29 2021-01-19        0          0           32
# 44983     83       whole 2021-04-29     5639       4998       275959
#
#        n_cum_complet  couv_dose1  couv_complet
# 38825           2994         7.5           4.2
# 44044              0         0.3           0.0
# 44983         126630        25.7          11.8

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (62176, 11)
#                  entity three_class       jour  n_dose1  n_complet  \
# 58177   Hauts-de-France       30-59 2021-03-09     3406        595
# 60153  Outre-mer (DROM)       30-59 2021-01-26      317          1
# 12106                24         60+ 2021-03-15      773        149
#
#        n_cum_dose1  n_cum_complet  couv_dose1  couv_complet  taux dose 1  \
# 58177        97979          38700        60.6          25.2     4.306491
# 60153         2694              1         5.0           0.0     0.322480
# 12106        26323          11630        87.9          38.6    17.052993
#
#        taux complet
# 58177      1.700989
# 60153      0.000120
# 12106      7.534335

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 6.95866322517395  s
