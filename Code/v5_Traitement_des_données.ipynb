# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 13/06/2021. Retrieve data from how many days?
# Ok, will retrieve data from 12/06/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-06-12-19h09.csv
# ./Temp/v5/sp-pos-quot-dep-2021-06-12-19h09-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour  P   T  cl_age90      pop
# 251969  58 2020-09-02  1  71        39  18995.0
# 407680  94 2020-09-09  4  77        90  15048.0
# 106725  26 2021-02-07  2  23        39  62462.0
# (449592, 6)
#       entity three_class       jour    P     T       pop
# 87830     55         60+ 2021-04-20   14   218   55929.0
# 21543     14       whole 2021-02-13   93  2159  691453.0
# 30967     21       whole 2021-02-11  108  2445  532886.0
# (182352, 6)
#            entity three_class       jour    P      T        pop  P hebdo  \
# 55618          35         60+ 2020-10-09   53    527   258341.0    213.0
# 175956  Occitanie        0-29 2021-05-14  441  15648  1956236.0   1966.0
# 125768         80        0-29 2020-05-15    0    105   205711.0      0.0
#
#         T hebdo  incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 55618    2853.0        82.449166                7.465825          1104.354322
# 175956  74265.0       100.499122                2.647277          3796.321098
# 125768      0.0         0.000000                     NaN             0.000000
# (182352, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-06-12-19h05.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-06-12-19h05-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (89496, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres   rad  dc  \
# 87497 2021-06-02    20    5      10.0       4.0     1.0  1316   6
# 8132  2020-04-28     1    0       NaN       NaN     NaN     2   0
# 88334 2021-06-07    13    3       9.0       0.0     1.0   541   1
#
#                            entity three_class
# 87497  Provence-Alpes-Côte d'Azur        0-29
# 8132             Outre-mer (DROM)        0-29
# 88334            Outre-mer (DROM)       30-59
# 'd_hosp_2: '
# (27120, 6)
#                     entity three_class       jour  hosp  rea  dc
# 13400            Normandie        0-29 2020-09-20     2    1   0
# 4153              Bretagne       30-59 2020-07-30    17    3  10
# 6293   Centre-Val de Loire       30-59 2020-10-21    50   18  23
# 'd_hosp_3: '
# (27120, 10)
#                     entity three_class       jour  hosp  rea   dc  dc hebdo  \
# 8633                 Corse       30-59 2021-03-03     6    1    9       0.0
# 6696   Centre-Val de Loire        0-29 2021-01-30     7    2    0       0.0
# 10898      Hauts-de-France         60+ 2020-03-30   980  272  232     149.0
#
#        taux hosp   taux rea  taux décès
# 8633    4.385997   0.730999    0.000000
# 6696    0.826112   0.236032    0.000000
# 10898  66.617451  18.489742   10.128572

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1, True)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute-DROM.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-06-12-19h05.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-06-12-19h05-3C-compute-DROM.csv

# %%
dout.entity.unique()
# Out:
# array(['Auvergne-Rhône-Alpes', 'Bourgogne-Franche-Comté', 'Bretagne',
#        'Centre-Val de Loire', 'Corse', 'Grand Est', 'Guadeloupe',
#        'Guyane', 'Hauts-de-France', 'La Réunion', 'Martinique', 'Mayotte',
#        'Normandie', 'Nouvelle-Aquitaine', 'Occitanie', 'Pays de la Loire',
#        "Provence-Alpes-Côte d'Azur", 'Île-de-France', 'France'],
#       dtype=object)

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-06-12-19h06.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-06-12-19h06-compute.csv

# %%
dout.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres    rad    dc  \
# 34289     75 2021-04-11  1699  519     961.0     218.0     1.0  16228  3805
#
#        dc hebdo  taux hosp   taux rea  taux décès
# 34289     106.0  79.086856  24.158963    4.934201

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 136951  974     1 2021-06-12    93   23      52.0      18.0     0.0   951  127
# 136952  974     2 2021-06-12    67    9      40.0      18.0     0.0   900   97
# 136953  976     0 2021-06-12     7    4       3.0       0.0     0.0  1266  130
# 136954  976     1 2021-06-12     3    2       1.0       0.0     0.0   574   76
# 136955  976     2 2021-06-12     4    2       2.0       0.0     0.0   671   53
#
# [136956 rows x 10 columns]
# (136956, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 45647    976 2021-06-08     8    4       4.0       0.0     0.0  1264  130
# 45648    976 2021-06-09     8    4       4.0       0.0     0.0  1264  130
# 45649    976 2021-06-10     7    4       3.0       0.0     0.0  1266  130
# 45650    976 2021-06-11     7    4       3.0       0.0     0.0  1266  130
# 45651    976 2021-06-12     7    4       3.0       0.0     0.0  1266  130
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 45647       0.0   2.862551  1.431276         0.0
# 45648       0.0   2.862551  1.431276         0.0
# 45649       0.0   2.504732  1.431276         0.0
# 45650       0.0   2.504732  1.431276         0.0
# 45651       0.0   2.504732  1.431276         0.0
#
# [45652 rows x 13 columns]
# (45652, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[(d_vac_1.dep != '20') & (d_vac_1.dep != '98')]
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-06-12-19h05.csv
# ./Temp/v5/vacsi-a-dep-2021-06-12-19h05-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (192885, 9)
#         dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 70006    40           80 2021-01-29      223          0         4483
# 171857  976           80 2021-01-10        0          0            0
# 182666   42            0 2021-05-11     5543       3859       229182
#
#         n_cum_complet  couv_dose1  couv_complet
# 70006               7        14.0           0.0
# 171857              0         0.0           0.0
# 182666         112451        30.0          14.7

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (77488, 9)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 41389     61       30-59 2021-06-05     1081        393        48095
# 12752     21        0-29 2021-01-11       42          0          101
# 16353     26       30-59 2021-03-17      108         33         9928
#
#        n_cum_complet  couv_dose1  couv_complet
# 41389          15535       142.0          45.2
# 12752              0         0.3           0.0
# 16353           3577        14.7           5.2

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (77488, 11)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 59893     89       30-59 2021-04-16      320        129        13042
# 49078     73         60+ 2021-03-15     1037        343        28489
# 58612     87        0-29 2021-04-30      124         80         3216
#
#        n_cum_complet  couv_dose1  couv_complet  taux dose 1  taux complet
# 59893           4139        30.6           9.8    10.597652      3.363263
# 49078          14866       125.4          67.4    23.589077     12.309145
# 58612            948        14.5           4.5     2.741478      0.808122

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 9.796863555908203  s
