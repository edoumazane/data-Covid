# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v5_dicts as dc
import my_package.v5_datepaths as dp
import my_package.v5_calculus as cc
# Out:
# Today is 31/05/2021. Retrieve data from how many days?
# Ok, will retrieve data from 30/05/2021
# You are running the v5 version

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-05-30-19h06.csv
# ./Temp/v5/sp-pos-quot-dep-2021-05-30-19h06-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#         dep       jour  P   T  cl_age90       pop
# 423421  976 2020-09-02  0   0        90     181.0
# 50843    13 2020-07-14  0  35        19  242619.0
# 243834   58 2020-09-16  1  59        89   14937.0
# (434720, 6)
#        entity three_class       jour    P     T       pop
# 46860      30        0-29 2021-03-24  135  1509  240726.0
# 108000     71        0-29 2020-06-02    0    62  163376.0
# 14007      10       whole 2020-08-02    0    42  309907.0
# (176320, 6)
#        entity three_class       jour    P     T       pop  P hebdo  T hebdo  \
# 149357    973       30-59 2020-08-20   23   293  101385.0    103.0   2000.0
# 114853     75       30-59 2020-12-12  139  3888  869271.0   1145.0  30484.0
# 14098      10         60+ 2020-08-25    2   315   87700.0     13.0   1100.0
#
#         incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 149357       101.592938                5.150000          1972.678404
# 114853       131.719567                3.756069          3506.846542
# 14098         14.823261                1.181818          1254.275941
# (176320, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-05-30-19h06.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-05-30-19h06-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (86922, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 62010 2021-01-25     1    0       NaN       NaN     NaN    71    1
# 20398 2020-06-29     1    1       NaN       NaN     NaN     4    0
# 78382 2021-04-17   699  216     373.0     101.0     9.0  7047  878
#
#                      entity three_class
# 62010      Outre-mer (DROM)        0-29
# 20398      Outre-mer (DROM)       30-59
# 78382  Auvergne-Rhône-Alpes         60+
# 'd_hosp_2: '
# (26340, 6)
#                  entity three_class       jour  hosp   rea     dc
# 10101         Grand Est       30-59 2021-02-11   303    60    297
# 19770  Pays de la Loire         60+ 2020-07-09   123     1    453
# 25426            France         60+ 2020-10-14  7387  1279  20608
# 'd_hosp_3: '
# (26340, 10)
#                      entity three_class       jour  hosp  rea    dc  dc hebdo  \
# 15571    Nouvelle-Aquitaine       whole 2021-04-02  1161  228  3189      63.0
# 15594    Nouvelle-Aquitaine         60+ 2021-04-08  1028  178  3133      70.0
# 302    Auvergne-Rhône-Alpes         60+ 2020-06-01  1023  101  1593      42.0
#
#        taux hosp  taux rea  taux décès
# 15571  19.350058  3.800011    1.050003
# 15594  54.968529  9.517897    3.742993
# 302    48.446469  4.783082    1.989005

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1, True)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute-DROM.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-05-30-19h06.csv
# ./Temp/v5/donnees-hospitalieres-classe-age-covid19-2021-05-30-19h06-3C-compute-DROM.csv

# %%
dout.entity.unique()
# Out:
# array(['Auvergne-Rhône-Alpes', 'Bourgogne-Franche-Comté', 'Bretagne',
#        'Centre-Val de Loire', 'Corse', 'Grand Est', 'Guadeloupe',
#        'Guyane', 'Hauts-de-France', 'La Réunion', 'Martinique', 'Mayotte',
#        'Normandie', 'Nouvelle-Aquitaine', 'Occitanie', 'Pays de la Loire',
#        "Provence-Alpes-Côte d'Azur", 'Île-de-France', 'France'],
#       dtype=object)

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-05-30-19h06.csv
# ./Temp/v5/donnees-hospitalieres-covid19-2021-05-30-19h06-compute.csv

# %%
dout.sample()
# Out:
#      entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad   dc  \
# 6530     15 2021-04-06    31    6      23.0       2.0     0.0  481  109
#
#       dc hebdo  taux hosp  taux rea  taux décès
# 6530       4.0  21.707011  4.201357    2.800905

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 133012  974     1 2021-05-30    88   21      48.0      19.0     0.0   893  117
# 133013  974     2 2021-05-30    71   16      37.0      18.0     0.0   847   88
# 133014  976     0 2021-05-30     6    3       3.0       0.0     0.0  1262  130
# 133015  976     1 2021-05-30     1    1       0.0       0.0     0.0   573   76
# 133016  976     2 2021-05-30     5    2       3.0       0.0     0.0   668   53
#
# [133017 rows x 10 columns]
# (133017, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 44334    976 2021-05-26     9    4       5.0       0.0     0.0  1261  128
# 44335    976 2021-05-27     7    3       4.0       0.0     0.0  1261  130
# 44336    976 2021-05-28     7    3       4.0       0.0     0.0  1261  130
# 44337    976 2021-05-29     7    3       4.0       0.0     0.0  1261  130
# 44338    976 2021-05-30     6    3       3.0       0.0     0.0  1262  130
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 44334       0.0   3.220370  1.431276    0.000000
# 44335       2.0   2.504732  1.073457    0.715638
# 44336       2.0   2.504732  1.073457    0.715638
# 44337       2.0   2.504732  1.073457    0.715638
# 44338       2.0   2.146913  1.073457    0.715638
#
# [44339 rows x 13 columns]
# (44339, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[(d_vac_1.dep != '20') & (d_vac_1.dep != '98')]
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-05-30-19h05.csv
# ./Temp/v5/vacsi-a-dep-2021-05-30-19h05-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (181258, 9)
#        dep  clage_vacsi       jour  n_dose1  n_complet  n_cum_dose1  \
# 22048   14           49 2021-01-22       57          0         1056
# 101923  65           29 2021-05-05       19         18          806
# 27157   17           69 2021-02-18       43         68         1208
#
#         n_cum_complet  couv_dose1  couv_complet
# 22048               1         1.2           0.0
# 101923            240         8.5           2.5
# 27157             600         2.3           1.2

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (71456, 9)
#          entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 27924        45        0-29 2021-02-16       24          2          448
# 52081        84       30-59 2021-03-21       27          5        10023
# 63836  Bretagne        0-29 2021-04-03      118         13        12684
#
#        n_cum_complet  couv_dose1  couv_complet
# 27924            109         1.1           0.3
# 52081           4363        13.7           6.0
# 63836           2517        26.2           5.4

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (71456, 11)
#       entity three_class       jour  n_dose1  n_complet  n_cum_dose1  \
# 46536     75        0-29 2021-03-21      159         13        13451
# 41924     68        0-29 2021-01-05        0          0            0
# 13813     24       30-59 2021-03-02      120         94         5925
#
#        n_cum_complet  couv_dose1  couv_complet  taux dose 1  taux complet
# 46536           2118         6.1           1.0     1.696469      0.267127
# 41924              0         0.0           0.0     0.000000      0.000000
# 13813           3292        11.3           6.2     4.041858      2.245704

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 9.569461345672607  s
