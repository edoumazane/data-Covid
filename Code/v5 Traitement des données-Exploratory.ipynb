# %%
import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v4_dicts as dc
import my_package.v4_datepaths as dp
import my_package.v4_calculus as cc
# Out:
# Today is 20/04/2021. Retrieve data from how many days?
# Ok, will retrieve data from 19/04/2021

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1, three_class = False)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-04-19-19h06.csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-685b82e3ce9a> in <module>
#       1 d_tests_1, path_temp = cc.sp_input()
#       2 d_tests_2 = cc.sp_tot_3C(d_tests_1, three_class = False)
# ----> 3 d_tests_3 = cc.sp_compute(d_tests_2)
#       4
#       5 dout = d_tests_3
#
# /home/edmz/data-Covid/Code/my_package/v4_calculus.py in sp_compute(din)
#      90     d = din.copy()
#      91     d1 = (d
# ---> 92             .groupby(['entity', 'three_class'])
#      93             .rolling(window = 7, on = 'jour')
#      94             .sum()
#
# /home/edmz/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6722             squeeze=squeeze,
#    6723             observed=observed,
# -> 6724             dropna=dropna,
#    6725         )
#    6726
#
# /home/edmz/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     566                 observed=observed,
#     567                 mutated=self.mutated,
# --> 568                 dropna=self.dropna,
#     569             )
#     570
#
# /home/edmz/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     809                 in_axis, name, level, gpr = False, None, gpr, None
#     810             else:
# --> 811                 raise KeyError(gpr)
#     812         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     813             # Add key to exclusions
#
# KeyError: 'three_class'

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour   P     T  cl_age90        pop
# 76606   22 2020-12-03   5   219        29    47869.0
# 189406  50 2021-03-27  10   106        89    32934.0
# 44945   13 2020-06-11  77  2626         0  2034469.0
# (386672, 6)
#            entity three_class       jour    P      T        pop
# 83609          61       30-59 2021-02-21    2     35    98601.0
# 373            01       30-59 2020-08-14   11    337   265057.0
# 146012  Grand Est        0-29 2021-04-15  869  10258  1874571.0
# (156832, 6)
#       entity three_class       jour    P     T       pop  P hebdo  T hebdo  \
# 53060     39        0-29 2020-08-04    0    69   80151.0      0.0    445.0
# 75114     55         60+ 2020-11-17   20   202   55929.0     99.0   1148.0
# 80582     59         60+ 2020-12-02  131  1920  601674.0    883.0  12755.0
#
#        incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 53060         0.000000                0.000000           555.202056
# 75114       177.010138                8.623693          2052.602407
# 80582       146.757214                6.922775          2119.918760
# (156832, 11)

# %% [markdown]
# # Données hospitalières (1)

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-04-18-19h10.csv
# ./Temp/v4/donnees-hospitalieres-classe-age-covid19-2021-04-18-19h10-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (78606, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 2687  2020-03-31    41    5       NaN       NaN     NaN   82   1
# 36462 2020-09-18     1    0       NaN       NaN     NaN  108  17
# 50975 2020-11-30     2    0       NaN       NaN     NaN   33   0
#
#                  entity three_class
# 2687          Grand Est        0-29
# 36462  Outre-mer (DROM)         60+
# 50975         Normandie        0-29
# 'd_hosp_2: '
# (23820, 6)
#                      entity three_class       jour  hosp  rea    dc
# 147    Auvergne-Rhône-Alpes       whole 2020-04-23  2760  483  1167
# 11944             Normandie        0-29 2020-10-11     4    0     0
# 216    Auvergne-Rhône-Alpes        0-29 2020-05-11    21    3     0
# 'd_hosp_3: '
# (23820, 10)
#                  entity three_class       jour  hosp  rea   dc  dc hebdo  \
# 6891              Corse       whole 2020-07-30     8    1   59       0.0
# 16616  Outre-mer (DROM)        0-29 2020-09-18    17    0    5       0.0
# 11198         Normandie         60+ 2020-04-07   543  149  136      79.0
#
#        taux hosp   taux rea  taux décès
# 6891    2.321000   0.290125     0.00000
# 16616   1.776622   0.000000     0.00000
# 11198  57.028470  15.648696     8.29696

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-04-18-19h10.csv
# ./Temp/v4/donnees-hospitalieres-covid19-2021-04-18-19h10-compute.csv

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 120286  974     1 2021-04-18    83   28      40.0      15.0     0.0   676   88
# 120287  974     2 2021-04-18    60   12      37.0      11.0     0.0   659   61
# 120288  976     0 2021-04-18    15    7       8.0       0.0     0.0  1228  124
# 120289  976     1 2021-04-18     3    1       2.0       0.0     0.0   560   73
# 120290  976     2 2021-04-18    11    6       5.0       0.0     0.0   649   50
#
# [120291 rows x 10 columns]
# (120291, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 40092    976 2021-04-14    15    6       9.0       0.0     0.0  1222  124
# 40093    976 2021-04-15    12    6       6.0       0.0     0.0  1228  124
# 40094    976 2021-04-16    12    6       6.0       0.0     0.0  1228  124
# 40095    976 2021-04-17    14    6       8.0       0.0     0.0  1228  124
# 40096    976 2021-04-18    15    7       8.0       0.0     0.0  1228  124
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 40092       0.0   5.367283  2.146913         0.0
# 40093       0.0   4.293827  2.146913         0.0
# 40094       0.0   4.293827  2.146913         0.0
# 40095       0.0   5.009464  2.146913         0.0
# 40096       0.0   5.367283  2.504732         0.0
#
# [40097 rows x 13 columns]
# (40097, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-04-18-19h05.csv
# ./Temp/v4/vacsi-a-dep-2021-04-18-19h05-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (130592, 7)
#       dep  clage_vacsi       jour  n_dose1  n_dose2  n_cum_dose1  n_cum_dose2
# 1159   01           24 2021-02-04        0        2           32            4
# 60631  53           29 2021-02-04        0        3           59            8
# 19599  17           59 2021-04-17      318       21        15906         4493

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (51968, 7)
#       entity three_class       jour  n_dose1  n_dose2  n_cum_dose1  \
# 32481     72       30-59 2021-02-21        0        0         5030
# 25338     56         60+ 2021-02-27      491      336        31659
# 29976     66        0-29 2021-04-08       34        7         1001
#
#        n_cum_dose2
# 32481         2934
# 25338        15346
# 29976          248

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (51968, 9)
#       entity three_class       jour  n_dose1  n_dose2  n_cum_dose1  \
# 82        01         60+ 2021-01-16      143        0         1208
# 24841     55       30-59 2021-02-15       11       89         1417
# 44314    973         60+ 2021-04-08      111       79         4878
#
#        n_cum_dose2  taux dose 1  taux dose 2
# 82               0     0.761012     0.000000
# 24841          651     2.075613     0.953581
# 44314         2777    17.295419     9.846121

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 8.114840030670166  s

# %% [markdown]
# # Données hospitalières (3) Estimation par classe d'âge et par département

# %% [markdown]
# ## dfs pops et pops_prop

# %% [markdown]
# ### df dpops

# %%
fname = dp.retrieve_temp('sp-pos-quot-dep', 'tot-3C-compute')
dtes = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v4/sp-pos-quot-dep-2021-04-18-19h10-tot-3C-compute.csv

# %%
columns = pd.Index(dtes.three_class.unique(), name = 'clage')
index = pd.Index(dtes.entity.unique(), name = 'entity')
dpops = pd.DataFrame(index = index, columns = columns)
dpops.sample()
# Out:
# clage  0-29 30-59  60+ whole
# entity
# 04      NaN   NaN  NaN   NaN

# %%
for entity in dtes.entity.unique():
    for clage in dtes.three_class.unique():
        dpops.loc[entity, clage] = dtes[(dtes.entity == entity) & (dtes.three_class == clage) & (dtes.jour == '2021-01-01')]["pop"].values[0]

# %%
dpops.sample()
# Out:
# clage       0-29     30-59       60+      whole
# entity
# 77      557352.0  574493.0  291762.0  1423607.0

# %%
dpops.shape
dpops.loc['France', :]
dpops.loc['France','60+']
# Out:
# (116, 4)
# clage
# 0-29     23555651.0
# 30-59    25657812.0
# 60+      17850240.0
# whole    67063703.0
# Name: France, dtype: object
# 17850240.0

# %% [markdown]
# ### df dpops_prop

# %%
dpops_prop = dpops.divide(dpops.whole, axis = 'index')
dpops_prop
# Out:
# clage                           0-29     30-59       60+ whole
# entity
# 01                          0.354913  0.403463  0.241624   1.0
# 02                          0.344635   0.37594  0.279426   1.0
# 03                          0.286133  0.358127   0.35574   1.0
# 04                          0.287838  0.369062  0.343099   1.0
# 05                          0.296248   0.37973  0.324022   1.0
# ...                              ...       ...       ...   ...
# Occitanie                   0.330174  0.374871  0.294955   1.0
# Outre-mer (DROM)            0.432203  0.375058  0.192739   1.0
# Pays de la Loire            0.350137  0.375243   0.27462   1.0
# Provence-Alpes-Côte d'Azur  0.324136  0.377594   0.29827   1.0
# Île-de-France               0.390357  0.404643     0.205   1.0
#
# [116 rows x 4 columns]

# %% [markdown]
# ## taux hosp

# %% [markdown]
# ### empty df dhosps

# %%
fname = dp.retrieve_temp('donnees-hospitalieres-classe-age-covid19', '3C-compute')
dhos = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
fname = dp.retrieve_temp('donnees-hospitalieres-covid19', 'compute')
dhosdep = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v4/donnees-hospitalieres-classe-age-covid19-2021-04-18-19h10-3C-compute.csv
# ./Temp/v4/donnees-hospitalieres-covid19-2021-04-18-19h10-compute.csv

# %%
columns = pd.MultiIndex.from_tuples([(i, j) for i in dpops.index.unique() for j in dtes.three_class.unique()],
                       name = ['entity', 'clage'])
index = pd.Index(dhos.jour.unique(), name = "jour")
dhosps = pd.DataFrame(index = index, columns = columns)
dhosps.shape
dhosps.sample()
# Out:
# (397, 464)
# entity       01                    02                    03        ...  \
# clage      0-29 30-59  60+ whole 0-29 30-59  60+ whole 0-29 30-59  ...
# jour                                                               ...
# 2020-11-23  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire       Provence-Alpes-Côte d'Azur                   \
# clage                   60+ whole                       0-29 30-59  60+ whole
# jour
# 2020-11-23              NaN   NaN                        NaN   NaN  NaN   NaN
#
# entity     Île-de-France
# clage               0-29 30-59  60+ whole
# jour
# 2020-11-23           NaN   NaN  NaN   NaN
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (1) fill it with data for each (entity = dc.regs, clage)

# %%
dhos.sample()
# Out:
#                    entity three_class       jour  hosp  rea  dc  dc hebdo  \
# 5452  Centre-Val de Loire        0-29 2020-09-06     1    0   1       0.0
#
#       taux hosp  taux rea  taux décès
# 5452   0.118016       0.0         0.0

# %%
dhos = dhos.set_index(dhos.jour)
dhos.sample()
# Out:
#                      entity three_class       jour  hosp  rea    dc  dc hebdo  \
# jour
# 2020-06-14  Hauts-de-France         60+ 2020-06-14  1017   62  1697      17.0
#
#             taux hosp  taux rea  taux décès
# jour
# 2020-06-14    69.1326  4.214573    1.155609

# %%
for entity, clage in dhosps.columns:
    dhosps.loc[:,(entity,clage)] = dhos[(dhos.entity == entity) & (dhos.three_class == clage)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                   02                   03        ...  \
# clage      0-29 30-59 60+ whole 0-29 30-59 60+ whole 0-29 30-59  ...
# jour                                                             ...
# 2021-03-24  NaN   NaN NaN   NaN  NaN   NaN NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire            Provence-Alpes-Côte d'Azur             \
# clage                   60+      whole                       0-29      30-59
# jour
# 2021-03-24        68.962148  22.094815                   2.501951  26.558672
#
# entity                            Île-de-France                        \
# clage              60+      whole          0-29      30-59        60+
# jour
# 2021-03-24  166.716514  61.040606      2.920998  29.265573  197.53416
#
# entity
# clage           whole
# jour
# 2021-03-24  54.103978
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (2) fill it with data for each (entity = dc.deps, clage = ['whole'])

# %%
dhosdep.sample()
dhosdep = dhosdep.set_index(dhosdep.jour)
dhosdep.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad   dc  \
# 21493     54 2020-05-12   282   32       NaN       NaN     NaN  847  321
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 21493      29.0  38.609087  4.381173    3.970438
#            entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# jour
# 2020-05-22     55 2020-05-22   128    5       NaN       NaN     NaN  348  93
#
#             dc hebdo  taux hosp  taux rea  taux décès
# jour
# 2020-05-22      -3.0  70.468672  2.752682   -1.651609

# %%
for entity in dhosdep.entity.unique():
    for clage in ['whole']:
        dhosps.loc[:,(entity, clage)] = dhosdep[(dhosdep.entity == entity)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                      02                        03        ...  \
# clage      0-29 30-59 60+    whole 0-29 30-59 60+      whole 0-29 30-59  ...
# jour                                                                     ...
# 2020-12-04  NaN   NaN NaN  56.7771  NaN   NaN NaN  40.300352  NaN   NaN  ...
#
# entity     Pays de la Loire            Provence-Alpes-Côte d'Azur             \
# clage                   60+      whole                       0-29      30-59
# jour
# 2020-12-04        82.084113  24.330599                   2.318882  11.262553
#
# entity                           Île-de-France                        \
# clage             60+      whole          0-29      30-59        60+
# jour
# 2020-12-04  143.63881  48.045247      2.315934  14.652914  174.29251
#
# entity
# clage           whole
# jour
# 2020-12-04  43.011156
#
# [1 rows x 464 columns]

# %%
dhosps['01', 'whole']
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-14    28.160224
# 2021-04-15    29.682398
# 2021-04-16    29.530181
# 2021-04-17    28.312441
# 2021-04-18    28.312441
# Name: (01, whole), Length: 397, dtype: float64

# %%
dhosps.loc[:,('01', 'whole')]
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-14    28.160224
# 2021-04-15    29.682398
# 2021-04-16    29.530181
# 2021-04-17    28.312441
# 2021-04-18    28.312441
# Name: (01, whole), Length: 397, dtype: float64

# %% [markdown]
# ### (3) estimate data for missing (entity = dc.deps, clage = ['0-29', '30-59', '60+'])

# %% [markdown]
# La proportion observée au niveau régional pour la classe d'âge considérée par rapport à l'ensemble de la population est appliquée au taux départemental :
# Taux (département, classe d'âge) = taux (département) * taux (région, classe d'âge) / taux (région)

# %%
for entity in dc.deps:
    for clage in ['0-29', '30-59', '60+']:
        dhosps.loc[:,(entity, clage)] = (
            dhosps.loc[:,(entity, 'whole')]
            * dhosps.loc[:,(dc.dep2reg[entity], clage)]
            / dhosps.loc[:,(dc.dep2reg[entity], 'whole')]
#             * dpops_prop.loc[entity, clage]
#             / dpops_prop.loc[dc.dep2reg[entity], clage]
        )

# %%
dhosps.loc[:,('Auvergne-Rhône-Alpes', '0-29')]
# Out:
# jour
# 2020-03-18    0.141085
# 2020-03-19    0.176356
# 2020-03-20    0.141085
# 2020-03-21    0.246899
# 2020-03-22    0.387984
#                 ...
# 2021-04-14    2.151546
# 2021-04-15    2.010461
# 2021-04-16    2.151546
# 2021-04-17    2.116274
# 2021-04-18    2.116274
# Name: (Auvergne-Rhône-Alpes, 0-29), Length: 397, dtype: float64

# %% [markdown]
# ## Fonction

# %%
def estimate_deps(din, dindep, column):
    columns = pd.MultiIndex.from_tuples([(i, j) for i in dtes.entity.unique() for j in dtes.three_class.unique()],
                       name = ['entity', 'clage'])
    index = pd.Index(din.jour.unique(), name = "jour")
    dout = pd.DataFrame(index = index, columns = columns)

    din = din.copy().set_index(din.jour)
    for entity, clage in dout.columns:
        dout.loc[:,(entity,clage)] = din[(din.entity == entity) & (din.three_class == clage)][column]

    dindep = dindep.copy().set_index(dindep.jour)
    for entity in dindep.entity.unique():
        for clage in ['whole']:
            dout.loc[:,(entity, clage)] = dindep[(dindep.entity == entity)][column]

    for entity in dc.deps:
        for clage in ['0-29', '30-59', '60+']:
            dout.loc[:,(entity, clage)] = (
                dout.loc[:,(entity, 'whole')]
                * dout.loc[:,(dc.dep2reg[entity], clage)]
                / dout.loc[:,(dc.dep2reg[entity], 'whole')]
            )
    dout = pd.melt(dout.T.reset_index(), id_vars = ['entity', 'clage'], value_name = column)
    return dout

# %%
d1 = estimate_deps(dhos, dhosdep, "taux hosp")

# %%
d2 = estimate_deps(dhos, dhosdep, "taux rea")

# %%
d3 = estimate_deps(dhos, dhosdep, "taux décès")

# %%
dout = pd.merge(pd.merge(d1,d2), d3)
fname = path_temp + '-estimates-hosp.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ./Temp/v4/donnees-hospitalieres-classe-age-covid19-2021-04-18-19h10-estimates-hosp.csv

# %%
dout
# Out:
#                             entity  clage       jour   taux hosp   taux rea  \
# 0                               01   0-29 2020-03-18    0.020058   0.000000
# 1                               01  30-59 2020-03-18    0.152049   0.000000
# 2                               01    60+ 2020-03-18    0.855067   0.000000
# 3                               01  whole 2020-03-18    0.304435   0.000000
# 4                               02   0-29 2020-03-18    1.406754   0.176344
# ...                            ...    ...        ...         ...        ...
# 184203  Provence-Alpes-Côte d'Azur  whole 2021-04-18   64.304280  11.314072
# 184204               Île-de-France   0-29 2021-04-18    4.193719   0.438150
# 184205               Île-de-France  30-59 2021-04-18   40.355897  12.599896
# 184206               Île-de-France    60+ 2021-04-18  232.217853  44.258458
# 184207               Île-de-France  whole 2021-04-18   66.353320  14.546094
#
#         taux décès
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 184203    3.817510
# 184204    0.041729
# 184205    0.945999
# 184206   18.553591
# 184207    4.227001
#
# [184208 rows x 6 columns]
