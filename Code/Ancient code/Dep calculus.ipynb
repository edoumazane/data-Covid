# %%
# %matplotlib inline

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import time
import json

# %%
fname = 'dep-name.json'
with open(fname, 'r') as file:
    dep_name = json.loads(file.read())

# %%
tic = time.time()

# %%
fname = 'sp-pos-quot-dep-2021-03-28-19h20.csv'
d = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'dep': str})

# %%
d.sample(10)
# Out:
#         dep       jour   P    T  cl_age90       pop
# 83433    25 2021-03-02   2   27        90    6624.0
# 5475     02 2020-11-09  12  106        89   25627.0
# 355870  977 2020-05-30   0    0        90      35.0
# 329036   94 2020-09-04  42  754        49  189650.0
# 300280   86 2020-06-18   1   13        29   51459.0
# 215638   61 2021-02-03  10  178        59   38069.0
# 245241   70 2020-08-25   0   40        79   23536.0
# 168955   48 2020-10-03   0    3        69   11069.0
# 319683   91 2020-12-14  29  452        19  178366.0
# 27258    08 2021-01-27   6   41         9   28385.0

# %%
d.dtypes
# Out:
# dep                 object
# jour        datetime64[ns]
# P                    int64
# T                    int64
# cl_age90             int64
# pop                float64
# dtype: object

# %%
d.describe()
# Out:
#                    P              T       cl_age90           pop
# count  362648.000000  362648.000000  362648.000000  3.626480e+05
# mean       23.628599     343.060985      48.272727  1.173339e+05
# std        91.030944    1052.507968      30.265807  2.351773e+05
# min         0.000000       0.000000       0.000000  3.500000e+01
# 25%         0.000000      22.000000      19.000000  2.325950e+04
# 50%         3.000000      85.000000      49.000000  5.070600e+04
# 75%        15.000000     258.000000      79.000000  1.066215e+05
# max      4365.000000   45740.000000      90.000000  2.588988e+06

# %%
d['incidence'] = d['P'] / d['pop'] * 100000
d['positivite'] = d['P'] / d['T'] * 100

# %%
d.sample(10)
# Out:
#         dep       jour    P     T  cl_age90       pop   incidence  positivite
# 110929   31 2021-01-25  112  1396        59  174175.0   64.303143    8.022923
# 335438  971 2020-07-14    0     5        49   48928.0    0.000000    0.000000
# 176237   50 2020-10-31    7   108        69   69331.0   10.096494    6.481481
# 8402     03 2020-09-19    0     7        90    7107.0    0.000000    0.000000
# 294019   84 2020-08-22    1    22         9   63998.0    1.562549    4.545455
# 55196    16 2021-01-30   13    52        90    6701.0  194.000895   25.000000
# 175033   50 2020-07-14    0     0        19   56234.0    0.000000         NaN
# 209536   60 2020-06-10    1    51        89   31232.0    3.201844    1.960784
# 320677   91 2021-03-14   28   204        59  169548.0   16.514497   13.725490
# 236956   67 2021-03-11   45   942        59  155713.0   28.899321    4.777070

# %%
deps = d['dep'].unique()
ages = d['cl_age90'].unique()

# %%
tic1 = time.time()
d['incidence hebdo'] = np.zeros(len(d))
for dep in deps:
    for age in ages:
        d2 = d[(d['dep'] == dep) & (d['cl_age90'] == age)]
        d['temp'] = d2.apply(lambda x : (d2[ (d2['jour'] <= x['jour']) 
                                                        & (d2['jour'] > x['jour'] - np.timedelta64(1,'W'))]
                                                    ['incidence']
                                                    .sum()), axis = 1)
        d['incidence hebdo'] = d['incidence hebdo'] + d['temp'].fillna(0)
    toc1 = time.time()
    print('{:.2f} s : département {} ({})'.format(-tic1+toc1, dep, dep_name[dep]))
# Out:
# 2.34 s : département 01 (Ain)
# 4.66 s : département 02 (Aisne)
# 6.98 s : département 03 (Allier)
# 9.30 s : département 04 (Alpes-de-Haute-Provence)
# 11.61 s : département 05 (Hautes-Alpes)
# 13.94 s : département 06 (Alpes-Maritimes)
# 16.25 s : département 07 (Ardèche)
# 18.57 s : département 08 (Ardennes)
# 20.88 s : département 09 (Ariège)
# 23.20 s : département 10 (Aube)
# 25.51 s : département 11 (Aude)
# 27.84 s : département 12 (Aveyron)
# 30.17 s : département 13 (Bouches-du-Rhône)
# 32.49 s : département 14 (Calvados)
# 34.80 s : département 15 (Cantal)
# 37.15 s : département 16 (Charente)
# 39.49 s : département 17 (Charente-Maritime)
# 41.81 s : département 18 (Cher)
# 44.13 s : département 19 (Corrèze)
# 46.47 s : département 21 (Côte-d'Or)
# 48.79 s : département 22 (Côtes-d'Armor)
# 51.12 s : département 23 (Creuse)
# 53.47 s : département 24 (Dordogne)
# 55.80 s : département 25 (Doubs)
# 58.13 s : département 26 (Drôme)
# 60.47 s : département 27 (Eure)
# 62.83 s : département 28 (Eure-et-Loir)
# 65.20 s : département 29 (Finistère)
# 67.56 s : département 2A (Corse-du-Sud)
# 69.88 s : département 2B (Haute-Corse)
# 72.22 s : département 30 (Gard)
# 74.56 s : département 31 (Haute-Garonne)
# 76.90 s : département 32 (Gers)
# 79.21 s : département 33 (Gironde)
# 81.52 s : département 34 (Hérault)
# 83.85 s : département 35 (Ille-et-Vilaine)
# 86.16 s : département 36 (Indre)
# 88.48 s : département 37 (Indre-et-Loire)
# 90.82 s : département 38 (Isère)
# 93.20 s : département 39 (Jura)
# 95.55 s : département 40 (Landes)
# 97.86 s : département 41 (Loir-et-Cher)
# 100.17 s : département 42 (Loire)
# 102.50 s : département 43 (Haute-Loire)
# 104.87 s : département 44 (Loire-Atlantique)
# 107.22 s : département 45 (Loiret)
# 109.58 s : département 46 (Lot)
# 111.90 s : département 47 (Lot-et-Garonne)
# 114.22 s : département 48 (Lozère)
# 116.54 s : département 49 (Maine-et-Loire)
# 118.91 s : département 50 (Manche)
# 121.25 s : département 51 (Marne)
# 123.57 s : département 52 (Haute-Marne)
# 125.92 s : département 53 (Mayenne)
# 128.24 s : département 54 (Meurthe-et-Moselle)
# 130.57 s : département 55 (Meuse)
# 132.99 s : département 56 (Morbihan)
# 135.35 s : département 57 (Moselle)
# 137.71 s : département 58 (Nièvre)
# 140.08 s : département 59 (Nord)
# 142.52 s : département 60 (Oise)
# 144.87 s : département 61 (Orne)
# 147.24 s : département 62 (Pas-de-Calais)
# 149.58 s : département 63 (Puy-de-Dôme)
# 151.94 s : département 64 (Pyrénées-Atlantiques)
# 154.27 s : département 65 (Hautes-Pyrénées)
# 156.59 s : département 66 (Pyrénées-Orientales)
# 158.91 s : département 67 (Bas-Rhin)
# 161.22 s : département 68 (Haut-Rhin)
# 163.55 s : département 69 (Rhône)
# 165.87 s : département 70 (Haute-Saône)
# 168.19 s : département 71 (Saône-et-Loire)
# 170.51 s : département 72 (Sarthe)
# 172.82 s : département 73 (Savoie)
# 175.14 s : département 74 (Haute-Savoie)
# 177.45 s : département 75 (Paris)
# 179.77 s : département 76 (Seine-Maritime)
# 182.08 s : département 77 (Seine-et-Marne)
# 184.41 s : département 78 (Yvelines)
# 186.73 s : département 79 (Deux-Sèvres)
# 189.05 s : département 80 (Somme)
# 191.37 s : département 81 (Tarn)
# 193.70 s : département 82 (Tarn-et-Garonne)
# 196.03 s : département 83 (Var)
# 198.34 s : département 84 (Vaucluse)
# 200.64 s : département 85 (Vendée)
# 202.96 s : département 86 (Vienne)
# 205.27 s : département 87 (Haute-Vienne)
# 207.57 s : département 88 (Vosges)
# 209.89 s : département 89 (Yonne)
# 212.21 s : département 90 (Territoire de Belfort)
# 214.51 s : département 91 (Essonne)
# 216.84 s : département 92 (Hauts-de-Seine)
# 219.15 s : département 93 (Seine-Saint-Denis)
# 221.47 s : département 94 (Val-de-Marne)
# 223.79 s : département 95 (Val-d'Oise)
# 226.09 s : département 971 (Guadeloupe)
# 228.38 s : département 972 (Martinique)
# 230.68 s : département 973 (Guyane)
# 232.98 s : département 974 (La Réunion)
# 235.28 s : département 975 (Saint-Pierre-et-Miquelon)
# 237.58 s : département 976 (Mayotte)
# 239.91 s : département 977 (Saint-Barthélémy)
# 242.23 s : département 978 (Saint-Martin)

# %%
d = d.drop(columns = ['temp'])
fname2 = fname[:-4] + '-processed.csv'
d.to_csv(fname2, sep = ';')

# %%
d.sample(10)
# Out:
#        dep       jour   P    T  cl_age90       pop  incidence  positivite  \
# 46605   14 2020-09-05   0   17        90   10772.0   0.000000    0.000000
# 266829  76 2020-10-25  28  233        29  142048.0  19.711647   12.017167
# 251799  72 2020-07-18   0   12        90    9356.0   0.000000    0.000000
# 167085  47 2021-02-27   2  116        69   47036.0   4.252062    1.724138
# 136880  39 2020-08-01   1   12        79   26160.0   3.822630    8.333333
# 198143  56 2021-01-29   5   87         9   76812.0   6.509400    5.747126
# 179170  51 2020-09-11  16  386        29   68195.0  23.462131    4.145078
# 27061   08 2021-01-09   4  101        19   31952.0  12.518778    3.960396
# 56019   17 2020-06-02   0   15        79   77944.0   0.000000    0.000000
# 193196  55 2020-09-18   2   75        39   20573.0   9.721480    2.666667
#
#         incidence hebdo
# 46605          0.000000
# 266829       508.278892
# 251799         0.000000
# 167085        70.159027
# 136880         7.645260
# 198143        32.546998
# 179170       108.512354
# 27061        262.894342
# 56019          0.000000
# 193196        48.607398

# %%
toc = time.time()
print('notebook run in {:.2f} minutes.'.format((-tic+toc)/60))
# Out:
# notebook run in 4.09 minutes.
