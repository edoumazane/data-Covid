# %%
import pandas as pd
from time import time

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v4_dicts as dc
import my_package.v4_datepaths as dp
import my_package.v4_calculus as cc
# Out:
# Today is 16/04/2021. Retrieve data from how many days? 0
# Ok, will retrieve data from 16/04/2021

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-04-16-19h05.csv
# ./Temp/v4/sp-pos-quot-dep-2021-04-16-19h05-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour    P     T  cl_age90       pop
# 169091  45 2021-01-19  328  3837         0  682890.0
# 74127   22 2020-05-31    0     6        90   10814.0
# 332649  90 2020-05-13    0     2        90    1787.0
# (384384, 6)
#                   entity three_class       jour    P     T        pop
# 152896  Pays de la Loire        0-29 2021-01-24   51   817  1331149.0
# 25830                 21         60+ 2020-07-25    1   284   148425.0
# 126201                93       30-59 2021-03-11  788  6072   684201.0
# (155904, 6)
#        entity three_class       jour    P     T       pop  P hebdo  T hebdo  \
# 106118     78         60+ 2021-03-30  183  2140  326931.0   1007.0  11558.0
# 86220      64        0-29 2020-07-03    3   147  208299.0      5.0    875.0
# 81408      60        0-29 2020-11-21   34   409  301721.0    461.0   4844.0
#
#         incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 106118       308.016065                8.712580          3535.302556
# 86220          2.400396                0.571429           420.069227
# 81408        152.790160                9.516928          1605.456697
# (155904, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-04-16-19h11.csv
# ./Temp/v4/donnees-hospitalieres-classe-age-covid19-2021-04-16-19h11-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (78210, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 36602 2020-09-18    33    5       NaN       NaN     NaN  661  12
# 43320 2020-10-22     4    1       NaN       NaN     NaN   48   0
# 7383  2020-04-24    25   10       NaN       NaN     NaN   98   3
#
#                      entity three_class
# 36602  Auvergne-Rhône-Alpes       30-59
# 43320             Occitanie        0-29
# 7383          Île-de-France        0-29
# 'd_hosp_2: '
# (23700, 6)
#                 entity three_class       jour  hosp  rea    dc
# 3181          Bretagne       30-59 2020-03-23    30   10     0
# 9627   Hauts-de-France       whole 2020-04-23  2435  421  1233
# 12060        Normandie        0-29 2020-11-23    14    3     0
# 'd_hosp_3: '
# (23700, 10)
#           entity three_class       jour  hosp  rea  dc  dc hebdo  taux hosp  \
# 11673  Normandie       30-59 2020-08-18     7    1  31       1.0   0.569996
# 6334       Corse         60+ 2020-03-21    53   11   4       NaN  50.016987
# 8372   Grand Est        0-29 2020-07-14    17    2   3       0.0   0.906874
#
#         taux rea  taux décès
# 11673   0.081428    0.081428
# 6334   10.380884         NaN
# 8372    0.106691    0.000000

# %% [markdown]
# # Données hospitalières départementales (pas de répartition par classe d'âge !)

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-04-16-19h11.csv
# ./Temp/v4/donnees-hospitalieres-covid19-2021-04-16-19h11-compute.csv

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 119680  974     1 2021-04-16    79   25      38.0      16.0     0.0   667   88
# 119681  974     2 2021-04-16    65   13      41.0      11.0     0.0   649   60
# 119682  976     0 2021-04-16    12    6       6.0       0.0     0.0  1228  124
# 119683  976     1 2021-04-16     3    1       2.0       0.0     0.0   560   73
# 119684  976     2 2021-04-16     9    5       4.0       0.0     0.0   649   50
#
# [119685 rows x 10 columns]
# (119685, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 39890    976 2021-04-12    28    8      20.0       0.0     0.0  1212  124
# 39891    976 2021-04-13    15    6       9.0       0.0     0.0  1222  124
# 39892    976 2021-04-14    15    6       9.0       0.0     0.0  1222  124
# 39893    976 2021-04-15    12    6       6.0       0.0     0.0  1228  124
# 39894    976 2021-04-16    12    6       6.0       0.0     0.0  1228  124
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 39890       0.0  10.018929  2.862551         0.0
# 39891       0.0   5.367283  2.146913         0.0
# 39892       0.0   5.367283  2.146913         0.0
# 39893       0.0   4.293827  2.146913         0.0
# 39894       0.0   4.293827  2.146913         0.0
#
# [39895 rows x 13 columns]
# (39895, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-04-16-19h10.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-04ba1a85a748> in <module>
#       1 d_vac_1, path_temp = cc.vac_input()
#       2 d_vac_2 = cc.vac_tot_3C(d_vac_1)
# ----> 3 d_vac_3 = cc.vac_compute(d_vac_2)
#       4
#       5 dout = d_vac_3
#
# /home/edmz/data-Covid/Code/my_package/v4_calculus.py in vac_compute(din)
#     231                                                     [ x['entity'] ]
#     232                                                     [ x['three_class'] ] * 100,
# --> 233                          axis = "columns")
#     234     d['taux dose 2'] = d.apply(lambda x: x['n_cum_dose2'] / reg_3C_pop
#     235                                                     [ x['entity'] ]
#
# /home/edmz/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7763             kwds=kwds,
#    7764         )
# -> 7765         return op.get_result()
#    7766
#    7767     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# /home/edmz/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# /home/edmz/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# /home/edmz/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     288             for i, v in enumerate(series_gen):
#     289                 # ignore SettingWithCopy here in case the user mutates
# --> 290                 results[i] = self.f(v)
#     291                 if isinstance(results[i], ABCSeries):
#     292                     # If we have a view on v, we need to make a copy because
#
# KeyboardInterrupt:

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)

# %%
toc = time()
print(-tic+toc, ' s')
