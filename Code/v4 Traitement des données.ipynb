# %%
import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v4_dicts as dc
import my_package.v4_datepaths as dp
import my_package.v4_calculus as cc
# Out:
# Today is 20/04/2021. Retrieve data from how many days? 0
# Ok, will retrieve data from 20/04/2021

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-04-20-20h11.csv
# ./Temp/v4/sp-pos-quot-dep-2021-04-20-20h11-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour   P    T  cl_age90       pop
# 45741   13 2020-07-30  20  854        39  254362.0
# 215444  57 2020-12-04   8   97        90   11416.0
# 96415   27 2021-02-02   7  105         9   72945.0
# (388960, 6)
#       entity three_class       jour   P    T       pop
# 56555     41       whole 2020-11-27  72  956  327835.0
# 301       01       30-59 2020-07-27   9  344  265057.0
# 16301     12       30-59 2021-04-13  56  697  101784.0
# (157760, 6)
#       entity three_class       jour  P    T        pop  P hebdo  T hebdo  \
# 6895      06       whole 2020-06-05  8  969  1079396.0     41.0   4326.0
# 98219     72       whole 2020-07-26  2   84   560227.0     58.0   2943.0
# 71274     52         60+ 2020-09-28  3   84    56052.0     17.0    500.0
#
#        incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 6895          3.798421                0.947758           400.779695
# 98219        10.352946                1.970778           525.322771
# 71274        30.328980                3.400000           892.028830
# (157760, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-04-20-20h11.csv
# ./Temp/v4/donnees-hospitalieres-classe-age-covid19-2021-04-20-20h11-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (79002, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres    rad    dc  \
# 71609 2021-03-14   126    0      72.0      54.0     0.0   1210   598
# 19583 2020-06-24     2    1       NaN       NaN     NaN    302     1
# 17479 2020-06-14  4876  415       NaN       NaN     NaN  26343  7328
#
#                            entity three_class
# 71609            Pays de la Loire         60+
# 19583  Provence-Alpes-Côte d'Azur        0-29
# 17479               Île-de-France       whole
# 'd_hosp_2: '
# (23940, 6)
#                         entity three_class       jour  hosp  rea   dc
# 11574                Normandie         60+ 2020-06-26   205    5  402
# 8540                 Grand Est        0-29 2020-08-05     5    0    3
# 1712   Bourgogne-Franche-Comté        0-29 2020-04-16    13    2    0
# 'd_hosp_3: '
# (23940, 10)
#           entity three_class       jour  hosp  rea    dc  dc hebdo  taux hosp  \
# 23349     France       30-59 2020-11-24  3519  809  1828      70.0  13.702774
# 12744  Normandie        0-29 2021-04-15    22    2     1       0.0   1.958574
# 6741       Corse       30-59 2020-06-15     2    0     2       0.0   1.461999
#
#        taux rea  taux décès
# 23349  3.150197    0.272576
# 12744  0.178052    0.000000
# 6741   0.000000    0.000000

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-04-20-20h11.csv
# ./Temp/v4/donnees-hospitalieres-covid19-2021-04-20-20h11-compute.csv

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 120892  974     1 2021-04-20    92   25      52.0      15.0     0.0   686   88
# 120893  974     2 2021-04-20    58   15      34.0       9.0     0.0   667   64
# 120894  976     0 2021-04-20    16    6      10.0       0.0     0.0  1228  124
# 120895  976     1 2021-04-20     3    1       2.0       0.0     0.0   560   73
# 120896  976     2 2021-04-20    12    5       7.0       0.0     0.0   649   50
#
# [120897 rows x 10 columns]
# (120897, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 40294    976 2021-04-16    12    6       6.0       0.0     0.0  1228  124
# 40295    976 2021-04-17    14    6       8.0       0.0     0.0  1228  124
# 40296    976 2021-04-18    15    7       8.0       0.0     0.0  1228  124
# 40297    976 2021-04-19    15    7       8.0       0.0     0.0  1228  124
# 40298    976 2021-04-20    16    6      10.0       0.0     0.0  1228  124
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 40294       0.0   4.293827  2.146913         0.0
# 40295       0.0   5.009464  2.146913         0.0
# 40296       0.0   5.367283  2.504732         0.0
# 40297       0.0   5.367283  2.504732         0.0
# 40298       0.0   5.725102  2.146913         0.0
#
# [40299 rows x 13 columns]
# (40299, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-04-20-20h05.csv
# ./Temp/v4/vacsi-a-dep-2021-04-20-20h05-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (132924, 7)
#         dep  clage_vacsi       jour  n_dose1  n_dose2  n_cum_dose1  \
# 72400    62           64 2021-01-06       12        0           15
# 50959    43           74 2020-12-28        0        0            0
# 120482  978           69 2021-04-04        0        0          142
#
#         n_cum_dose2
# 72400             0
# 50959             0
# 120482           91

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (52896, 7)
#       entity three_class       jour  n_dose1  n_dose2  n_cum_dose1  \
# 24799     54       whole 2021-02-08      116      785        25182
# 48303  Corse       whole 2021-04-11     1170      336        78080
# 11492     27        0-29 2021-01-19        8        0          125
#
#        n_cum_dose2
# 24799        11552
# 48303        31393
# 11492            0

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (52896, 9)
#       entity three_class       jour  n_dose1  n_dose2  n_cum_dose1  \
# 23719     52       whole 2020-12-28        0        0            0
# 30580     67        0-29 2021-01-03        0        0            0
# 13021     2A       30-59 2021-02-28       16        4         1600
#
#        n_cum_dose2  taux dose 1  taux dose 2
# 23719            0     0.000000     0.000000
# 30580            0     0.000000     0.000000
# 13021          985     2.425382     1.493126

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 7.9039530754089355  s

# %% [markdown]
# # Données hospitalières (3) Estimation par classe d'âge et par département

# %% [markdown]
# ## dfs pops et pops_prop

# %% [markdown]
# ### df dpops

# %%
fname = dp.retrieve_temp('sp-pos-quot-dep', 'tot-3C-compute')
dtes = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v4/sp-pos-quot-dep-2021-04-20-20h11-tot-3C-compute.csv

# %%
columns = pd.Index(dtes.three_class.unique(), name = 'clage')
index = pd.Index(dtes.entity.unique(), name = 'entity')
dpops = pd.DataFrame(index = index, columns = columns)
dpops.sample()
# Out:
# clage  0-29 30-59  60+ whole
# entity
# 88      NaN   NaN  NaN   NaN

# %%
for entity in dtes.entity.unique():
    for clage in dtes.three_class.unique():
        dpops.loc[entity, clage] = dtes[(dtes.entity == entity) & (dtes.three_class == clage) & (dtes.jour == '2021-01-01')]["pop"].values[0]

# %%
dpops.sample()
# Out:
# clage       0-29     30-59       60+     whole
# entity
# 14      237080.0  252920.0  201453.0  691453.0

# %%
dpops.shape
dpops.loc['France', :]
dpops.loc['France','60+']
# Out:
# (116, 4)
# clage
# 0-29     23555651.0
# 30-59    25657812.0
# 60+      17850240.0
# whole    67063703.0
# Name: France, dtype: object
# 17850240.0

# %%
dout = dpops
fname = path_temp + '-pops.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ./Temp/v4/vacsi-a-dep-2021-04-20-20h05-pops.csv

# %% [markdown]
# ### df dpops_prop

# %%
dpops_prop = dpops.divide(dpops.whole, axis = 'index')
dpops_prop
# Out:
# clage                           0-29     30-59       60+ whole
# entity
# 01                          0.354913  0.403463  0.241624   1.0
# 02                          0.344635   0.37594  0.279426   1.0
# 03                          0.286133  0.358127   0.35574   1.0
# 04                          0.287838  0.369062  0.343099   1.0
# 05                          0.296248   0.37973  0.324022   1.0
# ...                              ...       ...       ...   ...
# Occitanie                   0.330174  0.374871  0.294955   1.0
# Outre-mer (DROM)            0.432203  0.375058  0.192739   1.0
# Pays de la Loire            0.350137  0.375243   0.27462   1.0
# Provence-Alpes-Côte d'Azur  0.324136  0.377594   0.29827   1.0
# Île-de-France               0.390357  0.404643     0.205   1.0
#
# [116 rows x 4 columns]

# %% [markdown]
# ## taux hosp

# %% [markdown]
# ### empty df dhosps

# %%
fname = dp.retrieve_temp('donnees-hospitalieres-classe-age-covid19', '3C-compute')
dhos = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
fname = dp.retrieve_temp('donnees-hospitalieres-covid19', 'compute')
dhosdep = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v4/donnees-hospitalieres-classe-age-covid19-2021-04-20-20h11-3C-compute.csv
# ./Temp/v4/donnees-hospitalieres-covid19-2021-04-20-20h11-compute.csv

# %%
columns = pd.MultiIndex.from_tuples([(i, j) for i in dpops.index.unique() for j in dtes.three_class.unique()],
                       name = ['entity', 'clage'])
index = pd.Index(dhos.jour.unique(), name = "jour")
dhosps = pd.DataFrame(index = index, columns = columns)
dhosps.shape
dhosps.sample()
# Out:
# (399, 464)
# entity       01                    02                    03        ...  \
# clage      0-29 30-59  60+ whole 0-29 30-59  60+ whole 0-29 30-59  ...
# jour                                                               ...
# 2020-09-14  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire       Provence-Alpes-Côte d'Azur                   \
# clage                   60+ whole                       0-29 30-59  60+ whole
# jour
# 2020-09-14              NaN   NaN                        NaN   NaN  NaN   NaN
#
# entity     Île-de-France
# clage               0-29 30-59  60+ whole
# jour
# 2020-09-14           NaN   NaN  NaN   NaN
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (1) fill it with data for each (entity = dc.regs, clage)

# %%
dhos.sample()
# Out:
#               entity three_class       jour  hosp  rea    dc  dc hebdo  \
# 21543  Île-de-France       whole 2020-10-02  2210  394  8120     107.0
#
#        taux hosp  taux rea  taux décès
# 21543  17.999366  3.208937    0.871463

# %%
dhos = dhos.set_index(dhos.jour)
dhos.sample()
# Out:
#                       entity three_class       jour  hosp  rea    dc  \
# jour
# 2020-12-08  Pays de la Loire         60+ 2020-12-08   846   68  1039
#
#             dc hebdo  taux hosp  taux rea  taux décès
# jour
# 2020-12-08      70.0  81.030524  6.513092    6.704653

# %%
for entity, clage in dhosps.columns:
    dhosps.loc[:,(entity,clage)] = dhos[(dhos.entity == entity) & (dhos.three_class == clage)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                   02                   03        ...  \
# clage      0-29 30-59 60+ whole 0-29 30-59 60+ whole 0-29 30-59  ...
# jour                                                             ...
# 2020-09-25  NaN   NaN NaN   NaN  NaN   NaN NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire           Provence-Alpes-Côte d'Azur            \
# clage                   60+     whole                       0-29     30-59
# jour
# 2020-09-25        12.259937  4.418963                   0.793302  7.176604
#
# entity                           Île-de-France
# clage             60+      whole          0-29     30-59        60+      whole
# jour
# 2020-09-25  42.043862  15.586519      1.210128  9.721645  54.508622  15.710759
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (2) fill it with data for each (entity = dc.deps, clage = ['whole'])

# %%
dhosdep.sample()
dhosdep = dhosdep.set_index(dhosdep.jour)
dhosdep.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 12308     30 2021-02-19   216   33       NaN       NaN     NaN  1790  427
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 12308      10.0  28.858949  4.409006    1.336062
#            entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad   dc  \
# jour
# 2021-03-31     04 2021-03-31   141    7      58.0      73.0     3.0  904  219
#
#             dc hebdo  taux hosp  taux rea  taux décès
# jour
# 2021-03-31      10.0   85.35264  4.237365    6.053379

# %%
for entity in dhosdep.entity.unique():
    for clage in ['whole']:
        dhosps.loc[:,(entity, clage)] = dhosdep[(dhosdep.entity == entity)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                        02                        03        \
# clage      0-29 30-59 60+      whole 0-29 30-59 60+      whole 0-29 30-59
# jour
# 2021-04-19  NaN   NaN NaN  28.464659  NaN   NaN NaN  62.921775  NaN   NaN
#
# entity      ... Pays de la Loire            Provence-Alpes-Côte d'Azur  \
# clage       ...              60+      whole                       0-29
# jour        ...
# 2021-04-19  ...        69.728394  24.093869                   2.440928
#
# entity                                     Île-de-France             \
# clage           30-59       60+      whole          0-29      30-59
# jour
# 2021-04-19  32.687596  172.7512  65.214153      4.235447  41.080491
#
# entity
# clage              60+      whole
# jour
# 2021-04-19  233.131628  66.866424
#
# [1 rows x 464 columns]

# %%
dhosps['01', 'whole']
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-16    29.530181
# 2021-04-17    28.312441
# 2021-04-18    28.312441
# 2021-04-19    28.464659
# 2021-04-20    29.225746
# Name: (01, whole), Length: 399, dtype: float64

# %%
dhosps.loc[:,('01', 'whole')]
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-16    29.530181
# 2021-04-17    28.312441
# 2021-04-18    28.312441
# 2021-04-19    28.464659
# 2021-04-20    29.225746
# Name: (01, whole), Length: 399, dtype: float64

# %% [markdown]
# ### (3) estimate data for missing (entity = dc.deps, clage = ['0-29', '30-59', '60+'])

# %% [markdown]
# La proportion observée au niveau régional pour la classe d'âge considérée par rapport à l'ensemble de la population est appliquée au taux départemental :
# Taux (département, classe d'âge) = taux (département) * taux (région, classe d'âge) / taux (région)

# %%
for entity in dc.deps:
    for clage in ['0-29', '30-59', '60+']:
        dhosps.loc[:,(entity, clage)] = (
            dhosps.loc[:,(entity, 'whole')]
            * dhosps.loc[:,(dc.dep2reg[entity], clage)]
            / dhosps.loc[:,(dc.dep2reg[entity], 'whole')]
#             * dpops_prop.loc[entity, clage]
#             / dpops_prop.loc[dc.dep2reg[entity], clage]
        )

# %%
dhosps.loc[:,('Auvergne-Rhône-Alpes', '0-29')]
# Out:
# jour
# 2020-03-18    0.141085
# 2020-03-19    0.176356
# 2020-03-20    0.141085
# 2020-03-21    0.246899
# 2020-03-22    0.387984
#                 ...
# 2021-04-16    2.151546
# 2021-04-17    2.116274
# 2021-04-18    2.116274
# 2021-04-19    2.292631
# 2021-04-20    2.292631
# Name: (Auvergne-Rhône-Alpes, 0-29), Length: 399, dtype: float64

# %% [markdown]
# ## Fonction

# %%
def estimate_deps(din, dindep, column):
    columns = pd.MultiIndex.from_tuples([(i, j) for i in dtes.entity.unique() for j in dtes.three_class.unique()],
                       name = ['entity', 'clage'])
    index = pd.Index(din.jour.unique(), name = "jour")
    dout = pd.DataFrame(index = index, columns = columns)

    din = din.copy().set_index(din.jour)
    for entity, clage in dout.columns:
        dout.loc[:,(entity,clage)] = din[(din.entity == entity) & (din.three_class == clage)][column]

    dindep = dindep.copy().set_index(dindep.jour)
    for entity in dindep.entity.unique():
        for clage in ['whole']:
            dout.loc[:,(entity, clage)] = dindep[(dindep.entity == entity)][column]

    for entity in dc.deps:
        for clage in ['0-29', '30-59', '60+']:
            dout.loc[:,(entity, clage)] = (
                dout.loc[:,(entity, 'whole')]
                * dout.loc[:,(dc.dep2reg[entity], clage)]
                / dout.loc[:,(dc.dep2reg[entity], 'whole')]
            )
    dout = pd.melt(dout.T.reset_index(), id_vars = ['entity', 'clage'], value_name = column)
    return dout

# %%
d1 = estimate_deps(dhos, dhosdep, "taux hosp")

# %%
d2 = estimate_deps(dhos, dhosdep, "taux rea")

# %%
d3 = estimate_deps(dhos, dhosdep, "taux décès")

# %%
dout = pd.merge(pd.merge(d1,d2), d3)
fname = path_temp + '-estimates-hosp.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ./Temp/v4/vacsi-a-dep-2021-04-20-20h05-estimates-hosp.csv

# %%
dout
# Out:
#                             entity  clage       jour   taux hosp   taux rea  \
# 0                               01   0-29 2020-03-18    0.020058   0.000000
# 1                               01  30-59 2020-03-18    0.152049   0.000000
# 2                               01    60+ 2020-03-18    0.855067   0.000000
# 3                               01  whole 2020-03-18    0.304435   0.000000
# 4                               02   0-29 2020-03-18    1.406754   0.176344
# ...                            ...    ...        ...         ...        ...
# 185131  Provence-Alpes-Côte d'Azur  whole 2021-04-20   63.671325  11.155833
# 185132               Île-de-France   0-29 2021-04-20    4.151990   0.625928
# 185133               Île-de-France  30-59 2021-04-20   40.577301  12.982321
# 185134               Île-de-France    60+ 2021-04-20  231.184891  43.980353
# 185135               Île-de-France  whole 2021-04-20   66.223008  14.668262
#
#         taux décès
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 185131    3.797730
# 185132    0.104321
# 185133    1.086892
# 185134   19.666012
# 185135    4.536492
#
# [185136 rows x 6 columns]
