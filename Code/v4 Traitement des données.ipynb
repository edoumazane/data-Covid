# %%
import pandas as pd
from time import time

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v4_dicts as dc
import my_package.v4_datepaths as dp
import my_package.v4_calculus as cc
# Out:
# Today is 18/04/2021. Retrieve data from how many days?
# Ok, will retrieve data from 17/04/2021

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-04-17-19h05.csv
# ./Temp/v4/sp-pos-quot-dep-2021-04-17-19h05-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour   P     T  cl_age90       pop
# 110091  2B 2021-01-03   0    33        39   22967.0
# 46733   13 2020-12-03  61  1219        59  265649.0
# 190710  51 2020-10-10  11   106        39   69338.0
# (385528, 6)
#        entity three_class       jour    P    T       pop
# 131353    972       30-59 2020-10-09   59  459  139918.0
# 8730       07         60+ 2020-10-20  117  448  107028.0
# 2970       03         60+ 2020-07-20    0  129  117862.0
# (156368, 6)
#       entity three_class       jour   P     T       pop  P hebdo  T hebdo  \
# 69785     51       30-59 2021-01-27  83  1202  211753.0    516.0   7823.0
# 90733     67       30-59 2020-08-25  32  1361  444563.0    155.0   7817.0
# 81673     60       30-59 2020-11-27  74  1163  327864.0    408.0   5712.0
#
#        incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 69785       243.680137                6.595935          3694.398663
# 90733        34.865700                1.982858          1758.355959
# 81673       124.441842                7.142857          1742.185784
# (156368, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-04-17-19h11.csv
# ./Temp/v4/donnees-hospitalieres-classe-age-covid19-2021-04-17-19h11-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (78408, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres   rad    dc  \
# 36692 2020-09-19   358   76       NaN       NaN     NaN  6102  1128
# 53060 2020-12-10     5    2       NaN       NaN     NaN    85    11
# 9576  2020-05-05    54   14       NaN       NaN     NaN   186    11
#
#                     entity three_class
# 36692        Île-de-France         60+
# 53060                Corse         60+
# 9576   Centre-Val de Loire       30-59
# 'd_hosp_2: '
# (23760, 6)
#                         entity three_class       jour  hosp  rea    dc
# 2163   Bourgogne-Franche-Comté       whole 2020-08-09    23    4  1062
# 18864         Pays de la Loire        0-29 2021-03-13    13    0     0
# 14119       Nouvelle-Aquitaine       whole 2021-03-14  1120  196  2981
# 'd_hosp_3: '
# (23760, 10)
#                      entity three_class       jour  hosp  rea    dc  dc hebdo  \
# 6879                  Corse       whole 2020-07-31     7    0    59       0.0
# 13437    Nouvelle-Aquitaine       30-59 2020-09-25    54   12    19       1.0
# 714    Auvergne-Rhône-Alpes         60+ 2020-09-12   410   51  1718      19.0
#
#        taux hosp  taux rea  taux décès
# 6879    2.030875  0.000000    0.000000
# 13437   2.409791  0.535509    0.044626
# 714    19.416473  2.415220    0.899788

# %% [markdown]
# # Données hospitalières départementales (pas de répartition par classe d'âge !)

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-04-17-19h11.csv
# ./Temp/v4/donnees-hospitalieres-covid19-2021-04-17-19h11-compute.csv

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 119983  974     1 2021-04-17    82   25      42.0      15.0     0.0   672   88
# 119984  974     2 2021-04-17    57   13      33.0      11.0     0.0   659   60
# 119985  976     0 2021-04-17    14    6       8.0       0.0     0.0  1228  124
# 119986  976     1 2021-04-17     3    1       2.0       0.0     0.0   560   73
# 119987  976     2 2021-04-17    11    5       6.0       0.0     0.0   649   50
#
# [119988 rows x 10 columns]
# (119988, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 39991    976 2021-04-13    15    6       9.0       0.0     0.0  1222  124
# 39992    976 2021-04-14    15    6       9.0       0.0     0.0  1222  124
# 39993    976 2021-04-15    12    6       6.0       0.0     0.0  1228  124
# 39994    976 2021-04-16    12    6       6.0       0.0     0.0  1228  124
# 39995    976 2021-04-17    14    6       8.0       0.0     0.0  1228  124
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 39991       0.0   5.367283  2.146913         0.0
# 39992       0.0   5.367283  2.146913         0.0
# 39993       0.0   4.293827  2.146913         0.0
# 39994       0.0   4.293827  2.146913         0.0
# 39995       0.0   5.009464  2.146913         0.0
#
# [39996 rows x 13 columns]
# (39996, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-04-17-19h10.csv
# ./Temp/v4/vacsi-a-dep-2021-04-17-19h10-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (129426, 7)
#        dep  clage_vacsi       jour  n_dose1  n_dose2  n_cum_dose1  n_cum_dose2
# 122010  38            0 2021-01-17        3        0         9077           12
# 32235   2A           24 2021-02-10        0        1           16            4
# 59659   52           74 2021-02-17        3       10          389          209

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (51504, 7)
#       entity three_class       jour  n_dose1  n_dose2  n_cum_dose1  \
# 40835     91       whole 2021-04-13     3646     2416       169802
# 34481     77       30-59 2021-03-10      619       60        15009
# 37461     84       30-59 2021-02-06       15       35         3705
#
#        n_cum_dose2
# 40835        62891
# 34481         6423
# 37461          832

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (51504, 9)
#       entity three_class       jour  n_dose1  n_dose2  n_cum_dose1  \
# 30406     68         60+ 2021-02-18     1294     1280        24622
# 12397     29       30-59 2021-04-08      923      447        34874
# 3795      09       whole 2021-02-25      205      135         7981
#
#        n_cum_dose2  taux dose 1  taux dose 2
# 30406         6583    11.955387     3.196422
# 12397        11963    10.344193     3.548420
# 3795          5821     5.236945     3.819604

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 7.874160528182983  s
