# %%
import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v4_dicts as dc
import my_package.v4_datepaths as dp
import my_package.v4_calculus as cc
# Out:
# Today is 24/04/2021. Retrieve data from how many days? 0
# Ok, will retrieve data from 24/04/2021

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-04-24-19h10.csv
# ./Temp/v4/sp-pos-quot-dep-2021-04-24-19h10-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour  P    T  cl_age90      pop
# 15946   05 2020-07-25  0    5        79  14617.0
# 77281   22 2020-10-05  9  162        69  87705.0
# 276944  73 2020-07-16  0   24        89  22041.0
# (393536, 6)
#        entity three_class       jour    P     T       pop
# 79276      57        0-29 2020-12-10  112  1326  340828.0
# 124902     90         60+ 2021-02-02   33   381   38060.0
# 82658      60         60+ 2020-06-06    2    33  195492.0
# (159616, 6)
#       entity three_class       jour    P     T       pop  P hebdo  T hebdo  \
# 56359     40       whole 2021-04-07   64  1852  411979.0    401.0  11674.0
# 4290      04         60+ 2020-06-22    0    59   56679.0      1.0    344.0
# 87412     63        0-29 2020-11-10  132  1204  222772.0    815.0   6816.0
#
#        incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 56359        97.335058                3.434984          2833.639579
# 4290          1.764322                0.290698           606.926728
# 87412       365.844900               11.957160          3059.630474
# (159616, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-04-24-19h05.csv
# ./Temp/v4/donnees-hospitalieres-classe-age-covid19-2021-04-24-19h05-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (79794, 10)
#            jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 7520 2020-04-24    11    2       NaN       NaN     NaN   28   1
# 787  2020-03-21    10    3       NaN       NaN     NaN    5   0
# 4401 2020-04-09     0    0       NaN       NaN     NaN    0   0
#
#                 entity three_class
# 7520             Corse         60+
# 787              Corse       30-59
# 4401  Outre-mer (DROM)        0-29
# 'd_hosp_2: '
# (24180, 6)
#                         entity three_class       jour  hosp  rea    dc
# 10598          Hauts-de-France         60+ 2020-11-04  2349  369  2454
# 2184   Bourgogne-Franche-Comté        0-29 2020-08-08     1    0     0
# 1833   Bourgogne-Franche-Comté       30-59 2020-05-12    87   17    27
# 'd_hosp_3: '
# (24180, 10)
#           entity three_class       jour  hosp  rea    dc  dc hebdo  taux hosp  \
# 15935  Occitanie       whole 2021-03-09  1340  243  3338     101.0  22.616576
# 6586       Corse         60+ 2020-04-21    59   11    46      10.0  55.679287
# 11864  Normandie        0-29 2020-08-10     0    0     0       0.0   0.000000
#
#         taux rea  taux décès
# 15935   4.101364    1.704682
# 6586   10.380884    9.437167
# 11864   0.000000    0.000000

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-04-24-19h05.csv
# ./Temp/v4/donnees-hospitalieres-covid19-2021-04-24-19h05-compute.csv

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 122104  974     1 2021-04-24    91   29      45.0      17.0     0.0   711   90
# 122105  974     2 2021-04-24    56   13      32.0      11.0     0.0   681   64
# 122106  976     0 2021-04-24    18    5      13.0       0.0     0.0  1228  124
# 122107  976     1 2021-04-24     4    1       3.0       0.0     0.0   560   73
# 122108  976     2 2021-04-24    13    4       9.0       0.0     0.0   649   50
#
# [122109 rows x 10 columns]
# (122109, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 40698    976 2021-04-20    16    6      10.0       0.0     0.0  1228  124
# 40699    976 2021-04-21    17    5      12.0       0.0     0.0  1228  124
# 40700    976 2021-04-22    17    5      12.0       0.0     0.0  1228  124
# 40701    976 2021-04-23    18    5      13.0       0.0     0.0  1228  124
# 40702    976 2021-04-24    18    5      13.0       0.0     0.0  1228  124
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 40698       0.0   5.725102  2.146913         0.0
# 40699       0.0   6.082921  1.789094         0.0
# 40700       0.0   6.082921  1.789094         0.0
# 40701       0.0   6.440740  1.789094         0.0
# 40702       0.0   6.440740  1.789094         0.0
#
# [40703 rows x 13 columns]
# (40703, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[d_vac_1.dep != '20']
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-04-24-19h11.csv
# ./Temp/v4/vacsi-a-dep-2021-04-24-19h11-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (137588, 7)
#       dep  clage_vacsi       jour  n_dose1  n_dose2  n_cum_dose1  n_cum_dose2
# 86935  71           69 2021-03-24      521       30         5378          986
# 57772  46           80 2021-03-07        1        1         5666         3383
# 73773  60           64 2021-01-19       52        0          477            1

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (54752, 7)
#       entity three_class       jour  n_dose1  n_dose2  n_cum_dose1  \
# 42015     89       whole 2020-12-28        0        0            0
# 41396     87        0-29 2021-03-20        8        2         1098
# 33279     70       whole 2021-02-24      127      234         9587
#
#        n_cum_dose2
# 42015            0
# 41396          180
# 33279         4752

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (54752, 9)
#       entity three_class       jour  n_dose1  n_dose2  n_cum_dose1  \
# 16493     34       30-59 2021-04-17      706      367        51282
# 35128     74        0-29 2021-02-15       25       10          280
# 436       01        0-29 2021-04-15       57        9         1541
#
#        n_cum_dose2  taux dose 1  taux dose 2
# 16493        13163    11.781247     3.023996
# 35128           61     0.095867     0.020885
# 436            191     0.660914     0.081917

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 8.051966667175293  s

# %% [markdown]
# # Données hospitalières (3) Estimation par classe d'âge et par département

# %% [markdown]
# ## dfs pops et pops_prop

# %% [markdown]
# ### df dpops

# %%
fname = dp.retrieve_temp('sp-pos-quot-dep', 'tot-3C-compute')
dtes = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v4/sp-pos-quot-dep-2021-04-24-19h10-tot-3C-compute.csv

# %%
columns = pd.Index(dtes.three_class.unique(), name = 'clage')
index = pd.Index(dtes.entity.unique(), name = 'entity')
dpops = pd.DataFrame(index = index, columns = columns)
dpops.sample()
# Out:
# clage  0-29 30-59  60+ whole
# entity
# 01      NaN   NaN  NaN   NaN

# %%
for entity in dtes.entity.unique():
    for clage in dtes.three_class.unique():
        dpops.loc[entity, clage] = dtes[(dtes.entity == entity) & (dtes.three_class == clage) & (dtes.jour == '2021-01-01')]["pop"].values[0]

# %%
dpops.sample()
# Out:
# clage         0-29       30-59         60+       whole
# entity
# France  23555651.0  25657812.0  17850240.0  67063703.0

# %%
dpops.shape
dpops.loc['France', :]
dpops.loc['France','60+']
# Out:
# (116, 4)
# clage
# 0-29     23555651.0
# 30-59    25657812.0
# 60+      17850240.0
# whole    67063703.0
# Name: France, dtype: object
# 17850240.0

# %%
dout = dpops
fname = path_temp + '-pops.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ./Temp/v4/vacsi-a-dep-2021-04-24-19h11-pops.csv

# %% [markdown]
# ### df dpops_prop

# %%
dpops_prop = dpops.divide(dpops.whole, axis = 'index')
dpops_prop
# Out:
# clage                           0-29     30-59       60+ whole
# entity
# 01                          0.354913  0.403463  0.241624   1.0
# 02                          0.344635   0.37594  0.279426   1.0
# 03                          0.286133  0.358127   0.35574   1.0
# 04                          0.287838  0.369062  0.343099   1.0
# 05                          0.296248   0.37973  0.324022   1.0
# ...                              ...       ...       ...   ...
# Occitanie                   0.330174  0.374871  0.294955   1.0
# Outre-mer (DROM)            0.432203  0.375058  0.192739   1.0
# Pays de la Loire            0.350137  0.375243   0.27462   1.0
# Provence-Alpes-Côte d'Azur  0.324136  0.377594   0.29827   1.0
# Île-de-France               0.390357  0.404643     0.205   1.0
#
# [116 rows x 4 columns]

# %% [markdown]
# ## taux hosp

# %% [markdown]
# ### empty df dhosps

# %%
fname = dp.retrieve_temp('donnees-hospitalieres-classe-age-covid19', '3C-compute')
dhos = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
fname = dp.retrieve_temp('donnees-hospitalieres-covid19', 'compute')
dhosdep = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v4/donnees-hospitalieres-classe-age-covid19-2021-04-24-19h05-3C-compute.csv
# ./Temp/v4/donnees-hospitalieres-covid19-2021-04-24-19h05-compute.csv

# %%
columns = pd.MultiIndex.from_tuples([(i, j) for i in dpops.index.unique() for j in dtes.three_class.unique()],
                       name = ['entity', 'clage'])
index = pd.Index(dhos.jour.unique(), name = "jour")
dhosps = pd.DataFrame(index = index, columns = columns)
dhosps.shape
dhosps.sample()
# Out:
# (403, 464)
# entity       01                    02                    03        ...  \
# clage      0-29 30-59  60+ whole 0-29 30-59  60+ whole 0-29 30-59  ...
# jour                                                               ...
# 2020-03-27  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire       Provence-Alpes-Côte d'Azur                   \
# clage                   60+ whole                       0-29 30-59  60+ whole
# jour
# 2020-03-27              NaN   NaN                        NaN   NaN  NaN   NaN
#
# entity     Île-de-France
# clage               0-29 30-59  60+ whole
# jour
# 2020-03-27           NaN   NaN  NaN   NaN
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (1) fill it with data for each (entity = dc.regs, clage)

# %%
dhos.sample()
# Out:
#               entity three_class       jour  hosp  rea    dc  dc hebdo  \
# 21611  Île-de-France       whole 2020-08-28  2291  173  7705      34.0
#
#        taux hosp  taux rea  taux décès
# 21611  18.659072     1.409    0.276913

# %%
dhos = dhos.set_index(dhos.jour)
dhos.sample()
# Out:
#                       entity three_class       jour  hosp  rea   dc  dc hebdo  \
# jour
# 2020-10-08  Outre-mer (DROM)         60+ 2020-10-08   216   36  190      21.0
#
#             taux hosp  taux rea  taux décès
# jour
# 2020-10-08  50.851408  8.475235    4.943887

# %%
for entity, clage in dhosps.columns:
    dhosps.loc[:,(entity,clage)] = dhos[(dhos.entity == entity) & (dhos.three_class == clage)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                   02                   03        ...  \
# clage      0-29 30-59 60+ whole 0-29 30-59 60+ whole 0-29 30-59  ...
# jour                                                             ...
# 2020-04-21  NaN   NaN NaN   NaN  NaN   NaN NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire            Provence-Alpes-Côte d'Azur             \
# clage                   60+      whole                       0-29      30-59
# jour
# 2020-04-21        63.406864  19.990547                   2.379905  16.134262
#
# entity                           Île-de-France                         \
# clage             60+      whole          0-29      30-59         60+
# jour
# 2020-04-21  94.830793  35.227906      4.423226  56.558638  363.404055
#
# entity
# clage           whole
# jour
# 2020-04-21  99.924989
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (2) fill it with data for each (entity = dc.deps, clage = ['whole'])

# %%
dhosdep.sample()
dhosdep = dhosdep.set_index(dhosdep.jour)
dhosdep.sample()
# Out:
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 20554     51 2020-03-19    39    7       NaN       NaN     NaN   14   2
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 20554       NaN   6.917064  1.241524         NaN
#            entity       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# jour
# 2020-06-21     04 2020-06-21     3    0       NaN       NaN     NaN  127  13
#
#             dc hebdo  taux hosp  taux rea  taux décès
# jour
# 2020-06-21       0.0   1.816014       0.0         0.0

# %%
for entity in dhosdep.entity.unique():
    for clage in ['whole']:
        dhosps.loc[:,(entity, clage)] = dhosdep[(dhosdep.entity == entity)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                      02                        03        ...  \
# clage      0-29 30-59 60+    whole 0-29 30-59 60+      whole 0-29 30-59  ...
# jour                                                                     ...
# 2020-07-26  NaN   NaN NaN  4.71874  NaN   NaN NaN  11.025568  NaN   NaN  ...
#
# entity     Pays de la Loire           Provence-Alpes-Côte d'Azur            \
# clage                   60+     whole                       0-29     30-59
# jour
# 2020-07-26         7.279338  2.446212                   0.061023  1.833439
#
# entity                          Île-de-France
# clage             60+     whole          0-29      30-59        60+      whole
# jour
# 2020-07-26  23.276649  7.654801      1.418771  10.627388  84.901549  22.462558
#
# [1 rows x 464 columns]

# %%
dhosps['01', 'whole']
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-20    29.225746
# 2021-04-21    29.834616
# 2021-04-22    27.551354
# 2021-04-23    28.008007
# 2021-04-24    28.312441
# Name: (01, whole), Length: 403, dtype: float64

# %%
dhosps.loc[:,('01', 'whole')]
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-20    29.225746
# 2021-04-21    29.834616
# 2021-04-22    27.551354
# 2021-04-23    28.008007
# 2021-04-24    28.312441
# Name: (01, whole), Length: 403, dtype: float64

# %% [markdown]
# ### (3) estimate data for missing (entity = dc.deps, clage = ['0-29', '30-59', '60+'])

# %% [markdown]
# La proportion observée au niveau régional pour la classe d'âge considérée par rapport à l'ensemble de la population est appliquée au taux départemental :
# Taux (département, classe d'âge) = taux (département) * taux (région, classe d'âge) / taux (région)

# %%
for entity in dc.deps:
    for clage in ['0-29', '30-59', '60+']:
        dhosps.loc[:,(entity, clage)] = (
            dhosps.loc[:,(entity, 'whole')]
            * dhosps.loc[:,(dc.dep2reg[entity], clage)]
            / dhosps.loc[:,(dc.dep2reg[entity], 'whole')]
#             * dpops_prop.loc[entity, clage]
#             / dpops_prop.loc[dc.dep2reg[entity], clage]
        )

# %%
dhosps.loc[:,('Auvergne-Rhône-Alpes', '0-29')]
# Out:
# jour
# 2020-03-18    0.141085
# 2020-03-19    0.176356
# 2020-03-20    0.141085
# 2020-03-21    0.246899
# 2020-03-22    0.387984
#                 ...
# 2021-04-20    2.292631
# 2021-04-21    2.222088
# 2021-04-22    2.292631
# 2021-04-23    2.186817
# 2021-04-24    2.010461
# Name: (Auvergne-Rhône-Alpes, 0-29), Length: 403, dtype: float64

# %% [markdown]
# ## Fonction

# %%
def estimate_deps(din, dindep, column):
    columns = pd.MultiIndex.from_tuples([(i, j) for i in dtes.entity.unique() for j in dtes.three_class.unique()],
                       name = ['entity', 'clage'])
    index = pd.Index(din.jour.unique(), name = "jour")
    dout = pd.DataFrame(index = index, columns = columns)

    din = din.copy().set_index(din.jour)
    for entity, clage in dout.columns:
        dout.loc[:,(entity,clage)] = din[(din.entity == entity) & (din.three_class == clage)][column]

    dindep = dindep.copy().set_index(dindep.jour)
    for entity in dindep.entity.unique():
        for clage in ['whole']:
            dout.loc[:,(entity, clage)] = dindep[(dindep.entity == entity)][column]

    for entity in dc.deps:
        for clage in ['0-29', '30-59', '60+']:
            dout.loc[:,(entity, clage)] = (
                dout.loc[:,(entity, 'whole')]
                * dout.loc[:,(dc.dep2reg[entity], clage)]
                / dout.loc[:,(dc.dep2reg[entity], 'whole')]
            )
    dout = pd.melt(dout.T.reset_index(), id_vars = ['entity', 'clage'], value_name = column)
    return dout

# %%
d1 = estimate_deps(dhos, dhosdep, "taux hosp")

# %%
d2 = estimate_deps(dhos, dhosdep, "taux rea")

# %%
d3 = estimate_deps(dhos, dhosdep, "taux décès")

# %%
dout = pd.merge(pd.merge(d1,d2), d3)
fname = path_temp + '-estimates-hosp.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ./Temp/v4/vacsi-a-dep-2021-04-24-19h11-estimates-hosp.csv

# %%
dout
# Out:
#                             entity  clage       jour   taux hosp   taux rea  \
# 0                               01   0-29 2020-03-18    0.020058   0.000000
# 1                               01  30-59 2020-03-18    0.152049   0.000000
# 2                               01    60+ 2020-03-18    0.855067   0.000000
# 3                               01  whole 2020-03-18    0.304435   0.000000
# 4                               02   0-29 2020-03-18    1.406754   0.176344
# ...                            ...    ...        ...         ...        ...
# 186987  Provence-Alpes-Côte d'Azur  whole 2021-04-24   60.704348  10.720677
# 186988               Île-de-France   0-29 2021-04-24    3.964212   0.584200
# 186989               Île-de-France  30-59 2021-04-24   39.067728  13.143342
# 186990               Île-de-France    60+ 2021-04-24  223.040381  42.430910
# 186991               Île-de-France  whole 2021-04-24   63.893678  14.407638
#
#         taux décès
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 186987    3.817510
# 186988    0.083457
# 186989    0.925871
# 186990   19.507094
# 186991    4.438758
#
# [186992 rows x 6 columns]
