# %%
import pandas as pd
from time import time
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import my_package.v4_dicts as dc
import my_package.v4_datepaths as dp
import my_package.v4_calculus as cc
# Out:
# Today is 26/04/2021. Retrieve data from how many days?
# Ok, will retrieve data from 25/04/2021

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %% [markdown]
# # Données relatives aux résultats des tests virologiques

# %%
tic = time()

# %%
d_tests_1, path_temp = cc.sp_input()
d_tests_2 = cc.sp_tot_3C(d_tests_1)
d_tests_3 = cc.sp_compute(d_tests_2)

dout = d_tests_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/sp-pos-quot-dep-2021-04-25-19h05.csv
# ./Temp/v4/sp-pos-quot-dep-2021-04-25-19h05-tot-3C-compute.csv

# %%
#
d_tests_1.sample(3)
d_tests_1.shape
#
d_tests_2.sample(3)
d_tests_2.shape
#
d_tests_3.sample(3)
d_tests_3.shape
# Out:
#        dep       jour   P    T  cl_age90       pop
# 234140  61 2021-01-08  14  218        59   38069.0
# 317306  83 2020-12-10   4   73         9  108243.0
# 18705   05 2021-03-29  21  177        59   20029.0
# (394680, 6)
#        entity three_class       jour    P     T        pop
# 118167     85       whole 2020-12-15   95  2172   683187.0
# 144967  Corse       whole 2020-05-29    1   256   344679.0
# 49575      35       whole 2021-03-27  290  4583  1082073.0
# (160080, 6)
#        entity three_class       jour   P    T        pop  P hebdo  T hebdo  \
# 132043     95       whole 2021-01-03  64  850  1248354.0   1780.0  29781.0
# 11669      09       30-59 2020-10-17  13   54    56230.0    195.0   1958.0
# 76317      55       30-59 2020-08-25   1  155    68269.0      3.0    685.0
#
#         incidence hebdo  taux de positifs hebdo  taux de tests hebdo
# 132043       142.587760                5.976965          2385.621386
# 11669        346.789970                9.959142          3482.126978
# 76317          4.394381                0.437956          1003.383673
# (160080, 11)

# %% [markdown]
# # Données hospitalières

# %%
d_hosp_1, path_temp = cc.hosp_input()
d_hosp_2 = cc.hosp_3C(d_hosp_1)
d_hosp_3 = cc.hosp_compute(d_hosp_2)

dout = d_hosp_3
fname = path_temp + '-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-04-25-19h10.csv
# ./Temp/v4/donnees-hospitalieres-classe-age-covid19-2021-04-25-19h10-3C-compute.csv

# %%
'd_hosp_1: '
d_hosp_1.shape
d_hosp_1.sample(3)
'd_hosp_2: '
d_hosp_2.shape
d_hosp_2.sample(3)
'd_hosp_3: '
d_hosp_3.shape
d_hosp_3.sample(3)
# Out:
# 'd_hosp_1: '
# (79992, 10)
#             jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc  \
# 35028 2020-09-10    11    1       NaN       NaN     NaN  528   3
# 19694 2020-06-25     4    1       NaN       NaN     NaN   95   2
# 5045  2020-04-12   158   57       NaN       NaN     NaN  112  32
#
#                            entity three_class
# 35028  Provence-Alpes-Côte d'Azur       30-59
# 19694                   Normandie       30-59
# 5045                    Normandie         60+
# 'd_hosp_2: '
# (24240, 6)
#                            entity three_class       jour  hosp  rea  dc
# 20716  Provence-Alpes-Côte d'Azur        0-29 2021-02-12    33    3   2
# 15625                   Occitanie       30-59 2020-12-13   128   34  53
# 19388            Pays de la Loire        0-29 2021-04-25    16    4   0
# 'd_hosp_3: '
# (24240, 10)
#                    entity three_class       jour  hosp  rea   dc  dc hebdo  \
# 16829    Outre-mer (DROM)       30-59 2020-09-01    67   11   23       3.0
# 16978    Outre-mer (DROM)         60+ 2020-10-08   216   36  190      21.0
# 13328  Nouvelle-Aquitaine        0-29 2020-06-26     2    0    2       0.0
#
#        taux hosp  taux rea  taux décès
# 16829   8.020101  1.316733    0.359109
# 16978  50.851408  8.475235    4.943887
# 13328   0.105878  0.000000    0.000000

# %% [markdown]
# # Données hospitalières départementales (2) : pas de répartition par classe d'âge !

# %%
d_hosp_dep_1, path_temp = cc.hosp_dep_input()
d_hosp_dep_2 = cc.hosp_dep_compute(d_hosp_dep_1)

dout = d_hosp_dep_2
fname = path_temp + '-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/donnees-hospitalieres-covid19-2021-04-25-19h10.csv
# ./Temp/v4/donnees-hospitalieres-covid19-2021-04-25-19h10-compute.csv

# %%
d_hosp_dep_1
d_hosp_dep_1.shape
d_hosp_dep_2
d_hosp_dep_2.shape
# Out:
#         dep  sexe       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc
# 0        01     0 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1        01     1 2020-03-18     1    0       NaN       NaN     NaN     1    0
# 2        01     2 2020-03-18     1    0       NaN       NaN     NaN     0    0
# 3        02     0 2020-03-18    41   10       NaN       NaN     NaN    18   11
# 4        02     1 2020-03-18    19    4       NaN       NaN     NaN    11    6
# ...     ...   ...        ...   ...  ...       ...       ...     ...   ...  ...
# 122407  974     1 2021-04-25    93   26      50.0      17.0     0.0   712   90
# 122408  974     2 2021-04-25    57   14      32.0      11.0     0.0   683   65
# 122409  976     0 2021-04-25    18    5      13.0       0.0     0.0  1228  124
# 122410  976     1 2021-04-25     4    1       3.0       0.0     0.0   560   73
# 122411  976     2 2021-04-25    13    4       9.0       0.0     0.0   649   50
#
# [122412 rows x 10 columns]
# (122412, 10)
#       entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 0         01 2020-03-18     2    0       NaN       NaN     NaN     1    0
# 1         01 2020-03-19     2    0       NaN       NaN     NaN     1    0
# 2         01 2020-03-20     2    0       NaN       NaN     NaN     1    0
# 3         01 2020-03-21     4    0       NaN       NaN     NaN     1    0
# 4         01 2020-03-22     8    1       NaN       NaN     NaN     2    0
# ...      ...        ...   ...  ...       ...       ...     ...   ...  ...
# 40799    976 2021-04-21    17    5      12.0       0.0     0.0  1228  124
# 40800    976 2021-04-22    17    5      12.0       0.0     0.0  1228  124
# 40801    976 2021-04-23    18    5      13.0       0.0     0.0  1228  124
# 40802    976 2021-04-24    18    5      13.0       0.0     0.0  1228  124
# 40803    976 2021-04-25    18    5      13.0       0.0     0.0  1228  124
#
#        dc hebdo  taux hosp  taux rea  taux décès
# 0           NaN   0.304435  0.000000         NaN
# 1           NaN   0.304435  0.000000         NaN
# 2           NaN   0.304435  0.000000         NaN
# 3           NaN   0.608870  0.000000         NaN
# 4           NaN   1.217739  0.152217         NaN
# ...         ...        ...       ...         ...
# 40799       0.0   6.082921  1.789094         0.0
# 40800       0.0   6.082921  1.789094         0.0
# 40801       0.0   6.440740  1.789094         0.0
# 40802       0.0   6.440740  1.789094         0.0
# 40803       0.0   6.440740  1.789094         0.0
#
# [40804 rows x 13 columns]
# (40804, 13)

# %% [markdown]
# # Données relatives aux personnes vaccinées (VACSI)

# %%
d_vac_1, path_temp = cc.vac_input()
d_vac_1 = d_vac_1[d_vac_1.dep != '20']
d_vac_2 = cc.vac_tot_3C(d_vac_1)
d_vac_3 = cc.vac_compute(d_vac_2)

dout = d_vac_3
fname = path_temp + '-tot-3C-compute.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ../Data/vacsi-a-dep-2021-04-25-19h10.csv
# ./Temp/v4/vacsi-a-dep-2021-04-25-19h10-tot-3C-compute.csv

# %%
print(d_vac_1.shape)
d_vac_1.sample(3)
# Out:
# (138754, 7)
#       dep  clage_vacsi       jour  n_dose1  n_dose2  n_cum_dose1  n_cum_dose2
# 11414  09           64 2021-04-15      157       24         2978          510
# 8670   07           39 2021-04-08       45       49         1409          683
# 50505  40           59 2021-02-14        0        0         2401         1240

# %%
print(d_vac_2.shape)
d_vac_2.sample(3)
# Out:
# (55216, 7)
#      entity three_class       jour  n_dose1  n_dose2  n_cum_dose1  n_cum_dose2
# 2435     06       whole 2021-01-09      381        0         2038            0
# 1298     03         60+ 2021-03-23     1111      318        35053        18426
# 5794     13         60+ 2021-01-16      216        7         2402            7

# %%
print(d_vac_3.shape)
d_vac_3.sample(3)
# Out:
# (55216, 9)
#               entity three_class       jour  n_dose1  n_dose2  n_cum_dose1  \
# 30481             64       30-59 2020-12-31        0        0            0
# 55105  Île-de-France       30-59 2021-03-28     2448       32       307253
# 35871             75       whole 2021-02-07      151      826        77566
#
#        n_cum_dose2  taux dose 1  taux dose 2
# 30481            0     0.000000     0.000000
# 55105        77934     6.184274     1.568627
# 35871        11366     3.610625     0.529077

# %%
toc = time()
print(-tic+toc, ' s')
# Out:
# 8.106494665145874  s

# %% [markdown]
# # Données hospitalières (3) Estimation par classe d'âge et par département

# %% [markdown]
# ## dfs pops et pops_prop

# %% [markdown]
# ### df dpops

# %%
fname = dp.retrieve_temp('sp-pos-quot-dep', 'tot-3C-compute')
dtes = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v4/sp-pos-quot-dep-2021-04-25-19h05-tot-3C-compute.csv

# %%
columns = pd.Index(dtes.three_class.unique(), name = 'clage')
index = pd.Index(dtes.entity.unique(), name = 'entity')
dpops = pd.DataFrame(index = index, columns = columns)
dpops.sample()
# Out:
# clage  0-29 30-59  60+ whole
# entity
# 71      NaN   NaN  NaN   NaN

# %%
for entity in dtes.entity.unique():
    for clage in dtes.three_class.unique():
        dpops.loc[entity, clage] = dtes[(dtes.entity == entity) & (dtes.three_class == clage) & (dtes.jour == '2021-01-01')]["pop"].values[0]

# %%
dpops.sample()
# Out:
# clage       0-29     30-59       60+     whole
# entity
# 81      117950.0  143783.0  126165.0  387898.0

# %%
dpops.shape
dpops.loc['France', :]
dpops.loc['France','60+']
# Out:
# (116, 4)
# clage
# 0-29     23555651.0
# 30-59    25657812.0
# 60+      17850240.0
# whole    67063703.0
# Name: France, dtype: object
# 17850240.0

# %%
dout = dpops
fname = path_temp + '-pops.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ./Temp/v4/vacsi-a-dep-2021-04-25-19h10-pops.csv

# %% [markdown]
# ### df dpops_prop

# %%
dpops_prop = dpops.divide(dpops.whole, axis = 'index')
dpops_prop
# Out:
# clage                           0-29     30-59       60+ whole
# entity
# 01                          0.354913  0.403463  0.241624   1.0
# 02                          0.344635   0.37594  0.279426   1.0
# 03                          0.286133  0.358127   0.35574   1.0
# 04                          0.287838  0.369062  0.343099   1.0
# 05                          0.296248   0.37973  0.324022   1.0
# ...                              ...       ...       ...   ...
# Occitanie                   0.330174  0.374871  0.294955   1.0
# Outre-mer (DROM)            0.432203  0.375058  0.192739   1.0
# Pays de la Loire            0.350137  0.375243   0.27462   1.0
# Provence-Alpes-Côte d'Azur  0.324136  0.377594   0.29827   1.0
# Île-de-France               0.390357  0.404643     0.205   1.0
#
# [116 rows x 4 columns]

# %% [markdown]
# ## taux hosp

# %% [markdown]
# ### empty df dhosps

# %%
fname = dp.retrieve_temp('donnees-hospitalieres-classe-age-covid19', '3C-compute')
dhos = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
fname = dp.retrieve_temp('donnees-hospitalieres-covid19', 'compute')
dhosdep = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
# Out:
# ./Temp/v4/donnees-hospitalieres-classe-age-covid19-2021-04-25-19h10-3C-compute.csv
# ./Temp/v4/donnees-hospitalieres-covid19-2021-04-25-19h10-compute.csv

# %%
columns = pd.MultiIndex.from_tuples([(i, j) for i in dpops.index.unique() for j in dtes.three_class.unique()],
                       name = ['entity', 'clage'])
index = pd.Index(dhos.jour.unique(), name = "jour")
dhosps = pd.DataFrame(index = index, columns = columns)
dhosps.shape
dhosps.sample()
# Out:
# (404, 464)
# entity       01                    02                    03        ...  \
# clage      0-29 30-59  60+ whole 0-29 30-59  60+ whole 0-29 30-59  ...
# jour                                                               ...
# 2020-07-02  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire       Provence-Alpes-Côte d'Azur                   \
# clage                   60+ whole                       0-29 30-59  60+ whole
# jour
# 2020-07-02              NaN   NaN                        NaN   NaN  NaN   NaN
#
# entity     Île-de-France
# clage               0-29 30-59  60+ whole
# jour
# 2020-07-02           NaN   NaN  NaN   NaN
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (1) fill it with data for each (entity = dc.regs, clage)

# %%
dhos.sample()
# Out:
#         entity three_class       jour  hosp  rea  dc  dc hebdo  taux hosp  \
# 3793  Bretagne       30-59 2020-08-05    18    6  10       0.0   1.445565
#
#       taux rea  taux décès
# 3793  0.481855         0.0

# %%
dhos = dhos.set_index(dhos.jour)
dhos.sample()
# Out:
#                                 entity three_class       jour  hosp  rea  \
# jour
# 2020-09-13  Provence-Alpes-Côte d'Azur       whole 2020-09-13   577  123
#
#               dc  dc hebdo  taux hosp  taux rea  taux décès
# jour
# 2020-09-13  1044      39.0  11.412971  2.432921    0.771414

# %%
for entity, clage in dhosps.columns:
    dhosps.loc[:,(entity,clage)] = dhos[(dhos.entity == entity) & (dhos.three_class == clage)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                   02                   03        ...  \
# clage      0-29 30-59 60+ whole 0-29 30-59 60+ whole 0-29 30-59  ...
# jour                                                             ...
# 2020-08-15  NaN   NaN NaN   NaN  NaN   NaN NaN   NaN  NaN   NaN  ...
#
# entity     Pays de la Loire           Provence-Alpes-Côte d'Azur            \
# clage                   60+     whole                       0-29     30-59
# jour
# 2020-08-15         8.332926  2.761852                    0.18307  2.409663
#
# entity                          Île-de-France
# clage             60+     whole          0-29     30-59        60+      whole
# jour
# 2020-08-15  18.767213  6.566909      1.543956  9.802155  78.505129  20.882523
#
# [1 rows x 464 columns]

# %% [markdown]
# ### (2) fill it with data for each (entity = dc.deps, clage = ['whole'])

# %%
dhosdep.sample()
dhosdep = dhosdep.set_index(dhosdep.jour)
dhosdep.sample()
# Out:
#     entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad   dc  \
# 550     02 2020-08-11    52    9       NaN       NaN     NaN  1101  281
#
#      dc hebdo  taux hosp  taux rea  taux décès
# 550       1.0   9.884992  1.710864    0.190096
#            entity       jour  hosp  rea  HospConv  SSR_USLD  autres   rad  \
# jour
# 2021-02-08     49 2021-02-08   282   41       NaN       NaN     NaN  2048
#
#              dc  dc hebdo  taux hosp  taux rea  taux décès
# jour
# 2021-02-08  510      22.0  34.563864  5.025243    2.696472

# %%
for entity in dhosdep.entity.unique():
    for clage in ['whole']:
        dhosps.loc[:,(entity, clage)] = dhosdep[(dhosdep.entity == entity)]["taux hosp"]

# %%
dhosps.sample()
# Out:
# entity       01                       02                       03        ...  \
# clage      0-29 30-59 60+     whole 0-29 30-59 60+     whole 0-29 30-59  ...
# jour                                                                     ...
# 2020-08-24  NaN   NaN NaN  3.805436  NaN   NaN NaN  8.364224  NaN   NaN  ...
#
# entity     Pays de la Loire           Provence-Alpes-Côte d'Azur           \
# clage                   60+     whole                       0-29    30-59
# jour
# 2020-08-24         8.045584  2.814459                   0.427162  3.03827
#
# entity                          Île-de-France
# clage             60+     whole          0-29     30-59       60+     whole
# jour
# 2020-08-24  18.700898  7.002066      1.314449  9.480113  73.81707  19.68528
#
# [1 rows x 464 columns]

# %%
dhosps['01', 'whole']
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-21    29.834616
# 2021-04-22    27.551354
# 2021-04-23    28.008007
# 2021-04-24    28.312441
# 2021-04-25    28.312441
# Name: (01, whole), Length: 404, dtype: float64

# %%
dhosps.loc[:,('01', 'whole')]
# Out:
# jour
# 2020-03-18     0.304435
# 2020-03-19     0.304435
# 2020-03-20     0.304435
# 2020-03-21     0.608870
# 2020-03-22     1.217739
#                 ...
# 2021-04-21    29.834616
# 2021-04-22    27.551354
# 2021-04-23    28.008007
# 2021-04-24    28.312441
# 2021-04-25    28.312441
# Name: (01, whole), Length: 404, dtype: float64

# %% [markdown]
# ### (3) estimate data for missing (entity = dc.deps, clage = ['0-29', '30-59', '60+'])

# %% [markdown]
# La proportion observée au niveau régional pour la classe d'âge considérée par rapport à l'ensemble de la population est appliquée au taux départemental :
# Taux (département, classe d'âge) = taux (département) * taux (région, classe d'âge) / taux (région)

# %%
for entity in dc.deps:
    for clage in ['0-29', '30-59', '60+']:
        dhosps.loc[:,(entity, clage)] = (
            dhosps.loc[:,(entity, 'whole')]
            * dhosps.loc[:,(dc.dep2reg[entity], clage)]
            / dhosps.loc[:,(dc.dep2reg[entity], 'whole')]
#             * dpops_prop.loc[entity, clage]
#             / dpops_prop.loc[dc.dep2reg[entity], clage]
        )

# %%
dhosps.loc[:,('Auvergne-Rhône-Alpes', '0-29')]
# Out:
# jour
# 2020-03-18    0.141085
# 2020-03-19    0.176356
# 2020-03-20    0.141085
# 2020-03-21    0.246899
# 2020-03-22    0.387984
#                 ...
# 2021-04-21    2.222088
# 2021-04-22    2.292631
# 2021-04-23    2.186817
# 2021-04-24    2.010461
# 2021-04-25    1.798833
# Name: (Auvergne-Rhône-Alpes, 0-29), Length: 404, dtype: float64

# %% [markdown]
# ## Fonction

# %%
def estimate_deps(din, dindep, column):
    columns = pd.MultiIndex.from_tuples([(i, j) for i in dtes.entity.unique() for j in dtes.three_class.unique()],
                       name = ['entity', 'clage'])
    index = pd.Index(din.jour.unique(), name = "jour")
    dout = pd.DataFrame(index = index, columns = columns)

    din = din.copy().set_index(din.jour)
    for entity, clage in dout.columns:
        dout.loc[:,(entity,clage)] = din[(din.entity == entity) & (din.three_class == clage)][column]

    dindep = dindep.copy().set_index(dindep.jour)
    for entity in dindep.entity.unique():
        for clage in ['whole']:
            dout.loc[:,(entity, clage)] = dindep[(dindep.entity == entity)][column]

    for entity in dc.deps:
        for clage in ['0-29', '30-59', '60+']:
            dout.loc[:,(entity, clage)] = (
                dout.loc[:,(entity, 'whole')]
                * dout.loc[:,(dc.dep2reg[entity], clage)]
                / dout.loc[:,(dc.dep2reg[entity], 'whole')]
            )
    dout = pd.melt(dout.T.reset_index(), id_vars = ['entity', 'clage'], value_name = column)
    return dout

# %%
d1 = estimate_deps(dhos, dhosdep, "taux hosp")

# %%
d2 = estimate_deps(dhos, dhosdep, "taux rea")

# %%
d3 = estimate_deps(dhos, dhosdep, "taux décès")

# %%
dout = pd.merge(pd.merge(d1,d2), d3)
fname = path_temp + '-estimates-hosp.csv'
dout.to_csv(fname, sep = ';', index = False)
print(fname)
# Out:
# ./Temp/v4/vacsi-a-dep-2021-04-25-19h10-estimates-hosp.csv

# %%
dout
# Out:
#                             entity  clage       jour   taux hosp   taux rea  \
# 0                               01   0-29 2020-03-18    0.020058   0.000000
# 1                               01  30-59 2020-03-18    0.152049   0.000000
# 2                               01    60+ 2020-03-18    0.855067   0.000000
# 3                               01  whole 2020-03-18    0.304435   0.000000
# 4                               02   0-29 2020-03-18    1.406754   0.176344
# ...                            ...    ...        ...         ...        ...
# 187451  Provence-Alpes-Côte d'Azur  whole 2021-04-25   61.119725  10.799796
# 187452               Île-de-France   0-29 2021-04-25    3.985076   0.563335
# 187453               Île-de-France  30-59 2021-04-25   39.792323  13.304363
# 187454               Île-de-France    60+ 2021-04-25  224.629554  42.152805
# 187455               Île-de-France  whole 2021-04-25   64.561528  14.399493
#
#         taux décès
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 187451    3.698831
# 187452    0.083457
# 187453    0.925871
# 187454   19.228989
# 187455    4.381746
#
# [187456 rows x 6 columns]
