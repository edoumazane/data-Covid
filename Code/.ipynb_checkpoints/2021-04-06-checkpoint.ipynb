# %%
# %matplotlib inline

import time
import datetime as dt
import os
import glob
import json

import itertools as it

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

os.getcwd()
# Out:
# '/home/edmz/Data Covid/Code'

# %%
from dictfns import *
from graphfns import *

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %%
print(today)
print(date_choice)
print(date)
print(date_text)
# Out:
# 2021-04-05
# 2021-04-05
# 2021-04-05
# 05/04/2021

# %% [markdown]
# ### File paths

# %%
print('SIDEP\n   Données d\'entrée :') 
print(path_test)
print(fname_temp_test)
print(fname_output_test)

print('Données hospitalières\n   Données d\'entrée :') 
print(path_hosp)
print(fname_temp_hosp)
print(fname_output_hosp)

print('VAC-SI\n   Données d\'entrée :') 
print(path_vac)
print(fname_temp_vac)
print(fname_output_vac)
# Out:
# SIDEP
#    Données d'entrée :
# ['../Data/sp-pos-quot-dep-2021-04-05-19h25.csv']
# ./Temp/sp-pos-quot-dep-2021-04-05-19h25
# ../Output/sp-pos-quot-dep-2021-04-05-19h25
# Données hospitalières
#    Données d'entrée :
# ['../Data/donnees-hospitalieres-classe-age-covid19-2021-04-05-19h19.csv']
# ./Temp/donnees-hospitalieres-classe-age-covid19-2021-04-05-19h19
# ../Output/donnees-hospitalieres-classe-age-covid19-2021-04-05-19h19
# VAC-SI
#    Données d'entrée :
# ['../Data/vacsi-a-dep-2021-04-05-19h30.csv']
# ./Temp/vacsi-a-dep-2021-04-05-19h30
# ../Output/vacsi-a-dep-2021-04-05-19h30

# %% [markdown]
# ### Dictionnaries

# %%
print('Dict. reg_name\n     "11" :', reg_name['11'])
print('Dict. reg2dep\n     "Corse" :', reg2dep['Corse'])
print('Dict. dep2reg\n     "75" :', dep2reg['75'])
print('Dict. dep_name\n     "67" :', dep_name['67'])
print('Dict. class_2_3C\n      29 : ', class_2_3C[29])
print('Dict reg_3C_pop\n     "Grand Est" :', reg_3C_pop['Grand Est'])
print('Dict reg_2lignes\n      "Auvergne-Rhône-Alpes" :', reg_2lignes["Auvergne-Rhône-Alpes"], sep = '\n')
# Out:
# Dict. reg_name
#      "11" : Île-de-France
# Dict. reg2dep
#      "Corse" : ['2A', '2B']
# Dict. dep2reg
#      "75" : Île-de-France
# Dict. dep_name
#      "67" : Bas-Rhin
# Dict. class_2_3C
#       29 :  0-29
# Dict reg_3C_pop
#      "Grand Est" : {'0-29': 1874571, '30-59': 2124342, '60+': 1512834, 'whole': 5511747}
# Dict reg_2lignes
#       "Auvergne-Rhône-Alpes" :
# Auvergne-
# Rhône-Alpes

# %% [markdown]
# ### Functions

# %%
help(groupby_sum)
# Out:
# Help on function groupby_sum in module dictfns:
#
# groupby_sum(d, columns)
#     d: dataframe
#     columns: list of column names
#     returns: dataframe is grouped according to columns fed in
#             other columns are summed
#             dataframe is then formatted into a dataframe

# %%
help(columns_first)
# Out:
# Help on function columns_first in module dictfns:
#
# columns_first(d, columns)
#     d: dataframe
#     by: a list of column names
#     returns: dataframe reordered

# %%
help(calc_hebdo)
# Out:
# Help on function calc_hebdo in module dictfns:
#
# calc_hebdo(d, columns_to_group, columns_to_sum)
#     d: a dataframe
#     columns_to_group: list of columns from which groups will be formed
#             for example ['entity', 'three_class'] -> will calculate hebdo for regionA, class1, regionA, class2, etc.
#     columns_to_sum: list of columns which values will be summed on a week-wise base
#             for example ['P', 'T']

# %% [markdown]
# # Traitement des données SIDEP

# %%
fname = path_test[0]
din = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'dep': str})
din.sample(3)
# Out:
#        dep       jour  P    T  cl_age90      pop
# 64728   19 2020-06-16  0    8        49  29167.0
# 295285  82 2020-11-23  9   94        19  33408.0
# 94492   28 2020-09-30  6  120        29  39348.0

# %%
d = din.copy()
d = d.rename(columns = {'dep': 'entity'})
d = columns_first(d, columns = ['entity', 'cl_age90', 'jour'])
d_dep = d
d_dep.sample(3)
# Out:
#        entity  cl_age90       jour  P   T      pop
# 146699     41        39 2020-05-24  0   2  34921.0
# 221131     61        90 2021-02-14  0   7   5705.0
# 141986     39        90 2020-12-31  6  67   4585.0

# %%
d = din.copy()
d['reg'] = d['dep'].map(lambda x: dep2reg[x])
d = d.drop(columns = ['dep'])
dg = groupby_sum(d, columns = ['reg', 'jour', 'cl_age90'])
dg = d.rename(columns = {'reg': 'entity'})
dg = columns_first(dg, columns = ['entity', 'cl_age90', 'jour'])
d_reg = dg
d_reg.sample(3)
# Out:
#                       entity  cl_age90       jour  P    T      pop
# 38907              Occitanie         9 2021-02-24  2   42  36668.0
# 234709             Occitanie        29 2020-12-11  8  113  19425.0
# 265064  Auvergne-Rhône-Alpes        89 2020-06-28  0    8  31929.0

# %%
d = din.copy()
d = d.drop(columns = ['dep'])
dg = groupby_sum(d, columns = ['jour', 'cl_age90'])
dg['entity'] = 'France entière'
dg = columns_first(dg, columns = ['entity', 'cl_age90', 'jour'])
d_nat = dg
d_nat.sample(3)
# Out:
#               entity  cl_age90       jour     P      T           pop
# 957   France entière         0 2020-08-08   984  49335  6.711500e+07
# 666   France entière        59 2020-07-12    12    881  8.792675e+06
# 3495  France entière        79 2021-03-26  1922  30993  5.695639e+06

# %%
d = pd.merge(d_dep, d_reg, how = 'outer')
dout = pd.merge(d, d_nat, how = 'outer')
dout = columns_first(dout, columns = ['entity', 'cl_age90', 'jour'])
dout.head(3)
# Out:
#   entity  cl_age90       jour  P   T      pop
# 0     01         9 2020-05-13  0  16  83001.0
# 1     01        19 2020-05-13  1  17  84665.0
# 2     01        29 2020-05-13  0  34  65496.0

# %%
dout.tail(3)
# Out:
#                 entity  cl_age90       jour     P      T           pop
# 747172  France entière        79 2021-04-02  1867  27514  5.695639e+06
# 747173  France entière        89 2021-04-02  1033  15357  3.245281e+06
# 747174  France entière        90 2021-04-02   350   7367  9.125806e+05

# %%
fname = fname_temp_test + '-tot.csv'
dout.to_csv(fname, sep = ';', index = False)

# %% [markdown]
# ### SIDEP - 3 classes d'âge

# %%
fname = fname_temp_test + '-tot.csv'
din = pd.read_csv(fname, 
                sep = ';', 
                parse_dates = ['jour'], 
                dtype = {'entity': str},
                skiprows = [])
din.tail(3)
# Out:
#                 entity  cl_age90       jour     P      T           pop
# 747172  France entière        79 2021-04-02  1867  27514  5.695639e+06
# 747173  France entière        89 2021-04-02  1033  15357  3.245281e+06
# 747174  France entière        90 2021-04-02   350   7367  9.125806e+05

# %%
d = din.copy()
d['three_class'] = d['cl_age90'].map(lambda x: class_2_3C[x])
d = d.drop(columns = 'cl_age90')
dg = groupby_sum(d,['entity', 'jour', 'three_class'])
dg = columns_first(dg, columns = ['entity', 'three_class', 'jour'])
dout = dg
dout.tail(10)
# Out:
#                entity three_class       jour      P       T         pop
# 154690  Île-de-France         60+ 2021-03-31   1582   15567   2517033.0
# 154691  Île-de-France       whole 2021-03-31  13626  134632  12278210.0
# 154692  Île-de-France        0-29 2021-04-01   4923   65869   4792882.0
# 154693  Île-de-France       30-59 2021-04-01   6190   61540   4968295.0
# 154694  Île-de-France         60+ 2021-04-01   1546   15442   2517033.0
# 154695  Île-de-France       whole 2021-04-01  12664  142905  12278210.0
# 154696  Île-de-France        0-29 2021-04-02   4816   69009   4792882.0
# 154697  Île-de-France       30-59 2021-04-02   5871   66808   4968295.0
# 154698  Île-de-France         60+ 2021-04-02   1418   16171   2517033.0
# 154699  Île-de-France       whole 2021-04-02  12108  152071  12278210.0

# %%
fname = fname_temp_test + '-tot-3C.csv'
dout.to_csv(fname, sep = ';', index = False)

# %% [markdown]
# ### SIDEP - calculs chiffres hebdomadaires

# %%
fname = fname_temp_test + '-tot-3C.csv'
din = pd.read_csv(fname, 
                sep = ';', 
                parse_dates = ['jour'], 
                dtype = {'entity': str},
                skiprows = [])
din.sample(3)
# Out:
#        entity three_class       jour   P     T           pop
# 134752    978        0-29 2020-12-12   2    16  1.545147e+04
# 32334      26         60+ 2021-02-20  24   370  1.506940e+05
# 77092      59        0-29 2020-08-19  48  1828  1.005422e+06

# %%
d = din.copy()

dh = calc_hebdo(d, 
           columns_to_group = ['entity', 'three_class'], 
           columns_to_sum = ['P', 'T'])
# Out:
# 0.38 s : (P hebdo, T hebdo) calculated for (01, 0-29)
# 0.77 s : (P hebdo, T hebdo) calculated for (01, 30-59)
# 1.15 s : (P hebdo, T hebdo) calculated for (01, 60+)
# 1.54 s : (P hebdo, T hebdo) calculated for (01, whole)
# 1.91 s : (P hebdo, T hebdo) calculated for (02, 0-29)
# 2.30 s : (P hebdo, T hebdo) calculated for (02, 30-59)
# 2.68 s : (P hebdo, T hebdo) calculated for (02, 60+)
# 3.09 s : (P hebdo, T hebdo) calculated for (02, whole)
# 3.46 s : (P hebdo, T hebdo) calculated for (03, 0-29)
# 3.83 s : (P hebdo, T hebdo) calculated for (03, 30-59)
# 4.22 s : (P hebdo, T hebdo) calculated for (03, 60+)
# 4.60 s : (P hebdo, T hebdo) calculated for (03, whole)
# 4.98 s : (P hebdo, T hebdo) calculated for (04, 0-29)
# 5.37 s : (P hebdo, T hebdo) calculated for (04, 30-59)
# 5.77 s : (P hebdo, T hebdo) calculated for (04, 60+)
# 6.15 s : (P hebdo, T hebdo) calculated for (04, whole)
# 6.53 s : (P hebdo, T hebdo) calculated for (05, 0-29)
# 6.91 s : (P hebdo, T hebdo) calculated for (05, 30-59)
# 7.28 s : (P hebdo, T hebdo) calculated for (05, 60+)
# 7.66 s : (P hebdo, T hebdo) calculated for (05, whole)
# 8.03 s : (P hebdo, T hebdo) calculated for (06, 0-29)
# 8.41 s : (P hebdo, T hebdo) calculated for (06, 30-59)
# 8.78 s : (P hebdo, T hebdo) calculated for (06, 60+)
# 9.15 s : (P hebdo, T hebdo) calculated for (06, whole)
# 9.52 s : (P hebdo, T hebdo) calculated for (07, 0-29)
# 9.90 s : (P hebdo, T hebdo) calculated for (07, 30-59)
# 10.31 s : (P hebdo, T hebdo) calculated for (07, 60+)
# 10.68 s : (P hebdo, T hebdo) calculated for (07, whole)
# 11.05 s : (P hebdo, T hebdo) calculated for (08, 0-29)
# 11.42 s : (P hebdo, T hebdo) calculated for (08, 30-59)
# 11.79 s : (P hebdo, T hebdo) calculated for (08, 60+)
# 12.17 s : (P hebdo, T hebdo) calculated for (08, whole)
# 12.54 s : (P hebdo, T hebdo) calculated for (09, 0-29)
# 12.91 s : (P hebdo, T hebdo) calculated for (09, 30-59)
# 13.29 s : (P hebdo, T hebdo) calculated for (09, 60+)
# 13.66 s : (P hebdo, T hebdo) calculated for (09, whole)
# 14.06 s : (P hebdo, T hebdo) calculated for (10, 0-29)
# 14.44 s : (P hebdo, T hebdo) calculated for (10, 30-59)
# 14.81 s : (P hebdo, T hebdo) calculated for (10, 60+)
# 15.20 s : (P hebdo, T hebdo) calculated for (10, whole)
# 15.58 s : (P hebdo, T hebdo) calculated for (11, 0-29)
# 15.96 s : (P hebdo, T hebdo) calculated for (11, 30-59)
# 16.35 s : (P hebdo, T hebdo) calculated for (11, 60+)
# 16.76 s : (P hebdo, T hebdo) calculated for (11, whole)
# 17.14 s : (P hebdo, T hebdo) calculated for (12, 0-29)
# 17.54 s : (P hebdo, T hebdo) calculated for (12, 30-59)
# 17.91 s : (P hebdo, T hebdo) calculated for (12, 60+)
# 18.28 s : (P hebdo, T hebdo) calculated for (12, whole)
# 18.65 s : (P hebdo, T hebdo) calculated for (13, 0-29)
# 19.03 s : (P hebdo, T hebdo) calculated for (13, 30-59)
# 19.41 s : (P hebdo, T hebdo) calculated for (13, 60+)
# 19.78 s : (P hebdo, T hebdo) calculated for (13, whole)
# 20.18 s : (P hebdo, T hebdo) calculated for (14, 0-29)
# 20.56 s : (P hebdo, T hebdo) calculated for (14, 30-59)
# 20.94 s : (P hebdo, T hebdo) calculated for (14, 60+)
# 21.31 s : (P hebdo, T hebdo) calculated for (14, whole)
# 21.74 s : (P hebdo, T hebdo) calculated for (15, 0-29)
# 22.14 s : (P hebdo, T hebdo) calculated for (15, 30-59)
# 22.54 s : (P hebdo, T hebdo) calculated for (15, 60+)
# 22.94 s : (P hebdo, T hebdo) calculated for (15, whole)
# 23.36 s : (P hebdo, T hebdo) calculated for (16, 0-29)
# 23.75 s : (P hebdo, T hebdo) calculated for (16, 30-59)
# 24.14 s : (P hebdo, T hebdo) calculated for (16, 60+)
# 24.53 s : (P hebdo, T hebdo) calculated for (16, whole)
# 24.90 s : (P hebdo, T hebdo) calculated for (17, 0-29)
# 25.27 s : (P hebdo, T hebdo) calculated for (17, 30-59)
# 25.64 s : (P hebdo, T hebdo) calculated for (17, 60+)
# 26.02 s : (P hebdo, T hebdo) calculated for (17, whole)
# 26.44 s : (P hebdo, T hebdo) calculated for (18, 0-29)
# 26.82 s : (P hebdo, T hebdo) calculated for (18, 30-59)
# 27.19 s : (P hebdo, T hebdo) calculated for (18, 60+)
# 27.58 s : (P hebdo, T hebdo) calculated for (18, whole)
# 27.95 s : (P hebdo, T hebdo) calculated for (19, 0-29)
# 28.34 s : (P hebdo, T hebdo) calculated for (19, 30-59)
# 28.72 s : (P hebdo, T hebdo) calculated for (19, 60+)
# 29.09 s : (P hebdo, T hebdo) calculated for (19, whole)
# 29.47 s : (P hebdo, T hebdo) calculated for (21, 0-29)
# 29.84 s : (P hebdo, T hebdo) calculated for (21, 30-59)
# 30.21 s : (P hebdo, T hebdo) calculated for (21, 60+)
# 30.59 s : (P hebdo, T hebdo) calculated for (21, whole)
# 30.96 s : (P hebdo, T hebdo) calculated for (22, 0-29)
# 31.35 s : (P hebdo, T hebdo) calculated for (22, 30-59)
# 31.72 s : (P hebdo, T hebdo) calculated for (22, 60+)
# 32.10 s : (P hebdo, T hebdo) calculated for (22, whole)
# 32.50 s : (P hebdo, T hebdo) calculated for (23, 0-29)
# 32.88 s : (P hebdo, T hebdo) calculated for (23, 30-59)
# 33.25 s : (P hebdo, T hebdo) calculated for (23, 60+)
# 33.62 s : (P hebdo, T hebdo) calculated for (23, whole)
# 34.02 s : (P hebdo, T hebdo) calculated for (24, 0-29)
# 34.41 s : (P hebdo, T hebdo) calculated for (24, 30-59)
# 34.79 s : (P hebdo, T hebdo) calculated for (24, 60+)
# 35.16 s : (P hebdo, T hebdo) calculated for (24, whole)
# 35.54 s : (P hebdo, T hebdo) calculated for (25, 0-29)
# 35.91 s : (P hebdo, T hebdo) calculated for (25, 30-59)
# 36.28 s : (P hebdo, T hebdo) calculated for (25, 60+)
# 36.66 s : (P hebdo, T hebdo) calculated for (25, whole)
# 37.03 s : (P hebdo, T hebdo) calculated for (26, 0-29)
# 37.40 s : (P hebdo, T hebdo) calculated for (26, 30-59)
# 37.78 s : (P hebdo, T hebdo) calculated for (26, 60+)
# 38.16 s : (P hebdo, T hebdo) calculated for (26, whole)
# 38.54 s : (P hebdo, T hebdo) calculated for (27, 0-29)
# 38.91 s : (P hebdo, T hebdo) calculated for (27, 30-59)
# 39.28 s : (P hebdo, T hebdo) calculated for (27, 60+)
# 39.65 s : (P hebdo, T hebdo) calculated for (27, whole)
# 40.03 s : (P hebdo, T hebdo) calculated for (28, 0-29)
# 40.41 s : (P hebdo, T hebdo) calculated for (28, 30-59)
# 40.78 s : (P hebdo, T hebdo) calculated for (28, 60+)
# 41.16 s : (P hebdo, T hebdo) calculated for (28, whole)
# 41.53 s : (P hebdo, T hebdo) calculated for (29, 0-29)
# 41.93 s : (P hebdo, T hebdo) calculated for (29, 30-59)
# 42.31 s : (P hebdo, T hebdo) calculated for (29, 60+)
# 42.68 s : (P hebdo, T hebdo) calculated for (29, whole)
# 43.05 s : (P hebdo, T hebdo) calculated for (2A, 0-29)
# 43.42 s : (P hebdo, T hebdo) calculated for (2A, 30-59)
# 43.79 s : (P hebdo, T hebdo) calculated for (2A, 60+)
# 44.16 s : (P hebdo, T hebdo) calculated for (2A, whole)
# 44.53 s : (P hebdo, T hebdo) calculated for (2B, 0-29)
# 44.92 s : (P hebdo, T hebdo) calculated for (2B, 30-59)
# 45.29 s : (P hebdo, T hebdo) calculated for (2B, 60+)
# 45.66 s : (P hebdo, T hebdo) calculated for (2B, whole)
# 46.05 s : (P hebdo, T hebdo) calculated for (30, 0-29)
# 46.42 s : (P hebdo, T hebdo) calculated for (30, 30-59)
# 46.79 s : (P hebdo, T hebdo) calculated for (30, 60+)
# 47.17 s : (P hebdo, T hebdo) calculated for (30, whole)
# 47.56 s : (P hebdo, T hebdo) calculated for (31, 0-29)
# 47.94 s : (P hebdo, T hebdo) calculated for (31, 30-59)
# 48.33 s : (P hebdo, T hebdo) calculated for (31, 60+)
# 48.72 s : (P hebdo, T hebdo) calculated for (31, whole)
# 49.13 s : (P hebdo, T hebdo) calculated for (32, 0-29)
# 49.51 s : (P hebdo, T hebdo) calculated for (32, 30-59)
# 49.90 s : (P hebdo, T hebdo) calculated for (32, 60+)
# 50.29 s : (P hebdo, T hebdo) calculated for (32, whole)
# 50.68 s : (P hebdo, T hebdo) calculated for (33, 0-29)
# 51.06 s : (P hebdo, T hebdo) calculated for (33, 30-59)
# 51.43 s : (P hebdo, T hebdo) calculated for (33, 60+)
# 51.81 s : (P hebdo, T hebdo) calculated for (33, whole)
# 52.18 s : (P hebdo, T hebdo) calculated for (34, 0-29)
# 52.56 s : (P hebdo, T hebdo) calculated for (34, 30-59)
# 52.94 s : (P hebdo, T hebdo) calculated for (34, 60+)
# 53.32 s : (P hebdo, T hebdo) calculated for (34, whole)
# 53.70 s : (P hebdo, T hebdo) calculated for (35, 0-29)
# 54.09 s : (P hebdo, T hebdo) calculated for (35, 30-59)
# 54.48 s : (P hebdo, T hebdo) calculated for (35, 60+)
# 54.86 s : (P hebdo, T hebdo) calculated for (35, whole)
# 55.24 s : (P hebdo, T hebdo) calculated for (36, 0-29)
# 55.65 s : (P hebdo, T hebdo) calculated for (36, 30-59)
# 56.03 s : (P hebdo, T hebdo) calculated for (36, 60+)
# 56.42 s : (P hebdo, T hebdo) calculated for (36, whole)
# 56.81 s : (P hebdo, T hebdo) calculated for (37, 0-29)
# 57.20 s : (P hebdo, T hebdo) calculated for (37, 30-59)
# 57.58 s : (P hebdo, T hebdo) calculated for (37, 60+)
# 57.97 s : (P hebdo, T hebdo) calculated for (37, whole)
# 58.35 s : (P hebdo, T hebdo) calculated for (38, 0-29)
# 58.73 s : (P hebdo, T hebdo) calculated for (38, 30-59)
# 59.11 s : (P hebdo, T hebdo) calculated for (38, 60+)
# 59.48 s : (P hebdo, T hebdo) calculated for (38, whole)
# 59.86 s : (P hebdo, T hebdo) calculated for (39, 0-29)
# 60.25 s : (P hebdo, T hebdo) calculated for (39, 30-59)
# 60.62 s : (P hebdo, T hebdo) calculated for (39, 60+)
# 61.00 s : (P hebdo, T hebdo) calculated for (39, whole)
# 61.37 s : (P hebdo, T hebdo) calculated for (40, 0-29)
# 61.74 s : (P hebdo, T hebdo) calculated for (40, 30-59)
# 62.12 s : (P hebdo, T hebdo) calculated for (40, 60+)
# 62.49 s : (P hebdo, T hebdo) calculated for (40, whole)
# 62.87 s : (P hebdo, T hebdo) calculated for (41, 0-29)
# 63.24 s : (P hebdo, T hebdo) calculated for (41, 30-59)
# 63.62 s : (P hebdo, T hebdo) calculated for (41, 60+)
# 64.00 s : (P hebdo, T hebdo) calculated for (41, whole)
# 64.37 s : (P hebdo, T hebdo) calculated for (42, 0-29)
# 64.75 s : (P hebdo, T hebdo) calculated for (42, 30-59)
# 65.17 s : (P hebdo, T hebdo) calculated for (42, 60+)
# 65.54 s : (P hebdo, T hebdo) calculated for (42, whole)
# 65.92 s : (P hebdo, T hebdo) calculated for (43, 0-29)
# 66.30 s : (P hebdo, T hebdo) calculated for (43, 30-59)
# 66.67 s : (P hebdo, T hebdo) calculated for (43, 60+)
# 67.05 s : (P hebdo, T hebdo) calculated for (43, whole)
# 67.42 s : (P hebdo, T hebdo) calculated for (44, 0-29)
# 67.80 s : (P hebdo, T hebdo) calculated for (44, 30-59)
# 68.17 s : (P hebdo, T hebdo) calculated for (44, 60+)
# 68.55 s : (P hebdo, T hebdo) calculated for (44, whole)
# 68.92 s : (P hebdo, T hebdo) calculated for (45, 0-29)
# 69.30 s : (P hebdo, T hebdo) calculated for (45, 30-59)
# 69.67 s : (P hebdo, T hebdo) calculated for (45, 60+)
# 70.04 s : (P hebdo, T hebdo) calculated for (45, whole)
# 70.41 s : (P hebdo, T hebdo) calculated for (46, 0-29)
# 70.79 s : (P hebdo, T hebdo) calculated for (46, 30-59)
# 71.20 s : (P hebdo, T hebdo) calculated for (46, 60+)
# 71.57 s : (P hebdo, T hebdo) calculated for (46, whole)
# 71.94 s : (P hebdo, T hebdo) calculated for (47, 0-29)
# 72.31 s : (P hebdo, T hebdo) calculated for (47, 30-59)
# 72.68 s : (P hebdo, T hebdo) calculated for (47, 60+)
# 73.05 s : (P hebdo, T hebdo) calculated for (47, whole)
# 73.42 s : (P hebdo, T hebdo) calculated for (48, 0-29)
# 73.80 s : (P hebdo, T hebdo) calculated for (48, 30-59)
# 74.17 s : (P hebdo, T hebdo) calculated for (48, 60+)
# 74.54 s : (P hebdo, T hebdo) calculated for (48, whole)
# 74.91 s : (P hebdo, T hebdo) calculated for (49, 0-29)
# 75.28 s : (P hebdo, T hebdo) calculated for (49, 30-59)
# 75.65 s : (P hebdo, T hebdo) calculated for (49, 60+)
# 76.02 s : (P hebdo, T hebdo) calculated for (49, whole)
# 76.39 s : (P hebdo, T hebdo) calculated for (50, 0-29)
# 76.76 s : (P hebdo, T hebdo) calculated for (50, 30-59)
# 77.14 s : (P hebdo, T hebdo) calculated for (50, 60+)
# 77.51 s : (P hebdo, T hebdo) calculated for (50, whole)
# 77.88 s : (P hebdo, T hebdo) calculated for (51, 0-29)
# 78.25 s : (P hebdo, T hebdo) calculated for (51, 30-59)
# 78.63 s : (P hebdo, T hebdo) calculated for (51, 60+)
# 79.00 s : (P hebdo, T hebdo) calculated for (51, whole)
# 79.37 s : (P hebdo, T hebdo) calculated for (52, 0-29)
# 79.76 s : (P hebdo, T hebdo) calculated for (52, 30-59)
# 80.14 s : (P hebdo, T hebdo) calculated for (52, 60+)
# 80.54 s : (P hebdo, T hebdo) calculated for (52, whole)
# 80.92 s : (P hebdo, T hebdo) calculated for (53, 0-29)
# 81.30 s : (P hebdo, T hebdo) calculated for (53, 30-59)
# 81.67 s : (P hebdo, T hebdo) calculated for (53, 60+)
# 82.05 s : (P hebdo, T hebdo) calculated for (53, whole)
# 82.42 s : (P hebdo, T hebdo) calculated for (54, 0-29)
# 82.79 s : (P hebdo, T hebdo) calculated for (54, 30-59)
# 83.17 s : (P hebdo, T hebdo) calculated for (54, 60+)
# 83.54 s : (P hebdo, T hebdo) calculated for (54, whole)
# 83.92 s : (P hebdo, T hebdo) calculated for (55, 0-29)
# 84.30 s : (P hebdo, T hebdo) calculated for (55, 30-59)
# 84.67 s : (P hebdo, T hebdo) calculated for (55, 60+)
# 85.06 s : (P hebdo, T hebdo) calculated for (55, whole)
# 85.43 s : (P hebdo, T hebdo) calculated for (56, 0-29)
# 85.80 s : (P hebdo, T hebdo) calculated for (56, 30-59)
# 86.17 s : (P hebdo, T hebdo) calculated for (56, 60+)
# 86.55 s : (P hebdo, T hebdo) calculated for (56, whole)
# 86.92 s : (P hebdo, T hebdo) calculated for (57, 0-29)
# 87.29 s : (P hebdo, T hebdo) calculated for (57, 30-59)
# 87.69 s : (P hebdo, T hebdo) calculated for (57, 60+)
# 88.06 s : (P hebdo, T hebdo) calculated for (57, whole)
# 88.43 s : (P hebdo, T hebdo) calculated for (58, 0-29)
# 88.81 s : (P hebdo, T hebdo) calculated for (58, 30-59)
# 89.18 s : (P hebdo, T hebdo) calculated for (58, 60+)
# 89.55 s : (P hebdo, T hebdo) calculated for (58, whole)
# 89.92 s : (P hebdo, T hebdo) calculated for (59, 0-29)
# 90.29 s : (P hebdo, T hebdo) calculated for (59, 30-59)
# 90.67 s : (P hebdo, T hebdo) calculated for (59, 60+)
# 91.05 s : (P hebdo, T hebdo) calculated for (59, whole)
# 91.43 s : (P hebdo, T hebdo) calculated for (60, 0-29)
# 91.80 s : (P hebdo, T hebdo) calculated for (60, 30-59)
# 92.18 s : (P hebdo, T hebdo) calculated for (60, 60+)
# 92.57 s : (P hebdo, T hebdo) calculated for (60, whole)
# 92.95 s : (P hebdo, T hebdo) calculated for (61, 0-29)
# 93.32 s : (P hebdo, T hebdo) calculated for (61, 30-59)
# 93.70 s : (P hebdo, T hebdo) calculated for (61, 60+)
# 94.11 s : (P hebdo, T hebdo) calculated for (61, whole)
# 94.48 s : (P hebdo, T hebdo) calculated for (62, 0-29)
# 94.86 s : (P hebdo, T hebdo) calculated for (62, 30-59)
# 95.24 s : (P hebdo, T hebdo) calculated for (62, 60+)
# 95.61 s : (P hebdo, T hebdo) calculated for (62, whole)
# 95.99 s : (P hebdo, T hebdo) calculated for (63, 0-29)
# 96.37 s : (P hebdo, T hebdo) calculated for (63, 30-59)
# 96.74 s : (P hebdo, T hebdo) calculated for (63, 60+)
# 97.11 s : (P hebdo, T hebdo) calculated for (63, whole)
# 97.49 s : (P hebdo, T hebdo) calculated for (64, 0-29)
# 97.86 s : (P hebdo, T hebdo) calculated for (64, 30-59)
# 98.23 s : (P hebdo, T hebdo) calculated for (64, 60+)
# 98.60 s : (P hebdo, T hebdo) calculated for (64, whole)
# 98.97 s : (P hebdo, T hebdo) calculated for (65, 0-29)
# 99.34 s : (P hebdo, T hebdo) calculated for (65, 30-59)
# 99.71 s : (P hebdo, T hebdo) calculated for (65, 60+)
# 100.09 s : (P hebdo, T hebdo) calculated for (65, whole)
# 100.46 s : (P hebdo, T hebdo) calculated for (66, 0-29)
# 100.83 s : (P hebdo, T hebdo) calculated for (66, 30-59)
# 101.20 s : (P hebdo, T hebdo) calculated for (66, 60+)
# 101.58 s : (P hebdo, T hebdo) calculated for (66, whole)
# 101.95 s : (P hebdo, T hebdo) calculated for (67, 0-29)
# 102.32 s : (P hebdo, T hebdo) calculated for (67, 30-59)
# 102.69 s : (P hebdo, T hebdo) calculated for (67, 60+)
# 103.06 s : (P hebdo, T hebdo) calculated for (67, whole)
# 103.47 s : (P hebdo, T hebdo) calculated for (68, 0-29)
# 103.84 s : (P hebdo, T hebdo) calculated for (68, 30-59)
# 104.21 s : (P hebdo, T hebdo) calculated for (68, 60+)
# 104.59 s : (P hebdo, T hebdo) calculated for (68, whole)
# 104.96 s : (P hebdo, T hebdo) calculated for (69, 0-29)
# 105.33 s : (P hebdo, T hebdo) calculated for (69, 30-59)
# 105.70 s : (P hebdo, T hebdo) calculated for (69, 60+)
# 106.07 s : (P hebdo, T hebdo) calculated for (69, whole)
# 106.44 s : (P hebdo, T hebdo) calculated for (70, 0-29)
# 106.81 s : (P hebdo, T hebdo) calculated for (70, 30-59)
# 107.18 s : (P hebdo, T hebdo) calculated for (70, 60+)
# 107.55 s : (P hebdo, T hebdo) calculated for (70, whole)
# 107.93 s : (P hebdo, T hebdo) calculated for (71, 0-29)
# 108.30 s : (P hebdo, T hebdo) calculated for (71, 30-59)
# 108.67 s : (P hebdo, T hebdo) calculated for (71, 60+)
# 109.04 s : (P hebdo, T hebdo) calculated for (71, whole)
# 109.45 s : (P hebdo, T hebdo) calculated for (72, 0-29)
# 109.82 s : (P hebdo, T hebdo) calculated for (72, 30-59)
# 110.19 s : (P hebdo, T hebdo) calculated for (72, 60+)
# 110.56 s : (P hebdo, T hebdo) calculated for (72, whole)
# 110.93 s : (P hebdo, T hebdo) calculated for (73, 0-29)
# 111.31 s : (P hebdo, T hebdo) calculated for (73, 30-59)
# 111.68 s : (P hebdo, T hebdo) calculated for (73, 60+)
# 112.05 s : (P hebdo, T hebdo) calculated for (73, whole)
# 112.42 s : (P hebdo, T hebdo) calculated for (74, 0-29)
# 112.79 s : (P hebdo, T hebdo) calculated for (74, 30-59)
# 113.16 s : (P hebdo, T hebdo) calculated for (74, 60+)
# 113.54 s : (P hebdo, T hebdo) calculated for (74, whole)
# 113.91 s : (P hebdo, T hebdo) calculated for (75, 0-29)
# 114.28 s : (P hebdo, T hebdo) calculated for (75, 30-59)
# 114.65 s : (P hebdo, T hebdo) calculated for (75, 60+)
# 115.02 s : (P hebdo, T hebdo) calculated for (75, whole)
# 115.39 s : (P hebdo, T hebdo) calculated for (76, 0-29)
# 115.77 s : (P hebdo, T hebdo) calculated for (76, 30-59)
# 116.14 s : (P hebdo, T hebdo) calculated for (76, 60+)
# 116.51 s : (P hebdo, T hebdo) calculated for (76, whole)
# 116.88 s : (P hebdo, T hebdo) calculated for (77, 0-29)
# 117.25 s : (P hebdo, T hebdo) calculated for (77, 30-59)
# 117.62 s : (P hebdo, T hebdo) calculated for (77, 60+)
# 118.00 s : (P hebdo, T hebdo) calculated for (77, whole)
# 118.38 s : (P hebdo, T hebdo) calculated for (78, 0-29)
# 118.78 s : (P hebdo, T hebdo) calculated for (78, 30-59)
# 119.15 s : (P hebdo, T hebdo) calculated for (78, 60+)
# 119.53 s : (P hebdo, T hebdo) calculated for (78, whole)
# 119.90 s : (P hebdo, T hebdo) calculated for (79, 0-29)
# 120.28 s : (P hebdo, T hebdo) calculated for (79, 30-59)
# 120.66 s : (P hebdo, T hebdo) calculated for (79, 60+)
# 121.03 s : (P hebdo, T hebdo) calculated for (79, whole)
# 121.41 s : (P hebdo, T hebdo) calculated for (80, 0-29)
# 121.78 s : (P hebdo, T hebdo) calculated for (80, 30-59)
# 122.15 s : (P hebdo, T hebdo) calculated for (80, 60+)
# 122.53 s : (P hebdo, T hebdo) calculated for (80, whole)
# 122.90 s : (P hebdo, T hebdo) calculated for (81, 0-29)
# 123.28 s : (P hebdo, T hebdo) calculated for (81, 30-59)
# 123.65 s : (P hebdo, T hebdo) calculated for (81, 60+)
# 124.02 s : (P hebdo, T hebdo) calculated for (81, whole)
# 124.40 s : (P hebdo, T hebdo) calculated for (82, 0-29)
# 124.78 s : (P hebdo, T hebdo) calculated for (82, 30-59)
# 125.15 s : (P hebdo, T hebdo) calculated for (82, 60+)
# 125.53 s : (P hebdo, T hebdo) calculated for (82, whole)
# 125.94 s : (P hebdo, T hebdo) calculated for (83, 0-29)
# 126.32 s : (P hebdo, T hebdo) calculated for (83, 30-59)
# 126.70 s : (P hebdo, T hebdo) calculated for (83, 60+)
# 127.08 s : (P hebdo, T hebdo) calculated for (83, whole)
# 127.46 s : (P hebdo, T hebdo) calculated for (84, 0-29)
# 127.83 s : (P hebdo, T hebdo) calculated for (84, 30-59)
# 128.21 s : (P hebdo, T hebdo) calculated for (84, 60+)
# 128.59 s : (P hebdo, T hebdo) calculated for (84, whole)
# 128.97 s : (P hebdo, T hebdo) calculated for (85, 0-29)
# 129.35 s : (P hebdo, T hebdo) calculated for (85, 30-59)
# 129.72 s : (P hebdo, T hebdo) calculated for (85, 60+)
# 130.09 s : (P hebdo, T hebdo) calculated for (85, whole)
# 130.46 s : (P hebdo, T hebdo) calculated for (86, 0-29)
# 130.83 s : (P hebdo, T hebdo) calculated for (86, 30-59)
# 131.20 s : (P hebdo, T hebdo) calculated for (86, 60+)
# 131.58 s : (P hebdo, T hebdo) calculated for (86, whole)
# 131.95 s : (P hebdo, T hebdo) calculated for (87, 0-29)
# 132.36 s : (P hebdo, T hebdo) calculated for (87, 30-59)
# 132.73 s : (P hebdo, T hebdo) calculated for (87, 60+)
# 133.10 s : (P hebdo, T hebdo) calculated for (87, whole)
# 133.48 s : (P hebdo, T hebdo) calculated for (88, 0-29)
# 133.86 s : (P hebdo, T hebdo) calculated for (88, 30-59)
# 134.23 s : (P hebdo, T hebdo) calculated for (88, 60+)
# 134.61 s : (P hebdo, T hebdo) calculated for (88, whole)
# 134.99 s : (P hebdo, T hebdo) calculated for (89, 0-29)
# 135.38 s : (P hebdo, T hebdo) calculated for (89, 30-59)
# 135.76 s : (P hebdo, T hebdo) calculated for (89, 60+)
# 136.14 s : (P hebdo, T hebdo) calculated for (89, whole)
# 136.52 s : (P hebdo, T hebdo) calculated for (90, 0-29)
# 136.90 s : (P hebdo, T hebdo) calculated for (90, 30-59)
# 137.27 s : (P hebdo, T hebdo) calculated for (90, 60+)
# 137.65 s : (P hebdo, T hebdo) calculated for (90, whole)
# 138.02 s : (P hebdo, T hebdo) calculated for (91, 0-29)
# 138.40 s : (P hebdo, T hebdo) calculated for (91, 30-59)
# 138.77 s : (P hebdo, T hebdo) calculated for (91, 60+)
# 139.14 s : (P hebdo, T hebdo) calculated for (91, whole)
# 139.51 s : (P hebdo, T hebdo) calculated for (92, 0-29)
# 139.89 s : (P hebdo, T hebdo) calculated for (92, 30-59)
# 140.26 s : (P hebdo, T hebdo) calculated for (92, 60+)
# 140.65 s : (P hebdo, T hebdo) calculated for (92, whole)
# 141.03 s : (P hebdo, T hebdo) calculated for (93, 0-29)
# 141.41 s : (P hebdo, T hebdo) calculated for (93, 30-59)
# 141.82 s : (P hebdo, T hebdo) calculated for (93, 60+)
# 142.20 s : (P hebdo, T hebdo) calculated for (93, whole)
# 142.57 s : (P hebdo, T hebdo) calculated for (94, 0-29)
# 142.94 s : (P hebdo, T hebdo) calculated for (94, 30-59)
# 143.31 s : (P hebdo, T hebdo) calculated for (94, 60+)
# 143.69 s : (P hebdo, T hebdo) calculated for (94, whole)
# 144.07 s : (P hebdo, T hebdo) calculated for (95, 0-29)
# 144.44 s : (P hebdo, T hebdo) calculated for (95, 30-59)
# 144.81 s : (P hebdo, T hebdo) calculated for (95, 60+)
# 145.19 s : (P hebdo, T hebdo) calculated for (95, whole)
# 145.56 s : (P hebdo, T hebdo) calculated for (971, 0-29)
# 145.93 s : (P hebdo, T hebdo) calculated for (971, 30-59)
# 146.30 s : (P hebdo, T hebdo) calculated for (971, 60+)
# 146.67 s : (P hebdo, T hebdo) calculated for (971, whole)
# 147.04 s : (P hebdo, T hebdo) calculated for (972, 0-29)
# 147.42 s : (P hebdo, T hebdo) calculated for (972, 30-59)
# 147.82 s : (P hebdo, T hebdo) calculated for (972, 60+)
# 148.19 s : (P hebdo, T hebdo) calculated for (972, whole)
# 148.56 s : (P hebdo, T hebdo) calculated for (973, 0-29)
# 148.93 s : (P hebdo, T hebdo) calculated for (973, 30-59)
# 149.31 s : (P hebdo, T hebdo) calculated for (973, 60+)
# 149.69 s : (P hebdo, T hebdo) calculated for (973, whole)
# 150.06 s : (P hebdo, T hebdo) calculated for (974, 0-29)
# 150.43 s : (P hebdo, T hebdo) calculated for (974, 30-59)
# 150.81 s : (P hebdo, T hebdo) calculated for (974, 60+)
# 151.18 s : (P hebdo, T hebdo) calculated for (974, whole)
# 151.55 s : (P hebdo, T hebdo) calculated for (975, 0-29)
# 151.92 s : (P hebdo, T hebdo) calculated for (975, 30-59)
# 152.29 s : (P hebdo, T hebdo) calculated for (975, 60+)
# 152.66 s : (P hebdo, T hebdo) calculated for (975, whole)
# 153.03 s : (P hebdo, T hebdo) calculated for (976, 0-29)
# 153.40 s : (P hebdo, T hebdo) calculated for (976, 30-59)
# 153.77 s : (P hebdo, T hebdo) calculated for (976, 60+)
# 154.14 s : (P hebdo, T hebdo) calculated for (976, whole)
# 154.52 s : (P hebdo, T hebdo) calculated for (977, 0-29)
# 154.89 s : (P hebdo, T hebdo) calculated for (977, 30-59)
# 155.26 s : (P hebdo, T hebdo) calculated for (977, 60+)
# 155.63 s : (P hebdo, T hebdo) calculated for (977, whole)
# 156.00 s : (P hebdo, T hebdo) calculated for (978, 0-29)
# 156.37 s : (P hebdo, T hebdo) calculated for (978, 30-59)
# 156.74 s : (P hebdo, T hebdo) calculated for (978, 60+)
# 157.15 s : (P hebdo, T hebdo) calculated for (978, whole)
# 157.52 s : (P hebdo, T hebdo) calculated for (Auvergne-Rhône-Alpes, 0-29)
# 157.89 s : (P hebdo, T hebdo) calculated for (Auvergne-Rhône-Alpes, 30-59)
# 158.26 s : (P hebdo, T hebdo) calculated for (Auvergne-Rhône-Alpes, 60+)
# 158.63 s : (P hebdo, T hebdo) calculated for (Auvergne-Rhône-Alpes, whole)
# 159.00 s : (P hebdo, T hebdo) calculated for (Bourgogne-Franche-Comté, 0-29)
# 159.37 s : (P hebdo, T hebdo) calculated for (Bourgogne-Franche-Comté, 30-59)
# 159.74 s : (P hebdo, T hebdo) calculated for (Bourgogne-Franche-Comté, 60+)
# 160.12 s : (P hebdo, T hebdo) calculated for (Bourgogne-Franche-Comté, whole)
# 160.49 s : (P hebdo, T hebdo) calculated for (Bretagne, 0-29)
# 160.86 s : (P hebdo, T hebdo) calculated for (Bretagne, 30-59)
# 161.23 s : (P hebdo, T hebdo) calculated for (Bretagne, 60+)
# 161.60 s : (P hebdo, T hebdo) calculated for (Bretagne, whole)
# 161.97 s : (P hebdo, T hebdo) calculated for (Centre-Val de Loire, 0-29)
# 162.34 s : (P hebdo, T hebdo) calculated for (Centre-Val de Loire, 30-59)
# 162.71 s : (P hebdo, T hebdo) calculated for (Centre-Val de Loire, 60+)
# 163.09 s : (P hebdo, T hebdo) calculated for (Centre-Val de Loire, whole)
# 163.46 s : (P hebdo, T hebdo) calculated for (Corse, 0-29)
# 163.83 s : (P hebdo, T hebdo) calculated for (Corse, 30-59)
# 164.23 s : (P hebdo, T hebdo) calculated for (Corse, 60+)
# 164.61 s : (P hebdo, T hebdo) calculated for (Corse, whole)
# 164.98 s : (P hebdo, T hebdo) calculated for (France entière, 0-29)
# 165.35 s : (P hebdo, T hebdo) calculated for (France entière, 30-59)
# 165.72 s : (P hebdo, T hebdo) calculated for (France entière, 60+)
# 166.09 s : (P hebdo, T hebdo) calculated for (France entière, whole)
# 166.46 s : (P hebdo, T hebdo) calculated for (Grand Est, 0-29)
# 166.84 s : (P hebdo, T hebdo) calculated for (Grand Est, 30-59)
# 167.21 s : (P hebdo, T hebdo) calculated for (Grand Est, 60+)
# 167.58 s : (P hebdo, T hebdo) calculated for (Grand Est, whole)
# 167.95 s : (P hebdo, T hebdo) calculated for (Hauts-de-France, 0-29)
# 168.32 s : (P hebdo, T hebdo) calculated for (Hauts-de-France, 30-59)
# 168.69 s : (P hebdo, T hebdo) calculated for (Hauts-de-France, 60+)
# 169.07 s : (P hebdo, T hebdo) calculated for (Hauts-de-France, whole)
# 169.44 s : (P hebdo, T hebdo) calculated for (Normandie, 0-29)
# 169.81 s : (P hebdo, T hebdo) calculated for (Normandie, 30-59)
# 170.18 s : (P hebdo, T hebdo) calculated for (Normandie, 60+)
# 170.59 s : (P hebdo, T hebdo) calculated for (Normandie, whole)
# 170.96 s : (P hebdo, T hebdo) calculated for (Nouvelle-Aquitaine, 0-29)
# 171.33 s : (P hebdo, T hebdo) calculated for (Nouvelle-Aquitaine, 30-59)
# 171.70 s : (P hebdo, T hebdo) calculated for (Nouvelle-Aquitaine, 60+)
# 172.08 s : (P hebdo, T hebdo) calculated for (Nouvelle-Aquitaine, whole)
# 172.45 s : (P hebdo, T hebdo) calculated for (Occitanie, 0-29)
# 172.82 s : (P hebdo, T hebdo) calculated for (Occitanie, 30-59)
# 173.19 s : (P hebdo, T hebdo) calculated for (Occitanie, 60+)
# 173.56 s : (P hebdo, T hebdo) calculated for (Occitanie, whole)
# 173.93 s : (P hebdo, T hebdo) calculated for (Outre-mer, 0-29)
# 174.30 s : (P hebdo, T hebdo) calculated for (Outre-mer, 30-59)
# 174.68 s : (P hebdo, T hebdo) calculated for (Outre-mer, 60+)
# 175.05 s : (P hebdo, T hebdo) calculated for (Outre-mer, whole)
# 175.42 s : (P hebdo, T hebdo) calculated for (Pays de la Loire, 0-29)
# 175.79 s : (P hebdo, T hebdo) calculated for (Pays de la Loire, 30-59)
# 176.18 s : (P hebdo, T hebdo) calculated for (Pays de la Loire, 60+)
# 176.59 s : (P hebdo, T hebdo) calculated for (Pays de la Loire, whole)
# 176.97 s : (P hebdo, T hebdo) calculated for (Provence-Alpes-Côte d'Azur, 0-29)
# 177.34 s : (P hebdo, T hebdo) calculated for (Provence-Alpes-Côte d'Azur, 30-59)
# 177.72 s : (P hebdo, T hebdo) calculated for (Provence-Alpes-Côte d'Azur, 60+)
# 178.09 s : (P hebdo, T hebdo) calculated for (Provence-Alpes-Côte d'Azur, whole)
# 178.47 s : (P hebdo, T hebdo) calculated for (Île-de-France, 0-29)
# 178.86 s : (P hebdo, T hebdo) calculated for (Île-de-France, 30-59)
# 179.23 s : (P hebdo, T hebdo) calculated for (Île-de-France, 60+)
# 179.61 s : (P hebdo, T hebdo) calculated for (Île-de-France, whole)

# %%
dh.sample(3)
# Out:
#                          entity three_class       jour    P     T        pop  \
# 137600  Bourgogne-Franche-Comté        0-29 2021-02-12  219  3893   903017.0
# 85641                        65       30-59 2021-02-22   21   474    82277.0
# 13951                        11       whole 2021-01-05  135  2135   372705.0
# 85408                        65        0-29 2020-12-26   13   159    64264.0
# 111500                       85        0-29 2021-01-18   58   923   212122.0
# 154208            Île-de-France        0-29 2020-12-01  666  9882  4792882.0
# 53785                        41       30-59 2020-09-11    7   274   120994.0
# 100974                       77         60+ 2020-12-17   54  1640   291762.0
# 99275                        76       whole 2020-09-08  201  4075  1243788.0
# 61239                        47       whole 2020-06-16    0   236   330336.0
#
#         P hebdo  T hebdo
# 137600   1269.0  21320.0
# 85641      89.0   2125.0
# 13951     596.0  10699.0
# 85408      96.0   2321.0
# 111500    278.0   4716.0
# 154208   4352.0  61669.0
# 53785      36.0   1400.0
# 100974    419.0   8301.0
# 99275    1075.0  20097.0
# 61239       4.0   1112.0

# %%
d = dh
d['incidence hebdo'] = d['P hebdo'] / d['pop'] * 100000
d['positivite hebdo'] = d['P hebdo'] / d['T hebdo'] * 100
d['taux de test hebdo'] = d['T hebdo'] / d['pop'] * 100000
d.sample(3)
# Out:
#        entity three_class       jour   P     T       pop  P hebdo  T hebdo  \
# 121342     93         60+ 2020-08-31  34  1052  278626.0    159.0   5115.0
# 123557     95       30-59 2020-05-27  18   382  498065.0     66.0   1815.0
# 70670      54         60+ 2020-09-07  11   748  191550.0     42.0   3657.0
#
#         incidence hebdo  positivite hebdo  taux de test hebdo
# 121342        57.065744          3.108504         1835.794219
# 123557        13.251282          3.636364          364.410268
# 70670         21.926390          1.148482         1909.162099

# %%
d.tail(3)
# Out:
#                entity three_class       jour      P       T         pop  \
# 154697  Île-de-France       30-59 2021-04-02   5871   66808   4968295.0
# 154698  Île-de-France         60+ 2021-04-02   1418   16171   2517033.0
# 154699  Île-de-France       whole 2021-04-02  12108  152071  12278210.0
#
#         P hebdo   T hebdo  incidence hebdo  positivite hebdo  \
# 154697  39151.0  357639.0       788.016815         10.947072
# 154698  10134.0  102706.0       402.616891          9.866999
# 154699  82228.0  843433.0       669.706741          9.749204
#
#         taux de test hebdo
# 154697         7198.425214
# 154698         4080.439152
# 154699         6869.348219

# %%
fname = fname_temp_test + '-tot-3C-processed.csv'
d.to_csv(fname, sep = ';', index = False)

# %% [markdown]
# # Traitement des données hospitalières

# %%
fname = path_hosp[0]
din = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'dep': str})
din.sample(3)
# Out:
#        reg  cl_age90       jour  hosp  rea  HospConv  SSR_USLD  autres   rad  \
# 56662    4         9 2020-12-29     0    0       NaN       NaN     NaN    21
# 64039   27        79 2021-02-04   429   72       NaN       NaN     NaN  2792
# 50379   27        90 2020-11-27   248    1       NaN       NaN     NaN   725
#
#         dc
# 56662    0
# 64039  703
# 50379  448

# %%
d = din.copy()
d['entity'] = (d['reg']
               .map(lambda x: reg_name[str(x)] )
               .replace({
                   'Guadeloupe':'Outre-mer',
                   'Martinique':'Outre-mer',
                   'Guyane':'Outre-mer',
                   'La Réunion':'Outre-mer',
                   'Mayotte':'Outre-mer',
               })
              )
d = columns_first(d, columns = ['entity'])
d = d.drop(columns = ['reg'])
d.head(3)
# Out:
#       entity  cl_age90       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  \
# 0  Outre-mer         0 2020-03-18     0    0       NaN       NaN     NaN    0
# 1  Outre-mer         9 2020-03-18     0    0       NaN       NaN     NaN    0
# 2  Outre-mer        19 2020-03-18     0    0       NaN       NaN     NaN    0
#
#    dc
# 0   0
# 1   0
# 2   0

# %%
d['three_class'] = d['cl_age90'].map(lambda x: class_2_3C[x])
d = d.drop(columns = 'cl_age90')
dg = groupby_sum(d,['entity', 'jour', 'three_class',])
# dg = (dg.reset_index()
#       .drop(columns = ['cl_age90'])
#             )
dg = columns_first(dg, ['entity', 'three_class', 'jour',])
d_reg = dg.copy()
d_reg.tail(3)
# Out:
#               entity three_class       jour  hosp   rea  HospConv  SSR_USLD  \
# 21501  Île-de-France       30-59 2021-04-05  1879   570    1115.0     149.0
# 21502  Île-de-France         60+ 2021-04-05  5598  1026    2913.0    1622.0
# 21503  Île-de-France       whole 2021-04-05  7737  1634    4221.0    1788.0
#
#        autres    rad     dc
# 21501    45.0  24139   1273
# 21502    37.0  47893  15648
# 21503    94.0  77222  17064

# %%
d = d_reg.copy()
dg = groupby_sum(d, columns = ['jour', 'three_class',])
dg['entity'] = 'France entière'
dg = columns_first(dg, columns = ['entity', 'three_class', 'jour',])
d_nat = dg
d_nat.sample(3)
# Out:
#              entity three_class       jour  hosp  rea  HospConv  SSR_USLD  \
# 401  France entière       30-59 2020-06-26  1417  182       0.0       0.0
# 209  France entière       30-59 2020-05-09  3349  798       0.0       0.0
# 773  France entière       30-59 2020-09-27  1240  244       0.0       0.0
#
#      autres    rad    dc
# 401     0.0  22626  1238
# 209     0.0  19121  1029
# 773     0.0  28199  1345

# %%
d_tot = pd.merge(d_reg, d_nat, how = 'outer')
d_tot = d_tot.drop(columns = ['HospConv', 'SSR_USLD', 'autres', 'rad'])
d_tot.sample(3)
# Out:
#                      entity three_class       jour  hosp  rea     dc
# 418    Auvergne-Rhône-Alpes         60+ 2020-06-30   430   22   1653
# 8080              Grand Est        0-29 2020-06-26    20    1      3
# 21162         Île-de-France         60+ 2021-01-10  3937  394  11360

# %%
d = d_tot
d = calc_delta_hebdo(d, columns_to_group = ['entity', 'three_class'], columns_to_delta = ['dc'])
# Out:
# 0.54 s : (dc hebdo) calculated for (Auvergne-Rhône-Alpes, 0-29)
# 1.06 s : (dc hebdo) calculated for (Auvergne-Rhône-Alpes, 30-59)
# 1.58 s : (dc hebdo) calculated for (Auvergne-Rhône-Alpes, 60+)
# 2.10 s : (dc hebdo) calculated for (Auvergne-Rhône-Alpes, whole)
# 2.61 s : (dc hebdo) calculated for (Bourgogne-Franche-Comté, 0-29)
# 3.11 s : (dc hebdo) calculated for (Bourgogne-Franche-Comté, 30-59)
# 3.61 s : (dc hebdo) calculated for (Bourgogne-Franche-Comté, 60+)
# 4.12 s : (dc hebdo) calculated for (Bourgogne-Franche-Comté, whole)
# 4.62 s : (dc hebdo) calculated for (Bretagne, 0-29)
# 5.12 s : (dc hebdo) calculated for (Bretagne, 30-59)
# 5.63 s : (dc hebdo) calculated for (Bretagne, 60+)
# 6.14 s : (dc hebdo) calculated for (Bretagne, whole)
# 6.65 s : (dc hebdo) calculated for (Centre-Val de Loire, 0-29)
# 7.16 s : (dc hebdo) calculated for (Centre-Val de Loire, 30-59)
# 7.67 s : (dc hebdo) calculated for (Centre-Val de Loire, 60+)
# 8.18 s : (dc hebdo) calculated for (Centre-Val de Loire, whole)
# 8.69 s : (dc hebdo) calculated for (Corse, 0-29)
# 9.19 s : (dc hebdo) calculated for (Corse, 30-59)
# 9.70 s : (dc hebdo) calculated for (Corse, 60+)
# 10.20 s : (dc hebdo) calculated for (Corse, whole)
# 10.70 s : (dc hebdo) calculated for (Grand Est, 0-29)
# 11.21 s : (dc hebdo) calculated for (Grand Est, 30-59)
# 11.71 s : (dc hebdo) calculated for (Grand Est, 60+)
# 12.21 s : (dc hebdo) calculated for (Grand Est, whole)
# 12.72 s : (dc hebdo) calculated for (Hauts-de-France, 0-29)
# 13.23 s : (dc hebdo) calculated for (Hauts-de-France, 30-59)
# 13.73 s : (dc hebdo) calculated for (Hauts-de-France, 60+)
# 14.23 s : (dc hebdo) calculated for (Hauts-de-France, whole)
# 14.73 s : (dc hebdo) calculated for (Normandie, 0-29)
# 15.24 s : (dc hebdo) calculated for (Normandie, 30-59)
# 15.74 s : (dc hebdo) calculated for (Normandie, 60+)
# 16.25 s : (dc hebdo) calculated for (Normandie, whole)
# 16.75 s : (dc hebdo) calculated for (Nouvelle-Aquitaine, 0-29)
# 17.25 s : (dc hebdo) calculated for (Nouvelle-Aquitaine, 30-59)
# 17.76 s : (dc hebdo) calculated for (Nouvelle-Aquitaine, 60+)
# 18.26 s : (dc hebdo) calculated for (Nouvelle-Aquitaine, whole)
# 18.77 s : (dc hebdo) calculated for (Occitanie, 0-29)
# 19.28 s : (dc hebdo) calculated for (Occitanie, 30-59)
# 19.79 s : (dc hebdo) calculated for (Occitanie, 60+)
# 20.29 s : (dc hebdo) calculated for (Occitanie, whole)
# 20.81 s : (dc hebdo) calculated for (Outre-mer, 0-29)
# 21.31 s : (dc hebdo) calculated for (Outre-mer, 30-59)
# 21.81 s : (dc hebdo) calculated for (Outre-mer, 60+)
# 22.32 s : (dc hebdo) calculated for (Outre-mer, whole)
# 22.83 s : (dc hebdo) calculated for (Pays de la Loire, 0-29)
# 23.35 s : (dc hebdo) calculated for (Pays de la Loire, 30-59)
# 23.87 s : (dc hebdo) calculated for (Pays de la Loire, 60+)
# 24.39 s : (dc hebdo) calculated for (Pays de la Loire, whole)
# 24.89 s : (dc hebdo) calculated for (Provence-Alpes-Côte d'Azur, 0-29)
# 25.40 s : (dc hebdo) calculated for (Provence-Alpes-Côte d'Azur, 30-59)
# 25.91 s : (dc hebdo) calculated for (Provence-Alpes-Côte d'Azur, 60+)
# 26.43 s : (dc hebdo) calculated for (Provence-Alpes-Côte d'Azur, whole)
# 26.93 s : (dc hebdo) calculated for (Île-de-France, 0-29)
# 27.44 s : (dc hebdo) calculated for (Île-de-France, 30-59)
# 27.94 s : (dc hebdo) calculated for (Île-de-France, 60+)
# 28.44 s : (dc hebdo) calculated for (Île-de-France, whole)
# 28.96 s : (dc hebdo) calculated for (France entière, 0-29)
# 29.47 s : (dc hebdo) calculated for (France entière, 30-59)
# 29.98 s : (dc hebdo) calculated for (France entière, 60+)
# 30.49 s : (dc hebdo) calculated for (France entière, whole)

# %%
d['taux hosp'] = d.apply(lambda x: x['hosp'] / reg_3C_pop 
                                                    [ x['entity'] ]
                                                    [ x['three_class'] ] * 100000, 
                         axis = "columns")
d['taux rea'] = d.apply(lambda x: x['rea'] / reg_3C_pop
                                                    [ x['entity'] ]
                                                    [ x['three_class'] ] * 100000, 
                        axis = "columns")
d['taux décès'] = d.apply(lambda x: x['dc hebdo'] / reg_3C_pop
                                                    [ x['entity'] ]
                                                    [ x['three_class'] ] * 100000, 
                        axis = "columns")
d
# Out:
#                      entity three_class       jour   hosp   rea     dc  \
# 0      Auvergne-Rhône-Alpes        0-29 2020-03-18      4     0      0
# 1      Auvergne-Rhône-Alpes       30-59 2020-03-18     33    11      1
# 2      Auvergne-Rhône-Alpes         60+ 2020-03-18    127    24      6
# 3      Auvergne-Rhône-Alpes       whole 2020-03-18    172    35      7
# 4      Auvergne-Rhône-Alpes        0-29 2020-03-19      5     1      0
# ...                     ...         ...        ...    ...   ...    ...
# 23035        France entière       whole 2021-04-04  29356  5341  70574
# 23036        France entière        0-29 2021-04-05    483    60     74
# 23037        France entière       30-59 2021-04-05   5699  1534   3182
# 23038        France entière         60+ 2021-04-05  23461  3785  67139
# 23039        France entière       whole 2021-04-05  29907  5433  70771
#
#        dc hebdo   taux hosp   taux rea  taux décès
# 0           0.0    0.141085   0.000000    0.000000
# 1           0.0    1.069485   0.356495    0.000000
# 2           0.0    6.014371   1.136574    0.000000
# 3           0.0    2.141334   0.435737    0.000000
# 4           0.0    0.176356   0.035271    0.000000
# ...         ...         ...        ...         ...
# 23035    1977.0   43.739853   7.957983    2.945690
# 23036       3.0    2.048652   0.254491    0.012725
# 23037      86.0   22.191562   5.973303    0.334879
# 23038    1713.0  131.378362  21.195478    9.592564
# 23039    1814.0   44.560832   8.095061    2.702824
#
# [23040 rows x 10 columns]

# %%
dout = d
fname = fname_temp_hosp + '-processed.csv'
dout.to_csv(fname, sep = ';', index = False)

# %% [markdown]
# # Données VAC-SI

# %%
fname = path_vac[0]
din = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'dep': str})
din.sample(3)
# Out:
#       dep  clage_vacsi       jour  n_dose1  n_dose2  n_cum_dose1  n_cum_dose2
# 19149  19           49 2021-02-07        0        0          447          105
# 33121  32           59 2021-02-20        0        1         1398          896
# 84298  83           29 2021-02-14        0        0          476          192

# %% [markdown]
# # Fusion SIDEP et données hospitalières

# %%
fname = fname_temp_test + '-tot-3C-processed.csv'
d = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
d.sample(3)
# Out:
#                  entity three_class       jour     P      T        pop  \
# 26143                22       whole 2020-06-17     2    394   596186.0
# 67                   01       whole 2020-05-29     6    334   656955.0
# 144983  Hauts-de-France       whole 2020-10-30  6137  42275  5962662.0
#
#         P hebdo   T hebdo  incidence hebdo  positivite hebdo  \
# 26143       7.0    1615.0         1.174130          0.433437
# 67         18.0    2193.0         2.739914          0.820793
# 144983  36684.0  233829.0       615.228567         15.688388
#
#         taux de test hebdo
# 26143           270.888615
# 67              333.812818
# 144983         3921.553829

# %%
len(d)
# Out:
# 154700

# %%
fname = fname_temp_hosp + '-processed.csv'
d2 = pd.read_csv(fname, sep = ';', parse_dates = ['jour'])
d2.sample(3)
# Out:
#                         entity three_class       jour  hosp  rea    dc  \
# 19994            Île-de-France         60+ 2020-03-24  2356  534   234
# 1847   Bourgogne-Franche-Comté       whole 2020-06-03   351   29  1017
# 10307          Hauts-de-France       whole 2020-12-15  2433  272  3983
#
#        dc hebdo  taux hosp   taux rea  taux décès
# 19994       0.0  93.602269  21.215455    0.000000
# 1847       16.0  12.612112   1.042026    0.574911
# 10307     220.0  40.803923   4.561721    3.689627

# %%
len(d2)
# Out:
# 23040

# %%
d = pd.merge(d2, d, how = 'outer')
d.sample(10)
# Out:
#           entity three_class       jour  hosp  rea   dc  dc hebdo  taux hosp  \
# 23280         01        0-29 2020-07-12   NaN  NaN  NaN       NaN        NaN
# 39384         13        0-29 2020-11-15   NaN  NaN  NaN       NaN        NaN
# 116689        72       30-59 2020-05-25   NaN  NaN  NaN       NaN        NaN
# 38811         13       whole 2020-06-24   NaN  NaN  NaN       NaN        NaN
# 93885         54       30-59 2020-10-21   NaN  NaN  NaN       NaN        NaN
# 99522         58         60+ 2021-02-07   NaN  NaN  NaN       NaN        NaN
# 92124         53        0-29 2020-06-28   NaN  NaN  NaN       NaN        NaN
# 56747         27       whole 2021-03-10   NaN  NaN  NaN       NaN        NaN
# 132837        84       30-59 2020-10-09   NaN  NaN  NaN       NaN        NaN
# 3924    Bretagne        0-29 2020-10-17   7.0  0.0  0.0       0.0   0.630663
#
#         taux rea  taux décès      P       T        pop  P hebdo  T hebdo  \
# 23280        NaN         NaN    0.0    11.0   233162.0      7.0   1269.0
# 39384        NaN         NaN   16.0   204.0   710300.0   1494.0  17765.0
# 116689       NaN         NaN    3.0    87.0   204725.0     15.0    488.0
# 38811        NaN         NaN   11.0  2249.0  2034469.0     63.0  13531.0
# 93885        NaN         NaN  168.0  1626.0   273994.0    723.0   8931.0
# 99522        NaN         NaN    2.0    42.0    76495.0    104.0   1917.0
# 92124        NaN         NaN    2.0     4.0   103116.0     10.0    226.0
# 56747        NaN         NaN  274.0  2553.0   600687.0   1603.0  15946.0
# 132837       NaN         NaN  106.0   856.0   211169.0    381.0   4117.0
# 3924         0.0         0.0  133.0  2240.0  1109943.0   1392.0  22461.0
#
#         incidence hebdo  positivite hebdo  taux de test hebdo
# 23280          3.002204          0.551615          544.256783
# 39384        210.333662          8.409795         2501.055892
# 116689         7.326902          3.073770          238.368543
# 38811          3.096631          0.465598          665.087549
# 93885        263.874391          8.095398         3259.560428
# 99522        135.956598          5.425143         2506.046147
# 92124          9.697816          4.424779          219.170643
# 56747        266.861111         10.052678         2654.627119
# 132837       180.424210          9.254311         1949.623288
# 3924         125.411845          6.197409         2023.617429

# %%
len(d)
# Out:
# 158240

# %%
d.tail()
# Out:
#        entity three_class       jour  hosp  rea  dc  dc hebdo  taux hosp  \
# 158235    978       whole 2021-04-01   NaN  NaN NaN       NaN        NaN
# 158236    978        0-29 2021-04-02   NaN  NaN NaN       NaN        NaN
# 158237    978       30-59 2021-04-02   NaN  NaN NaN       NaN        NaN
# 158238    978         60+ 2021-04-02   NaN  NaN NaN       NaN        NaN
# 158239    978       whole 2021-04-02   NaN  NaN NaN       NaN        NaN
#
#         taux rea  taux décès    P      T           pop  P hebdo  T hebdo  \
# 158235       NaN         NaN  2.0  218.0  35334.000000     20.0   1026.0
# 158236       NaN         NaN  3.0   28.0  15451.470743     11.0    226.0
# 158237       NaN         NaN  1.0   76.0  15252.902558      7.0    590.0
# 158238       NaN         NaN  0.0   24.0   4629.626699      1.0    176.0
# 158239       NaN         NaN  4.0  128.0  35334.000000     19.0    992.0
#
#         incidence hebdo  positivite hebdo  taux de test hebdo
# 158235        56.602706          1.949318         2903.718798
# 158236        71.190634          4.867257         1462.643937
# 158237        45.892904          1.186441         3868.116234
# 158238        21.600014          0.568182         3801.602407
# 158239        53.772570          1.915323         2807.494198

# %%
dout = d
fname = path_synth
dout.to_csv(fname, sep = ';', index = False)

# %% [markdown]
# # Graphes

# %%
fname = path_synth
d = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'entity': str})
d.sample(3)
# Out:
#        entity three_class       jour  hosp  rea  dc  dc hebdo  taux hosp  \
# 103493     61       30-59 2021-02-25   NaN  NaN NaN       NaN        NaN
# 47468      19        0-29 2021-01-25   NaN  NaN NaN       NaN        NaN
# 51848      24        0-29 2020-07-04   NaN  NaN NaN       NaN        NaN
#
#         taux rea  taux décès     P      T       pop  P hebdo  T hebdo  \
# 103493       NaN         NaN  28.0  529.0   98601.0    138.0   2819.0
# 47468        NaN         NaN  15.0  371.0   68716.0     93.0   1584.0
# 51848        NaN         NaN   0.0   18.0  107442.0      0.0    220.0
#
#         incidence hebdo  positivite hebdo  taux de test hebdo
# 103493       139.958013          4.895353         2858.997373
# 47468        135.339659          5.871212         2305.139997
# 51848          0.000000          0.000000          204.761639

# %%
entities = d['entity'].unique()
three_class = d['three_class'].unique()
regions = entities[:14]
last_week = d.jour >= np.datetime64(dt.datetime.fromisoformat(date) - dt.timedelta(weeks = 1))
regions_ordered = (d[(last_week) 
                    & (d.entity.isin(regions))
                    & (d.three_class == '60+')]
                   .groupby('entity')['taux hosp']
                   .mean()
                   .sort_values(ascending = False)
                   .index
                   .tolist())
regions_ordered
# Out:
# ['Île-de-France',
#  'Hauts-de-France',
#  "Provence-Alpes-Côte d'Azur",
#  'Grand Est',
#  'Auvergne-Rhône-Alpes',
#  'Normandie',
#  'Bourgogne-Franche-Comté',
#  'Centre-Val de Loire',
#  'Corse',
#  'Occitanie',
#  'Pays de la Loire',
#  'Bretagne',
#  'Nouvelle-Aquitaine',
#  'Outre-mer']

# %%
produce_fig_lines(d, regions_ordered[:4], regions_ordered[:-1], 1)
produce_fig_lines(d, regions_ordered[4:8], regions_ordered[:-1], 2)
produce_fig_lines(d, regions_ordered[8:-1], regions_ordered[:-1], 3)
produce_fig_lines(d, regions_ordered, regions_ordered, 'toutes')

# %%
produce_fig(ymin = -40,
    ymax = 1190,
            d = d,
    column_to_plot = "incidence hebdo",
    main_color = "darkturquoise",
    title = '{}\nCas positifs par semaine\npour 100 000 personnes'.format(date),
    regions_ordered = regions_ordered,
    fname = fname_output_synth + '-fig-incidence.pdf',)
produce_fig(ymin = -400,
    ymax = 11900,
            d = d,
    column_to_plot = "taux de test hebdo",
    main_color = "gray",
    title = '{}\nTests pratiqués par semaine\npour 100 000 personnes'.format(date),
    regions_ordered = regions_ordered,
    fname = fname_output_synth + '-fig-tests.pdf',)
produce_fig(ymin = -4,
    ymax = 29,
            d = d,
    column_to_plot = "positivite hebdo",
    main_color = "orange",
    title = '{}\nTests positifs hebdomadaire\n(%)'.format(date),
    regions_ordered = regions_ordered,
    fname = fname_output_synth + '-fig-positifs.pdf',)
produce_fig(ymin = -15,
    ymax = 379,
            d = d,
    column_to_plot = "taux hosp",
    main_color = "mediumseagreen",
    title = '{}\nPatients hospitalisés\npour 100 000 personnes'.format(date),
    regions_ordered = regions_ordered,
    fname = fname_output_synth + '-fig-hosp.pdf',)
produce_fig(ymin = -3,
    ymax = 76,
            d = d,
    column_to_plot = "taux rea",
    main_color = "darksalmon",
    title = '{}\nPatients en réanimation\npour 100 000 personnes'.format(date),
    regions_ordered = regions_ordered,
    fname = fname_output_synth +  '-fig-rea.pdf',)
produce_fig(ymin = -3,
    ymax = 76,
            d = d,
    column_to_plot = "taux décès",
    main_color = "orchid",
    title = '{}\nDécès à l\'hôpital par semaine\npour 100 000 personnes)'.format(date),
    regions_ordered = regions_ordered,
    fname = fname_output_synth +  '-fig-deces.pdf',)
