# %%
# %matplotlib inline

import time
import datetime as dt
import os
import glob
import json

import itertools as it

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

os.getcwd()
# Out:
# '/home/edmz/Data Covid/Code'

# %%
from dicts_paths_v3 import *
from calc_functions_v3 import *
# from graph_functions_v1 import *

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %%
date_choice, date_text = date(1)
# Out:
# 09/04/2021

# %% [markdown]
# # dep -> dep-tot-3C-hebd

# %%
dataset = 'sp-pos-quot-dep'
data_fname, path_temp = data_path(date_choice, dataset, version = '5Lv3')
din = pd.read_csv(data_fname, sep = ';', parse_dates = ['jour'], dtype = {'dep': str})
din.sample(3)
# Out:
# ../Data/sp-pos-quot-dep-2021-04-09-20h00.csv
#        dep       jour    P     T  cl_age90       pop
# 226624  62 2020-12-03   46   564        29  155051.0
# 144360  39 2021-03-01    8   121        79   26160.0
# 234035  64 2020-12-18  123  4838         0  683169.0

# %%
d = din.copy()
d = d.rename(columns = {'dep': 'entity'})
d = columns_first(d, columns = ['entity', 'cl_age90', 'jour'])
d_dep = d

d = din.copy()
d['reg'] = d['dep'].map(lambda x: dep2reg[x])
d = d.drop(columns = ['dep'])
dg = groupby_sum(d, columns = ['reg', 'jour', 'cl_age90'])
dg = d.rename(columns = {'reg': 'entity'})
dg = columns_first(dg, columns = ['entity', 'cl_age90', 'jour'])
d_reg = dg

d = din.copy()
d = d.drop(columns = ['dep'])
dg = groupby_sum(d, columns = ['jour', 'cl_age90'])
dg['entity'] = 'France entière'
dg = columns_first(dg, columns = ['entity', 'cl_age90', 'jour'])
d_nat = dg

d = pd.merge(d_dep, d_reg, how = 'outer')
d = pd.merge(d, d_nat, how = 'outer')
d = columns_first(d, columns = ['entity', 'cl_age90', 'jour'])
d.sample(3)
# Out:
#                             entity  cl_age90       jour   P    T       pop
# 49380                           14        19 2020-12-11   8  259   88223.0
# 390713  Provence-Alpes-Côte d'Azur        49 2021-03-25  27  206   19525.0
# 239810                          66         0 2020-08-07   5  501  479000.0

# %% [markdown]
# ### dep-tot -> dep-tot-3C

# %%
d['three_class'] = d['cl_age90'].map(lambda x: class_2_3C[x])
d = d.drop(columns = 'cl_age90')
dg = groupby_sum(d,['entity', 'jour', 'three_class'])
dg = columns_first(dg, columns = ['entity', 'three_class', 'jour'])
d = dg
d.sample(3)
# Out:
#        entity three_class       jour    P     T       pop
# 93123      70       whole 2021-01-18  132  1312  233194.0
# 131592    974        0-29 2021-04-05   20   435  354358.0
# 97018      73         60+ 2021-01-05   28   557  120772.0

# %% [markdown]
# ### tot-3C ->tot-3C-hebd

# %%
dg = (d
      .groupby(['entity', 'three_class'])
      .rolling(window = 7, on = 'jour')
      .sum()
      .fillna(0)
      .reset_index()
      .set_index('level_2')
      .rename(columns = {
          'P': 'P hebdo',
          'T': 'T hebdo',
              })
     )
d[['P hebdo', 'T hebdo']] = dg[['P hebdo', 'T hebdo']]
d['incidence hebdo'] = d['P hebdo'] / d['pop'] * 100000
d['positivite hebdo'] = d['P hebdo'] / d['T hebdo'] * 100
d['taux de test hebdo'] = d['T hebdo'] / d['pop'] * 100000
d.sample(3)
# Out:
#        entity three_class       jour   P    T       pop  P hebdo  T hebdo  \
# 62088      47        0-29 2020-07-11   0   20   98425.0      4.0    284.0
# 17928      14        0-29 2020-12-04  30  541  237080.0    133.0   2980.0
# 106111     80       whole 2020-12-06  23  199  569769.0    496.0   8638.0
#
#         incidence hebdo  positivite hebdo  taux de test hebdo
# 62088          4.064008          1.408451          288.544577
# 17928         56.099207          4.463087         1256.959676
# 106111        87.052823          5.742070         1516.052997

# %%
fname = path_temp + '-tot-3C-hebd.csv'
d.to_csv(fname, sep = ';', index = False)

# %% [markdown]
# ### fra, reg, dep  -> fra-3C, reg-3C, dep-3C

# %%
dataset = 'sp-pos-quot-fra'
fname, path_temp, = data_path(date_choice, dataset, version = '5Lv3')
din = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {})
din.sample(3)
# Out:
# ../Data/sp-pos-quot-fra-2021-04-09-20h00.csv
#     fra       jour  P_f  P_h   P   T_f   T_h     T  cl_age90           pop
# 412  FR 2020-06-19   42   35  85  2757  2492  6113        59  8.792675e+06
# 347  FR 2020-06-13    7   12  20  1002  1118  2514        69  8.004083e+06
# 965  FR 2020-08-08   19   19  38  1622  1228  2851        89  3.245281e+06

# %%
d = din.copy()
d = d.rename(columns = {'fra': 'entity'})
d['three_class'] = d['cl_age90'].map(lambda x: class_2_3C[x])
d = d.drop(columns = 'cl_age90')
dg = groupby_sum(d,['entity', 'jour', 'three_class'])
dg = columns_first(dg, columns = ['entity', 'three_class', 'jour'])
d = dg
d.sample(3)
# Out:
#      entity three_class       jour   P_f   P_h     P    T_f    T_h       T  \
# 564      FR        0-29 2020-10-01  2963  2954  5976  37175  33804   71439
# 387      FR       whole 2020-08-17  2449  2567  5026  80888  73272  154447
# 1290     FR         60+ 2021-03-31  3691  3039  6741  53812  42087   96019
#
#                pop
# 564   2.357648e+07
# 387   6.711500e+07
# 1290  1.785758e+07

# %%
dg = (d
      .groupby(['entity', 'three_class'])
      .rolling(window = 7, on = 'jour')
      .sum()
      .fillna(0)
      .reset_index()
      .set_index('level_2')
      .rename(columns = {
          'P': 'P hebdo',
          'T': 'T hebdo',
              })
     )
d[['P hebdo', 'T hebdo']] = dg[['P hebdo', 'T hebdo']]
d['incidence hebdo'] = d['P hebdo'] / d['pop'] * 100000
d['positivite hebdo'] = d['P hebdo'] / d['T hebdo'] * 100
d['taux de test hebdo'] = d['T hebdo'] / d['pop'] * 100000
d.sample(3)
# Out:
#      entity three_class       jour   P_f   P_h     P    T_f    T_h       T  \
# 343      FR       whole 2020-08-06  1067  1087  2165  57374  52216  109884
# 1172     FR        0-29 2021-03-02  4308  4042  8452  55678  49281  105602
# 27       FR       whole 2020-05-19   620   428  1056  30593  22498   53467
#
#                pop  P hebdo   T hebdo  incidence hebdo  positivite hebdo  \
# 343   6.711500e+07  10849.0  611171.0        16.164793          1.775117
# 1172  2.357648e+07  50533.0  659606.0       214.336500          7.661089
# 27    6.711500e+07   5572.0  260242.0         8.302169          2.141084
#
#       taux de test hebdo
# 343           910.632564
# 1172         2797.729038
# 27            387.755374

# %%
dout = d
fname = path_temp + '-3C-hebd.csv'
dout.to_csv(fname, sep = ';', index = False)

# %%
dataset = 'sp-pos-quot-reg'
fname, path_temp, = data_path(date_choice, dataset, version = '5Lv3')
din = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'reg': str})
din.sample(3)
# Out:
# ../Data/sp-pos-quot-reg-2021-04-09-20h00.csv
#       reg       jour  P_f  P_h    P  T_f  T_h     T  cl_age90            pop
# 7682   06 2020-06-15    1    2    4   11   11    27        49   28132.000000
# 69811  05 2021-03-11    0    0    0    2    2     4        59     978.233666
# 61424  93 2021-02-02   60   47  107  745  770  1524         9  551927.000000

# %%
d = din.copy()
d = d.rename(columns = {'reg': 'entity'})
d['three_class'] = d['cl_age90'].map(lambda x: class_2_3C[x])
d = d.drop(columns = 'cl_age90')
dg = groupby_sum(d,['entity', 'jour', 'three_class'])
dg = columns_first(dg, columns = ['entity', 'three_class', 'jour'])
d = dg
d.sample(3)
# Out:
#       entity three_class       jour  P_f  P_h    P   T_f   T_h     T  \
# 10337     08       30-59 2021-02-18    5    3    8    90    59   149
# 22779     76       whole 2020-08-22   87  111  198  3168  2629  5811
# 13025     24       30-59 2021-03-04  165  151  316  2589  2039  4632
#
#                 pop
# 10337  1.525290e+04
# 22779  5.924858e+06
# 13025  9.535180e+05

# %%
dg = (d
      .groupby(['entity', 'three_class'])
      .rolling(window = 7, on = 'jour')
      .sum()
      .fillna(0)
      .reset_index()
      .set_index('level_2')
      .rename(columns = {
          'P': 'P hebdo',
          'T': 'T hebdo',
              })
     )
d[['P hebdo', 'T hebdo']] = dg[['P hebdo', 'T hebdo']]
d['incidence hebdo'] = d['P hebdo'] / d['pop'] * 100000
d['positivite hebdo'] = d['P hebdo'] / d['T hebdo'] * 100
d['taux de test hebdo'] = d['T hebdo'] / d['pop'] * 100000
d.sample(3)
# Out:
#       entity three_class       jour  P_f  P_h    P   T_f   T_h     T  \
# 11258     11         60+ 2020-11-11  140  146  286  1424  1198  2625
# 20384     53        0-29 2020-10-21  158  145  308  2095  1955  4101
# 4958      04         60+ 2021-01-20    5    6   11   255   221   476
#
#              pop  P hebdo  T hebdo  incidence hebdo  positivite hebdo  \
# 11258  2517033.0   7100.0  58276.0       282.078145         12.183403
# 20384  1109943.0   1674.0  23620.0       150.818556          7.087214
# 4958    161821.0     44.0   2886.0        27.190538          1.524602
#
#        taux de test hebdo
# 11258         2315.265632
# 20384         2128.037206
# 4958          1783.452086

# %%
dout = d
fname = path_temp + '-3C-hebd.csv'
dout.to_csv(fname, sep = ';', index = False)

# %%
dataset = 'sp-pos-quot-dep'
fname, path_temp, = data_path(date_choice, dataset, version = '5Lv3')
din = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'dep': str})
din.sample(3)
# Out:
# ../Data/sp-pos-quot-dep-2021-04-09-20h00.csv
#         dep       jour   P    T  cl_age90      pop
# 366110  976 2020-07-05   0    0        89   1005.0
# 270480   74 2021-01-11  39  436        19  98955.0
# 26121    08 2020-07-23   0   58        79  24132.0

# %%
d = din.copy()
d = d.rename(columns = {'dep': 'entity'})
d['three_class'] = d['cl_age90'].map(lambda x: class_2_3C[x])
d = d.drop(columns = 'cl_age90')
dg = groupby_sum(d,['entity', 'jour', 'three_class'])
dg = columns_first(dg, columns = ['entity', 'three_class', 'jour'])
d = dg
d.sample(3)
# Out:
#       entity three_class       jour   P     T       pop
# 60579     46       whole 2020-05-23   0    13  173166.0
# 59575     45       whole 2020-08-09   1   101  682890.0
# 67082     50         60+ 2021-03-29  61  1039  162094.0

# %%
dg = (d
      .groupby(['entity', 'three_class'])
      .rolling(window = 7, on = 'jour')
      .sum()
      .fillna(0)
      .reset_index()
      .set_index('level_2')
      .rename(columns = {
          'P': 'P hebdo',
          'T': 'T hebdo',
              })
     )
d[['P hebdo', 'T hebdo']] = dg[['P hebdo', 'T hebdo']]
d['incidence hebdo'] = d['P hebdo'] / d['pop'] * 100000
d['positivite hebdo'] = d['P hebdo'] / d['T hebdo'] * 100
d['taux de test hebdo'] = d['T hebdo'] / d['pop'] * 100000
d.sample(3)
# Out:
#        entity three_class       jour    P     T        pop  P hebdo  T hebdo  \
# 124067     94       whole 2020-08-11  112  2663  1406041.0    562.0  15931.0
# 85401      64       30-59 2021-03-03   22  1204   261406.0    129.0   6985.0
# 113855     86       whole 2020-10-29  266  2431   437398.0   1373.0  11993.0
#
#         incidence hebdo  positivite hebdo  taux de test hebdo
# 124067        39.970385          3.527713         1133.039506
# 85401         49.348523          1.846815         2672.088628
# 113855       313.901755         11.448345         2741.896396

# %%
fname = path_temp + '-3C-hebd.csv'
dout.to_csv(fname, sep = ';', index = False)

# %% [markdown]
# # Traitement des données hospitalières

# %%
dataset = 'donnees-hospitalieres-classe-age-covid19'
fname, path_temp, = data_path(date_choice, dataset, version = '5Lv3')
din = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'reg': int})
din.sample(3)
# Out:
# ../Data/donnees-hospitalieres-classe-age-covid19-2021-04-09-19h52.csv
#        reg  cl_age90       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  \
# 18011   94        39 2020-06-16     0    0       NaN       NaN     NaN   18
# 68154    4        89 2021-02-25     8    2       NaN       NaN     NaN   70
# 24144   93        90 2020-07-17    87    0       NaN       NaN     NaN  494
#
#         dc
# 18011    0
# 68154   16
# 24144  234

# %%
d = din.copy()
d['entity'] = (d['reg']
               .map(lambda x: reg_name[str(x)] )
               .replace({
                   'Guadeloupe':'Outre-mer',
                   'Martinique':'Outre-mer',
                   'Guyane':'Outre-mer',
                   'La Réunion':'Outre-mer',
                   'Mayotte':'Outre-mer',
               })
              )
d = columns_first(d, columns = ['entity'])
d = d.drop(columns = ['reg'])
d.head(3)
# Out:
#       entity  cl_age90       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  \
# 0  Outre-mer         0 2020-03-18     0    0       NaN       NaN     NaN    0
# 1  Outre-mer         9 2020-03-18     0    0       NaN       NaN     NaN    0
# 2  Outre-mer        19 2020-03-18     0    0       NaN       NaN     NaN    0
#
#    dc
# 0   0
# 1   0
# 2   0

# %%
d['three_class'] = d['cl_age90'].map(lambda x: class_2_3C[x])
d = d.drop(columns = 'cl_age90')
dg = groupby_sum(d,['entity', 'jour', 'three_class',])
dg = columns_first(dg, ['entity', 'three_class', 'jour',])
d_reg = dg
d_reg.tail(3)
# Out:
#               entity three_class       jour  hosp   rea  HospConv  SSR_USLD  \
# 21725  Île-de-France       30-59 2021-04-09  1943   608    1130.0     162.0
# 21726  Île-de-France         60+ 2021-04-09  5694  1077    2823.0    1758.0
# 21727  Île-de-France       whole 2021-04-09  7907  1726    4144.0    1941.0
#
#        autres    rad     dc
# 21725    43.0  24906   1304
# 21726    36.0  48909  15972
# 21727    96.0  79154  17423

# %%
d = d_reg.copy()
dg = groupby_sum(d, columns = ['jour', 'three_class',])
dg['entity'] = 'France entière'
dg = columns_first(dg, columns = ['entity', 'three_class', 'jour',])
d_nat = dg
d_nat.sample(3)
# Out:
#              entity three_class       jour   hosp   rea  HospConv  SSR_USLD  \
# 243  France entière       whole 2020-05-17  19302  2047       0.0       0.0
# 901  France entière       30-59 2020-10-29   3023   603       0.0       0.0
# 541  France entière       30-59 2020-07-31    866    97       0.0       0.0
#
#      autres    rad     dc
# 243     0.0  61204  17447
# 901     0.0  34106   1482
# 541     0.0  24093   1272

# %%
d_tot = pd.merge(d_reg, d_nat, how = 'outer')
d_tot = d_tot.drop(columns = ['HospConv', 'SSR_USLD', 'autres', 'rad'])
d = d_tot
d.sample(3)
# Out:
#                 entity three_class       jour  hosp  rea   dc
# 10257  Hauts-de-France       30-59 2020-11-09   420  101  120
# 14027        Occitanie       whole 2020-04-01   926  304  108
# 3952          Bretagne        0-29 2020-10-16     6    0    0

# %%
d['dc hebdo'] = d['dc'] - (d.groupby(['entity', 'three_class'])
                              .shift(7)
                             )['dc']


d['taux hosp'] = d.apply(lambda x: x['hosp'] / reg_3C_pop 
                                                    [ x['entity'] ]
                                                    [ x['three_class'] ] * 100000, 
                         axis = "columns")
d['taux rea'] = d.apply(lambda x: x['rea'] / reg_3C_pop
                                                    [ x['entity'] ]
                                                    [ x['three_class'] ] * 100000, 
                        axis = "columns")
d['taux décès'] = d.apply(lambda x: x['dc hebdo'] / reg_3C_pop
                                                    [ x['entity'] ]
                                                    [ x['three_class'] ] * 100000, 
                        axis = "columns")
d.sample(10)
# Out:
#                      entity three_class       jour  hosp  rea   dc  dc hebdo  \
# 10465       Hauts-de-France       30-59 2020-12-31   230   50  199       7.0
# 17499      Pays de la Loire       whole 2020-07-02   145    2  469       2.0
# 10348       Hauts-de-France        0-29 2020-12-02    34    4    2       0.0
# 8717              Grand Est       30-59 2020-11-12   273   53  184      12.0
# 17242      Pays de la Loire         60+ 2020-04-29   580   61  320      47.0
# 4799    Centre-Val de Loire       whole 2020-04-22   973  151  328      83.0
# 4768    Centre-Val de Loire        0-29 2020-04-15    13    2    0       0.0
# 5809    Centre-Val de Loire       30-59 2020-12-31    73   17   44       0.0
# 1308   Auvergne-Rhône-Alpes        0-29 2021-02-08    25    2    9       1.0
# 10504       Hauts-de-France        0-29 2021-01-10    24    1    3       0.0
#
#        taux hosp  taux rea  taux décès
# 10465  10.109237  2.197660    0.307672
# 17499   3.813986  0.052607    0.052607
# 10348   1.533999  0.180470    0.000000
# 8717   12.851038  2.494890    0.564881
# 17242  55.552842  5.842626    4.501696
# 4799   38.021580  5.900574    3.243362
# 4768    1.534208  0.236032    0.000000
# 5809    7.655860  1.782871    0.000000
# 1308    0.881781  0.070542    0.035271
# 10504   1.082823  0.045118    0.000000

# %%
dout = d
fname = path_temp + '-3C-hebd.csv'
dout.to_csv(fname, sep = ';', index = False)

# %% [markdown]
# # Traitement des données VAC-SI

# %%
dataset = 'vacsi-a-dep'
fname, path_temp, = data_path(date_choice, dataset, version = '5Lv3')
din = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'dep': str})
din.sample(3)
# Out:
# ../Data/vacsi-a-dep-2021-04-09-20h01.csv
#        dep  clage_vacsi       jour  n_dose1  n_dose2  n_cum_dose1  n_cum_dose2
# 118541  88            0 2021-03-28       59        0        51051        19061
# 89582   84           80 2021-03-12      425      291        12347         7850
# 52824   50           39 2021-03-25       54        6         2117          840

# %%
d = din.copy()
d = d[(d.dep != '00') & (d.dep != '750') & (d.dep != '970')] 
d = d.rename(columns = {'dep': 'entity'})
d = columns_first(d, columns = ['entity', 'clage_vacsi', 'jour'])
d_dep = d
d_dep.sample(3)
# Out:
#       entity  clage_vacsi       jour  n_dose1  n_dose2  n_cum_dose1  \
# 99688     94           74 2021-03-24      955       52        14727
# 91315     86           69 2021-02-22        6       15          787
# 2890      02           79 2021-01-02        0        0            0
#
#        n_cum_dose2
# 99688         2846
# 91315          450
# 2890             0

# %%
d = din.copy()
d = d[(d.dep != '00') & (d.dep != '750') & (d.dep != '970')] #supprime lignes suspectes
d['reg'] = d['dep'].map(lambda x: dep2reg[x])
d = d.drop(columns = ['dep'])
dg = groupby_sum(d, columns = ['reg', 'jour', 'clage_vacsi'])
dg = d.rename(columns = {'reg': 'entity'})
dg = columns_first(dg, columns = ['entity', 'clage_vacsi', 'jour'])
d_reg = dg
d_reg.sample(3)
# Out:
#                   entity  clage_vacsi       jour  n_dose1  n_dose2  \
# 46746   Pays de la Loire           49 2021-03-24      172       23
# 109112         Outre-mer           80 2021-01-31        0        0
# 116032         Occitanie            0 2021-02-19      153      511
#
#         n_cum_dose1  n_cum_dose2
# 46746          8416         2697
# 109112            0            0
# 116032        13941         6294

# %%
d = din.copy()
d = d[(d.dep != '00') & (d.dep != '750') & (d.dep != '970')] 
d = d.drop(columns = ['dep'])
dg = groupby_sum(d, columns = ['jour', 'clage_vacsi'])
dg['entity'] = 'France entière'
dg = columns_first(dg, columns = ['entity', 'clage_vacsi', 'jour'])
d_nat = dg
d_nat.sample(3)
# Out:
#              entity  clage_vacsi       jour  n_dose1  n_dose2  n_cum_dose1  \
# 984  France entière           59 2021-03-26    42077     2397      1023355
# 25   France entière           39 2020-12-29        1        0            1
# 422  France entière           49 2021-02-03     2268     3647       102749
#
#      n_cum_dose2
# 984       344380
# 25             0
# 422        13835

# %%
d = pd.merge(d_dep, d_reg, how = 'outer')
dout = pd.merge(d, d_nat, how = 'outer')
dout = columns_first(dout, columns = ['entity', 'clage_vacsi', 'jour'])
dout.head(3)
# Out:
#   entity  clage_vacsi       jour  n_dose1  n_dose2  n_cum_dose1  n_cum_dose2
# 0     01           24 2020-12-27        0        0            0            0
# 1     01           24 2020-12-28        0        0            0            0
# 2     01           24 2020-12-29        0        0            0            0

# %%
d = dout.copy()
d['three_class'] = d['clage_vacsi'].map(lambda x: classvac_2_3C[x])
d = d.drop(columns = 'clage_vacsi')
dg = groupby_sum(d,['entity', 'jour', 'three_class'])
dg = columns_first(dg, columns = ['entity', 'three_class', 'jour'])
dout = dg
dout.tail(10)
# Out:
#               entity three_class       jour  n_dose1  n_dose2  n_cum_dose1  \
# 48606  Île-de-France         60+ 2021-04-06    17069    14712      1065728
# 48607  Île-de-France       whole 2021-04-06    26121    16146      1494107
# 48608  Île-de-France        0-29 2021-04-07     1264      134        48923
# 48609  Île-de-France       30-59 2021-04-07    10786     1520       391041
# 48610  Île-de-France         60+ 2021-04-07    22048    14974      1087776
# 48611  Île-de-France       whole 2021-04-07    34110    16629      1528217
# 48612  Île-de-France        0-29 2021-04-08     1961      197        50884
# 48613  Île-de-France       30-59 2021-04-08    14222     1906       405263
# 48614  Île-de-France         60+ 2021-04-08    25434    15536      1113210
# 48615  Île-de-France       whole 2021-04-08    41638    17639      1569855
#
#        n_cum_dose2
# 48606       378150
# 48607       470974
# 48608         6608
# 48609        87782
# 48610       393124
# 48611       487603
# 48612         6805
# 48613        89688
# 48614       408660
# 48615       505242

# %%
d = dout.copy()
d['taux dose 1'] = d.apply(lambda x: x['n_cum_dose1'] / reg_3C_pop 
                                                    [ x['entity'] ]
                                                    [ x['three_class'] ] * 100000, 
                         axis = "columns")
d['taux dose 2'] = d.apply(lambda x: x['n_cum_dose2'] / reg_3C_pop
                                                    [ x['entity'] ]
                                                    [ x['three_class'] ] * 100000, 
                        axis = "columns")
d.sample(3)
# Out:
#       entity three_class       jour  n_dose1  n_dose2  n_cum_dose1  \
# 18858     45         60+ 2021-03-16      873      784        35938
# 16481     40       30-59 2020-12-27        0        0            0
# 14672     35        0-29 2021-02-28        1        0         1951
#
#        n_cum_dose2   taux dose 1   taux dose 2
# 18858        18503  19901.428730  10246.428176
# 16481            0      0.000000      0.000000
# 14672          351    477.662953     85.935262

# %%
dout = d.copy()
fname = path_temp + '-3C.csv'
dout.to_csv(fname, sep = ';', index = False)

# %% [markdown]
# # Fusion SIDEP et données hospitalières

# %%
fname = fname_temp_test + '-tot-3C-processed.csv'
d = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
d.sample(3)
# Out:
#       entity three_class       jour   P    T        pop  P hebdo  T hebdo  \
# 87309     66       30-59 2020-11-08   1   25   172592.0    615.0   7272.0
# 46639     35       whole 2020-11-08  39  396  1082073.0   3156.0  26916.0
# 6003      05       whole 2020-11-17  94  711   141756.0    513.0   3433.0
#
#        incidence hebdo  positivite hebdo  taux de test hebdo
# 87309       356.331696          8.457096         4213.405025
# 46639       291.662392         11.725368         2487.447705
# 6003        361.889444         14.943198         2421.766980

# %%
len(d)
# Out:
# 156128

# %%
fname = fname_temp_hosp + '-processed.csv'
d2 = pd.read_csv(fname, sep = ';', parse_dates = ['jour'])
d2.sample(3)
# Out:
#                      entity three_class       jour  hosp  rea   dc  dc hebdo  \
# 1149   Auvergne-Rhône-Alpes       30-59 2020-12-30   409   76  184       4.0
# 12487    Nouvelle-Aquitaine       whole 2020-04-12   832  257  190      70.0
# 7391                  Corse       whole 2021-01-11    22   11  116       1.0
#
#        taux hosp  taux rea  taux décès
# 1149   13.255133  2.463057    0.129635
# 12487  13.866708  4.283346    1.166670
# 7391    6.382750  3.191375    0.290125

# %%
len(d2)
# Out:
# 23220

# %%
d = pd.merge(d2, d, how = 'outer')
d.sample(10)
# Out:
#        entity three_class       jour  hosp  rea  dc  dc hebdo  taux hosp  \
# 31521      07       30-59 2020-08-28   NaN  NaN NaN       NaN        NaN
# 157375    977       whole 2020-08-03   NaN  NaN NaN       NaN        NaN
# 132966     83         60+ 2020-12-11   NaN  NaN NaN       NaN        NaN
# 59820      29        0-29 2021-03-03   NaN  NaN NaN       NaN        NaN
# 49825      22       30-59 2020-08-12   NaN  NaN NaN       NaN        NaN
# 110719     66       whole 2020-12-25   NaN  NaN NaN       NaN        NaN
# 145605     93       30-59 2020-08-13   NaN  NaN NaN       NaN        NaN
# 145734     93         60+ 2020-09-14   NaN  NaN NaN       NaN        NaN
# 55038      26         60+ 2020-08-03   NaN  NaN NaN       NaN        NaN
# 72502      37         60+ 2020-11-13   NaN  NaN NaN       NaN        NaN
#
#         taux rea  taux décès     P       T       pop  P hebdo  T hebdo  \
# 31521        NaN         NaN   9.0   223.0  122997.0     24.0   1185.0
# 157375       NaN         NaN   1.0    40.0    9961.0      2.0    199.0
# 132966       NaN         NaN  55.0  1687.0  357417.0    333.0   8939.0
# 59820        NaN         NaN  35.0   860.0  291361.0    252.0   5724.0
# 49825        NaN         NaN   1.0   375.0  214063.0     14.0   2331.0
# 110719       NaN         NaN   7.0   121.0  479000.0    352.0  15665.0
# 145605       NaN         NaN  71.0  1773.0  684201.0    372.0   9017.0
# 145734       NaN         NaN  72.0   992.0  278626.0    274.0   4896.0
# 55038        NaN         NaN   0.0   155.0  150694.0      3.0    724.0
# 72502        NaN         NaN  44.0   675.0  172953.0    362.0   4119.0
#
#         incidence hebdo  positivite hebdo  taux de test hebdo
# 31521         19.512671          2.025316          963.438133
# 157375        20.078305          1.005025         1997.791386
# 132966        93.168484          3.725249         2501.000232
# 59820         86.490642          4.402516         1964.573158
# 49825          6.540131          0.600601         1088.931763
# 110719        73.486430          2.247048         3270.354906
# 145605        54.369988          4.125541         1317.887580
# 145734        98.339710          5.596405         1757.194232
# 55038          1.990789          0.414365          480.443813
# 72502        209.305418          8.788541         2381.571872

# %%
len(d)
# Out:
# 159668

# %%
d.tail()
# Out:
#        entity three_class       jour  hosp  rea  dc  dc hebdo  taux hosp  \
# 159663    978       whole 2021-04-04   NaN  NaN NaN       NaN        NaN
# 159664    978        0-29 2021-04-05   NaN  NaN NaN       NaN        NaN
# 159665    978       30-59 2021-04-05   NaN  NaN NaN       NaN        NaN
# 159666    978         60+ 2021-04-05   NaN  NaN NaN       NaN        NaN
# 159667    978       whole 2021-04-05   NaN  NaN NaN       NaN        NaN
#
#         taux rea  taux décès    P     T           pop  P hebdo  T hebdo  \
# 159663       NaN         NaN  0.0   7.0  35334.000000     16.0    974.0
# 159664       NaN         NaN  0.0  21.0  15451.470743      6.0    194.0
# 159665       NaN         NaN  0.0  40.0  15252.902558      3.0    510.0
# 159666       NaN         NaN  0.0  20.0   4629.626699      0.0    150.0
# 159667       NaN         NaN  0.0  81.0  35334.000000      9.0    854.0
#
#         incidence hebdo  positivite hebdo  taux de test hebdo
# 159663        45.282164          1.642710         2756.551763
# 159664        38.831255          3.092784         1255.543910
# 159665        19.668388          0.588235         3343.625897
# 159666         0.000000          0.000000         3240.002051
# 159667        25.471218          1.053864         2416.935530

# %%
dout = d
fname = path_synth
dout.to_csv(fname, sep = ';', index = False)

# %% [markdown]
# # Graphes

# %%
fname = path_synth
d = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'entity': str})
d.sample(3)
# Out:
#        entity three_class       jour  hosp  rea  dc  dc hebdo  taux hosp  \
# 112280     67        0-29 2021-02-26   NaN  NaN NaN       NaN        NaN
# 104596     62        0-29 2020-05-21   NaN  NaN NaN       NaN        NaN
# 75460      39        0-29 2021-02-05   NaN  NaN NaN       NaN        NaN
#
#         taux rea  taux décès      P       T       pop  P hebdo  T hebdo  \
# 112280       NaN         NaN  122.0  2806.0  399593.0    689.0  14032.0
# 104596       NaN         NaN    0.0    22.0  522280.0     16.0    793.0
# 75460        NaN         NaN   31.0   456.0   80151.0    208.0   2505.0
#
#         incidence hebdo  positivite hebdo  taux de test hebdo
# 112280       172.425443          4.910205         3511.573026
# 104596         3.063491          2.017654          151.834265
# 75460        259.510175          8.303393         3125.350900

# %%
entities = d['entity'].unique()
three_class = d['three_class'].unique()
regions = entities[:14]
last_week = d.jour >= np.datetime64(dt.datetime.fromisoformat(date) - dt.timedelta(weeks = 1))
regions_ordered = (d[(last_week) 
                    & (d.entity.isin(regions))
                    & (d.three_class == '60+')]
                   .groupby('entity')['taux hosp']
                   .mean()
                   .sort_values(ascending = False)
                   .index
                   .tolist())
regions_ordered
# Out:
# ['Île-de-France',
#  'Hauts-de-France',
#  "Provence-Alpes-Côte d'Azur",
#  'Auvergne-Rhône-Alpes',
#  'Grand Est',
#  'Normandie',
#  'Bourgogne-Franche-Comté',
#  'Centre-Val de Loire',
#  'Occitanie',
#  'Corse',
#  'Pays de la Loire',
#  'Bretagne',
#  'Nouvelle-Aquitaine',
#  'Outre-mer']

# %%
produce_fig_lines(d, regions_ordered[:4], regions_ordered[:-1], 1)
produce_fig_lines(d, regions_ordered[4:8], regions_ordered[:-1], 2)
produce_fig_lines(d, regions_ordered[8:-1], regions_ordered[:-1], 3)
produce_fig_lines(d, regions_ordered, regions_ordered, 'toutes')

# %%
produce_fig(ymin = -40,
    ymax = 1190,
            d = d,
    column_to_plot = "incidence hebdo",
    main_color = "darkturquoise",
    title = '{}\nCas positifs par semaine\npour 100 000 personnes'.format(date_text),
    regions_ordered = regions_ordered,
    fname = fname_output_synth + '-fig-incidence',)
produce_fig(ymin = -400,
    ymax = 11900,
            d = d,
    column_to_plot = "taux de test hebdo",
    main_color = "gray",
    title = '{}\nTests pratiqués par semaine\npour 100 000 personnes'.format(date_text),
    regions_ordered = regions_ordered,
    fname = fname_output_synth + '-fig-tests',)
produce_fig(ymin = -4,
    ymax = 29,
            d = d,
    column_to_plot = "positivite hebdo",
    main_color = "orange",
    title = '{}\nTests positifs hebdomadaire\n(%)'.format(date_text),
    regions_ordered = regions_ordered,
    fname = fname_output_synth + '-fig-positifs',)
produce_fig(ymin = -15,
    ymax = 379,
            d = d,
    column_to_plot = "taux hosp",
    main_color = "mediumseagreen",
    title = '{}\nPatients hospitalisés\npour 100 000 personnes'.format(date_text),
    regions_ordered = regions_ordered,
    fname = fname_output_synth + '-fig-hosp',)
produce_fig(ymin = -3,
    ymax = 79,
            d = d,
    column_to_plot = "taux rea",
    main_color = "darksalmon",
    title = '{}\nPatients en réanimation\npour 100 000 personnes'.format(date_text),
    regions_ordered = regions_ordered,
    fname = fname_output_synth +  '-fig-rea',)
produce_fig(ymin = -3,
    ymax = 79,
            d = d,
    column_to_plot = "taux décès",
    main_color = "orchid",
    title = '{}\nDécès à l\'hôpital par semaine\npour 100 000 personnes)'.format(date_text),
    regions_ordered = regions_ordered,
    fname = fname_output_synth +  '-fig-deces',)

# %%
fname = fname_temp_vac + '-tot-3C.csv'
d2 = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'entity': str})
d2.sample(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-9fbd3d14a77e> in <module>
# ----> 1 fname = fname_temp_vac + '-tot-3C.csv'
#       2 d2 = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'entity': str})
#       3 d2.sample(3)
#
# NameError: name 'fname_temp_vac' is not defined

# %%
produce_fig(ymin = -10000,
    ymax = 70000,
            d = d2,
    column_to_plot = "taux dose 1",
    main_color = "orchid",
    title = '{}\nNombre de 1res doses cumulées\npour 100 000 personnes)'.format(date_text),
    regions_ordered = regions_ordered,
    fname = fname_output_synth +  '-fig-vac1',)

# %%
produce_fig(ymin = -10000,
    ymax = 70000,
            d = d2,
    column_to_plot = "taux dose 2",
    main_color = "orchid",
    title = '{}\nNombre de 2es doses cumulées\npour 100 000 personnes)'.format(date_text),
    regions_ordered = regions_ordered,
    fname = fname_output_synth +  '-fig-vac2',)

# %%
fig, axs = plt.subplots(11, 10, figsize = (15,20))
axs = axs.ravel()
for ax in axs:
    ax.set_axis_off()
for i, dep in enumerate(deps):
    sns.set_palette("mako",2)
    
    dplot = d.loc[d.dep == dep].loc[d.cl_age90 == 19]
    axs[i].plot(dplot.jour, dplot["incidence hebdo"], c = "darkturquoise", linewidth = 4)
    
    dplot = d.loc[d.dep == dep].loc[d.cl_age90 == 0]
    axs[i].plot(dplot.jour, dplot["incidence hebdo"], c = "black")
    
    dplot = d.loc[d.dep == dep].loc[d.cl_age90 == 89]
    #axs[i].plot(dplot.jour, dplot["incidence hebdo"], c = 'blue')
    axs[i].set_ylim(-500,1500)
    axs[i].set_axis_off()
    axs[i].set_title(dep, loc = 'left', y = 0.7, fontsize = 22, c = "darkturquoise")
    axs[i].set_title(dep_name[dep], x = -0.05, y = 0.2, rotation = 90, fontsize = 7)
fig.savefig("fig2.svg", pad_inches = 0)

# %%
produce_fig_dep(d, deps)

# %%
produce_fig_dep(d, reg2dep['Île-de-France'])

# %%
for reg in regs:
    print(reg)
    produce_fig_dep(d, reg2dep[reg])
