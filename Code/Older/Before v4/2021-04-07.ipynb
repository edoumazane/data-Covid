# %%
# %matplotlib inline

import time
import datetime as dt
import os
import glob
import json

import itertools as it

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

os.getcwd()
# Out:
# '/home/edmz/Data Covid/Code'

# %%
from dicts_paths_v1 import *
from calc_functions_v1 import *
from graph_functions_v1 import *

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/donnees-hospitalieres-relatives-a-lepidemie-de-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-resultats-des-tests-virologiques-covid-19/
#
# https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/

# %%
print(today)
print(date_choice)
print(date)
print(date_text)
# Out:
# 2021-04-09
# 2021-04-09
# 2021-04-09
# 09/04/2021

# %% [markdown]
# ### File paths

# %%
print('SIDEP\n   Données d\'entrée :') 
print(path_test)
print(fname_temp_test)
print(fname_output_test)

print('Données hospitalières\n   Données d\'entrée :') 
print(path_hosp)
print(fname_temp_hosp)
print(fname_output_hosp)

# print('VAC-SI\n   Données d\'entrée :') 
# print(path_vac)
# print(fname_temp_vac)
# print(fname_output_vac)
# Out:
# SIDEP
#    Données d'entrée :
# ['../Data/sp-pos-quot-dep-2021-04-09-20h00.csv']
# ./Temp/sp-pos-quot-dep-2021-04-09-20h00
# ../Output/sp-pos-quot-dep-2021-04-09-20h00
# Données hospitalières
#    Données d'entrée :
# ['../Data/donnees-hospitalieres-classe-age-covid19-2021-04-09-19h52.csv']
# ./Temp/donnees-hospitalieres-classe-age-covid19-2021-04-09-19h52
# ../Output/donnees-hospitalieres-classe-age-covid19-2021-04-09-19h52

# %% [markdown]
# ### Dictionnaries

# %%
print('Dict. reg_name\n     "11" :', reg_name['11'])
print('Dict. reg2dep\n     "Corse" :', reg2dep['Corse'])
print('Dict. dep2reg\n     "75" :', dep2reg['75'])
print('Dict. dep_name\n     "67" :', dep_name['67'])
print('Dict. class_2_3C\n      29 : ', class_2_3C[29])
print('Dict reg_3C_pop\n     "Grand Est" :', reg_3C_pop['Grand Est'])
print('Dict reg_2lignes\n      "Auvergne-Rhône-Alpes" :', reg_2lignes["Auvergne-Rhône-Alpes"], sep = '\n')
# Out:
# Dict. reg_name
#      "11" : Île-de-France
# Dict. reg2dep
#      "Corse" : ['2A', '2B']
# Dict. dep2reg
#      "75" : Île-de-France
# Dict. dep_name
#      "67" : Bas-Rhin
# Dict. class_2_3C
#       29 :  0-29
# Dict reg_3C_pop
#      "Grand Est" : {'0-29': 1874571, '30-59': 2124342, '60+': 1512834, 'whole': 5511747}
# Dict reg_2lignes
#       "Auvergne-Rhône-Alpes" :
# Auvergne-
# Rhône-Alpes

# %% [markdown]
# ### Functions

# %%
help(groupby_sum)
# Out:
# Help on function groupby_sum in module calc_functions_v1:
#
# groupby_sum(d, columns)
#     d: dataframe
#     columns: list of column names
#     returns: dataframe is grouped according to columns fed in
#             other columns are summed
#             dataframe is then formatted into a dataframe

# %%
help(columns_first)
# Out:
# Help on function columns_first in module calc_functions_v1:
#
# columns_first(d, columns)
#     d: dataframe
#     by: a list of column names
#     returns: dataframe reordered

# %%
help(calc_hebdo)
# Out:
# Help on function calc_hebdo in module calc_functions_v1:
#
# calc_hebdo(d, columns_to_group, columns_to_sum)
#     d: a dataframe
#     columns_to_group: list of columns from which groups will be formed
#             for example ['entity', 'three_class'] -> will calculate hebdo sums for (regionA, class1), (regionA, class2), etc.
#     columns_to_sum: list of columns which values will be summed on a week-wise base
#             for example ['P', 'T']

# %% [markdown]
# # Traitement des données SIDEP

# %%
fname = path_test[0]
din = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'dep': str})
din.sample(3)
# Out:
#        dep       jour   P    T  cl_age90      pop
# 302080  83 2020-10-14  11  132        90  17690.0
# 182228  50 2020-09-06   0   21        29  43715.0
# 262570  72 2020-11-11   5   34         9  63602.0

# %%
d = din.copy()
d = d.rename(columns = {'dep': 'entity'})
d = columns_first(d, columns = ['entity', 'cl_age90', 'jour'])
d_dep = d
d_dep.sample(3)
# Out:
#        entity  cl_age90       jour   P    T       pop
# 357861    973        90 2021-02-27   0    1     669.0
# 180669     49        59 2021-03-12  45  598  102416.0
# 90358      26        49 2021-03-27  24  285   65055.0

# %%
d = din.copy()
d['reg'] = d['dep'].map(lambda x: dep2reg[x])
d = d.drop(columns = ['dep'])
dg = groupby_sum(d, columns = ['reg', 'jour', 'cl_age90'])
dg = d.rename(columns = {'reg': 'entity'})
dg = columns_first(dg, columns = ['entity', 'cl_age90', 'jour'])
d_reg = dg
d_reg.sample(3)
# Out:
#                          entity  cl_age90       jour   P    T      pop
# 193561         Pays de la Loire        59 2020-10-19  15  137  40380.0
# 78453        Nouvelle-Aquitaine        19 2020-12-22   1   71  11416.0
# 70000   Bourgogne-Franche-Comté        79 2020-09-02   4  179  47831.0

# %%
d = din.copy()
d = d.drop(columns = ['dep'])
dg = groupby_sum(d, columns = ['jour', 'cl_age90'])
dg['entity'] = 'France entière'
dg = columns_first(dg, columns = ['entity', 'cl_age90', 'jour'])
d_nat = dg
d_nat.sample(3)
# Out:
#               entity  cl_age90       jour     P      T           pop
# 2095  France entière        49 2020-11-19  2451  33473  8.592886e+06
# 406   France entière        90 2020-06-18     5   1690  9.125806e+05
# 58    France entière        29 2020-05-18   126   6208  7.476787e+06

# %%
d = pd.merge(d_dep, d_reg, how = 'outer')
dout = pd.merge(d, d_nat, how = 'outer')
dout = columns_first(dout, columns = ['entity', 'cl_age90', 'jour'])
dout.head(3)
# Out:
#   entity  cl_age90       jour  P   T      pop
# 0     01         9 2020-05-13  0  16  83001.0
# 1     01        19 2020-05-13  1  17  84665.0
# 2     01        29 2020-05-13  0  34  65496.0

# %%
dout.tail(3)
# Out:
#                 entity  cl_age90       jour     P      T           pop
# 756368  France entière        79 2021-04-06  2648  40423  5.695639e+06
# 756369  France entière        89 2021-04-06  1308  24275  3.245281e+06
# 756370  France entière        90 2021-04-06   535  12436  9.125806e+05

# %%
fname = fname_temp_test + '-tot.csv'
dout.to_csv(fname, sep = ';', index = False)

# %% [markdown]
# ### SIDEP - 3 classes d'âge

# %%
fname = fname_temp_test + '-tot.csv'
din = pd.read_csv(fname, 
                sep = ';', 
                parse_dates = ['jour'], 
                dtype = {'entity': str},
                skiprows = [])
din.tail(3)
# Out:
#                 entity  cl_age90       jour     P      T           pop
# 756368  France entière        79 2021-04-06  2648  40423  5.695639e+06
# 756369  France entière        89 2021-04-06  1308  24275  3.245281e+06
# 756370  France entière        90 2021-04-06   535  12436  9.125806e+05

# %%
d = din.copy()
d['three_class'] = d['cl_age90'].map(lambda x: class_2_3C[x])
d = d.drop(columns = 'cl_age90')
dg = groupby_sum(d,['entity', 'jour', 'three_class'])
dg = columns_first(dg, columns = ['entity', 'three_class', 'jour'])
dout = dg
dout.tail(10)
# Out:
#                entity three_class       jour      P       T         pop
# 156594  Île-de-France         60+ 2021-04-04    295    2792   2517033.0
# 156595  Île-de-France       whole 2021-04-04   1683   18833  12278210.0
# 156596  Île-de-France        0-29 2021-04-05   1043   10761   4792882.0
# 156597  Île-de-France       30-59 2021-04-05   1540   12942   4968295.0
# 156598  Île-de-France         60+ 2021-04-05    452    4113   2517033.0
# 156599  Île-de-France       whole 2021-04-05   3036   27830  12278210.0
# 156600  Île-de-France        0-29 2021-04-06   6017   49758   4792882.0
# 156601  Île-de-France       30-59 2021-04-06   9120   63823   4968295.0
# 156602  Île-de-France         60+ 2021-04-06   2168   21608   2517033.0
# 156603  Île-de-France       whole 2021-04-06  17313  135230  12278210.0

# %%
fname = fname_temp_test + '-tot-3C.csv'
dout.to_csv(fname, sep = ';', index = False)

# %% [markdown]
# ### SIDEP - calculs chiffres hebdomadaires

# %%
fname = fname_temp_test + '-tot-3C.csv'
din = pd.read_csv(fname, 
                sep = ';', 
                parse_dates = ['jour'], 
                dtype = {'entity': str},
                skiprows = [])
din.sample(3)
# Out:
#        entity three_class       jour   P     T       pop
# 124458     94         60+ 2020-11-17  89  1186  288118.0
# 57920      44        0-29 2020-05-17   1    23  531273.0
# 53119      40       whole 2020-09-09  69  1295  411979.0

# %%
d = din.copy()

dh = calc_hebdo(d, 
           columns_to_group = ['entity', 'three_class'], 
           columns_to_sum = ['P', 'T'])
# Out:
# 0.39 s : (P hebdo, T hebdo) calculated for (01, 0-29)
# 0.77 s : (P hebdo, T hebdo) calculated for (01, 30-59)
# 1.15 s : (P hebdo, T hebdo) calculated for (01, 60+)
# 1.53 s : (P hebdo, T hebdo) calculated for (01, whole)
# 1.92 s : (P hebdo, T hebdo) calculated for (02, 0-29)
# 2.31 s : (P hebdo, T hebdo) calculated for (02, 30-59)
# 2.69 s : (P hebdo, T hebdo) calculated for (02, 60+)
# 3.12 s : (P hebdo, T hebdo) calculated for (02, whole)
# 3.51 s : (P hebdo, T hebdo) calculated for (03, 0-29)
# 3.89 s : (P hebdo, T hebdo) calculated for (03, 30-59)
# 4.27 s : (P hebdo, T hebdo) calculated for (03, 60+)
# 4.65 s : (P hebdo, T hebdo) calculated for (03, whole)
# 5.04 s : (P hebdo, T hebdo) calculated for (04, 0-29)
# 5.42 s : (P hebdo, T hebdo) calculated for (04, 30-59)
# 5.80 s : (P hebdo, T hebdo) calculated for (04, 60+)
# 6.20 s : (P hebdo, T hebdo) calculated for (04, whole)
# 6.57 s : (P hebdo, T hebdo) calculated for (05, 0-29)
# 6.97 s : (P hebdo, T hebdo) calculated for (05, 30-59)
# 7.36 s : (P hebdo, T hebdo) calculated for (05, 60+)
# 7.74 s : (P hebdo, T hebdo) calculated for (05, whole)
# 8.14 s : (P hebdo, T hebdo) calculated for (06, 0-29)
# 8.53 s : (P hebdo, T hebdo) calculated for (06, 30-59)
# 8.92 s : (P hebdo, T hebdo) calculated for (06, 60+)
# 9.30 s : (P hebdo, T hebdo) calculated for (06, whole)
# 9.68 s : (P hebdo, T hebdo) calculated for (07, 0-29)
# 10.06 s : (P hebdo, T hebdo) calculated for (07, 30-59)
# 10.47 s : (P hebdo, T hebdo) calculated for (07, 60+)
# 10.85 s : (P hebdo, T hebdo) calculated for (07, whole)
# 11.23 s : (P hebdo, T hebdo) calculated for (08, 0-29)
# 11.61 s : (P hebdo, T hebdo) calculated for (08, 30-59)
# 11.99 s : (P hebdo, T hebdo) calculated for (08, 60+)
# 12.37 s : (P hebdo, T hebdo) calculated for (08, whole)
# 12.75 s : (P hebdo, T hebdo) calculated for (09, 0-29)
# 13.12 s : (P hebdo, T hebdo) calculated for (09, 30-59)
# 13.50 s : (P hebdo, T hebdo) calculated for (09, 60+)
# 13.88 s : (P hebdo, T hebdo) calculated for (09, whole)
# 14.25 s : (P hebdo, T hebdo) calculated for (10, 0-29)
# 14.63 s : (P hebdo, T hebdo) calculated for (10, 30-59)
# 15.01 s : (P hebdo, T hebdo) calculated for (10, 60+)
# 15.39 s : (P hebdo, T hebdo) calculated for (10, whole)
# 15.77 s : (P hebdo, T hebdo) calculated for (11, 0-29)
# 16.15 s : (P hebdo, T hebdo) calculated for (11, 30-59)
# 16.53 s : (P hebdo, T hebdo) calculated for (11, 60+)
# 16.94 s : (P hebdo, T hebdo) calculated for (11, whole)
# 17.32 s : (P hebdo, T hebdo) calculated for (12, 0-29)
# 17.69 s : (P hebdo, T hebdo) calculated for (12, 30-59)
# 18.07 s : (P hebdo, T hebdo) calculated for (12, 60+)
# 18.45 s : (P hebdo, T hebdo) calculated for (12, whole)
# 18.83 s : (P hebdo, T hebdo) calculated for (13, 0-29)
# 19.21 s : (P hebdo, T hebdo) calculated for (13, 30-59)
# 19.58 s : (P hebdo, T hebdo) calculated for (13, 60+)
# 19.96 s : (P hebdo, T hebdo) calculated for (13, whole)
# 20.34 s : (P hebdo, T hebdo) calculated for (14, 0-29)
# 20.71 s : (P hebdo, T hebdo) calculated for (14, 30-59)
# 21.09 s : (P hebdo, T hebdo) calculated for (14, 60+)
# 21.47 s : (P hebdo, T hebdo) calculated for (14, whole)
# 21.85 s : (P hebdo, T hebdo) calculated for (15, 0-29)
# 22.23 s : (P hebdo, T hebdo) calculated for (15, 30-59)
# 22.61 s : (P hebdo, T hebdo) calculated for (15, 60+)
# 22.99 s : (P hebdo, T hebdo) calculated for (15, whole)
# 23.36 s : (P hebdo, T hebdo) calculated for (16, 0-29)
# 23.74 s : (P hebdo, T hebdo) calculated for (16, 30-59)
# 24.12 s : (P hebdo, T hebdo) calculated for (16, 60+)
# 24.51 s : (P hebdo, T hebdo) calculated for (16, whole)
# 24.88 s : (P hebdo, T hebdo) calculated for (17, 0-29)
# 25.26 s : (P hebdo, T hebdo) calculated for (17, 30-59)
# 25.64 s : (P hebdo, T hebdo) calculated for (17, 60+)
# 26.02 s : (P hebdo, T hebdo) calculated for (17, whole)
# 26.43 s : (P hebdo, T hebdo) calculated for (18, 0-29)
# 26.82 s : (P hebdo, T hebdo) calculated for (18, 30-59)
# 27.21 s : (P hebdo, T hebdo) calculated for (18, 60+)
# 27.60 s : (P hebdo, T hebdo) calculated for (18, whole)
# 27.98 s : (P hebdo, T hebdo) calculated for (19, 0-29)
# 28.36 s : (P hebdo, T hebdo) calculated for (19, 30-59)
# 28.74 s : (P hebdo, T hebdo) calculated for (19, 60+)
# 29.12 s : (P hebdo, T hebdo) calculated for (19, whole)
# 29.51 s : (P hebdo, T hebdo) calculated for (21, 0-29)
# 29.89 s : (P hebdo, T hebdo) calculated for (21, 30-59)
# 30.27 s : (P hebdo, T hebdo) calculated for (21, 60+)
# 30.65 s : (P hebdo, T hebdo) calculated for (21, whole)
# 31.03 s : (P hebdo, T hebdo) calculated for (22, 0-29)
# 31.41 s : (P hebdo, T hebdo) calculated for (22, 30-59)
# 31.80 s : (P hebdo, T hebdo) calculated for (22, 60+)
# 32.19 s : (P hebdo, T hebdo) calculated for (22, whole)
# 32.57 s : (P hebdo, T hebdo) calculated for (23, 0-29)
# 32.95 s : (P hebdo, T hebdo) calculated for (23, 30-59)
# 33.33 s : (P hebdo, T hebdo) calculated for (23, 60+)
# 33.75 s : (P hebdo, T hebdo) calculated for (23, whole)
# 34.14 s : (P hebdo, T hebdo) calculated for (24, 0-29)
# 34.52 s : (P hebdo, T hebdo) calculated for (24, 30-59)
# 34.91 s : (P hebdo, T hebdo) calculated for (24, 60+)
# 35.29 s : (P hebdo, T hebdo) calculated for (24, whole)
# 35.67 s : (P hebdo, T hebdo) calculated for (25, 0-29)
# 36.05 s : (P hebdo, T hebdo) calculated for (25, 30-59)
# 36.43 s : (P hebdo, T hebdo) calculated for (25, 60+)
# 36.81 s : (P hebdo, T hebdo) calculated for (25, whole)
# 37.19 s : (P hebdo, T hebdo) calculated for (26, 0-29)
# 37.57 s : (P hebdo, T hebdo) calculated for (26, 30-59)
# 37.95 s : (P hebdo, T hebdo) calculated for (26, 60+)
# 38.32 s : (P hebdo, T hebdo) calculated for (26, whole)
# 38.70 s : (P hebdo, T hebdo) calculated for (27, 0-29)
# 39.09 s : (P hebdo, T hebdo) calculated for (27, 30-59)
# 39.47 s : (P hebdo, T hebdo) calculated for (27, 60+)
# 39.89 s : (P hebdo, T hebdo) calculated for (27, whole)
# 40.27 s : (P hebdo, T hebdo) calculated for (28, 0-29)
# 40.65 s : (P hebdo, T hebdo) calculated for (28, 30-59)
# 41.03 s : (P hebdo, T hebdo) calculated for (28, 60+)
# 41.41 s : (P hebdo, T hebdo) calculated for (28, whole)
# 41.79 s : (P hebdo, T hebdo) calculated for (29, 0-29)
# 42.19 s : (P hebdo, T hebdo) calculated for (29, 30-59)
# 42.57 s : (P hebdo, T hebdo) calculated for (29, 60+)
# 42.94 s : (P hebdo, T hebdo) calculated for (29, whole)
# 43.32 s : (P hebdo, T hebdo) calculated for (2A, 0-29)
# 43.71 s : (P hebdo, T hebdo) calculated for (2A, 30-59)
# 44.10 s : (P hebdo, T hebdo) calculated for (2A, 60+)
# 44.49 s : (P hebdo, T hebdo) calculated for (2A, whole)
# 44.87 s : (P hebdo, T hebdo) calculated for (2B, 0-29)
# 45.26 s : (P hebdo, T hebdo) calculated for (2B, 30-59)
# 45.64 s : (P hebdo, T hebdo) calculated for (2B, 60+)
# 46.06 s : (P hebdo, T hebdo) calculated for (2B, whole)
# 46.43 s : (P hebdo, T hebdo) calculated for (30, 0-29)
# 46.81 s : (P hebdo, T hebdo) calculated for (30, 30-59)
# 47.19 s : (P hebdo, T hebdo) calculated for (30, 60+)
# 47.57 s : (P hebdo, T hebdo) calculated for (30, whole)
# 47.94 s : (P hebdo, T hebdo) calculated for (31, 0-29)
# 48.32 s : (P hebdo, T hebdo) calculated for (31, 30-59)
# 48.69 s : (P hebdo, T hebdo) calculated for (31, 60+)
# 49.07 s : (P hebdo, T hebdo) calculated for (31, whole)
# 49.46 s : (P hebdo, T hebdo) calculated for (32, 0-29)
# 49.84 s : (P hebdo, T hebdo) calculated for (32, 30-59)
# 50.22 s : (P hebdo, T hebdo) calculated for (32, 60+)
# 50.60 s : (P hebdo, T hebdo) calculated for (32, whole)
# 50.99 s : (P hebdo, T hebdo) calculated for (33, 0-29)
# 51.36 s : (P hebdo, T hebdo) calculated for (33, 30-59)
# 51.74 s : (P hebdo, T hebdo) calculated for (33, 60+)
# 52.12 s : (P hebdo, T hebdo) calculated for (33, whole)
# 52.50 s : (P hebdo, T hebdo) calculated for (34, 0-29)
# 52.88 s : (P hebdo, T hebdo) calculated for (34, 30-59)
# 53.26 s : (P hebdo, T hebdo) calculated for (34, 60+)
# 53.64 s : (P hebdo, T hebdo) calculated for (34, whole)
# 54.01 s : (P hebdo, T hebdo) calculated for (35, 0-29)
# 54.39 s : (P hebdo, T hebdo) calculated for (35, 30-59)
# 54.77 s : (P hebdo, T hebdo) calculated for (35, 60+)
# 55.16 s : (P hebdo, T hebdo) calculated for (35, whole)
# 55.57 s : (P hebdo, T hebdo) calculated for (36, 0-29)
# 55.95 s : (P hebdo, T hebdo) calculated for (36, 30-59)
# 56.33 s : (P hebdo, T hebdo) calculated for (36, 60+)
# 56.72 s : (P hebdo, T hebdo) calculated for (36, whole)
# 57.11 s : (P hebdo, T hebdo) calculated for (37, 0-29)
# 57.50 s : (P hebdo, T hebdo) calculated for (37, 30-59)
# 57.88 s : (P hebdo, T hebdo) calculated for (37, 60+)
# 58.26 s : (P hebdo, T hebdo) calculated for (37, whole)
# 58.64 s : (P hebdo, T hebdo) calculated for (38, 0-29)
# 59.01 s : (P hebdo, T hebdo) calculated for (38, 30-59)
# 59.40 s : (P hebdo, T hebdo) calculated for (38, 60+)
# 59.78 s : (P hebdo, T hebdo) calculated for (38, whole)
# 60.17 s : (P hebdo, T hebdo) calculated for (39, 0-29)
# 60.55 s : (P hebdo, T hebdo) calculated for (39, 30-59)
# 60.94 s : (P hebdo, T hebdo) calculated for (39, 60+)
# 61.32 s : (P hebdo, T hebdo) calculated for (39, whole)
# 61.71 s : (P hebdo, T hebdo) calculated for (40, 0-29)
# 62.09 s : (P hebdo, T hebdo) calculated for (40, 30-59)
# 62.47 s : (P hebdo, T hebdo) calculated for (40, 60+)
# 62.89 s : (P hebdo, T hebdo) calculated for (40, whole)
# 63.28 s : (P hebdo, T hebdo) calculated for (41, 0-29)
# 63.66 s : (P hebdo, T hebdo) calculated for (41, 30-59)
# 64.04 s : (P hebdo, T hebdo) calculated for (41, 60+)
# 64.43 s : (P hebdo, T hebdo) calculated for (41, whole)
# 64.81 s : (P hebdo, T hebdo) calculated for (42, 0-29)
# 65.19 s : (P hebdo, T hebdo) calculated for (42, 30-59)
# 65.57 s : (P hebdo, T hebdo) calculated for (42, 60+)
# 65.95 s : (P hebdo, T hebdo) calculated for (42, whole)
# 66.33 s : (P hebdo, T hebdo) calculated for (43, 0-29)
# 66.70 s : (P hebdo, T hebdo) calculated for (43, 30-59)
# 67.08 s : (P hebdo, T hebdo) calculated for (43, 60+)
# 67.46 s : (P hebdo, T hebdo) calculated for (43, whole)
# 67.83 s : (P hebdo, T hebdo) calculated for (44, 0-29)
# 68.21 s : (P hebdo, T hebdo) calculated for (44, 30-59)
# 68.58 s : (P hebdo, T hebdo) calculated for (44, 60+)
# 68.96 s : (P hebdo, T hebdo) calculated for (44, whole)
# 69.37 s : (P hebdo, T hebdo) calculated for (45, 0-29)
# 69.75 s : (P hebdo, T hebdo) calculated for (45, 30-59)
# 70.13 s : (P hebdo, T hebdo) calculated for (45, 60+)
# 70.51 s : (P hebdo, T hebdo) calculated for (45, whole)
# 70.88 s : (P hebdo, T hebdo) calculated for (46, 0-29)
# 71.26 s : (P hebdo, T hebdo) calculated for (46, 30-59)
# 71.64 s : (P hebdo, T hebdo) calculated for (46, 60+)
# 72.01 s : (P hebdo, T hebdo) calculated for (46, whole)
# 72.39 s : (P hebdo, T hebdo) calculated for (47, 0-29)
# 72.77 s : (P hebdo, T hebdo) calculated for (47, 30-59)
# 73.15 s : (P hebdo, T hebdo) calculated for (47, 60+)
# 73.53 s : (P hebdo, T hebdo) calculated for (47, whole)
# 73.91 s : (P hebdo, T hebdo) calculated for (48, 0-29)
# 74.29 s : (P hebdo, T hebdo) calculated for (48, 30-59)
# 74.67 s : (P hebdo, T hebdo) calculated for (48, 60+)
# 75.04 s : (P hebdo, T hebdo) calculated for (48, whole)
# 75.42 s : (P hebdo, T hebdo) calculated for (49, 0-29)
# 75.80 s : (P hebdo, T hebdo) calculated for (49, 30-59)
# 76.18 s : (P hebdo, T hebdo) calculated for (49, 60+)
# 76.57 s : (P hebdo, T hebdo) calculated for (49, whole)
# 76.96 s : (P hebdo, T hebdo) calculated for (50, 0-29)
# 77.34 s : (P hebdo, T hebdo) calculated for (50, 30-59)
# 77.73 s : (P hebdo, T hebdo) calculated for (50, 60+)
# 78.12 s : (P hebdo, T hebdo) calculated for (50, whole)
# 78.51 s : (P hebdo, T hebdo) calculated for (51, 0-29)
# 78.93 s : (P hebdo, T hebdo) calculated for (51, 30-59)
# 79.30 s : (P hebdo, T hebdo) calculated for (51, 60+)
# 79.69 s : (P hebdo, T hebdo) calculated for (51, whole)
# 80.06 s : (P hebdo, T hebdo) calculated for (52, 0-29)
# 80.44 s : (P hebdo, T hebdo) calculated for (52, 30-59)
# 80.82 s : (P hebdo, T hebdo) calculated for (52, 60+)
# 81.20 s : (P hebdo, T hebdo) calculated for (52, whole)
# 81.58 s : (P hebdo, T hebdo) calculated for (53, 0-29)
# 81.96 s : (P hebdo, T hebdo) calculated for (53, 30-59)
# 82.34 s : (P hebdo, T hebdo) calculated for (53, 60+)
# 82.71 s : (P hebdo, T hebdo) calculated for (53, whole)
# 83.09 s : (P hebdo, T hebdo) calculated for (54, 0-29)
# 83.47 s : (P hebdo, T hebdo) calculated for (54, 30-59)
# 83.85 s : (P hebdo, T hebdo) calculated for (54, 60+)
# 84.23 s : (P hebdo, T hebdo) calculated for (54, whole)
# 84.61 s : (P hebdo, T hebdo) calculated for (55, 0-29)
# 85.02 s : (P hebdo, T hebdo) calculated for (55, 30-59)
# 85.40 s : (P hebdo, T hebdo) calculated for (55, 60+)
# 85.78 s : (P hebdo, T hebdo) calculated for (55, whole)
# 86.16 s : (P hebdo, T hebdo) calculated for (56, 0-29)
# 86.53 s : (P hebdo, T hebdo) calculated for (56, 30-59)
# 86.91 s : (P hebdo, T hebdo) calculated for (56, 60+)
# 87.29 s : (P hebdo, T hebdo) calculated for (56, whole)
# 87.67 s : (P hebdo, T hebdo) calculated for (57, 0-29)
# 88.04 s : (P hebdo, T hebdo) calculated for (57, 30-59)
# 88.42 s : (P hebdo, T hebdo) calculated for (57, 60+)
# 88.80 s : (P hebdo, T hebdo) calculated for (57, whole)
# 89.17 s : (P hebdo, T hebdo) calculated for (58, 0-29)
# 89.55 s : (P hebdo, T hebdo) calculated for (58, 30-59)
# 89.93 s : (P hebdo, T hebdo) calculated for (58, 60+)
# 90.31 s : (P hebdo, T hebdo) calculated for (58, whole)
# 90.68 s : (P hebdo, T hebdo) calculated for (59, 0-29)
# 91.09 s : (P hebdo, T hebdo) calculated for (59, 30-59)
# 91.47 s : (P hebdo, T hebdo) calculated for (59, 60+)
# 91.86 s : (P hebdo, T hebdo) calculated for (59, whole)
# 92.23 s : (P hebdo, T hebdo) calculated for (60, 0-29)
# 92.62 s : (P hebdo, T hebdo) calculated for (60, 30-59)
# 93.00 s : (P hebdo, T hebdo) calculated for (60, 60+)
# 93.38 s : (P hebdo, T hebdo) calculated for (60, whole)
# 93.77 s : (P hebdo, T hebdo) calculated for (61, 0-29)
# 94.14 s : (P hebdo, T hebdo) calculated for (61, 30-59)
# 94.52 s : (P hebdo, T hebdo) calculated for (61, 60+)
# 94.90 s : (P hebdo, T hebdo) calculated for (61, whole)
# 95.28 s : (P hebdo, T hebdo) calculated for (62, 0-29)
# 95.66 s : (P hebdo, T hebdo) calculated for (62, 30-59)
# 96.04 s : (P hebdo, T hebdo) calculated for (62, 60+)
# 96.42 s : (P hebdo, T hebdo) calculated for (62, whole)
# 96.81 s : (P hebdo, T hebdo) calculated for (63, 0-29)
# 97.20 s : (P hebdo, T hebdo) calculated for (63, 30-59)
# 97.59 s : (P hebdo, T hebdo) calculated for (63, 60+)
# 97.96 s : (P hebdo, T hebdo) calculated for (63, whole)
# 98.35 s : (P hebdo, T hebdo) calculated for (64, 0-29)
# 98.73 s : (P hebdo, T hebdo) calculated for (64, 30-59)
# 99.11 s : (P hebdo, T hebdo) calculated for (64, 60+)
# 99.49 s : (P hebdo, T hebdo) calculated for (64, whole)
# 99.87 s : (P hebdo, T hebdo) calculated for (65, 0-29)
# 100.25 s : (P hebdo, T hebdo) calculated for (65, 30-59)
# 100.66 s : (P hebdo, T hebdo) calculated for (65, 60+)
# 101.04 s : (P hebdo, T hebdo) calculated for (65, whole)
# 101.43 s : (P hebdo, T hebdo) calculated for (66, 0-29)
# 101.80 s : (P hebdo, T hebdo) calculated for (66, 30-59)
# 102.18 s : (P hebdo, T hebdo) calculated for (66, 60+)
# 102.56 s : (P hebdo, T hebdo) calculated for (66, whole)
# 102.93 s : (P hebdo, T hebdo) calculated for (67, 0-29)
# 103.31 s : (P hebdo, T hebdo) calculated for (67, 30-59)
# 103.69 s : (P hebdo, T hebdo) calculated for (67, 60+)
# 104.06 s : (P hebdo, T hebdo) calculated for (67, whole)
# 104.45 s : (P hebdo, T hebdo) calculated for (68, 0-29)
# 104.82 s : (P hebdo, T hebdo) calculated for (68, 30-59)
# 105.21 s : (P hebdo, T hebdo) calculated for (68, 60+)
# 105.60 s : (P hebdo, T hebdo) calculated for (68, whole)
# 105.98 s : (P hebdo, T hebdo) calculated for (69, 0-29)
# 106.36 s : (P hebdo, T hebdo) calculated for (69, 30-59)
# 106.74 s : (P hebdo, T hebdo) calculated for (69, 60+)
# 107.12 s : (P hebdo, T hebdo) calculated for (69, whole)
# 107.50 s : (P hebdo, T hebdo) calculated for (70, 0-29)
# 107.92 s : (P hebdo, T hebdo) calculated for (70, 30-59)
# 108.30 s : (P hebdo, T hebdo) calculated for (70, 60+)
# 108.68 s : (P hebdo, T hebdo) calculated for (70, whole)
# 109.07 s : (P hebdo, T hebdo) calculated for (71, 0-29)
# 109.45 s : (P hebdo, T hebdo) calculated for (71, 30-59)
# 109.84 s : (P hebdo, T hebdo) calculated for (71, 60+)
# 110.23 s : (P hebdo, T hebdo) calculated for (71, whole)
# 110.62 s : (P hebdo, T hebdo) calculated for (72, 0-29)
# 111.01 s : (P hebdo, T hebdo) calculated for (72, 30-59)
# 111.39 s : (P hebdo, T hebdo) calculated for (72, 60+)
# 111.78 s : (P hebdo, T hebdo) calculated for (72, whole)
# 112.16 s : (P hebdo, T hebdo) calculated for (73, 0-29)
# 112.56 s : (P hebdo, T hebdo) calculated for (73, 30-59)
# 112.94 s : (P hebdo, T hebdo) calculated for (73, 60+)
# 113.32 s : (P hebdo, T hebdo) calculated for (73, whole)
# 113.70 s : (P hebdo, T hebdo) calculated for (74, 0-29)
# 114.08 s : (P hebdo, T hebdo) calculated for (74, 30-59)
# 114.50 s : (P hebdo, T hebdo) calculated for (74, 60+)
# 114.89 s : (P hebdo, T hebdo) calculated for (74, whole)
# 115.30 s : (P hebdo, T hebdo) calculated for (75, 0-29)
# 115.70 s : (P hebdo, T hebdo) calculated for (75, 30-59)
# 116.10 s : (P hebdo, T hebdo) calculated for (75, 60+)
# 116.49 s : (P hebdo, T hebdo) calculated for (75, whole)
# 116.88 s : (P hebdo, T hebdo) calculated for (76, 0-29)
# 117.28 s : (P hebdo, T hebdo) calculated for (76, 30-59)
# 117.67 s : (P hebdo, T hebdo) calculated for (76, 60+)
# 118.06 s : (P hebdo, T hebdo) calculated for (76, whole)
# 118.45 s : (P hebdo, T hebdo) calculated for (77, 0-29)
# 118.86 s : (P hebdo, T hebdo) calculated for (77, 30-59)
# 119.26 s : (P hebdo, T hebdo) calculated for (77, 60+)
# 119.64 s : (P hebdo, T hebdo) calculated for (77, whole)
# 120.03 s : (P hebdo, T hebdo) calculated for (78, 0-29)
# 120.41 s : (P hebdo, T hebdo) calculated for (78, 30-59)
# 120.79 s : (P hebdo, T hebdo) calculated for (78, 60+)
# 121.19 s : (P hebdo, T hebdo) calculated for (78, whole)
# 121.60 s : (P hebdo, T hebdo) calculated for (79, 0-29)
# 121.98 s : (P hebdo, T hebdo) calculated for (79, 30-59)
# 122.37 s : (P hebdo, T hebdo) calculated for (79, 60+)
# 122.75 s : (P hebdo, T hebdo) calculated for (79, whole)
# 123.14 s : (P hebdo, T hebdo) calculated for (80, 0-29)
# 123.53 s : (P hebdo, T hebdo) calculated for (80, 30-59)
# 123.91 s : (P hebdo, T hebdo) calculated for (80, 60+)
# 124.34 s : (P hebdo, T hebdo) calculated for (80, whole)
# 124.73 s : (P hebdo, T hebdo) calculated for (81, 0-29)
# 125.13 s : (P hebdo, T hebdo) calculated for (81, 30-59)
# 125.52 s : (P hebdo, T hebdo) calculated for (81, 60+)
# 125.93 s : (P hebdo, T hebdo) calculated for (81, whole)
# 126.34 s : (P hebdo, T hebdo) calculated for (82, 0-29)
# 126.72 s : (P hebdo, T hebdo) calculated for (82, 30-59)
# 127.11 s : (P hebdo, T hebdo) calculated for (82, 60+)
# 127.50 s : (P hebdo, T hebdo) calculated for (82, whole)
# 127.90 s : (P hebdo, T hebdo) calculated for (83, 0-29)
# 128.29 s : (P hebdo, T hebdo) calculated for (83, 30-59)
# 128.68 s : (P hebdo, T hebdo) calculated for (83, 60+)
# 129.07 s : (P hebdo, T hebdo) calculated for (83, whole)
# 129.46 s : (P hebdo, T hebdo) calculated for (84, 0-29)
# 129.86 s : (P hebdo, T hebdo) calculated for (84, 30-59)
# 130.25 s : (P hebdo, T hebdo) calculated for (84, 60+)
# 130.63 s : (P hebdo, T hebdo) calculated for (84, whole)
# 131.02 s : (P hebdo, T hebdo) calculated for (85, 0-29)
# 131.40 s : (P hebdo, T hebdo) calculated for (85, 30-59)
# 131.82 s : (P hebdo, T hebdo) calculated for (85, 60+)
# 132.20 s : (P hebdo, T hebdo) calculated for (85, whole)
# 132.59 s : (P hebdo, T hebdo) calculated for (86, 0-29)
# 132.98 s : (P hebdo, T hebdo) calculated for (86, 30-59)
# 133.37 s : (P hebdo, T hebdo) calculated for (86, 60+)
# 133.76 s : (P hebdo, T hebdo) calculated for (86, whole)
# 134.15 s : (P hebdo, T hebdo) calculated for (87, 0-29)
# 134.54 s : (P hebdo, T hebdo) calculated for (87, 30-59)
# 134.93 s : (P hebdo, T hebdo) calculated for (87, 60+)
# 135.32 s : (P hebdo, T hebdo) calculated for (87, whole)
# 135.72 s : (P hebdo, T hebdo) calculated for (88, 0-29)
# 136.11 s : (P hebdo, T hebdo) calculated for (88, 30-59)
# 136.50 s : (P hebdo, T hebdo) calculated for (88, 60+)
# 136.88 s : (P hebdo, T hebdo) calculated for (88, whole)
# 137.26 s : (P hebdo, T hebdo) calculated for (89, 0-29)
# 137.64 s : (P hebdo, T hebdo) calculated for (89, 30-59)
# 138.06 s : (P hebdo, T hebdo) calculated for (89, 60+)
# 138.46 s : (P hebdo, T hebdo) calculated for (89, whole)
# 138.85 s : (P hebdo, T hebdo) calculated for (90, 0-29)
# 139.26 s : (P hebdo, T hebdo) calculated for (90, 30-59)
# 139.67 s : (P hebdo, T hebdo) calculated for (90, 60+)
# 140.07 s : (P hebdo, T hebdo) calculated for (90, whole)
# 140.46 s : (P hebdo, T hebdo) calculated for (91, 0-29)
# 140.85 s : (P hebdo, T hebdo) calculated for (91, 30-59)
# 141.25 s : (P hebdo, T hebdo) calculated for (91, 60+)
# 141.64 s : (P hebdo, T hebdo) calculated for (91, whole)
# 142.03 s : (P hebdo, T hebdo) calculated for (92, 0-29)
# 142.42 s : (P hebdo, T hebdo) calculated for (92, 30-59)
# 142.81 s : (P hebdo, T hebdo) calculated for (92, 60+)
# 143.20 s : (P hebdo, T hebdo) calculated for (92, whole)
# 143.61 s : (P hebdo, T hebdo) calculated for (93, 0-29)
# 144.02 s : (P hebdo, T hebdo) calculated for (93, 30-59)
# 144.45 s : (P hebdo, T hebdo) calculated for (93, 60+)
# 144.84 s : (P hebdo, T hebdo) calculated for (93, whole)
# 145.23 s : (P hebdo, T hebdo) calculated for (94, 0-29)
# 145.61 s : (P hebdo, T hebdo) calculated for (94, 30-59)
# 145.99 s : (P hebdo, T hebdo) calculated for (94, 60+)
# 146.38 s : (P hebdo, T hebdo) calculated for (94, whole)
# 146.77 s : (P hebdo, T hebdo) calculated for (95, 0-29)
# 147.15 s : (P hebdo, T hebdo) calculated for (95, 30-59)
# 147.55 s : (P hebdo, T hebdo) calculated for (95, 60+)
# 147.94 s : (P hebdo, T hebdo) calculated for (95, whole)
# 148.34 s : (P hebdo, T hebdo) calculated for (971, 0-29)
# 148.72 s : (P hebdo, T hebdo) calculated for (971, 30-59)
# 149.12 s : (P hebdo, T hebdo) calculated for (971, 60+)
# 149.50 s : (P hebdo, T hebdo) calculated for (971, whole)
# 149.89 s : (P hebdo, T hebdo) calculated for (972, 0-29)
# 150.28 s : (P hebdo, T hebdo) calculated for (972, 30-59)
# 150.67 s : (P hebdo, T hebdo) calculated for (972, 60+)
# 151.06 s : (P hebdo, T hebdo) calculated for (972, whole)
# 151.46 s : (P hebdo, T hebdo) calculated for (973, 0-29)
# 151.85 s : (P hebdo, T hebdo) calculated for (973, 30-59)
# 152.24 s : (P hebdo, T hebdo) calculated for (973, 60+)
# 152.64 s : (P hebdo, T hebdo) calculated for (973, whole)
# 153.02 s : (P hebdo, T hebdo) calculated for (974, 0-29)
# 153.42 s : (P hebdo, T hebdo) calculated for (974, 30-59)
# 153.82 s : (P hebdo, T hebdo) calculated for (974, 60+)
# 154.25 s : (P hebdo, T hebdo) calculated for (974, whole)
# 154.63 s : (P hebdo, T hebdo) calculated for (975, 0-29)
# 155.03 s : (P hebdo, T hebdo) calculated for (975, 30-59)
# 155.42 s : (P hebdo, T hebdo) calculated for (975, 60+)
# 155.80 s : (P hebdo, T hebdo) calculated for (975, whole)
# 156.20 s : (P hebdo, T hebdo) calculated for (976, 0-29)
# 156.59 s : (P hebdo, T hebdo) calculated for (976, 30-59)
# 156.99 s : (P hebdo, T hebdo) calculated for (976, 60+)
# 157.39 s : (P hebdo, T hebdo) calculated for (976, whole)
# 157.81 s : (P hebdo, T hebdo) calculated for (977, 0-29)
# 158.20 s : (P hebdo, T hebdo) calculated for (977, 30-59)
# 158.59 s : (P hebdo, T hebdo) calculated for (977, 60+)
# 159.00 s : (P hebdo, T hebdo) calculated for (977, whole)
# 159.39 s : (P hebdo, T hebdo) calculated for (978, 0-29)
# 159.79 s : (P hebdo, T hebdo) calculated for (978, 30-59)
# 160.17 s : (P hebdo, T hebdo) calculated for (978, 60+)
# 160.56 s : (P hebdo, T hebdo) calculated for (978, whole)
# 160.95 s : (P hebdo, T hebdo) calculated for (Auvergne-Rhône-Alpes, 0-29)
# 161.34 s : (P hebdo, T hebdo) calculated for (Auvergne-Rhône-Alpes, 30-59)
# 161.78 s : (P hebdo, T hebdo) calculated for (Auvergne-Rhône-Alpes, 60+)
# 162.17 s : (P hebdo, T hebdo) calculated for (Auvergne-Rhône-Alpes, whole)
# 162.55 s : (P hebdo, T hebdo) calculated for (Bourgogne-Franche-Comté, 0-29)
# 162.93 s : (P hebdo, T hebdo) calculated for (Bourgogne-Franche-Comté, 30-59)
# 163.31 s : (P hebdo, T hebdo) calculated for (Bourgogne-Franche-Comté, 60+)
# 163.70 s : (P hebdo, T hebdo) calculated for (Bourgogne-Franche-Comté, whole)
# 164.09 s : (P hebdo, T hebdo) calculated for (Bretagne, 0-29)
# 164.47 s : (P hebdo, T hebdo) calculated for (Bretagne, 30-59)
# 164.86 s : (P hebdo, T hebdo) calculated for (Bretagne, 60+)
# 165.25 s : (P hebdo, T hebdo) calculated for (Bretagne, whole)
# 165.63 s : (P hebdo, T hebdo) calculated for (Centre-Val de Loire, 0-29)
# 166.02 s : (P hebdo, T hebdo) calculated for (Centre-Val de Loire, 30-59)
# 166.42 s : (P hebdo, T hebdo) calculated for (Centre-Val de Loire, 60+)
# 166.82 s : (P hebdo, T hebdo) calculated for (Centre-Val de Loire, whole)
# 167.21 s : (P hebdo, T hebdo) calculated for (Corse, 0-29)
# 167.60 s : (P hebdo, T hebdo) calculated for (Corse, 30-59)
# 167.99 s : (P hebdo, T hebdo) calculated for (Corse, 60+)
# 168.41 s : (P hebdo, T hebdo) calculated for (Corse, whole)
# 168.80 s : (P hebdo, T hebdo) calculated for (France entière, 0-29)
# 169.20 s : (P hebdo, T hebdo) calculated for (France entière, 30-59)
# 169.58 s : (P hebdo, T hebdo) calculated for (France entière, 60+)
# 169.98 s : (P hebdo, T hebdo) calculated for (France entière, whole)
# 170.37 s : (P hebdo, T hebdo) calculated for (Grand Est, 0-29)
# 170.76 s : (P hebdo, T hebdo) calculated for (Grand Est, 30-59)
# 171.15 s : (P hebdo, T hebdo) calculated for (Grand Est, 60+)
# 171.53 s : (P hebdo, T hebdo) calculated for (Grand Est, whole)
# 171.92 s : (P hebdo, T hebdo) calculated for (Hauts-de-France, 0-29)
# 172.31 s : (P hebdo, T hebdo) calculated for (Hauts-de-France, 30-59)
# 172.70 s : (P hebdo, T hebdo) calculated for (Hauts-de-France, 60+)
# 173.09 s : (P hebdo, T hebdo) calculated for (Hauts-de-France, whole)
# 173.47 s : (P hebdo, T hebdo) calculated for (Normandie, 0-29)
# 173.85 s : (P hebdo, T hebdo) calculated for (Normandie, 30-59)
# 174.24 s : (P hebdo, T hebdo) calculated for (Normandie, 60+)
# 174.62 s : (P hebdo, T hebdo) calculated for (Normandie, whole)
# 175.00 s : (P hebdo, T hebdo) calculated for (Nouvelle-Aquitaine, 0-29)
# 175.38 s : (P hebdo, T hebdo) calculated for (Nouvelle-Aquitaine, 30-59)
# 175.76 s : (P hebdo, T hebdo) calculated for (Nouvelle-Aquitaine, 60+)
# 176.14 s : (P hebdo, T hebdo) calculated for (Nouvelle-Aquitaine, whole)
# 176.52 s : (P hebdo, T hebdo) calculated for (Occitanie, 0-29)
# 176.90 s : (P hebdo, T hebdo) calculated for (Occitanie, 30-59)
# 177.28 s : (P hebdo, T hebdo) calculated for (Occitanie, 60+)
# 177.66 s : (P hebdo, T hebdo) calculated for (Occitanie, whole)
# 178.07 s : (P hebdo, T hebdo) calculated for (Outre-mer, 0-29)
# 178.45 s : (P hebdo, T hebdo) calculated for (Outre-mer, 30-59)
# 178.83 s : (P hebdo, T hebdo) calculated for (Outre-mer, 60+)
# 179.20 s : (P hebdo, T hebdo) calculated for (Outre-mer, whole)
# 179.58 s : (P hebdo, T hebdo) calculated for (Pays de la Loire, 0-29)
# 179.96 s : (P hebdo, T hebdo) calculated for (Pays de la Loire, 30-59)
# 180.34 s : (P hebdo, T hebdo) calculated for (Pays de la Loire, 60+)
# 180.72 s : (P hebdo, T hebdo) calculated for (Pays de la Loire, whole)
# 181.09 s : (P hebdo, T hebdo) calculated for (Provence-Alpes-Côte d'Azur, 0-29)
# 181.47 s : (P hebdo, T hebdo) calculated for (Provence-Alpes-Côte d'Azur, 30-59)
# 181.85 s : (P hebdo, T hebdo) calculated for (Provence-Alpes-Côte d'Azur, 60+)
# 182.23 s : (P hebdo, T hebdo) calculated for (Provence-Alpes-Côte d'Azur, whole)
# 182.61 s : (P hebdo, T hebdo) calculated for (Île-de-France, 0-29)
# 182.99 s : (P hebdo, T hebdo) calculated for (Île-de-France, 30-59)
# 183.36 s : (P hebdo, T hebdo) calculated for (Île-de-France, 60+)
# 183.74 s : (P hebdo, T hebdo) calculated for (Île-de-France, whole)

# %%
dh.sample(3)
# Out:
#        entity three_class       jour   P    T       pop  P hebdo  T hebdo
# 42881      32       30-59 2020-11-21   4   56   70044.0     83.0   1329.0
# 117056     88        0-29 2021-03-21   1   31  108776.0    213.0   5706.0
# 119732     90        0-29 2021-04-01  31  655   48923.0    184.0   2768.0

# %%
d = dh
d['incidence hebdo'] = d['P hebdo'] / d['pop'] * 100000
d['positivite hebdo'] = d['P hebdo'] / d['T hebdo'] * 100
d['taux de test hebdo'] = d['T hebdo'] / d['pop'] * 100000
d.sample(3)
# Out:
#        entity three_class       jour    P     T        pop  P hebdo  T hebdo  \
# 102447     77       whole 2021-02-15  775  8270  1423607.0   3602.0  46069.0
# 55033      41       30-59 2021-02-06   19   280   120994.0    182.0   3242.0
# 1251       01       whole 2021-03-21   30   293   656955.0   1711.0  23745.0
#
#         incidence hebdo  positivite hebdo  taux de test hebdo
# 102447       253.019267          7.818707         3236.075687
# 55033        150.420682          5.613819         2679.471709
# 1251         260.444018          7.205728         3614.402813

# %%
d.tail(3)
# Out:
#                entity three_class       jour      P       T         pop  \
# 156601  Île-de-France       30-59 2021-04-06   9120   63823   4968295.0
# 156602  Île-de-France         60+ 2021-04-06   2168   21608   2517033.0
# 156603  Île-de-France       whole 2021-04-06  17313  135230  12278210.0
#
#         P hebdo   T hebdo  incidence hebdo  positivite hebdo  \
# 156601  34761.0  324173.0       699.656522         10.722978
# 156602   8720.0   88117.0       346.439637          9.895934
# 156603  70276.0  729387.0       572.363561          9.634940
#
#         taux de test hebdo
# 156601         6524.833972
# 156602         3500.828158
# 156603         5940.499470

# %%
fname = fname_temp_test + '-tot-3C-processed.csv'
d.to_csv(fname, sep = ';', index = False)

# %% [markdown]
# # Traitement des données hospitalières

# %%
fname = path_hosp[0]
din = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'dep': str})
din.sample(3)
# Out:
#        reg  cl_age90       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  \
# 58492   27        49 2021-01-07    45    7       NaN       NaN     NaN  692
# 20582   94         9 2020-06-29     0    0       NaN       NaN     NaN    6
# 63557   94        90 2021-02-01    14    1       NaN       NaN     NaN   33
#
#        dc
# 58492  13
# 20582   0
# 63557  22

# %%
d = din.copy()
d['entity'] = (d['reg']
               .map(lambda x: reg_name[str(x)] )
               .replace({
                   'Guadeloupe':'Outre-mer',
                   'Martinique':'Outre-mer',
                   'Guyane':'Outre-mer',
                   'La Réunion':'Outre-mer',
                   'Mayotte':'Outre-mer',
               })
              )
d = columns_first(d, columns = ['entity'])
d = d.drop(columns = ['reg'])
d.head(3)
# Out:
#       entity  cl_age90       jour  hosp  rea  HospConv  SSR_USLD  autres  rad  \
# 0  Outre-mer         0 2020-03-18     0    0       NaN       NaN     NaN    0
# 1  Outre-mer         9 2020-03-18     0    0       NaN       NaN     NaN    0
# 2  Outre-mer        19 2020-03-18     0    0       NaN       NaN     NaN    0
#
#    dc
# 0   0
# 1   0
# 2   0

# %%
d['three_class'] = d['cl_age90'].map(lambda x: class_2_3C[x])
d = d.drop(columns = 'cl_age90')
dg = groupby_sum(d,['entity', 'jour', 'three_class',])
# dg = (dg.reset_index()
#       .drop(columns = ['cl_age90'])
#             )
dg = columns_first(dg, ['entity', 'three_class', 'jour',])
d_reg = dg.copy()
d_reg.tail(3)
# Out:
#               entity three_class       jour  hosp   rea  HospConv  SSR_USLD  \
# 21725  Île-de-France       30-59 2021-04-09  1943   608    1130.0     162.0
# 21726  Île-de-France         60+ 2021-04-09  5694  1077    2823.0    1758.0
# 21727  Île-de-France       whole 2021-04-09  7907  1726    4144.0    1941.0
#
#        autres    rad     dc
# 21725    43.0  24906   1304
# 21726    36.0  48909  15972
# 21727    96.0  79154  17423

# %%
d = d_reg.copy()
dg = groupby_sum(d, columns = ['jour', 'three_class',])
dg['entity'] = 'France entière'
dg = columns_first(dg, columns = ['entity', 'three_class', 'jour',])
d_nat = dg
d_nat.sample(3)
# Out:
#               entity three_class       jour   hosp   rea  HospConv  SSR_USLD  \
# 1087  France entière       whole 2020-12-14  25449  2896       0.0       0.0
# 308   France entière        0-29 2020-06-03    202    37       0.0       0.0
# 585   France entière       30-59 2020-08-11    845    87       0.0       0.0
#
#       autres     rad     dc
# 1087     0.0  177616  40320
# 308      0.0    3406     27
# 585      0.0   24457   1285

# %%
d_tot = pd.merge(d_reg, d_nat, how = 'outer')
d_tot = d_tot.drop(columns = ['HospConv', 'SSR_USLD', 'autres', 'rad'])
d_tot.sample(3)
# Out:
#                      entity three_class       jour  hosp  rea    dc
# 15070             Occitanie         60+ 2020-12-18  1191  163  1905
# 1173   Auvergne-Rhône-Alpes       30-59 2021-01-05   419   73   188
# 4402               Bretagne         60+ 2021-02-05   636   31   943

# %%
d = d_tot
d = calc_delta_hebdo(d, columns_to_group = ['entity', 'three_class'], columns_to_delta = ['dc'])
# Out:
# 0.55 s : (dc hebdo) calculated for (Auvergne-Rhône-Alpes, 0-29)
# 1.06 s : (dc hebdo) calculated for (Auvergne-Rhône-Alpes, 30-59)
# 1.58 s : (dc hebdo) calculated for (Auvergne-Rhône-Alpes, 60+)
# 2.12 s : (dc hebdo) calculated for (Auvergne-Rhône-Alpes, whole)
# 2.63 s : (dc hebdo) calculated for (Bourgogne-Franche-Comté, 0-29)
# 3.14 s : (dc hebdo) calculated for (Bourgogne-Franche-Comté, 30-59)
# 3.66 s : (dc hebdo) calculated for (Bourgogne-Franche-Comté, 60+)
# 4.19 s : (dc hebdo) calculated for (Bourgogne-Franche-Comté, whole)
# 4.73 s : (dc hebdo) calculated for (Bretagne, 0-29)
# 5.29 s : (dc hebdo) calculated for (Bretagne, 30-59)
# 5.83 s : (dc hebdo) calculated for (Bretagne, 60+)
# 6.35 s : (dc hebdo) calculated for (Bretagne, whole)
# 6.87 s : (dc hebdo) calculated for (Centre-Val de Loire, 0-29)
# 7.39 s : (dc hebdo) calculated for (Centre-Val de Loire, 30-59)
# 7.92 s : (dc hebdo) calculated for (Centre-Val de Loire, 60+)
# 8.48 s : (dc hebdo) calculated for (Centre-Val de Loire, whole)
# 9.03 s : (dc hebdo) calculated for (Corse, 0-29)
# 9.58 s : (dc hebdo) calculated for (Corse, 30-59)
# 10.13 s : (dc hebdo) calculated for (Corse, 60+)
# 10.68 s : (dc hebdo) calculated for (Corse, whole)
# 11.20 s : (dc hebdo) calculated for (Grand Est, 0-29)
# 11.71 s : (dc hebdo) calculated for (Grand Est, 30-59)
# 12.23 s : (dc hebdo) calculated for (Grand Est, 60+)
# 12.75 s : (dc hebdo) calculated for (Grand Est, whole)
# 13.27 s : (dc hebdo) calculated for (Hauts-de-France, 0-29)
# 13.83 s : (dc hebdo) calculated for (Hauts-de-France, 30-59)
# 14.40 s : (dc hebdo) calculated for (Hauts-de-France, 60+)
# 14.93 s : (dc hebdo) calculated for (Hauts-de-France, whole)
# 15.47 s : (dc hebdo) calculated for (Normandie, 0-29)
# 16.01 s : (dc hebdo) calculated for (Normandie, 30-59)
# 16.53 s : (dc hebdo) calculated for (Normandie, 60+)
# 17.04 s : (dc hebdo) calculated for (Normandie, whole)
# 17.56 s : (dc hebdo) calculated for (Nouvelle-Aquitaine, 0-29)
# 18.08 s : (dc hebdo) calculated for (Nouvelle-Aquitaine, 30-59)
# 18.60 s : (dc hebdo) calculated for (Nouvelle-Aquitaine, 60+)
# 19.11 s : (dc hebdo) calculated for (Nouvelle-Aquitaine, whole)
# 19.62 s : (dc hebdo) calculated for (Occitanie, 0-29)
# 20.13 s : (dc hebdo) calculated for (Occitanie, 30-59)
# 20.65 s : (dc hebdo) calculated for (Occitanie, 60+)
# 21.16 s : (dc hebdo) calculated for (Occitanie, whole)
# 21.67 s : (dc hebdo) calculated for (Outre-mer, 0-29)
# 22.19 s : (dc hebdo) calculated for (Outre-mer, 30-59)
# 22.70 s : (dc hebdo) calculated for (Outre-mer, 60+)
# 23.22 s : (dc hebdo) calculated for (Outre-mer, whole)
# 23.74 s : (dc hebdo) calculated for (Pays de la Loire, 0-29)
# 24.26 s : (dc hebdo) calculated for (Pays de la Loire, 30-59)
# 24.78 s : (dc hebdo) calculated for (Pays de la Loire, 60+)
# 25.30 s : (dc hebdo) calculated for (Pays de la Loire, whole)
# 25.81 s : (dc hebdo) calculated for (Provence-Alpes-Côte d'Azur, 0-29)
# 26.33 s : (dc hebdo) calculated for (Provence-Alpes-Côte d'Azur, 30-59)
# 26.87 s : (dc hebdo) calculated for (Provence-Alpes-Côte d'Azur, 60+)
# 27.39 s : (dc hebdo) calculated for (Provence-Alpes-Côte d'Azur, whole)
# 27.91 s : (dc hebdo) calculated for (Île-de-France, 0-29)
# 28.43 s : (dc hebdo) calculated for (Île-de-France, 30-59)
# 28.95 s : (dc hebdo) calculated for (Île-de-France, 60+)
# 29.47 s : (dc hebdo) calculated for (Île-de-France, whole)
# 30.00 s : (dc hebdo) calculated for (France entière, 0-29)
# 30.53 s : (dc hebdo) calculated for (France entière, 30-59)
# 31.06 s : (dc hebdo) calculated for (France entière, 60+)
# 31.60 s : (dc hebdo) calculated for (France entière, whole)

# %%
d['taux hosp'] = d.apply(lambda x: x['hosp'] / reg_3C_pop 
                                                    [ x['entity'] ]
                                                    [ x['three_class'] ] * 100000, 
                         axis = "columns")
d['taux rea'] = d.apply(lambda x: x['rea'] / reg_3C_pop
                                                    [ x['entity'] ]
                                                    [ x['three_class'] ] * 100000, 
                        axis = "columns")
d['taux décès'] = d.apply(lambda x: x['dc hebdo'] / reg_3C_pop
                                                    [ x['entity'] ]
                                                    [ x['three_class'] ] * 100000, 
                        axis = "columns")
d
# Out:
#                      entity three_class       jour   hosp   rea     dc  \
# 0      Auvergne-Rhône-Alpes        0-29 2020-03-18      4     0      0
# 1      Auvergne-Rhône-Alpes       30-59 2020-03-18     33    11      1
# 2      Auvergne-Rhône-Alpes         60+ 2020-03-18    127    24      6
# 3      Auvergne-Rhône-Alpes       whole 2020-03-18    172    35      7
# 4      Auvergne-Rhône-Alpes        0-29 2020-03-19      5     1      0
# ...                     ...         ...        ...    ...   ...    ...
# 23275        France entière       whole 2021-04-08  30555  5705  71944
# 23276        France entière        0-29 2021-04-09    494    71     76
# 23277        France entière       30-59 2021-04-09   5910  1703   3263
# 23278        France entière         60+ 2021-04-09  23663  3933  68517
# 23279        France entière       whole 2021-04-09  30326  5757  72243
#
#        dc hebdo   taux hosp   taux rea  taux décès
# 0           0.0    0.141085   0.000000    0.000000
# 1           0.0    1.069485   0.356495    0.000000
# 2           0.0    6.014371   1.136574    0.000000
# 3           0.0    2.141334   0.435737    0.000000
# 4           0.0    0.176356   0.035271    0.000000
# ...         ...         ...        ...         ...
# 23275    2040.0   45.526339   8.500336    3.039559
# 23276       2.0    2.095309   0.301148    0.008483
# 23277     118.0   23.013183   6.631379    0.459485
# 23278    1906.0  132.509534  22.024257   10.673337
# 23279    2039.0   45.185133   8.577815    3.038069
#
# [23280 rows x 10 columns]

# %%
dout = d
fname = fname_temp_hosp + '-processed.csv'
dout.to_csv(fname, sep = ';', index = False)

# %% [markdown]
# # Données VAC-SI

# %%
fname = path_vac[0]
din = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'dep': str})
din.sample(3)
# Out:
#       dep  clage_vacsi       jour  n_dose1  n_dose2  n_cum_dose1  n_cum_dose2
# 64317  61           59 2021-02-10       33      147         1976         1201
# 88642  84           24 2021-02-27        0        0           83           37
# 14157  13           74 2021-02-11      314      282         4966         1193

# %%
d = din.copy()
d = d[(d.dep != '00') & (d.dep != '750') & (d.dep != '970')] 
d = d.rename(columns = {'dep': 'entity'})
d = columns_first(d, columns = ['entity', 'clage_vacsi', 'jour'])
d_dep = d
d_dep.sample(3)
# Out:
#       entity  clage_vacsi       jour  n_dose1  n_dose2  n_cum_dose1  \
# 1401      01           49 2021-02-27       22        4         1117
# 10694     10           49 2021-03-22       16        1         1907
# 64029     61           29 2021-03-03        2        1          211
#
#        n_cum_dose2
# 1401           460
# 10694          641
# 64029          105

# %%
d = din.copy()
d = d[(d.dep != '00') & (d.dep != '750') & (d.dep != '970')] #supprime lignes suspectes
d['reg'] = d['dep'].map(lambda x: dep2reg[x])
d = d.drop(columns = ['dep'])
dg = groupby_sum(d, columns = ['reg', 'jour', 'clage_vacsi'])
dg = d.rename(columns = {'reg': 'entity'})
dg = columns_first(dg, columns = ['entity', 'clage_vacsi', 'jour'])
d_reg = dg
d_reg.sample(3)
# Out:
#                    entity  clage_vacsi       jour  n_dose1  n_dose2  \
# 99211       Île-de-France           49 2021-01-18      161        0
# 16748  Nouvelle-Aquitaine           39 2021-02-27        2        0
# 11301           Grand Est           80 2021-03-11      302      104
#
#        n_cum_dose1  n_cum_dose2
# 99211         1162            0
# 16748          693          298
# 11301         7843         5250

# %%
d = din.copy()
d = d[(d.dep != '00') & (d.dep != '750') & (d.dep != '970')] 
d = d.drop(columns = ['dep'])
dg = groupby_sum(d, columns = ['jour', 'clage_vacsi'])
dg['entity'] = 'France entière'
dg = columns_first(dg, columns = ['entity', 'clage_vacsi', 'jour'])
d_nat = dg
d_nat.sample(3)
# Out:
#               entity  clage_vacsi       jour  n_dose1  n_dose2  n_cum_dose1  \
# 467   France entière           59 2021-02-07      384     1261       302950
# 1089  France entière            0 2021-04-05    57796     9749      9393309
# 598   France entière           49 2021-02-19     6920     4850       167156
#
#       n_cum_dose2
# 467         97321
# 1089      3156855
# 598         84199

# %%
d = pd.merge(d_dep, d_reg, how = 'outer')
dout = pd.merge(d, d_nat, how = 'outer')
dout = columns_first(dout, columns = ['entity', 'clage_vacsi', 'jour'])
dout.head(3)
# Out:
#   entity  clage_vacsi       jour  n_dose1  n_dose2  n_cum_dose1  n_cum_dose2
# 0     01           24 2020-12-27        0        0            0            0
# 1     01           24 2020-12-28        0        0            0            0
# 2     01           24 2020-12-29        0        0            0            0

# %%
d = dout.copy()
d['three_class'] = d['clage_vacsi'].map(lambda x: classvac_2_3C[x])
d = d.drop(columns = 'clage_vacsi')
dg = groupby_sum(d,['entity', 'jour', 'three_class'])
dg = columns_first(dg, columns = ['entity', 'three_class', 'jour'])
dout = dg
dout.tail(10)
# Out:
#               entity three_class       jour  n_dose1  n_dose2  n_cum_dose1  \
# 48606  Île-de-France         60+ 2021-04-06    17069    14712      1065728
# 48607  Île-de-France       whole 2021-04-06    26121    16146      1494107
# 48608  Île-de-France        0-29 2021-04-07     1264      134        48923
# 48609  Île-de-France       30-59 2021-04-07    10786     1520       391041
# 48610  Île-de-France         60+ 2021-04-07    22048    14974      1087776
# 48611  Île-de-France       whole 2021-04-07    34110    16629      1528217
# 48612  Île-de-France        0-29 2021-04-08     1961      197        50884
# 48613  Île-de-France       30-59 2021-04-08    14222     1906       405263
# 48614  Île-de-France         60+ 2021-04-08    25434    15536      1113210
# 48615  Île-de-France       whole 2021-04-08    41638    17639      1569855
#
#        n_cum_dose2
# 48606       378150
# 48607       470974
# 48608         6608
# 48609        87782
# 48610       393124
# 48611       487603
# 48612         6805
# 48613        89688
# 48614       408660
# 48615       505242

# %%
d = dout.copy()
d['taux dose 1'] = d.apply(lambda x: x['n_cum_dose1'] / reg_3C_pop 
                                                    [ x['entity'] ]
                                                    [ x['three_class'] ] * 100000, 
                         axis = "columns")
d['taux dose 2'] = d.apply(lambda x: x['n_cum_dose2'] / reg_3C_pop
                                                    [ x['entity'] ]
                                                    [ x['three_class'] ] * 100000, 
                        axis = "columns")
d
# Out:
#               entity three_class       jour  n_dose1  n_dose2  n_cum_dose1  \
# 0                 01        0-29 2020-12-27        0        0            0
# 1                 01       30-59 2020-12-27        0        0            0
# 2                 01         60+ 2020-12-27        0        0            0
# 3                 01       whole 2020-12-27        0        0            0
# 4                 01        0-29 2020-12-28        0        0            0
# ...              ...         ...        ...      ...      ...          ...
# 48611  Île-de-France       whole 2021-04-07    34110    16629      1528217
# 48612  Île-de-France        0-29 2021-04-08     1961      197        50884
# 48613  Île-de-France       30-59 2021-04-08    14222     1906       405263
# 48614  Île-de-France         60+ 2021-04-08    25434    15536      1113210
# 48615  Île-de-France       whole 2021-04-08    41638    17639      1569855
#
#        n_cum_dose2   taux dose 1   taux dose 2
# 0                0      0.000000      0.000000
# 1                0      0.000000      0.000000
# 2                0      0.000000      0.000000
# 3                0      0.000000      0.000000
# 4                0      0.000000      0.000000
# ...            ...           ...           ...
# 48611       487603  12446.578125   3971.287346
# 48612         6805   1061.657683    141.981380
# 48613        89688   8156.983432   1805.206816
# 48614       408660  44227.072112  16235.782368
# 48615       505242  12785.699218   4114.948352
#
# [48616 rows x 9 columns]

# %%
dout = d.copy()
fname = fname_temp_vac + '-tot-3C.csv'
dout.to_csv(fname, sep = ';', index = False)

# %% [markdown]
# # Fusion SIDEP et données hospitalières

# %%
fname = fname_temp_test + '-tot-3C-processed.csv'
d = pd.read_csv(fname, sep = ';', 
                parse_dates = ['jour'],
                dtype = {'entity': str},
               )
d.sample(3)
# Out:
#                          entity three_class       jour    P     T        pop  \
# 5297                         05       30-59 2020-05-21    0     4    53829.0
# 88362                        67         60+ 2020-06-29    3   665   288451.0
# 138837  Bourgogne-Franche-Comté       30-59 2020-10-24  539  3372  1031075.0
#
#         P hebdo  T hebdo  incidence hebdo  positivite hebdo  \
# 5297        5.0    142.0         9.288673          3.521127
# 88362      10.0   2343.0         3.466793          0.426803
# 138837   4786.0  32959.0       464.175739         14.521072
#
#         taux de test hebdo
# 5297            263.798324
# 88362           812.269675
# 138837         3196.566690

# %%
len(d)
# Out:
# 156604

# %%
fname = fname_temp_hosp + '-processed.csv'
d2 = pd.read_csv(fname, sep = ';', parse_dates = ['jour'])
d2.sample(3)
# Out:
#                      entity three_class       jour  hosp  rea    dc  dc hebdo  \
# 789    Auvergne-Rhône-Alpes       30-59 2020-10-01   117   16    63       1.0
# 872    Auvergne-Rhône-Alpes        0-29 2020-10-22    45    2     2       0.0
# 21941        France entière       30-59 2020-05-10  3344  794  1033      74.0
#
#        taux hosp  taux rea  taux décès
# 789     3.791811  0.518538    0.032409
# 872     1.587206  0.070542    0.000000
# 21941  13.021334  3.091788    0.288152

# %%
len(d2)
# Out:
# 23280

# %%
d = pd.merge(d2, d, how = 'outer')
d.sample(10)
# Out:
#                     entity three_class       jour   hosp    rea    dc  \
# 33916                   09        0-29 2020-06-09    NaN    NaN   NaN
# 12475   Nouvelle-Aquitaine       whole 2020-04-01  700.0  215.0  82.0
# 83214                   45         60+ 2020-11-07    NaN    NaN   NaN
# 137238                  86         60+ 2020-11-24    NaN    NaN   NaN
# 29941                   06       30-59 2020-06-02    NaN    NaN   NaN
# 157756                 977        0-29 2020-07-13    NaN    NaN   NaN
# 107067                  63       whole 2020-12-18    NaN    NaN   NaN
# 79787                   42       whole 2021-03-17    NaN    NaN   NaN
# 62449                   2B       30-59 2021-01-19    NaN    NaN   NaN
# 68677                   34       30-59 2020-10-23    NaN    NaN   NaN
#
#         dc hebdo  taux hosp  taux rea  taux décès      P       T       pop  \
# 33916        NaN        NaN       NaN         NaN    0.0    15.0   43700.0
# 12475       57.0  11.666702  3.583344    0.950003    NaN     NaN       NaN
# 83214        NaN        NaN       NaN         NaN   60.0   528.0  180580.0
# 137238       NaN        NaN       NaN         NaN   19.0   305.0  127576.0
# 29941        NaN        NaN       NaN         NaN    2.0   428.0  409246.0
# 157756       NaN        NaN       NaN         NaN    0.0    13.0    3474.0
# 107067       NaN        NaN       NaN         NaN  308.0  9659.0  660240.0
# 79787        NaN        NaN       NaN         NaN  339.0  4234.0  764737.0
# 62449        NaN        NaN       NaN         NaN   17.0   663.0   70830.0
# 68677        NaN        NaN       NaN         NaN  440.0  3120.0  435285.0
#
#         P hebdo  T hebdo  incidence hebdo  positivite hebdo  \
# 33916       0.0     72.0         0.000000          0.000000
# 12475       NaN      NaN              NaN               NaN
# 83214     751.0   6869.0       415.882157         10.933178
# 137238    113.0   2698.0        88.574654          4.188288
# 29941      10.0   1729.0         2.443518          0.578369
# 157756      0.0     47.0         0.000000          0.000000
# 107067   1150.0  28536.0       174.179086          4.029997
# 79787    1959.0  26303.0       256.166499          7.447820
# 62449      79.0   3674.0       111.534660          2.150245
# 68677    2151.0  15528.0       494.158999         13.852396
#
#         taux de test hebdo
# 33916           164.759725
# 12475                  NaN
# 83214          3803.854247
# 137238         2114.817834
# 29941           422.484276
# 157756         1352.907311
# 107067         4322.064704
# 79787          3439.483116
# 62449          5187.067627
# 68677          3567.317964

# %%
len(d)
# Out:
# 160144

# %%
d.tail()
# Out:
#        entity three_class       jour  hosp  rea  dc  dc hebdo  taux hosp  \
# 160139    978       whole 2021-04-05   NaN  NaN NaN       NaN        NaN
# 160140    978        0-29 2021-04-06   NaN  NaN NaN       NaN        NaN
# 160141    978       30-59 2021-04-06   NaN  NaN NaN       NaN        NaN
# 160142    978         60+ 2021-04-06   NaN  NaN NaN       NaN        NaN
# 160143    978       whole 2021-04-06   NaN  NaN NaN       NaN        NaN
#
#         taux rea  taux décès    P      T           pop  P hebdo  T hebdo  \
# 160139       NaN         NaN  0.0   81.0  35334.000000     10.0    862.0
# 160140       NaN         NaN  0.0   62.0  15451.470743      5.0    228.0
# 160141       NaN         NaN  0.0  136.0  15252.902558      2.0    556.0
# 160142       NaN         NaN  0.0   41.0   4629.626699      1.0    168.0
# 160143       NaN         NaN  0.0  239.0  35334.000000      8.0    952.0
#
#         incidence hebdo  positivite hebdo  taux de test hebdo
# 160139        28.301353          1.160093         2439.576612
# 160140        32.359379          2.192982         1475.587689
# 160141        13.112258          0.359712         3645.207841
# 160142        21.600014          0.595238         3628.802297
# 160143        22.641082          0.840336         2694.288787

# %%
dout = d
fname = path_synth
dout.to_csv(fname, sep = ';', index = False)

# %% [markdown]
# # Graphes

# %%
fname = path_synth
d = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'entity': str})
d.sample(3)
# Out:
#                    entity three_class       jour  hosp   rea    dc  dc hebdo  \
# 44525                  17       30-59 2020-06-29   NaN   NaN   NaN       NaN
# 13213  Nouvelle-Aquitaine       30-59 2020-10-03  56.0  15.0  20.0       1.0
# 75375                  39       whole 2020-11-21   NaN   NaN   NaN       NaN
#
#        taux hosp  taux rea  taux décès      P       T        pop  P hebdo  \
# 44525        NaN       NaN         NaN    0.0    50.0   230945.0      1.0
# 13213   2.499043  0.669386    0.044626  140.0  2368.0  2240858.0   1533.0
# 75375        NaN       NaN         NaN   47.0   457.0   257849.0    632.0
#
#        T hebdo  incidence hebdo  positivite hebdo  taux de test hebdo
# 44525    307.0         0.433004          0.325733          132.932083
# 13213  30087.0        68.411296          5.095224         1342.655358
# 75375   6524.0       245.104693          9.687308         2530.163002

# %%
entities = d['entity'].unique()
three_class = d['three_class'].unique()
regions = entities[:14]
last_week = d.jour >= np.datetime64(dt.datetime.fromisoformat(date) - dt.timedelta(weeks = 1))
regions_ordered = (d[(last_week) 
                    & (d.entity.isin(regions))
                    & (d.three_class == '60+')]
                   .groupby('entity')['taux hosp']
                   .mean()
                   .sort_values(ascending = False)
                   .index
                   .tolist())
regions_ordered
# Out:
# ['Île-de-France',
#  'Hauts-de-France',
#  "Provence-Alpes-Côte d'Azur",
#  'Auvergne-Rhône-Alpes',
#  'Grand Est',
#  'Normandie',
#  'Bourgogne-Franche-Comté',
#  'Centre-Val de Loire',
#  'Occitanie',
#  'Corse',
#  'Pays de la Loire',
#  'Bretagne',
#  'Outre-mer',
#  'Nouvelle-Aquitaine']

# %%
produce_fig_lines(d, regions_ordered[:4], regions_ordered[:-1], 1)
produce_fig_lines(d, regions_ordered[4:8], regions_ordered[:-1], 2)
produce_fig_lines(d, regions_ordered[8:-1], regions_ordered[:-1], 3)
produce_fig_lines(d, regions_ordered, regions_ordered, 'toutes')

# %%
produce_fig(ymin = -40,
    ymax = 1190,
            d = d,
    column_to_plot = "incidence hebdo",
    main_color = "darkturquoise",
    title = '{}\nCas positifs par semaine\npour 100 000 personnes'.format(date_text),
    regions_ordered = regions_ordered,
    fname = fname_output_synth + '-fig-incidence',)
produce_fig(ymin = -400,
    ymax = 11900,
            d = d,
    column_to_plot = "taux de test hebdo",
    main_color = "gray",
    title = '{}\nTests pratiqués par semaine\npour 100 000 personnes'.format(date_text),
    regions_ordered = regions_ordered,
    fname = fname_output_synth + '-fig-tests',)
produce_fig(ymin = -4,
    ymax = 29,
            d = d,
    column_to_plot = "positivite hebdo",
    main_color = "orange",
    title = '{}\nTests positifs hebdomadaire\n(%)'.format(date_text),
    regions_ordered = regions_ordered,
    fname = fname_output_synth + '-fig-positifs',)
produce_fig(ymin = -15,
    ymax = 379,
            d = d,
    column_to_plot = "taux hosp",
    main_color = "mediumseagreen",
    title = '{}\nPatients hospitalisés\npour 100 000 personnes'.format(date_text),
    regions_ordered = regions_ordered,
    fname = fname_output_synth + '-fig-hosp',)
produce_fig(ymin = -3,
    ymax = 79,
            d = d,
    column_to_plot = "taux rea",
    main_color = "darksalmon",
    title = '{}\nPatients en réanimation\npour 100 000 personnes'.format(date_text),
    regions_ordered = regions_ordered,
    fname = fname_output_synth +  '-fig-rea',)
produce_fig(ymin = -3,
    ymax = 79,
            d = d,
    column_to_plot = "taux décès",
    main_color = "orchid",
    title = '{}\nDécès à l\'hôpital par semaine\npour 100 000 personnes)'.format(date_text),
    regions_ordered = regions_ordered,
    fname = fname_output_synth +  '-fig-deces',)

# %%
fname = fname_temp_vac + '-tot-3C.csv'
d2 = pd.read_csv(fname, sep = ';', parse_dates = ['jour'], dtype = {'entity': str})
d2.sample(3)
# Out:
#       entity three_class       jour  n_dose1  n_dose2  n_cum_dose1  \
# 4895      12       whole 2021-03-27      955       52        40958
# 25846     62         60+ 2021-03-12     4307      873        74667
# 34862     84         60+ 2021-02-28       10        0        19796
#
#        n_cum_dose2   taux dose 1  taux dose 2
# 4895         18742  14714.039373  6733.007616
# 25846        20345  19907.218556  5424.248484
# 34862        10823  12149.853927  6642.648467

# %%
produce_fig(ymin = -10000,
    ymax = 70000,
            d = d2,
    column_to_plot = "taux dose 1",
    main_color = "orchid",
    title = '{}\nNombre de 1res doses cumulées\npour 100 000 personnes)'.format(date_text),
    regions_ordered = regions_ordered,
    fname = fname_output_synth +  '-fig-vac1',)

# %%
produce_fig(ymin = -10000,
    ymax = 70000,
            d = d2,
    column_to_plot = "taux dose 2",
    main_color = "orchid",
    title = '{}\nNombre de 2es doses cumulées\npour 100 000 personnes)'.format(date_text),
    regions_ordered = regions_ordered,
    fname = fname_output_synth +  '-fig-vac2',)

# %%
fig, axs = plt.subplots(11, 10, figsize = (15,20))
axs = axs.ravel()
for ax in axs:
    ax.set_axis_off()
for i, dep in enumerate(deps):
    sns.set_palette("mako",2)
    
    dplot = d.loc[d.dep == dep].loc[d.cl_age90 == 19]
    axs[i].plot(dplot.jour, dplot["incidence hebdo"], c = "darkturquoise", linewidth = 4)
    
    dplot = d.loc[d.dep == dep].loc[d.cl_age90 == 0]
    axs[i].plot(dplot.jour, dplot["incidence hebdo"], c = "black")
    
    dplot = d.loc[d.dep == dep].loc[d.cl_age90 == 89]
    #axs[i].plot(dplot.jour, dplot["incidence hebdo"], c = 'blue')
    axs[i].set_ylim(-500,1500)
    axs[i].set_axis_off()
    axs[i].set_title(dep, loc = 'left', y = 0.7, fontsize = 22, c = "darkturquoise")
    axs[i].set_title(dep_name[dep], x = -0.05, y = 0.2, rotation = 90, fontsize = 7)
fig.savefig("fig2.svg", pad_inches = 0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-c75973fa479b> in <module>
#       6     sns.set_palette("mako",2)
#       7
# ----> 8     dplot = d.loc[d.dep == dep].loc[d.cl_age90 == 19]
#       9     axs[i].plot(dplot.jour, dplot["incidence hebdo"], c = "darkturquoise", linewidth = 4)
#      10
#
# /home/edmz/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dep'

# %%
produce_fig_dep(d, deps)

# %%
produce_fig_dep(d, reg2dep['Île-de-France'])

# %%
for reg in regs:
    print(reg)
    produce_fig_dep(d, reg2dep[reg])
